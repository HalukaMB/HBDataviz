# %%
import pandas as pd

# %%
pd.read_csv('../../Lit_StockJumps/Table4.csv')
# Out:
#                      Announcement  E-mini S&P 500 γm  E-mini S&P 500 R²  \
# 0    CB Consumer confidence index      0.023 (0.035)               0.01
# 1             Existing home sales   0.091 (0.034)***               0.02
# 2                 GDP preliminary     0.063 (0.034)*               0.06
# 3           Industrial production   0.077 (0.016)***               0.10
# 4         ISM Manufacturing index    0.076 (0.034)**               0.03
# 5     ISM Non-manufacturing index   0.139 (0.033)***               0.12
# 6              Pending home sales   0.087 (0.031)***               0.09
# 7            Advance retail sales     0.028 (0.016)*               0.01
# 8            Consumer price index  -0.051 (0.013)***               0.08
# 9                     GDP advance      0.035 (0.032)               0.05
# 10         Initial jobless claims     -0.009 (0.007)               0.00
# 11                            NaN                NaN                NaN
# ...
