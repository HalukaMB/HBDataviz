# %%
import pandas as pd

# %%
zensus_data=pd.read_csv("../data/DeStatisData/1000A-3037_de_flat.csv",sep=";", dtype=str)

# %%
zensus_data.columns
# Out:
# Index(['statistics_code', 'statistics_label', 'time_code', 'time_label',
#        'time', '1_variable_code', '1_variable_label',
#        '1_variable_attribute_code', '1_variable_attribute_label',
#        '2_variable_code', '2_variable_label', '2_variable_attribute_code',
#        '2_variable_attribute_label', '3_variable_code', '3_variable_label',
#        '3_variable_attribute_code', '3_variable_attribute_label',
#        '4_variable_code', '4_variable_label', '4_variable_attribute_code',
#        '4_variable_attribute_label', 'value', 'value_unit',
#        'value_variable_code', 'value_variable_label', 'value_q'],
#       dtype='object')

# %%
zensus_data_reduced=zensus_data[[
       '1_variable_attribute_code', '1_variable_attribute_label',
       '2_variable_attribute_label', '3_variable_attribute_label',
       '4_variable_attribute_label', 'value', 
       ]]
zensus_data_reduced.columns=["ARS","Name","Altersgruppe","Geschlecht","Nationalität","Zahl"]
zensus_data_reduced
# Out:
#                  ARS                  Name        Altersgruppe Geschlecht  \
# 0       091720122122            Laufen, St     50 bis 59 Jahre  Insgesamt
# 1       130725258082            Prebberede     14 bis 17 Jahre   Weiblich
# 2       010545453101        Oster-Ohrstedt     60 bis 64 Jahre  Insgesamt
# 3       146250200200  Großröhrsdorf, Stadt     40 bis 49 Jahre   Männlich
# 4       010535343019             Buchhorst     25 bis 29 Jahre   Männlich
# ...              ...                   ...                 ...        ...
# 582493            DG           Deutschland     40 bis 49 Jahre   Weiblich
# 582494            DG           Deutschland     30 bis 39 Jahre  Insgesamt
# 582495            DG           Deutschland     25 bis 29 Jahre  Insgesamt
# 582496            DG           Deutschland     14 bis 17 Jahre  Insgesamt
# 582497            DG           Deutschland  75 Jahre und älter  Insgesamt
#
#        Nationalität     Zahl
# 0       Deutschland      879
# ...

# %%
zensus_data_reduced["AGS"]=zensus_data_reduced["ARS"].str[:-7]+zensus_data_reduced["ARS"].str[-3:]
zensus_data_reduced
# Out:
# /var/folders/jf/2jm804y50jv2nrhclzdyvvdh0000gn/T/ipykernel_36149/3554328173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zensus_data_reduced["AGS"]=zensus_data_reduced["ARS"].str[:-7]+zensus_data_reduced["ARS"].str[-3:]
#                  ARS                  Name        Altersgruppe Geschlecht  \
# 0       091720122122            Laufen, St     50 bis 59 Jahre  Insgesamt
# 1       130725258082            Prebberede     14 bis 17 Jahre   Weiblich
# 2       010545453101        Oster-Ohrstedt     60 bis 64 Jahre  Insgesamt
# 3       146250200200  Großröhrsdorf, Stadt     40 bis 49 Jahre   Männlich
# 4       010535343019             Buchhorst     25 bis 29 Jahre   Männlich
# ...

# %%
stadt_data=pd.read_excel("../data/DeStatisData/AuszugGV3QAktuell.xlsx", dtype=str, sheet_name="Onlineprodukt_Gemeinden30092024")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/CodeRelated/HBDataviz/2024/NewTemplate12/Wrangle/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...
