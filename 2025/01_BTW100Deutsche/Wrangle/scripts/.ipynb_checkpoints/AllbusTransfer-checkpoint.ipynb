# %%
import pandas as pd
import sys
sys.path.append('/Users/halukamb/Documents/CodeRelated/HBDataviz_new/2025/01_BTW100Deutsche/Wrangle/lib/python3.12/site-packages')

# %%
! pip install pyreadstat
# Out:
# ...
#   Obtaining dependency information for pyreadstat from https://files.pythonhosted.org/packages/b0/6a/2a4c5deae5a89ba6231e7f028df63e26f40800e7834b11c58dd73caafc68/pyreadstat-1.2.8-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for pandas>=1.2.0 from https://files.pythonhosted.org/packages/e1/0c/ad295fd74bfac85358fd579e271cded3ac969de81f62dd0142c426b9da91/pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# ...
#   Obtaining dependency information for numpy>=1.26.0 from https://files.pythonhosted.org/packages/3d/c3/59df91ae1d8ad7c5e03efd63fd785dec62d96b0fe56d1f9ab600b55009af/numpy-2.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.2 MB/s eta 0:00:0000:01
# ...

# %%
df_old = pd.read_spss("../data/AllbusData/ZA5270_v2-0-0.sav")
df_old
# Out:
#             za_nr                  doi             version  respid  \
# 0     ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)     1.0
# 1     ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)     2.0
# 2     ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)     3.0
# 3     ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)     4.0
# 4     ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)     5.0
# ...           ...                  ...                 ...     ...
# 3472  ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)  3473.0
# 3473  ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)  3474.0
# 3474  ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)  3475.0
# 3475  ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)  3476.0
# 3476  ALLBUS 2018  doi:10.4232/1.13250  2.0.0 (2019-03-26)  3477.0
#
#                 eastwest german         ep01      ep03              ep04  \
# 0     ALTE BUNDESLAENDER     JA     SEHR GUT       GUT      ETWAS BESSER
# ...

# %%
df = pd.read_spss("../data/AllbusData/ZA8830_v1-0-0.sav")
df
# Out:
#             za_nr                              doi             version  \
# 0     ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 1     ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 2     ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 3     ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 4     ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# ...           ...                              ...                 ...
# 5241  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5242  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5243  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5244  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5245  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
#
#       respid     substudy  mode splt23_1   splt23_2            eastwest  \
# ...

# %%
for qu in df.columns:
    print(qu)
# Out:
# za_nr
# doi
# version
# respid
# substudy
# mode
# splt23_1
# splt23_2
# eastwest
# german
# ep01
# ep03
# ep04
# ep06
# xr19
# xr20
# lm27
# lm28
# lm29
# lm30
# lm31
# lm32
# lm33
# lm34
# la01
# li01
# li02
# li03
# li04
# li05
# li09
# li10
# li07
# li08
# id02
# id01
# vg01
# vg02
# vg03
# vg04
# vg05
# vg06
# vg07
# vg08
# vg09
# vg10
# vi01
# vi02
# vi03
# vi04
# vi05
# vi06
# vi07
# vi08
# vi09
# vi10
# vi11
# vi12
# vi13
# vi14
# lp03
# lp04
# lp05
# lp06
# st01
# mi05
# mi06
# mi07
# mi08
# mi09
# mi10
# mi11
# fr07
# fr08
# fr03b
# fr04b
# fr05b
# fr09
# fr10
# fr11
# fr12
# ca02
# ca03
# ca04
# ca05
# ca06
# ca08
# ca12
# ca13
# ca14
# sex
# mborn
# yborn
# age
# agec
# dn07
# dm02
# dm02c
# dm03
# dg10
# dg03
# dm06
# dn01
# dn02
# dn04
# dn05
# ma01b
# ma02
# ma03
# ma04
# mc01
# mc02
# mc03
# mc04
# pn11
# mp02
# mp04
# mp05
# mp06
# mp07
# mp10
# mp12
# mn01
# mn02
# mn03
# mn04
# mn05
# mn06
# mn07
# mn08
# mn09
# mg01
# mg02
# mg03
# mg04
# mg05
# mg06
# rb01
# ...

# %%
#inflation
df.groupby(["va03"]).count()
# Out:
# /var/folders/jf/2jm804y50jv2nrhclzdyvvdh0000gn/T/ipykernel_50283/4284956396.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["va03"]).count()
#                      za_nr   doi  version  respid  substudy  mode  splt23_1  \
# va03
# AM DRITTWICHTIGSTEN   1394  1394     1394    1394       846  1394       846
# AM VIERTWICHTIGSTEN   1978  1978     1978    1978      1193  1978      1193
# AM WICHTIGSTEN         627   627      627     627       368   627       368
# AM ZWEITWICHTIGSTEN   1092  1092     1092    1092       707  1092       707
#
#                      splt23_2  eastwest  german  ...  xi03  xi04  xi05  land  \
# va03                                             ...
# AM DRITTWICHTIGSTEN      1394      1394    1390  ...   548   548   548  1394
# ...

# %%
#inflation
df_old.groupby(["va03"]).count()
# Out:
# /var/folders/jf/2jm804y50jv2nrhclzdyvvdh0000gn/T/ipykernel_50283/4140301943.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_old.groupby(["va03"]).count()
#                      za_nr   doi  version  respid  eastwest  german  ep01  \
# va03
# AM DRITTWICHTIGSTEN    727   727      727     727       727     726   726
# AM VIERTWICHTIGSTEN   2132  2132     2132    2132      2132    2132  2128
# AM WICHTIGSTEN         131   131      131     131       131     131   131
# AM ZWEITWICHTIGSTEN    414   414      414     414       414     414   412
#
#                      ep03  ep04  ep06  ...  xi04  xi05  land   bik  gkpol  \
# va03                                   ...
# AM DRITTWICHTIGSTEN   726   715   718  ...   727   727   727   707    710
# ...

# %%
# stadt/land

df["gs01"]
# Out:
# 0                GROSSSTADT
# 1       MITTEL-, KLEINSTADT
# 2         VORORT GROSSSTADT
# 3              LAENDL. DORF
# 4       MITTEL-, KLEINSTADT
#                ...
# 5241           LAENDL. DORF
# 5242      VORORT GROSSSTADT
# 5243             GROSSSTADT
# 5244           LAENDL. DORF
# 5245           LAENDL. DORF
# Name: gs01, Length: 5246, dtype: category
# Categories (5, object): ['EINZELHAUS, LAND', 'GROSSSTADT', 'LAENDL. DORF', 'MITTEL-, KLEINSTADT', 'VORORT GROSSSTADT']

# %%
# alter

df["age"]
# Out:
# 0       50.0
# 1       51.0
# 2       69.0
# 3       72.0
# 4       18.0
#         ...
# 5241    73.0
# 5242    29.0
# 5243    65.0
# 5244    80.0
# 5245    82.0
# Name: age, Length: 5246, dtype: category
# Categories (79, float64): [18.0, 19.0, 20.0, 21.0, ..., 93.0, 94.0, 97.0, 99.0]

# %%
# bundesland

df["land"]
# Out:
# 0           RHEINLAND-PFALZ
# 1                    BAYERN
# 2                    BAYERN
# 3                THUERINGEN
# 4       NORDRHEIN-WESTFALEN
#                ...
# 5241          NIEDERSACHSEN
# 5242        RHEINLAND-PFALZ
# 5243    NORDRHEIN-WESTFALEN
# 5244        RHEINLAND-PFALZ
# 5245                 BAYERN
# Name: land, Length: 5246, dtype: category
# Categories (17, object): ['BADEN-WUERTTEMBERG', 'BAYERN', 'BRANDENBURG', 'BREMEN', ..., 'SACHSEN', 'SACHSEN-ANHALT', 'SCHLESWIG-HOLSTEIN', 'THUERINGEN']

# %%
# bundesland

df["sex"]
# Out:
# 0       MANN
# 1       MANN
# 2       FRAU
# 3       MANN
# 4       FRAU
#         ...
# 5241    FRAU
# 5242    FRAU
# 5243    FRAU
# 5244    MANN
# 5245    MANN
# Name: sex, Length: 5246, dtype: category
# Categories (3, object): ['DIVERS', 'FRAU', 'MANN']
