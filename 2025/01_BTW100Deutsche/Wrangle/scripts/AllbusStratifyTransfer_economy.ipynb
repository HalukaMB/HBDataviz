# %%
#we load our libraries
import pandas as pd
import sys
sys.path.append('/Users/halukamb/Documents/CodeRelated/HBDataviz_new/2025/01_BTW100Deutsche/Wrangle/lib/python3.12/site-packages')
import numpy as np
from json import loads, dumps

# %%
! pip install pyreadstat
# Out:
# Requirement already satisfied: pyreadstat in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.2.8)
# Requirement already satisfied: pandas>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyreadstat) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2.0->pyreadstat) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2.0->pyreadstat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2.0->pyreadstat) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2.0->pyreadstat) (2025.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadstat) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
#we have one function that filters the ALLBUS data for whether respondents are german and of voting age
def germanElectorate(df):
    german_df=df[df["german"]=="JA"]
    german_df=german_df.dropna(subset="age")
    german_df["age"]=german_df["age"].astype(float)
    german_electorate=german_df[german_df["age"]>=18]
    return german_electorate

# %%
#we have another function that regroups the data into fitting categories to the data we have from the zensus
def reformgroups(df):
    df["Alter"]=None
    df["Alter"]=np.where(df["age"]<30,"U30",df["Alter"])
    df["Alter"]=np.where(df["age"]>=30,"30-49",df["Alter"])
    df["Alter"]=np.where(df["age"]>=50,"50-64",df["Alter"])
    df["Alter"]=np.where(df["age"]>64,"Ü65",df["Alter"])
    df["Geschlecht"]=np.nan
    df["Geschlecht"]=np.where(df["sex"]=="FRAU","Weiblich",df["Geschlecht"])
    df["Geschlecht"]=np.where(df["sex"]=="MANN","Männlich",df["Geschlecht"])
    df["OstWest"]=np.nan
    df["OstWest"]=np.where(df["eastwest"]=="ALTE BUNDESLAENDER","West",df["OstWest"])
    df["OstWest"]=np.where(df["eastwest"]=="NEUE BUNDESLAENDER","Ost",df["OstWest"])
    df["OstWest"]=np.where(df["land"].str.contains("BERLIN"),"Berlin",df["OstWest"])

    df["Besiedelung"]=np.nan
    df["Besiedelung"]=np.where(df["gs01"].isin(['GROSSSTADT']),"dicht besiedelt",df["Besiedelung"])
    df["Besiedelung"]=np.where(df["gs01"].isin( ['MITTEL-, KLEINSTADT', 'VORORT GROSSSTADT']),"mittlere Besiedlungsdichte",df["Besiedelung"])
    df["Besiedelung"]=np.where(df["gs01"].isin( ['LAENDL. DORF','EINZELHAUS, LAND']),"gering besiedelt",df["Besiedelung"])
    
    


    
    return df

# %%
#and lastly we have a stratification function that takes the zensus data and the skewed dataset of allbus
#  and creates a stratified dataset based on the population shares of the zensus data
#for each combination of age, gender, eastwest and population density
def stratifier(zensus_model,skewed_df):

    stratified_dataset=pd.DataFrame()
    samplesize_sum=0

    #we go through each row of the zensus groups
    for index, row in zensus_model.iterrows():
        #take in which share of the population this group represents
        samplesize = round(row["Share"] * 100)
        samplesize_sum += samplesize
        #and then we take a copy of the skewed allbus data
        sub_df = skewed_df.copy()
        
        for i in range(0, 4):
            #and then we filter it down, feature by feature of the speficic row of the zensus data
            #we do this from 0 to 4 because in the first four rows we have the features we want to stratify by
            sub_df = sub_df[sub_df[row.index[i]] == row.values[i]]
            print(row.index[i],row.values[i],len(sub_df))
        
        
        #we draw a sample from this group that correlates to the share of the population
        #if the original dataset is too small, we sample with replacement
        sampled_subgroup = sub_df.sample(samplesize, random_state=1, replace=True)
        #and add this sampled group to the overall stratified dataset
        stratified_dataset = pd.concat([stratified_dataset, sampled_subgroup])
    print(len(stratified_dataset),samplesize_sum)
    return stratified_dataset

# %%
#this is the zensus data we need, we remove all rows with NaN values
#as we need as detailed data as possible for the stratification
zensus_model=pd.read_csv("zensus_model.csv")
zensus_model=zensus_model.dropna()
zensus_model=zensus_model.sort_values(by="Share",ascending=False)

# %%
#we read in the allbus data for 2021
df_2021 = pd.read_spss("../data/AllbusData/ZA5280_v2-0-1.sav")
# filter it for the german electorate

df_2021 = germanElectorate(df_2021)
# regroup it to fit the zensus data

df_2021_reform= reformgroups(df_2021)
# and stratify it based on the zensus data
df_2021= stratifier(zensus_model,df_2021)
df_2021
# Out:
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest West 744
# Alter Ü65 223
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest West 744
# Alter 50-64 247
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest West 752
# Alter 50-64 233
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest West 744
# Alter 30-49 193
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest West 752
# Alter 30-49 176
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest West 752
# Alter Ü65 263
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest West 250
# Alter Ü65 60
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest West 247
# Alter 30-49 79
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest West 250
# Alter 30-49 83
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest West 250
# Alter 50-64 60
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest West 247
# Alter 50-64 50
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest West 247
# Alter Ü65 57
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest West 752
# Alter U30 80
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest West 744
# Alter U30 81
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest West 250
# Alter U30 47
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest West 516
# Alter 50-64 186
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest West 526
# Alter 50-64 203
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest West 247
# Alter U30 61
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest West 526
# Alter Ü65 111
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest West 516
# Alter 30-49 140
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest West 526
# Alter 30-49 150
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest West 516
# Alter Ü65 128
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest Ost 441
# Alter Ü65 158
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest West 516
# Alter U30 62
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest Ost 404
# Alter Ü65 156
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest Ost 441
# Alter 50-64 150
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest Ost 404
# Alter 50-64 127
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest West 526
# Alter U30 62
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest Ost 224
# Alter Ü65 79
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest Ost 404
# Alter 30-49 99
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest Ost 441
# Alter 30-49 113
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest Ost 213
# Alter 50-64 72
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest Ost 224
# Alter 50-64 79
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest Ost 213
# Alter Ü65 74
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest Ost 213
# Alter 30-49 53
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest Ost 224
# Alter 30-49 47
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Ost 113
# Alter Ü65 34
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Berlin 102
# Alter 30-49 39
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Berlin 88
# Alter 30-49 37
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Berlin 102
# Alter Ü65 26
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Ost 116
# Alter 30-49 37
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Ost 113
# Alter 30-49 35
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Berlin 102
# Alter 50-64 28
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Berlin 88
# Alter 50-64 26
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Ost 116
# Alter Ü65 33
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Ost 113
# Alter 50-64 25
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Berlin 88
# Alter Ü65 15
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Ost 116
# Alter 50-64 28
# Geschlecht Männlich 2419
# Besiedelung mittlere Besiedlungsdichte 1182
# OstWest Ost 404
# Alter U30 22
# Geschlecht Weiblich 2474
# Besiedelung mittlere Besiedlungsdichte 1204
# OstWest Ost 441
# Alter U30 20
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Berlin 102
# Alter U30 9
# Geschlecht Weiblich 2474
# Besiedelung dicht besiedelt 465
# OstWest Ost 113
# Alter U30 19
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Berlin 88
# Alter U30 10
# Geschlecht Männlich 2419
# Besiedelung dicht besiedelt 451
# OstWest Ost 116
# Alter U30 18
# Geschlecht Männlich 2419
# Besiedelung gering besiedelt 730
# OstWest Ost 213
# Alter U30 14
# Geschlecht Weiblich 2474
# Besiedelung gering besiedelt 750
# OstWest Ost 224
# Alter U30 19
# 9993 9993
#             za_nr                              doi             version  \
# 986   ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 3459  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 1790  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 3381  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 4800  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# ...           ...                              ...                 ...
# 4710  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 1464  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 4710  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 2291  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
# 2232  ALLBUS 2021  https://doi.org/10.4232/1.14238  2.0.1 (2023-12-13)
#
#       respid     substudy  mode   splt21            eastwest german  \
# 986    987.0     SIMULTAN  MAIL  SPLIT A  ALTE BUNDESLAENDER     JA
# 3459  3460.0     SIMULTAN  MAIL  SPLIT C  ALTE BUNDESLAENDER     JA
# 1790  1791.0     SIMULTAN  MAIL  SPLIT A  ALTE BUNDESLAENDER     JA
# 3381  3382.0     SIMULTAN  MAIL  SPLIT A  ALTE BUNDESLAENDER     JA
# 4800  4801.0  SEQUENZIELL  CAWI  SPLIT C  ALTE BUNDESLAENDER     JA
# ...      ...          ...   ...      ...                 ...    ...
# 4710  4711.0     SIMULTAN  MAIL  SPLIT A  NEUE BUNDESLAENDER     JA
# 1464  1465.0     SIMULTAN  MAIL  SPLIT B  NEUE BUNDESLAENDER     JA
# 4710  4711.0     SIMULTAN  MAIL  SPLIT A  NEUE BUNDESLAENDER     JA
# 2291  2292.0     SIMULTAN  MAIL  SPLIT A  NEUE BUNDESLAENDER     JA
# 2232  2233.0  SEQUENZIELL  CAWI  SPLIT B  NEUE BUNDESLAENDER     JA
#
#              ep01  ...                 bik                 gkpol  \
# 986   TEILS TEILS  ...   ZONE 1  ;>499.999  100.000 - 499.999 E.
# 3459          NaN  ...   ZONE 1  ;<500.000  100.000 - 499.999 E.
# 1790          GUT  ...   ZONE 2-4;>499.999  20.000 - 49.999 EINW
# 3381          NaN  ...   ZONE 1  ;>499.999   500.000 UND MEHR E.
# 4800          NaN  ...   ZONE 2-4;<500.000  5.000  - 19.999 EINW
# ...           ...  ...                 ...                   ...
# 4710  TEILS TEILS  ...   ZONE 2-4;<100.000  2.000  -  4.999 EINW
# 1464     SCHLECHT  ...   ZONE 2-4;<500.000  20.000 - 49.999 EINW
# 4710  TEILS TEILS  ...   ZONE 2-4;<100.000  2.000  -  4.999 EINW
# 2291  TEILS TEILS  ...   ZONE 2-4;>499.999  5.000  - 19.999 EINW
# 2232          GUT  ...  5.000-19.999 EINW.  5.000  - 19.999 EINW
#
#                  wghtpew    wghtht             wghthew  wghthtew Alter  \
# 986   ALTE BUNDESLAENDER  1.685751  ALTE BUNDESLAENDER  2.083416   Ü65
# 3459  ALTE BUNDESLAENDER       NaN                 NaN       NaN   Ü65
# 1790  ALTE BUNDESLAENDER  0.842875  ALTE BUNDESLAENDER  1.041708   Ü65
# 3381  ALTE BUNDESLAENDER  1.685751  ALTE BUNDESLAENDER  2.083416   Ü65
# 4800  ALTE BUNDESLAENDER  0.842875  ALTE BUNDESLAENDER  1.041708   Ü65
# ...                  ...       ...                 ...       ...   ...
# 4710  NEUE BUNDESLAENDER  0.267321  NEUE BUNDESLAENDER  0.141565   U30
# 1464  NEUE BUNDESLAENDER  0.801962  NEUE BUNDESLAENDER  0.424695   U30
# 4710  NEUE BUNDESLAENDER  0.267321  NEUE BUNDESLAENDER  0.141565   U30
# 2291  NEUE BUNDESLAENDER  0.801962  NEUE BUNDESLAENDER  0.424695   U30
# 2232  NEUE BUNDESLAENDER  0.801962  NEUE BUNDESLAENDER  0.424695   U30
#
#      Geschlecht OstWest                 Besiedelung
# 986    Weiblich    West  mittlere Besiedlungsdichte
# 3459   Weiblich    West  mittlere Besiedlungsdichte
# 1790   Weiblich    West  mittlere Besiedlungsdichte
# 3381   Weiblich    West  mittlere Besiedlungsdichte
# 4800   Weiblich    West  mittlere Besiedlungsdichte
# ...         ...     ...                         ...
# 4710   Weiblich     Ost            gering besiedelt
# 1464   Weiblich     Ost            gering besiedelt
# 4710   Weiblich     Ost            gering besiedelt
# 2291   Weiblich     Ost            gering besiedelt
# 2232   Weiblich     Ost            gering besiedelt
#
# [9993 rows x 548 columns]

# %%
#we read in the allbus data for 2023
df_2023 = pd.read_spss("../data/AllbusData/ZA8830_v1-0-0.sav")
# filter it for the german electorate

df_2023 = germanElectorate(df_2023)
# regroup it to fit the zensus data

df_2023= reformgroups(df_2023)
#and straitify it based on the zensus data
df_2023= stratifier(zensus_model,df_2023)
df_2023
# Out:
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest West 729
# Alter Ü65 208
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest West 729
# Alter 50-64 230
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest West 666
# Alter 50-64 184
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest West 729
# Alter 30-49 197
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest West 666
# Alter 30-49 178
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest West 666
# Alter Ü65 222
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest West 259
# Alter Ü65 76
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest West 257
# Alter 30-49 85
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest West 259
# Alter 30-49 60
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest West 259
# Alter 50-64 64
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest West 257
# Alter 50-64 56
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest West 257
# Alter Ü65 56
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest West 666
# Alter U30 82
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest West 729
# Alter U30 94
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest West 259
# Alter U30 59
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest West 568
# Alter 50-64 194
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest West 529
# Alter 50-64 174
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest West 257
# Alter U30 60
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest West 529
# Alter Ü65 145
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest West 568
# Alter 30-49 148
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest West 529
# Alter 30-49 159
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest West 568
# Alter Ü65 161
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest Ost 465
# Alter Ü65 184
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest West 568
# Alter U30 65
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest Ost 391
# Alter Ü65 136
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest Ost 465
# Alter 50-64 128
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest Ost 391
# Alter 50-64 124
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest West 529
# Alter U30 51
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest Ost 141
# Alter Ü65 32
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest Ost 391
# Alter 30-49 101
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest Ost 465
# Alter 30-49 123
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest Ost 146
# Alter 50-64 43
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest Ost 141
# Alter 50-64 64
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest Ost 146
# Alter Ü65 54
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest Ost 146
# Alter 30-49 38
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest Ost 141
# Alter 30-49 35
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Ost 135
# Alter Ü65 44
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Berlin 91
# Alter 30-49 34
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Berlin 84
# Alter 30-49 25
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Berlin 91
# Alter Ü65 28
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Ost 130
# Alter 30-49 42
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Ost 135
# Alter 30-49 38
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Berlin 91
# Alter 50-64 19
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Berlin 84
# Alter 50-64 22
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Ost 130
# Alter Ü65 25
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Ost 135
# Alter 50-64 32
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Berlin 84
# Alter Ü65 24
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Ost 130
# Alter 50-64 35
# Geschlecht Männlich 2292
# Besiedelung mittlere Besiedlungsdichte 1078
# OstWest Ost 391
# Alter U30 30
# Geschlecht Weiblich 2412
# Besiedelung mittlere Besiedlungsdichte 1224
# OstWest Ost 465
# Alter U30 30
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Berlin 91
# Alter U30 10
# Geschlecht Weiblich 2412
# Besiedelung dicht besiedelt 485
# OstWest Ost 135
# Alter U30 21
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Berlin 84
# Alter U30 13
# Geschlecht Männlich 2292
# Besiedelung dicht besiedelt 471
# OstWest Ost 130
# Alter U30 28
# Geschlecht Männlich 2292
# Besiedelung gering besiedelt 716
# OstWest Ost 146
# Alter U30 11
# Geschlecht Weiblich 2412
# Besiedelung gering besiedelt 670
# OstWest Ost 141
# Alter U30 10
# 9993 9993
#             za_nr                              doi             version  \
# 770   ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 3538  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 1776  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 3432  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5150  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# ...           ...                              ...                 ...
# 1897  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 3272  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 4876  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 4876  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
# 5219  ALLBUS 2023  https://doi.org/10.4232/1.14387  v1.0.0, 2024-12-03
#
#       respid     substudy  mode splt23_1   splt23_2            eastwest  \
# 770    771.0          NaN  CAPI      NaN    SPLIT A  ALTE BUNDESLAENDER
# 3538  3539.0          NaN  CAPI      NaN    SPLIT B  ALTE BUNDESLAENDER
# 1776  1777.0     SIMULTAN  MAIL  SPLIT B  TNZ: MODE  ALTE BUNDESLAENDER
# 3432  3433.0  SEQUENZIELL  CAWI  SPLIT A  TNZ: MODE  ALTE BUNDESLAENDER
# 5150  5151.0          NaN  CAPI      NaN    SPLIT B  ALTE BUNDESLAENDER
# ...      ...          ...   ...      ...        ...                 ...
# 1897  1898.0          NaN  CAPI      NaN    SPLIT B  NEUE BUNDESLAENDER
# 3272  3273.0     SIMULTAN  MAIL  SPLIT A  TNZ: MODE  NEUE BUNDESLAENDER
# 4876  4877.0     SIMULTAN  MAIL  SPLIT A  TNZ: MODE  NEUE BUNDESLAENDER
# 4876  4877.0     SIMULTAN  MAIL  SPLIT A  TNZ: MODE  NEUE BUNDESLAENDER
# 5219  5220.0     SIMULTAN  MAIL  SPLIT A  TNZ: MODE  NEUE BUNDESLAENDER
#
#      german  ...                 bik   xs11   wghtpew    wghtht   wghthew  \
# 770      JA  ...   ZONE 2-4;>499.999  183.0  1.252326   1.69639  1.242308
# 3538     JA  ...   ZONE 1  ;>499.999   93.0  1.252326  0.848195  1.242308
# 1776     JA  ...    ZONE 1-4;<50.000   10.0  1.203727  1.693259  1.192166
# 3432     JA  ...   ZONE 1  ;<500.000  168.0  1.207467  0.554394  1.205184
# 5150     JA  ...   ZONE 2-4;>499.999  143.0  1.252326  0.848195  1.242308
# ...     ...  ...                 ...    ...       ...       ...       ...
# 1897     JA  ...  5.000-19.999 EINW.   55.0  0.501346  0.532744  0.524886
# 3272     JA  ...   ZONE 1  ;<500.000  176.0  0.544816  0.845091  0.572064
# 4876     JA  ...   ZONE 2-4;<500.000   31.0  0.544816  0.338036  0.572064
# 4876     JA  ...   ZONE 2-4;<500.000   31.0  0.544816  0.338036  0.572064
# 5219     JA  ...   ZONE 2-4;<100.000   19.0  0.544816  0.422545  0.572064
#
#       wghthtew Alter Geschlecht OstWest                 Besiedelung
# 770   2.107439   Ü65   Weiblich    West  mittlere Besiedlungsdichte
# 3538  1.053719   Ü65   Weiblich    West  mittlere Besiedlungsdichte
# 1776  2.018646   Ü65   Weiblich    West  mittlere Besiedlungsdichte
# 3432  0.668147   Ü65   Weiblich    West  mittlere Besiedlungsdichte
# 5150  1.053719   Ü65   Weiblich    West  mittlere Besiedlungsdichte
# ...        ...   ...        ...     ...                         ...
# 1897   0.27963   U30   Weiblich     Ost            gering besiedelt
# 3272  0.483446   U30   Weiblich     Ost            gering besiedelt
# 4876  0.193378   U30   Weiblich     Ost            gering besiedelt
# 4876  0.193378   U30   Weiblich     Ost            gering besiedelt
# 5219  0.241723   U30   Weiblich     Ost            gering besiedelt
#
# [9993 rows x 609 columns]

# %%
#this is a function that enables us to analyze for each for each subgroup how the respondents answered differently
#  to a given question/variable
def analyze_factor_patterns(dataset,variable_to_check):
    #we have a base dataframe that holds all results
    base_df=pd.DataFrame()
    #now we define the four features we want to use to check for changes in the respondents data in allbus
    factor_list=["Alter","Geschlecht","OstWest","Besiedelung"]
    #we iterate through all possible combinations of these features
    for element in factor_list:
        #print(element)
        for element2 in factor_list:
            #add we za_nr to the list of the variable to check, as it is the unique identifier for each respondent
            baselist=[variable_to_check,"za_nr"]

            #we build also a list of the features we want to check for
            extralist=[element,element2]
            #set it to remove duplicates, in case we pick the same feature twice
            extralist=list(set(extralist))

            #and combine the two lists and filter the dataset for the columns we need
            baselist.extend(extralist)
            dataset_reduced=dataset[baselist]
            #remove all rows with missing values
            dataset_reduced = dataset_reduced[~dataset_reduced.isin(["nan"]).any(axis=1)]

            #we also define a extralist plus which we need to group by the dataset
            #it is the name of the features we want to check for plus the variable
            # and then we count
            extralist_plus_factor=extralist+[variable_to_check]
            grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
            #we remove all columns that have missing values
            grouped_df=grouped_df.dropna(axis=1)
            #and then we calculate the share of the respondents for each subgroup by using the sum of the group
            grouped_df['percent'] = grouped_df['za_nr']*100 / grouped_df.groupby(by=extralist)['za_nr'].transform('sum')
            grouped_df['absolute'] = grouped_df['za_nr']
            
            #and we add this to the base dataframe that holds all results
            grouped_df=grouped_df.reset_index()
            base_df=pd.concat([base_df,grouped_df],axis=0)
    #at the end we drop duplicates
    base_df=base_df.drop_duplicates()
    #reduce the dataset
    base_df_cols=['Alter', 'Besiedelung', 'Geschlecht', 'OstWest', variable_to_check,
       'absolute','percent']
    #and return the dataset
    return base_df[base_df_cols]

# %%
# now we do this whole procedure for variable va03 which is for inflation
df_2023_inflation=analyze_factor_patterns(df_2023,"pd11")
df_2023_inflation.sort_values(by="absolute",ascending=False)
# Out:
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
#    Alter                 Besiedelung Geschlecht OstWest                  pd11  \
# 11   NaN                         NaN        NaN    West        STIMME VOLL ZU
# 9    NaN                         NaN        NaN    West        STIMME EHER ZU
# 5    NaN                         NaN   Weiblich     NaN        STIMME EHER ZU
# 1    NaN                         NaN   Männlich     NaN        STIMME EHER ZU
# 3    NaN                         NaN   Männlich     NaN        STIMME VOLL ZU
# ..   ...                         ...        ...     ...                   ...
# 14   Ü65                         NaN        NaN  Berlin   STIMME GAR NICHT ZU
# 7    NaN            gering besiedelt        NaN  Berlin        STIMME VOLL ZU
# 8    NaN  mittlere Besiedlungsdichte        NaN  Berlin  STIMME EHER NICHT ZU
# 9    NaN  mittlere Besiedlungsdichte        NaN  Berlin        STIMME EHER ZU
# 14   Ü65             dicht besiedelt        NaN     NaN   STIMME GAR NICHT ZU
#
#     absolute    percent
# 11      2566  48.570888
# 9       2349  44.463373
# 5       1584  46.891652
# 1       1541  46.151542
# 3       1531  45.852052
# ..       ...        ...
# 14         0   0.000000
# 7          0        NaN
# 8          0        NaN
# 9          0        NaN
# 14         0   0.000000
#
# [260 rows x 7 columns]

# %%
df_2023_inflation[df_2023_inflation.percent.isna()]
# Out:
#    Alter                 Besiedelung Geschlecht OstWest                 va03  \
# 4    NaN            gering besiedelt        NaN  Berlin  AM DRITTWICHTIGSTEN
# 5    NaN            gering besiedelt        NaN  Berlin  AM VIERTWICHTIGSTEN
# 6    NaN            gering besiedelt        NaN  Berlin       AM WICHTIGSTEN
# 7    NaN            gering besiedelt        NaN  Berlin  AM ZWEITWICHTIGSTEN
# 8    NaN  mittlere Besiedlungsdichte        NaN  Berlin  AM DRITTWICHTIGSTEN
# 9    NaN  mittlere Besiedlungsdichte        NaN  Berlin  AM VIERTWICHTIGSTEN
# 10   NaN  mittlere Besiedlungsdichte        NaN  Berlin       AM WICHTIGSTEN
# 11   NaN  mittlere Besiedlungsdichte        NaN  Berlin  AM ZWEITWICHTIGSTEN
#
#     absolute  percent
# 4          0      NaN
# 5          0      NaN
# 6          0      NaN
# 7          0      NaN
# 8          0      NaN
# 9          0      NaN
# 10         0      NaN
# 11         0      NaN

# %%
# now we do this whole procedure for variable va03 which is for inflation

df_2021_inflation=analyze_factor_patterns(df_2021,"pd11")
df_2021_inflation.sort_values(by="absolute",ascending=False)
# Out:
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_49450/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
#    Alter                 Besiedelung Geschlecht OstWest                  pd11  \
# 11   NaN                         NaN        NaN    West        STIMME VOLL ZU
# 9    NaN                         NaN        NaN    West        STIMME EHER ZU
# 7    NaN                         NaN   Weiblich     NaN        STIMME VOLL ZU
# 5    NaN                         NaN   Weiblich     NaN        STIMME EHER ZU
# 3    NaN                         NaN   Männlich     NaN        STIMME VOLL ZU
# ..   ...                         ...        ...     ...                   ...
# 7    NaN            gering besiedelt        NaN  Berlin        STIMME VOLL ZU
# 8    NaN  mittlere Besiedlungsdichte        NaN  Berlin  STIMME EHER NICHT ZU
# 9    NaN  mittlere Besiedlungsdichte        NaN  Berlin        STIMME EHER ZU
# 10   NaN  mittlere Besiedlungsdichte        NaN  Berlin   STIMME GAR NICHT ZU
# 10   U30                         NaN        NaN  Berlin   STIMME GAR NICHT ZU
#
#     absolute    percent
# 11      3959  50.484570
# 9       3518  44.861005
# 7       2513  49.332548
# 5       2362  46.368276
# 3       2241  46.941768
# ..       ...        ...
# 7          0        NaN
# 8          0        NaN
# 9          0        NaN
# 10         0        NaN
# 10         0   0.000000
#
# [260 rows x 7 columns]

# %%
df_2021_inflation[df_2021_inflation.percent.isna()]
# Out:
#    Alter                 Besiedelung Geschlecht OstWest                  pd11  \
# 4    NaN            gering besiedelt        NaN  Berlin  STIMME EHER NICHT ZU
# 5    NaN            gering besiedelt        NaN  Berlin        STIMME EHER ZU
# 6    NaN            gering besiedelt        NaN  Berlin   STIMME GAR NICHT ZU
# 7    NaN            gering besiedelt        NaN  Berlin        STIMME VOLL ZU
# 8    NaN  mittlere Besiedlungsdichte        NaN  Berlin  STIMME EHER NICHT ZU
# 9    NaN  mittlere Besiedlungsdichte        NaN  Berlin        STIMME EHER ZU
# 10   NaN  mittlere Besiedlungsdichte        NaN  Berlin   STIMME GAR NICHT ZU
# 11   NaN  mittlere Besiedlungsdichte        NaN  Berlin        STIMME VOLL ZU
#
#     absolute  percent
# 4          0      NaN
# 5          0      NaN
# 6          0      NaN
# 7          0      NaN
# 8          0      NaN
# 9          0      NaN
# 10         0      NaN
# 11         0      NaN

# %%
# and we merge the datasets of 2021 and 2023 based on all the features
comp_inflation=pd.merge(df_2021_inflation,df_2023_inflation,on=['Alter', 'Besiedelung', 'Geschlecht', 'OstWest', 'pd11'],suffixes=["_2021","_2023"])
comp_inflation
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 0    30-49                         NaN        NaN     NaN
# 1    30-49                         NaN        NaN     NaN
# 2    30-49                         NaN        NaN     NaN
# 3    30-49                         NaN        NaN     NaN
# 4    50-64                         NaN        NaN     NaN
# ..     ...                         ...        ...     ...
# 255    NaN            gering besiedelt        NaN     NaN
# 256    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 257    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 258    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 259    NaN  mittlere Besiedlungsdichte        NaN     NaN
#
#                      pd11  absolute_2021  percent_2021  absolute_2023  \
# 0    STIMME EHER NICHT ZU            159      5.760870            143
# 1          STIMME EHER ZU           1249     45.253623            896
# 2     STIMME GAR NICHT ZU             16      0.579710             29
# 3          STIMME VOLL ZU           1336     48.405797            890
# 4    STIMME EHER NICHT ZU            151      5.343241            152
# ..                    ...            ...           ...            ...
# 255        STIMME VOLL ZU            980     47.457627            619
# 256  STIMME EHER NICHT ZU            212      4.850149            233
# 257        STIMME EHER ZU           2036     46.579730           1286
# 258   STIMME GAR NICHT ZU             16      0.366049             41
# 259        STIMME VOLL ZU           2107     48.204072           1295
#
#      percent_2023
# 0        7.303371
# 1       45.760981
# 2        1.481103
# 3       45.454545
# 4        7.818930
# ..            ...
# 255     41.683502
# 256      8.161121
# 257     45.043783
# 258      1.436077
# 259     45.359019
#
# [260 rows x 9 columns]

# %%
comp_inflation["diff"]=comp_inflation["percent_2023"]-comp_inflation["percent_2021"]
comp_inflation[comp_inflation["OstWest"]!="Berlin"].sort_values(by="diff",ascending=False)
# Out:
#      Alter       Besiedelung Geschlecht OstWest                  pd11  \
# 65   30-49               NaN        NaN     Ost        STIMME EHER ZU
# 68   50-64               NaN        NaN     Ost  STIMME EHER NICHT ZU
# 72     U30               NaN        NaN     Ost  STIMME EHER NICHT ZU
# 37     U30               NaN   Weiblich     NaN        STIMME EHER ZU
# 121    U30  gering besiedelt        NaN     NaN        STIMME EHER ZU
# ..     ...               ...        ...     ...                   ...
# 167    NaN               NaN   Weiblich     Ost        STIMME VOLL ZU
# 231    NaN  gering besiedelt        NaN     Ost        STIMME VOLL ZU
# 115  30-49  gering besiedelt        NaN     NaN        STIMME VOLL ZU
# 39     U30               NaN   Weiblich     NaN        STIMME VOLL ZU
# 67   30-49               NaN        NaN     Ost        STIMME VOLL ZU
#
#      absolute_2021  percent_2021  absolute_2023  percent_2023       diff
# 65             238     52.654867            214     63.313609  10.658742
# 68              50     10.548523             64     19.692308   9.143784
# 72               8      4.761905             12     11.428571   6.666667
# 37             370     52.631579            252     59.154930   6.523351
# 121            138     55.200000            102     61.077844   5.877844
# ..             ...           ...            ...           ...        ...
# 167            341     40.546968            182     31.487889  -9.059079
# 231            220     40.366972            117     30.789474  -9.577499
# 115            278     48.857645            160     38.461538 -10.396107
# 39             307     43.669986            137     32.159624 -11.510361
# 67             182     40.265487             90     26.627219 -13.638268
#
# [220 rows x 10 columns]

# %%
#also we do the same for party preferences
df_2021_party=analyze_factor_patterns(df_2021,"pv01")
df_2021_party
# Out:
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
#     Alter                 Besiedelung Geschlecht OstWest  \
# 0   30-49                         NaN        NaN     NaN
# 1   30-49                         NaN        NaN     NaN
# 2   30-49                         NaN        NaN     NaN
# 3   30-49                         NaN        NaN     NaN
# 4   30-49                         NaN        NaN     NaN
# ..    ...                         ...        ...     ...
# 19    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 20    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 21    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 22    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 23    NaN  mittlere Besiedlungsdichte        NaN     NaN
#
#                     pv01  absolute    percent
# 0                    AFD       137   6.135244
# 1          ANDERE PARTEI       114   5.105240
# 2                CDU-CSU       477  21.361397
# 3            DIE GRUENEN       743  33.273623
# 4              DIE LINKE       143   6.403941
# ..                   ...       ...        ...
# 19           DIE GRUENEN       881  25.403691
# 20             DIE LINKE       200   5.767013
# 21                   FDP       471  13.581315
# 22                   SPD       537  15.484429
# 23  WUERDE NICHT WAEHLEN       133   3.835063
#
# [520 rows x 7 columns]

# %%
df_2023_party=analyze_factor_patterns(df_2023,"pv01")
df_2023_party
# Out:
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
# /var/folders/m2/_syds9sn2bjctwpf6p3_w19r0000gn/T/ipykernel_44214/1110048911.py:30: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df=dataset_reduced.groupby(by=extralist_plus_factor).count()
#     Alter                 Besiedelung Geschlecht OstWest  \
# 0   30-49                         NaN        NaN     NaN
# 1   30-49                         NaN        NaN     NaN
# 2   30-49                         NaN        NaN     NaN
# 3   30-49                         NaN        NaN     NaN
# 4   30-49                         NaN        NaN     NaN
# ..    ...                         ...        ...     ...
# 19    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 20    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 21    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 22    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 23    NaN  mittlere Besiedlungsdichte        NaN     NaN
#
#                     pv01  absolute    percent
# 0                    AFD       271  12.212708
# 1          ANDERE PARTEI        77   3.470032
# 2                CDU-CSU       426  19.197837
# 3            DIE GRUENEN       534  24.064894
# 4              DIE LINKE       138   6.219018
# ..                   ...       ...        ...
# 19           DIE GRUENEN       711  19.921547
# 20             DIE LINKE       158   4.427010
# 21                   FDP       381  10.675259
# 22                   SPD       721  20.201737
# 23  WUERDE NICHT WAEHLEN       173   4.847296
#
# [520 rows x 7 columns]

# %%
df_2023_party[df_2023_party.percent.isna()]
# Out:
#    Alter                 Besiedelung Geschlecht OstWest                  pv01  \
# 8    NaN            gering besiedelt        NaN  Berlin                   AFD
# 9    NaN            gering besiedelt        NaN  Berlin         ANDERE PARTEI
# 10   NaN            gering besiedelt        NaN  Berlin               CDU-CSU
# 11   NaN            gering besiedelt        NaN  Berlin           DIE GRUENEN
# 12   NaN            gering besiedelt        NaN  Berlin             DIE LINKE
# 13   NaN            gering besiedelt        NaN  Berlin                   FDP
# 14   NaN            gering besiedelt        NaN  Berlin                   SPD
# 15   NaN            gering besiedelt        NaN  Berlin  WUERDE NICHT WAEHLEN
# 16   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   AFD
# 17   NaN  mittlere Besiedlungsdichte        NaN  Berlin         ANDERE PARTEI
# 18   NaN  mittlere Besiedlungsdichte        NaN  Berlin               CDU-CSU
# 19   NaN  mittlere Besiedlungsdichte        NaN  Berlin           DIE GRUENEN
# 20   NaN  mittlere Besiedlungsdichte        NaN  Berlin             DIE LINKE
# 21   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   FDP
# 22   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   SPD
# 23   NaN  mittlere Besiedlungsdichte        NaN  Berlin  WUERDE NICHT WAEHLEN
#
#     absolute  percent
# 8          0      NaN
# 9          0      NaN
# 10         0      NaN
# 11         0      NaN
# 12         0      NaN
# 13         0      NaN
# 14         0      NaN
# 15         0      NaN
# 16         0      NaN
# 17         0      NaN
# 18         0      NaN
# 19         0      NaN
# 20         0      NaN
# 21         0      NaN
# 22         0      NaN
# 23         0      NaN

# %%
df_2021_party[df_2021_party.percent.isna()]
# Out:
#    Alter                 Besiedelung Geschlecht OstWest                  pv01  \
# 8    NaN            gering besiedelt        NaN  Berlin                   AFD
# 9    NaN            gering besiedelt        NaN  Berlin         ANDERE PARTEI
# 10   NaN            gering besiedelt        NaN  Berlin               CDU-CSU
# 11   NaN            gering besiedelt        NaN  Berlin           DIE GRUENEN
# 12   NaN            gering besiedelt        NaN  Berlin             DIE LINKE
# 13   NaN            gering besiedelt        NaN  Berlin                   FDP
# 14   NaN            gering besiedelt        NaN  Berlin                   SPD
# 15   NaN            gering besiedelt        NaN  Berlin  WUERDE NICHT WAEHLEN
# 16   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   AFD
# 17   NaN  mittlere Besiedlungsdichte        NaN  Berlin         ANDERE PARTEI
# 18   NaN  mittlere Besiedlungsdichte        NaN  Berlin               CDU-CSU
# 19   NaN  mittlere Besiedlungsdichte        NaN  Berlin           DIE GRUENEN
# 20   NaN  mittlere Besiedlungsdichte        NaN  Berlin             DIE LINKE
# 21   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   FDP
# 22   NaN  mittlere Besiedlungsdichte        NaN  Berlin                   SPD
# 23   NaN  mittlere Besiedlungsdichte        NaN  Berlin  WUERDE NICHT WAEHLEN
#
#     absolute  percent
# 8          0      NaN
# 9          0      NaN
# 10         0      NaN
# 11         0      NaN
# 12         0      NaN
# 13         0      NaN
# 14         0      NaN
# 15         0      NaN
# 16         0      NaN
# 17         0      NaN
# 18         0      NaN
# 19         0      NaN
# 20         0      NaN
# 21         0      NaN
# 22         0      NaN
# 23         0      NaN

# %%
#we also merge the datasets of 2021 and 2023 based on all the features for the party preferences
comp_party=pd.merge(df_2021_party,df_2023_party,on=['Alter', 'Besiedelung', 'Geschlecht', 'OstWest', 'pv01'],suffixes=["_2021","_2023"])
comp_party["diff_percent"]=comp_party["percent_2023"]-comp_party["percent_2021"]
comp_party.sort_values("diff_percent")
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 110  50-64                         NaN        NaN  Berlin
# 149    U30                         NaN        NaN     Ost
# 119    U30                         NaN        NaN  Berlin
# 122    Ü65                         NaN        NaN  Berlin
# 114    U30                         NaN        NaN  Berlin
# ..     ...                         ...        ...     ...
# 443    NaN  mittlere Besiedlungsdichte        NaN  Berlin
# 444    NaN  mittlere Besiedlungsdichte        NaN  Berlin
# 445    NaN  mittlere Besiedlungsdichte        NaN  Berlin
# 446    NaN  mittlere Besiedlungsdichte        NaN  Berlin
# 447    NaN  mittlere Besiedlungsdichte        NaN  Berlin
#
#                      pv01  absolute_2021  percent_2021  absolute_2023  \
# 110                   SPD             19     29.230769              7
# 149                   FDP             28     22.580645              5
# 119  WUERDE NICHT WAEHLEN              9     18.000000              0
# 122               CDU-CSU             30     35.294118             17
# 114               CDU-CSU              8     16.000000              0
# ..                    ...            ...           ...            ...
# 443           DIE GRUENEN              0           NaN              0
# 444             DIE LINKE              0           NaN              0
# 445                   FDP              0           NaN              0
# 446                   SPD              0           NaN              0
# 447  WUERDE NICHT WAEHLEN              0           NaN              0
#
#      percent_2023  diff_percent
# 110      9.459459    -19.771310
# 149      3.759398    -18.821247
# 119      0.000000    -18.000000
# 122     18.279570    -17.014548
# 114      0.000000    -16.000000
# ..            ...           ...
# 443           NaN           NaN
# 444           NaN           NaN
# 445           NaN           NaN
# 446           NaN           NaN
# 447           NaN           NaN
#
# [520 rows x 10 columns]

# %%
#and we pivot it based on the party preferences
comp_party_pivot=comp_party.pivot(index=['Alter','Besiedelung','Geschlecht','OstWest'], columns='pv01')[['percent_2021','percent_2023',"absolute_2021","absolute_2023"]].reset_index()
comp_party_pivot
# Out:
#      Alter                 Besiedelung Geschlecht OstWest percent_2021  \
# pv01                                                               AFD
# 0      NaN                         NaN        NaN  Berlin     2.950820
# 1      NaN                         NaN        NaN     Ost    11.746522
# 2      NaN                         NaN        NaN    West     4.289587
# 3      NaN                         NaN   Männlich     NaN     7.808564
# 4      NaN                         NaN   Männlich  Berlin     4.827586
# ..     ...                         ...        ...     ...          ...
# 60     Ü65                         NaN   Männlich     NaN     6.226766
# 61     Ü65                         NaN   Weiblich     NaN     1.906275
# 62     Ü65             dicht besiedelt        NaN     NaN     3.819918
# 63     Ü65            gering besiedelt        NaN     NaN     5.040323
# 64     Ü65  mittlere Besiedlungsdichte        NaN     NaN     3.435805
#
#                                                                  ...  \
# pv01 ANDERE PARTEI    CDU-CSU DIE GRUENEN  DIE LINKE        FDP  ...
# 0         3.606557  21.639344   26.885246   9.180328   7.213115  ...
# 1         5.641422  23.106646   14.992272  12.905719  12.210201  ...
# 2         3.412534  25.912933   29.835752   5.469622  11.880083  ...
# 3         3.803526  24.055416   24.382872   7.506297  13.173804  ...
# 4         2.068966  17.931034   27.586207   7.586207  12.413793  ...
# ..             ...        ...         ...        ...        ...  ...
# 60        0.743494  30.762082   14.962825   5.947955  13.661710  ...
# 61        1.985703  36.219222   17.553614   6.592534  10.484512  ...
# 62        1.227831  30.422920   17.462483   4.911323   8.867667  ...
# 63        2.016129  35.483871   13.709677   8.266129  11.693548  ...
# 64        1.265823  35.081374   16.817360   6.329114  14.104882  ...
#
#      absolute_2021                      absolute_2023                        \
# pv01           SPD WUERDE NICHT WAEHLEN           AFD ANDERE PARTEI CDU-CSU
# 0               60                   27            22             6      45
# 1              159                   92           294            49     267
# 2              961                  243           480           215    1609
# 3              618                  147           526           156     940
# 4               27                   13            15             3      20
# ..             ...                  ...           ...           ...     ...
# 60             267                   31            88             8     385
# 61             247                   71            57            23     426
# 62             202                   42            32             6     229
# 63              96                   22            46            13     193
# 64             216                   38            67            12     389
#
#
# pv01 DIE GRUENEN DIE LINKE  FDP   SPD WUERDE NICHT WAEHLEN
# 0             84        78   19    60                   23
# 1            146       140   77   252                   70
# 2           1518       240  641  1389                  318
# 3            760       225  442   816                  214
# 4             36        41    7    29                   12
# ..           ...       ...  ...   ...                  ...
# 60           154        54   92   321                   36
# 61           219        41   94   388                   52
# 62           101        37   84   292                   34
# 63            65        24   22   117                   17
# 64           207        34   80   300                   37
#
# [65 rows x 36 columns]

# %%
# to remove the double index ot the columns, we bring them to one name in one line
new_columns=[]
for index in comp_party_pivot:
    if index[1]!="":
        new_columns.append(index[1]+"_"+index[0])
    else:
        new_columns.append(index[0])
new_columns
comp_party_pivot.columns=new_columns
comp_party_pivot
# Out:
#    Alter                 Besiedelung Geschlecht OstWest  AFD_percent_2021  \
# 0    NaN                         NaN        NaN  Berlin          2.950820
# 1    NaN                         NaN        NaN     Ost         11.746522
# 2    NaN                         NaN        NaN    West          4.289587
# 3    NaN                         NaN   Männlich     NaN          7.808564
# 4    NaN                         NaN   Männlich  Berlin          4.827586
# ..   ...                         ...        ...     ...               ...
# 60   Ü65                         NaN   Männlich     NaN          6.226766
# 61   Ü65                         NaN   Weiblich     NaN          1.906275
# 62   Ü65             dicht besiedelt        NaN     NaN          3.819918
# 63   Ü65            gering besiedelt        NaN     NaN          5.040323
# 64   Ü65  mittlere Besiedlungsdichte        NaN     NaN          3.435805
#
#     ANDERE PARTEI_percent_2021  CDU-CSU_percent_2021  \
# 0                     3.606557             21.639344
# 1                     5.641422             23.106646
# 2                     3.412534             25.912933
# 3                     3.803526             24.055416
# 4                     2.068966             17.931034
# ..                         ...                   ...
# 60                    0.743494             30.762082
# 61                    1.985703             36.219222
# 62                    1.227831             30.422920
# 63                    2.016129             35.483871
# 64                    1.265823             35.081374
#
#     DIE GRUENEN_percent_2021  DIE LINKE_percent_2021  FDP_percent_2021  ...  \
# 0                  26.885246                9.180328          7.213115  ...
# 1                  14.992272               12.905719         12.210201  ...
# 2                  29.835752                5.469622         11.880083  ...
# 3                  24.382872                7.506297         13.173804  ...
# 4                  27.586207                7.586207         12.413793  ...
# ..                       ...                     ...               ...  ...
# 60                 14.962825                5.947955         13.661710  ...
# 61                 17.553614                6.592534         10.484512  ...
# 62                 17.462483                4.911323          8.867667  ...
# 63                 13.709677                8.266129         11.693548  ...
# 64                 16.817360                6.329114         14.104882  ...
#
#     SPD_absolute_2021  WUERDE NICHT WAEHLEN_absolute_2021  AFD_absolute_2023  \
# 0                  60                                  27                 22
# 1                 159                                  92                294
# 2                 961                                 243                480
# 3                 618                                 147                526
# 4                  27                                  13                 15
# ..                ...                                 ...                ...
# 60                267                                  31                 88
# 61                247                                  71                 57
# 62                202                                  42                 32
# 63                 96                                  22                 46
# 64                216                                  38                 67
#
#     ANDERE PARTEI_absolute_2023  CDU-CSU_absolute_2023  \
# 0                             6                     45
# 1                            49                    267
# 2                           215                   1609
# 3                           156                    940
# 4                             3                     20
# ..                          ...                    ...
# 60                            8                    385
# 61                           23                    426
# 62                            6                    229
# 63                           13                    193
# 64                           12                    389
#
#     DIE GRUENEN_absolute_2023  DIE LINKE_absolute_2023  FDP_absolute_2023  \
# 0                          84                       78                 19
# 1                         146                      140                 77
# 2                        1518                      240                641
# 3                         760                      225                442
# 4                          36                       41                  7
# ..                        ...                      ...                ...
# 60                        154                       54                 92
# 61                        219                       41                 94
# 62                        101                       37                 84
# 63                         65                       24                 22
# 64                        207                       34                 80
#
#     SPD_absolute_2023  WUERDE NICHT WAEHLEN_absolute_2023
# 0                  60                                  23
# 1                 252                                  70
# 2                1389                                 318
# 3                 816                                 214
# 4                  29                                  12
# ..                ...                                 ...
# 60                321                                  36
# 61                388                                  52
# 62                292                                  34
# 63                117                                  17
# 64                300                                  37
#
# [65 rows x 36 columns]

# %%
#same is done for inflation
comp_inflation_pivot=comp_inflation.pivot(index=['Alter','Besiedelung','Geschlecht','OstWest'], columns='va03')[['percent_2021','percent_2023',"absolute_2021","absolute_2023"]].reset_index()
new_columns=[]
for index in comp_inflation_pivot:
    if index[1]!="":
        new_columns.append(index[1]+"_"+index[0])
    else:
        new_columns.append(index[0])
new_columns
comp_inflation_pivot.columns=new_columns
comp_inflation_pivot
# Out:
#    Alter                 Besiedelung Geschlecht OstWest  \
# 0    NaN                         NaN        NaN  Berlin
# 1    NaN                         NaN        NaN     Ost
# 2    NaN                         NaN        NaN    West
# 3    NaN                         NaN   Männlich     NaN
# 4    NaN                         NaN   Männlich  Berlin
# ..   ...                         ...        ...     ...
# 60   Ü65                         NaN   Männlich     NaN
# 61   Ü65                         NaN   Weiblich     NaN
# 62   Ü65             dicht besiedelt        NaN     NaN
# 63   Ü65            gering besiedelt        NaN     NaN
# 64   Ü65  mittlere Besiedlungsdichte        NaN     NaN
#
#     AM DRITTWICHTIGSTEN_percent_2021  AM VIERTWICHTIGSTEN_percent_2021  \
# 0                          26.296296                         48.888889
# 1                          28.310502                         51.050228
# 2                          25.725726                         55.675676
# 3                          24.866057                         56.760164
# 4                          19.130435                         61.739130
# ..                               ...                               ...
# 60                         21.628190                         60.267315
# 61                         26.554268                         55.742887
# 62                         26.262626                         51.178451
# 63                         22.727273                         60.962567
# 64                         23.507463                         61.318408
#
#     AM WICHTIGSTEN_percent_2021  AM ZWEITWICHTIGSTEN_percent_2021  \
# 0                      7.037037                         17.777778
# 1                      5.388128                         15.251142
# 2                      4.924925                         13.673674
# 3                      5.263158                         13.110621
# 4                      2.608696                         16.521739
# ..                          ...                               ...
# 60                     3.766707                         14.337789
# 61                     1.369863                         16.332982
# 62                     5.050505                         17.508418
# 63                     0.267380                         16.042781
# 64                     1.616915                         13.557214
#
#     AM DRITTWICHTIGSTEN_percent_2023  AM VIERTWICHTIGSTEN_percent_2023  \
# 0                          34.010152                         31.979695
# 1                          23.569652                         40.858209
# 2                          27.720341                         39.738951
# 3                          29.421697                         41.325454
# 4                          36.702128                         38.297872
# ..                               ...                               ...
# 60                         28.267974                         48.447712
# 61                         25.371207                         48.030988
# 62                         28.571429                         53.406593
# 63                         22.203390                         47.627119
# 64                         27.336999                         44.776119
#
#     AM WICHTIGSTEN_percent_2023  AM ZWEITWICHTIGSTEN_percent_2023  \
# 0                     13.451777                         20.558376
# 1                     11.815920                         23.756219
# 2                     11.592143                         20.948566
# 3                      9.983115                         19.269734
# 4                     10.106383                         14.893617
# ..                          ...                               ...
# 60                     4.820261                         18.464052
# 61                     6.003873                         20.593932
# 62                     2.527473                         15.494505
# 63                     8.983051                         21.186441
# 64                     5.970149                         21.916732
#
#     AM DRITTWICHTIGSTEN_absolute_2021  AM VIERTWICHTIGSTEN_absolute_2021  \
# 0                                  71                                132
# 1                                 310                                559
# 2                                1285                               2781
# 3                                 789                               1801
# 4                                  22                                 71
# ..                                ...                                ...
# 60                                178                                496
# 61                                252                                529
# 62                                156                                304
# 63                                 85                                228
# 64                                189                                493
#
#     AM WICHTIGSTEN_absolute_2021  AM ZWEITWICHTIGSTEN_absolute_2021  \
# 0                             19                                 48
# 1                             59                                167
# 2                            246                                683
# 3                            167                                416
# 4                              3                                 19
# ..                           ...                                ...
# 60                            31                                118
# 61                            13                                155
# 62                            30                                104
# 63                             1                                 60
# 64                            13                                109
#
#     AM DRITTWICHTIGSTEN_absolute_2023  AM VIERTWICHTIGSTEN_absolute_2023  \
# 0                                 134                                126
# 1                                 379                                657
# 2                                2145                               3075
# 3                                1394                               1958
# 4                                  69                                 72
# ..                                ...                                ...
# 60                                346                                593
# 61                                393                                744
# 62                                260                                486
# 63                                131                                281
# 64                                348                                570
#
#     AM WICHTIGSTEN_absolute_2023  AM ZWEITWICHTIGSTEN_absolute_2023
# 0                             53                                 81
# 1                            190                                382
# 2                            897                               1621
# 3                            473                                913
# 4                             19                                 28
# ..                           ...                                ...
# 60                            59                                226
# 61                            93                                319
# 62                            23                                141
# 63                            53                                125
# 64                            76                                279
#
# [65 rows x 20 columns]

# %%
#and then again we merge both datasets
comp_inflation_party_pivot=pd.merge(comp_inflation_pivot,comp_party_pivot,on=['Alter', 'Besiedelung', 'Geschlecht', 'OstWest'])
comp_inflation_party_pivot
# Out:
#    Alter                 Besiedelung Geschlecht OstWest  \
# 0    NaN                         NaN        NaN  Berlin
# 1    NaN                         NaN        NaN     Ost
# 2    NaN                         NaN        NaN    West
# 3    NaN                         NaN   Männlich     NaN
# 4    NaN                         NaN   Männlich  Berlin
# ..   ...                         ...        ...     ...
# 60   Ü65                         NaN   Männlich     NaN
# 61   Ü65                         NaN   Weiblich     NaN
# 62   Ü65             dicht besiedelt        NaN     NaN
# 63   Ü65            gering besiedelt        NaN     NaN
# 64   Ü65  mittlere Besiedlungsdichte        NaN     NaN
#
#     AM DRITTWICHTIGSTEN_percent_2021  AM VIERTWICHTIGSTEN_percent_2021  \
# 0                          26.296296                         48.888889
# 1                          28.310502                         51.050228
# 2                          25.725726                         55.675676
# 3                          24.866057                         56.760164
# 4                          19.130435                         61.739130
# ..                               ...                               ...
# 60                         21.628190                         60.267315
# 61                         26.554268                         55.742887
# 62                         26.262626                         51.178451
# 63                         22.727273                         60.962567
# 64                         23.507463                         61.318408
#
#     AM WICHTIGSTEN_percent_2021  AM ZWEITWICHTIGSTEN_percent_2021  \
# 0                      7.037037                         17.777778
# 1                      5.388128                         15.251142
# 2                      4.924925                         13.673674
# 3                      5.263158                         13.110621
# 4                      2.608696                         16.521739
# ..                          ...                               ...
# 60                     3.766707                         14.337789
# 61                     1.369863                         16.332982
# 62                     5.050505                         17.508418
# 63                     0.267380                         16.042781
# 64                     1.616915                         13.557214
#
#     AM DRITTWICHTIGSTEN_percent_2023  AM VIERTWICHTIGSTEN_percent_2023  ...  \
# 0                          34.010152                         31.979695  ...
# 1                          23.569652                         40.858209  ...
# 2                          27.720341                         39.738951  ...
# 3                          29.421697                         41.325454  ...
# 4                          36.702128                         38.297872  ...
# ..                               ...                               ...  ...
# 60                         28.267974                         48.447712  ...
# 61                         25.371207                         48.030988  ...
# 62                         28.571429                         53.406593  ...
# 63                         22.203390                         47.627119  ...
# 64                         27.336999                         44.776119  ...
#
#     SPD_absolute_2021  WUERDE NICHT WAEHLEN_absolute_2021  AFD_absolute_2023  \
# 0                  60                                  27                 22
# 1                 159                                  92                294
# 2                 961                                 243                480
# 3                 618                                 147                526
# 4                  27                                  13                 15
# ..                ...                                 ...                ...
# 60                267                                  31                 88
# 61                247                                  71                 57
# 62                202                                  42                 32
# 63                 96                                  22                 46
# 64                216                                  38                 67
#
#     ANDERE PARTEI_absolute_2023  CDU-CSU_absolute_2023  \
# 0                             6                     45
# 1                            49                    267
# 2                           215                   1609
# 3                           156                    940
# 4                             3                     20
# ..                          ...                    ...
# 60                            8                    385
# 61                           23                    426
# 62                            6                    229
# 63                           13                    193
# 64                           12                    389
#
#     DIE GRUENEN_absolute_2023  DIE LINKE_absolute_2023  FDP_absolute_2023  \
# 0                          84                       78                 19
# 1                         146                      140                 77
# 2                        1518                      240                641
# 3                         760                      225                442
# 4                          36                       41                  7
# ..                        ...                      ...                ...
# 60                        154                       54                 92
# 61                        219                       41                 94
# 62                        101                       37                 84
# 63                         65                       24                 22
# 64                        207                       34                 80
#
#     SPD_absolute_2023  WUERDE NICHT WAEHLEN_absolute_2023
# 0                  60                                  23
# 1                 252                                  70
# 2                1389                                 318
# 3                 816                                 214
# 4                  29                                  12
# ..                ...                                 ...
# 60                321                                  36
# 61                388                                  52
# 62                292                                  34
# 63                117                                  17
# 64                300                                  37
#
# [65 rows x 52 columns]

# %%
comp_inflation_party_pivot.columns
# Out:
# Index(['Alter', 'Besiedelung', 'Geschlecht', 'OstWest',
#        'AM DRITTWICHTIGSTEN_percent_2021', 'AM VIERTWICHTIGSTEN_percent_2021',
#        'AM WICHTIGSTEN_percent_2021', 'AM ZWEITWICHTIGSTEN_percent_2021',
#        'AM DRITTWICHTIGSTEN_percent_2023', 'AM VIERTWICHTIGSTEN_percent_2023',
#        'AM WICHTIGSTEN_percent_2023', 'AM ZWEITWICHTIGSTEN_percent_2023',
#        'AM DRITTWICHTIGSTEN_absolute_2021',
#        'AM VIERTWICHTIGSTEN_absolute_2021', 'AM WICHTIGSTEN_absolute_2021',
#        'AM ZWEITWICHTIGSTEN_absolute_2021',
#        'AM DRITTWICHTIGSTEN_absolute_2023',
#        'AM VIERTWICHTIGSTEN_absolute_2023', 'AM WICHTIGSTEN_absolute_2023',
#        'AM ZWEITWICHTIGSTEN_absolute_2023', 'AFD_percent_2021',
#        'ANDERE PARTEI_percent_2021', 'CDU-CSU_percent_2021',
#        'DIE GRUENEN_percent_2021', 'DIE LINKE_percent_2021',
#        'FDP_percent_2021', 'SPD_percent_2021',
#        'WUERDE NICHT WAEHLEN_percent_2021', 'AFD_percent_2023',
#        'ANDERE PARTEI_percent_2023', 'CDU-CSU_percent_2023',
#        'DIE GRUENEN_percent_2023', 'DIE LINKE_percent_2023',
#        'FDP_percent_2023', 'SPD_percent_2023',
#        'WUERDE NICHT WAEHLEN_percent_2023', 'AFD_absolute_2021',
#        'ANDERE PARTEI_absolute_2021', 'CDU-CSU_absolute_2021',
#        'DIE GRUENEN_absolute_2021', 'DIE LINKE_absolute_2021',
#        'FDP_absolute_2021', 'SPD_absolute_2021',
#        'WUERDE NICHT WAEHLEN_absolute_2021', 'AFD_absolute_2023',
#        'ANDERE PARTEI_absolute_2023', 'CDU-CSU_absolute_2023',
#        'DIE GRUENEN_absolute_2023', 'DIE LINKE_absolute_2023',
#        'FDP_absolute_2023', 'SPD_absolute_2023',
#        'WUERDE NICHT WAEHLEN_absolute_2023'],
#       dtype='object')

# %%
#we take in the data from the zensus that gives a share of the population for each subgroup
#but only with two features defined as the same time
zensus_two_level=pd.read_csv("json_none.csv")
zensus_two_level
# Out:
#    Geschlecht                 Besiedelung OstWest  Alter      Share
# 0         NaN                         NaN     Ost    U30   1.675804
# 1         NaN            gering besiedelt     NaN    U30   2.543912
# 2         NaN             dicht besiedelt     Ost    NaN   3.853220
# 3         NaN                         NaN     Ost  30-49   4.559863
# 4         NaN                         NaN     Ost  50-64   4.751534
# 5         NaN                         NaN     Ost    Ü65   5.482466
# 6         NaN            gering besiedelt     Ost    NaN   5.491600
# 7         NaN            gering besiedelt     NaN  30-49   5.723338
# 8         NaN  mittlere Besiedlungsdichte     NaN    U30   5.842770
# 9         NaN             dicht besiedelt     NaN    U30   6.005464
# 10        NaN            gering besiedelt     NaN    Ü65   6.160283
# 11        NaN            gering besiedelt     NaN  50-64   6.572417
# 12   Weiblich                         NaN     NaN    U30   7.048535
# 13        NaN  mittlere Besiedlungsdichte     Ost    NaN   7.124847
# 14   Männlich                         NaN     NaN    U30   7.343611
# 15   Männlich                         NaN     Ost    NaN   7.956365
# 16   Weiblich                         NaN     Ost    NaN   8.513302
# 17        NaN             dicht besiedelt     NaN  50-64   9.052026
# 18        NaN             dicht besiedelt     NaN    Ü65   9.453909
# 19        NaN             dicht besiedelt     NaN  30-49  10.287935
# 20   Männlich            gering besiedelt     NaN    NaN  10.366007
# 21   Weiblich            gering besiedelt     NaN    NaN  10.633944
# 22        NaN  mittlere Besiedlungsdichte     NaN  30-49  11.790197
# 23        NaN                         NaN    West    U30  12.124164
# 24   Männlich                         NaN     NaN    Ü65  12.741598
# 25        NaN  mittlere Besiedlungsdichte     NaN  50-64  13.029092
# 26        NaN  mittlere Besiedlungsdichte     NaN    Ü65  13.482057
# 27   Weiblich                         NaN     NaN  30-49  13.845423
# 28   Männlich                         NaN     NaN  30-49  13.956047
# 29   Männlich                         NaN     NaN  50-64  14.218163
# 30        NaN                         NaN     NaN    U30  14.392146
# 31   Weiblich                         NaN     NaN  50-64  14.435372
# 32        NaN            gering besiedelt    West    NaN  15.508350
# 33   Weiblich                         NaN     NaN    Ü65  16.354651
# 34        NaN                         NaN     Ost    NaN  16.469667
# 35   Männlich             dicht besiedelt     NaN    NaN  16.644170
# 36   Weiblich             dicht besiedelt     NaN    NaN  18.155165
# 37        NaN            gering besiedelt     NaN    NaN  20.999950
# 38   Männlich  mittlere Besiedlungsdichte     NaN    NaN  21.249243
# 39        NaN                         NaN    West  30-49  21.949289
# 40        NaN                         NaN    West    Ü65  22.535343
# 41        NaN                         NaN    West  50-64  22.871233
# 42   Weiblich  mittlere Besiedlungsdichte     NaN    NaN  22.894873
# 43        NaN             dicht besiedelt    West    NaN  26.952408
# 44        NaN                         NaN     NaN  30-49  27.801470
# 45        NaN                         NaN     NaN  50-64  28.653535
# 46        NaN                         NaN     NaN    Ü65  29.096249
# 47        NaN             dicht besiedelt     NaN    NaN  34.799334
# 48        NaN  mittlere Besiedlungsdichte    West    NaN  37.019270
# 49   Männlich                         NaN    West    NaN  38.393686
# 50   Weiblich                         NaN    West    NaN  41.086342
# 51        NaN  mittlere Besiedlungsdichte     NaN    NaN  44.144116
# 52   Männlich                         NaN     NaN    NaN  48.259419
# 53   Weiblich                         NaN     NaN    NaN  51.683982
# 54        NaN                         NaN    West    NaN  79.480028

# %%
# we merge this
comp_inflation_party_pivot_zensus=pd.merge(comp_inflation_party_pivot,zensus_two_level,on=['Alter', 'Besiedelung', 'Geschlecht', 'OstWest'])

# %%
#and we filter only for the percentage results  
perc_share_df=comp_inflation_party_pivot_zensus[comp_inflation_party_pivot_zensus.columns[~comp_inflation_party_pivot_zensus.columns.str.contains("absolute")]]

# %%
perc_share_df
# Out:
#     Alter                 Besiedelung Geschlecht OstWest  \
# 0     NaN                         NaN        NaN     Ost
# 1     NaN                         NaN        NaN    West
# 2     NaN                         NaN   Männlich     NaN
# 3     NaN                         NaN   Männlich     Ost
# 4     NaN                         NaN   Männlich    West
# 5     NaN                         NaN   Weiblich     NaN
# 6     NaN                         NaN   Weiblich     Ost
# 7     NaN                         NaN   Weiblich    West
# 8     NaN             dicht besiedelt        NaN     NaN
# 9     NaN             dicht besiedelt        NaN     Ost
# 10    NaN             dicht besiedelt        NaN    West
# 11    NaN             dicht besiedelt   Männlich     NaN
# 12    NaN             dicht besiedelt   Weiblich     NaN
# 13    NaN            gering besiedelt        NaN     NaN
# 14    NaN            gering besiedelt        NaN     Ost
# 15    NaN            gering besiedelt        NaN    West
# 16    NaN            gering besiedelt   Männlich     NaN
# 17    NaN            gering besiedelt   Weiblich     NaN
# 18    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 19    NaN  mittlere Besiedlungsdichte        NaN     Ost
# 20    NaN  mittlere Besiedlungsdichte        NaN    West
# 21    NaN  mittlere Besiedlungsdichte   Männlich     NaN
# 22    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 23  30-49                         NaN        NaN     NaN
# 24  30-49                         NaN        NaN     Ost
# 25  30-49                         NaN        NaN    West
# 26  30-49                         NaN   Männlich     NaN
# 27  30-49                         NaN   Weiblich     NaN
# 28  30-49             dicht besiedelt        NaN     NaN
# 29  30-49            gering besiedelt        NaN     NaN
# 30  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 31  50-64                         NaN        NaN     NaN
# 32  50-64                         NaN        NaN     Ost
# 33  50-64                         NaN        NaN    West
# 34  50-64                         NaN   Männlich     NaN
# 35  50-64                         NaN   Weiblich     NaN
# 36  50-64             dicht besiedelt        NaN     NaN
# 37  50-64            gering besiedelt        NaN     NaN
# 38  50-64  mittlere Besiedlungsdichte        NaN     NaN
# 39    U30                         NaN        NaN     NaN
# 40    U30                         NaN        NaN     Ost
# 41    U30                         NaN        NaN    West
# 42    U30                         NaN   Männlich     NaN
# 43    U30                         NaN   Weiblich     NaN
# 44    U30             dicht besiedelt        NaN     NaN
# 45    U30            gering besiedelt        NaN     NaN
# 46    U30  mittlere Besiedlungsdichte        NaN     NaN
# 47    Ü65                         NaN        NaN     NaN
# 48    Ü65                         NaN        NaN     Ost
# 49    Ü65                         NaN        NaN    West
# 50    Ü65                         NaN   Männlich     NaN
# 51    Ü65                         NaN   Weiblich     NaN
# 52    Ü65             dicht besiedelt        NaN     NaN
# 53    Ü65            gering besiedelt        NaN     NaN
# 54    Ü65  mittlere Besiedlungsdichte        NaN     NaN
#
#     AM DRITTWICHTIGSTEN_percent_2021  AM VIERTWICHTIGSTEN_percent_2021  \
# 0                          28.310502                         51.050228
# 1                          25.725726                         55.675676
# 2                          24.866057                         56.760164
# 3                          29.906542                         50.841121
# 4                          24.058660                         57.788347
# 5                          27.518042                         52.431754
# 6                          26.785714                         51.250000
# 7                          27.427184                         53.519417
# 8                          27.350427                         53.126406
# 9                          36.401674                         51.464435
# 10                         26.254376                         54.025671
# 11                         23.251418                         59.262760
# 12                         31.072961                         47.553648
# 13                         24.482249                         53.106509
# 14                         26.410256                         49.230769
# 15                         23.700624                         54.677755
# 16                         26.037196                         50.357654
# 17                         22.817764                         56.049005
# 18                         26.104129                         56.481149
# 19                         25.751073                         52.360515
# 20                         26.175075                         57.309185
# 21                         25.494350                         58.050847
# 22                         26.734843                         54.857560
# 23                         29.872998                         46.548868
# 24                         30.793651                         45.396825
# 25                         30.360934                         46.426044
# 26                         29.175705                         46.203905
# 27                         30.596175                         46.906637
# 28                         33.382789                         44.955490
# 29                         27.664975                         41.878173
# 30                         27.860027                         50.471063
# 31                         22.668113                         62.689805
# 32                         23.547401                         59.021407
# 33                         21.621622                         64.379764
# 34                         22.060354                         65.140479
# 35                         23.329558                         60.022650
# 36                         23.172906                         63.814617
# 37                         21.428571                         60.368664
# 38                         22.968198                         63.133098
# 39                         29.689175                         48.017149
# 40                         28.971963                         42.990654
# 41                         29.643766                         49.745547
# 42                         27.837259                         54.175589
# 43                         31.545064                         41.845494
# 44                         24.619289                         54.822335
# 45                         29.333333                         42.000000
# 46                         34.961440                         43.444730
# 47                         24.266366                         57.844244
# 48                         30.346821                         51.156069
# 49                         22.985957                         59.497413
# 50                         21.628190                         60.267315
# 51                         26.554268                         55.742887
# 52                         26.262626                         51.178451
# 53                         22.727273                         60.962567
# 54                         23.507463                         61.318408
#
#     AM WICHTIGSTEN_percent_2021  AM ZWEITWICHTIGSTEN_percent_2021  \
# 0                      5.388128                         15.251142
# 1                      4.924925                         13.673674
# 2                      5.263158                         13.110621
# 3                      5.607477                         13.644860
# 4                      5.311138                         12.841855
# 5                      4.926263                         15.123941
# 6                      5.178571                         16.785714
# 7                      4.530744                         14.522654
# 8                      5.937922                         13.585245
# 9                      5.020921                          7.112971
# 10                     5.892649                         13.827305
# 11                     6.143667                         11.342155
# 12                     5.751073                         15.622318
# 13                     5.695266                         16.715976
# 14                     5.641026                         18.717949
# 15                     5.717256                         15.904366
# 16                     6.294707                         17.310443
# 17                     5.053599                         16.079632
# 18                     4.129264                         13.285458
# 19                     5.364807                         16.523605
# 20                     3.880983                         12.634756
# 21                     4.096045                         12.358757
# 22                     4.163623                         14.243974
# 23                     8.558807                         15.019326
# 24                     9.841270                         13.968254
# 25                     8.067941                         15.145081
# 26                     8.893709                         15.726681
# 27                     8.211474                         14.285714
# 28                     7.715134                         13.946588
# 29                    11.675127                         18.781726
# 30                     7.671602                         13.997308
# 31                     3.470716                         11.171367
# 32                     2.446483                         14.984709
# 33                     3.672904                         10.325710
# 34                     3.537981                          9.261186
# 35                     3.397508                         13.250283
# 36                     5.347594                          7.664884
# 37                     3.225806                         14.976959
# 38                     2.355713                         11.542992
# 39                     6.538049                         15.755627
# 40                    10.280374                         17.757009
# 41                     5.597964                         15.012723
# 42                     4.282655                         13.704497
# 43                     8.798283                         17.811159
# 44                     5.076142                         15.482234
# 45                    10.666667                         18.000000
# 46                     6.426735                         15.167095
# 47                     2.483070                         15.406321
# 48                     2.601156                         15.895954
# 49                     2.586844                         14.929786
# 50                     3.766707                         14.337789
# 51                     1.369863                         16.332982
# 52                     5.050505                         17.508418
# 53                     0.267380                         16.042781
# 54                     1.616915                         13.557214
#
#     AM DRITTWICHTIGSTEN_percent_2023  AM VIERTWICHTIGSTEN_percent_2023  ...  \
# 0                          23.569652                         40.858209  ...
# 1                          27.720341                         39.738951  ...
# 2                          29.421697                         41.325454  ...
# 3                          24.871795                         44.743590  ...
# 4                          30.000000                         40.769231  ...
# 5                          25.269892                         37.984806  ...
# 6                          22.342995                         37.198068  ...
# 7                          25.554435                         38.760081  ...
# 8                          29.111697                         40.662562  ...
# 9                          22.486772                         37.830688  ...
# 10                         29.329291                         42.364532  ...
# 11                         31.482611                         41.000610  ...
# 12                         26.918736                         40.349887  ...
# 13                         25.073457                         39.813908  ...
# 14                         20.479705                         44.095941  ...
# 15                         26.733333                         38.266667  ...
# 16                         29.940711                         41.501976  ...
# 17                         20.291262                         38.155340  ...
# 18                         26.895265                         38.675064  ...
# 19                         26.598837                         39.970930  ...
# 20                         26.951931                         38.427341  ...
# 21                         27.551509                         41.494969  ...
# 22                         26.272727                         36.000000  ...
# 23                         25.973081                         33.648599  ...
# 24                         19.599109                         36.080178  ...
# 25                         27.373272                         33.133641  ...
# 26                         26.873199                         39.193084  ...
# 27                         25.055107                         27.994122  ...
# 28                         29.394531                         35.156250  ...
# 29                         26.164875                         27.777778  ...
# 30                         22.879177                         35.132819  ...
# 31                         28.040057                         43.884120  ...
# 32                         22.961373                         48.283262  ...
# 33                         28.475336                         43.273543  ...
# 34                         31.066571                         44.667144  ...
# 35                         25.017870                         43.102216  ...
# 36                         29.213483                         41.910112  ...
# 37                         25.233645                         48.753894  ...
# 38                         28.639241                         42.800633  ...
# 39                         29.606188                         25.949367  ...
# 40                         26.946108                         20.359281  ...
# 41                         29.180602                         27.341137  ...
# 42                         33.058985                         27.023320  ...
# 43                         25.974026                         24.819625  ...
# 44                         29.301533                         28.620102  ...
# 45                         28.968254                         25.396825  ...
# 46                         30.188679                         23.499142  ...
# 47                         26.649838                         48.214930  ...
# 48                         26.425856                         44.866920  ...
# 49                         26.470588                         49.673203  ...
# 50                         28.267974                         48.447712  ...
# 51                         25.371207                         48.030988  ...
# 52                         28.571429                         53.406593  ...
# 53                         22.203390                         47.627119  ...
# 54                         27.336999                         44.776119  ...
#
#     WUERDE NICHT WAEHLEN_percent_2021  AFD_percent_2023  \
# 0                            7.109737         22.702703
# 1                            3.874980          7.488300
# 2                            3.702771         12.895317
# 3                            7.184751         27.835052
# 4                            2.704423          9.947482
# 5                            5.512821          6.813020
# 6                            7.026144         17.045455
# 7                            5.051151          4.979515
# 8                            4.384058          6.645570
# 9                            7.000000         16.993464
# 10                           3.387471          5.224898
# 11                           3.621582          9.377237
# 12                           5.117271          4.008293
# 13                           6.577345         14.610190
# 14                           8.724832         30.731707
# 15                           5.774059          9.187859
# 16                           5.365297         18.463303
# 17                           7.963446         10.171731
# 18                           3.835063         10.339031
# 19                           5.850091         20.034542
# 20                           3.457720          8.461538
# 21                           2.929351         12.928177
# 22                           4.748118          7.674815
# 23                           4.612629         12.212708
# 24                           6.442577         25.915493
# 25                           4.178430          9.423187
# 26                           3.897254         14.623838
# 27                           5.344203          9.459459
# 28                           3.344867          6.198830
# 29                           5.506608         21.296296
# 30                           5.372807         13.519313
# 31                           4.374128         12.818222
# 32                           9.090909         29.380054
# 33                           3.428239          9.754738
# 34                           3.968254         17.500000
# 35                           4.827586          7.784986
# 36                           4.375000         12.099125
# 37                           8.232932         14.785992
# 38                           2.472799         12.319538
# 39                           5.464007          8.115183
# 40                           6.451613         16.541353
# 41                           4.698672          7.112971
# 42                           4.278922         10.367893
# 43                           6.896552          5.656934
# 44                           4.230769          4.303279
# 45                          10.309278         12.903226
# 46                           4.783599         10.169492
# 47                           4.368308          5.947498
# 48                           6.222222         16.284404
# 49                           3.555556          3.771608
# 50                           2.881041          7.732865
# 51                           5.639396          4.384615
# 52                           5.729877          3.926380
# 53                           4.435484          9.255533
# 54                           3.435805          5.950266
#
#     ANDERE PARTEI_percent_2023  CDU-CSU_percent_2023  \
# 0                     3.783784             20.617761
# 1                     3.354134             25.101404
# 2                     3.824467             23.044864
# 3                     3.681885             19.882180
# 4                     3.954279             24.250850
# 5                     2.876609             24.753974
# 6                     3.896104             21.428571
# 7                     2.741885             25.969114
# 8                     2.390999             18.389592
# 9                     3.594771             17.973856
# 10                    2.317129             19.218537
# 11                    3.221188             17.322835
# 12                    1.589496             19.419489
# 13                    3.621854             29.772867
# 14                    2.439024             19.512195
# 15                    4.019688             33.223954
# 16                    3.096330             29.587156
# 17                    4.227213             29.986790
# 18                    4.006725             25.581395
# 19                    4.835924             22.797927
# 20                    3.846154             26.120401
# 21                    4.640884             24.309392
# 22                    3.354179             26.890279
# 23                    3.470032             19.197837
# 24                    5.070423             14.647887
# 25                    3.255283             20.959452
# 26                    4.311074             19.949281
# 27                    2.509653             18.339768
# 28                    4.327485             12.280702
# 29                    1.620370             28.009259
# 30                    3.540773             21.459227
# 31                    5.314873             23.760607
# 32                    3.773585             19.676550
# 33                    5.852843             24.414716
# 34                    6.034483             20.775862
# 35                    4.541242             26.969416
# 36                    1.603499             20.845481
# 37                    7.003891             26.070039
# 38                    6.929740             24.542830
# 39                    3.752182             13.263525
# 40                    6.766917             18.796992
# 41                    3.451883             13.284519
# 42                    4.515050             13.043478
# 43                    2.919708             13.503650
# 44                    2.868852              9.426230
# 45                    1.612903             19.892473
# 46                    5.508475             14.618644
# 47                    1.271534             33.264971
# 48                    1.834862             26.834862
# 49                    1.047669             35.463594
# 50                    0.702988             33.831283
# 51                    1.769231             32.769231
# 52                    0.736196             28.098160
# 53                    2.615694             38.832998
# 54                    1.065719             34.547069
#
#     DIE GRUENEN_percent_2023  DIE LINKE_percent_2023  FDP_percent_2023  \
# 0                  11.274131               10.810811          5.945946
# 1                  23.681747                3.744150         10.000000
# 2                  18.632018                5.516058         10.835989
# 3                   9.720177                9.720177          6.627393
# 4                  20.327464                3.645351         12.048193
# 5                  24.930608                5.879384          7.443856
# 6                  12.987013               12.012987          5.194805
# 7                  27.103687                3.844942          7.910495
# 8                  26.722925                7.735584          7.665260
# 9                  18.627451               10.130719          3.921569
# 10                 28.123580                5.043162          8.496138
# 11                 24.123121                7.301360          9.019327
# 12                 29.232896                8.154803          6.357982
# 13                 17.004297                4.910988          8.471455
# 14                  7.560976               12.195122          7.560976
# 15                 20.180476                2.461034          8.777687
# 16                 13.188073                6.077982          9.747706
# 17                 21.400264                3.566711          7.001321
# 18                 19.921547                4.427010         10.675259
# 19                 10.017271               10.189983          5.872193
# 20                 21.839465                3.311037         11.605351
# 21                 17.016575                3.867403         12.762431
# 22                 22.910745                5.002843          8.527572
# 23                 24.064894                6.219018         10.184768
# 24                 16.619718               10.985915          8.450704
# 25                 24.900057                4.283267         10.965163
# 26                 17.666948                5.494505         11.073542
# 27                 31.370656                7.046332          9.169884
# 28                 34.152047                8.187135          7.602339
# 29                 14.583333                5.555556          9.490741
# 30                 19.206009                4.721030         12.875536
# 31                 21.214828                5.270210          8.173292
# 32                 10.781671                8.625337          7.008086
# 33                 23.355630                4.292085          8.361204
# 34                 20.517241                5.086207         10.000000
# 35                 21.964782                5.468026          6.209453
# 36                 26.822157                6.705539          4.373178
# 37                 18.871595                4.280156         10.311284
# 38                 18.671800                4.812320          9.624639
# 39                 31.937173                9.336824         12.390925
# 40                 18.796992               14.285714          3.759398
# 41                 34.100418                6.694561         14.330544
# 42                 26.588629                7.859532         17.224080
# 43                 37.773723               10.948905          7.116788
# 44                 37.500000               13.729508          7.991803
# 45                 27.956989                5.376344         11.827957
# 46                 27.754237                6.355932         17.161017
# 47                 15.299426                3.896637          7.629204
# 48                  5.045872               11.467890          3.669725
# 49                 17.653222                1.257203          8.486118
# 50                 13.532513                4.745167          8.084359
# 51                 16.846154                3.153846          7.230769
# 52                 12.392638                4.539877         10.306748
# 53                 13.078471                4.828974          4.426559
# 54                 18.383659                3.019538          7.104796
#
#     SPD_percent_2023  WUERDE NICHT WAEHLEN_percent_2023      Share
# 0          19.459459                           5.405405  16.469667
# 1          21.669267                           4.960998  79.480028
# 2          20.004903                           5.246384  48.259419
# 3          15.611193                           6.921944   7.956365
# 4          21.037998                           4.788384  38.393686
# 5          22.331567                           4.970982  51.683982
# 6          23.701299                           3.733766   8.513302
# 7          22.313268                           5.137094  41.086342
# 8          24.964838                           5.485232  34.799334
# 9          22.875817                           5.882353   3.853220
# 10         26.351658                           5.224898  26.952408
# 11         24.123121                           5.511811  16.644170
# 12         25.777471                           5.459572  18.155165
# 13         16.574586                           5.033763  20.999950
# 14         14.634146                           5.365854   5.491600
# 15         17.227235                           4.922067  15.508350
# 16         14.908257                           4.931193  10.366007
# 17         18.494055                           5.151915  10.633944
# 18         20.201737                           4.847296  44.144116
# 19         21.070812                           5.181347   7.124847
# 20         20.033445                           4.782609  37.019270
# 21         19.281768                           5.193370  21.249243
# 22         21.148380                           4.491188  22.894873
# 23         17.755746                           6.894998  27.801470
# 24         10.422535                           7.887324   4.559863
# 25         19.531696                           6.681896  21.949289
# 26         19.019442                           7.861369  13.956047
# 27         16.312741                           5.791506  13.845423
# 28         23.625731                           3.625731  10.287935
# 29          9.259259                          10.185185   5.723338
# 30         16.309013                           8.369099  11.790197
# 31         17.686467                           5.761501  28.653535
# 32         14.555256                           6.199461   4.751534
# 33         18.673356                           5.295429  22.871233
# 34         15.086207                           5.000000  14.218163
# 35         20.481928                           6.580167  14.435372
# 36         17.492711                          10.058309   9.052026
# 37         15.564202                           3.112840   6.572417
# 38         18.864293                           4.234841  13.029092
# 39         17.626527                           3.577661  14.392146
# 40         19.548872                           1.503759   1.675804
# 41         16.945607                           4.079498  12.124164
# 42         15.886288                           4.515050   7.343611
# 43         19.525547                           2.554745   7.048535
# 44         19.672131                           4.508197   6.005464
# 45         17.741935                           2.688172   2.543912
# 46         15.466102                           2.966102   5.842770
# 47         29.081214                           3.609516  29.096249
# 48         30.963303                           3.899083   5.482466
# 49         28.810896                           3.509691  22.535343
# 50         28.207381                           3.163445  12.741598
# 51         29.846154                           4.000000  16.354651
# 52         35.828221                           4.171779   9.453909
# 53         23.541247                           3.420523   6.160283
# 54         26.642984                           3.285968  13.482057
#
# [55 rows x 29 columns]

# %%
perc_share_df=perc_share_df.round(1)
perc_share_df
# Out:
#     Alter                 Besiedelung Geschlecht OstWest  \
# 0     NaN                         NaN        NaN     Ost
# 1     NaN                         NaN        NaN    West
# 2     NaN                         NaN   Männlich     NaN
# 3     NaN                         NaN   Männlich     Ost
# 4     NaN                         NaN   Männlich    West
# 5     NaN                         NaN   Weiblich     NaN
# 6     NaN                         NaN   Weiblich     Ost
# 7     NaN                         NaN   Weiblich    West
# 8     NaN             dicht besiedelt        NaN     NaN
# 9     NaN             dicht besiedelt        NaN     Ost
# 10    NaN             dicht besiedelt        NaN    West
# 11    NaN             dicht besiedelt   Männlich     NaN
# 12    NaN             dicht besiedelt   Weiblich     NaN
# 13    NaN            gering besiedelt        NaN     NaN
# 14    NaN            gering besiedelt        NaN     Ost
# 15    NaN            gering besiedelt        NaN    West
# 16    NaN            gering besiedelt   Männlich     NaN
# 17    NaN            gering besiedelt   Weiblich     NaN
# 18    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 19    NaN  mittlere Besiedlungsdichte        NaN     Ost
# 20    NaN  mittlere Besiedlungsdichte        NaN    West
# 21    NaN  mittlere Besiedlungsdichte   Männlich     NaN
# 22    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 23  30-49                         NaN        NaN     NaN
# 24  30-49                         NaN        NaN     Ost
# 25  30-49                         NaN        NaN    West
# 26  30-49                         NaN   Männlich     NaN
# 27  30-49                         NaN   Weiblich     NaN
# 28  30-49             dicht besiedelt        NaN     NaN
# 29  30-49            gering besiedelt        NaN     NaN
# 30  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 31  50-64                         NaN        NaN     NaN
# 32  50-64                         NaN        NaN     Ost
# 33  50-64                         NaN        NaN    West
# 34  50-64                         NaN   Männlich     NaN
# 35  50-64                         NaN   Weiblich     NaN
# 36  50-64             dicht besiedelt        NaN     NaN
# 37  50-64            gering besiedelt        NaN     NaN
# 38  50-64  mittlere Besiedlungsdichte        NaN     NaN
# 39    U30                         NaN        NaN     NaN
# 40    U30                         NaN        NaN     Ost
# 41    U30                         NaN        NaN    West
# 42    U30                         NaN   Männlich     NaN
# 43    U30                         NaN   Weiblich     NaN
# 44    U30             dicht besiedelt        NaN     NaN
# 45    U30            gering besiedelt        NaN     NaN
# 46    U30  mittlere Besiedlungsdichte        NaN     NaN
# 47    Ü65                         NaN        NaN     NaN
# 48    Ü65                         NaN        NaN     Ost
# 49    Ü65                         NaN        NaN    West
# 50    Ü65                         NaN   Männlich     NaN
# 51    Ü65                         NaN   Weiblich     NaN
# 52    Ü65             dicht besiedelt        NaN     NaN
# 53    Ü65            gering besiedelt        NaN     NaN
# 54    Ü65  mittlere Besiedlungsdichte        NaN     NaN
#
#     AM DRITTWICHTIGSTEN_percent_2021  AM VIERTWICHTIGSTEN_percent_2021  \
# 0                               28.3                              51.1
# 1                               25.7                              55.7
# 2                               24.9                              56.8
# 3                               29.9                              50.8
# 4                               24.1                              57.8
# 5                               27.5                              52.4
# 6                               26.8                              51.2
# 7                               27.4                              53.5
# 8                               27.4                              53.1
# 9                               36.4                              51.5
# 10                              26.3                              54.0
# 11                              23.3                              59.3
# 12                              31.1                              47.6
# 13                              24.5                              53.1
# 14                              26.4                              49.2
# 15                              23.7                              54.7
# 16                              26.0                              50.4
# 17                              22.8                              56.0
# 18                              26.1                              56.5
# 19                              25.8                              52.4
# 20                              26.2                              57.3
# 21                              25.5                              58.1
# 22                              26.7                              54.9
# 23                              29.9                              46.5
# 24                              30.8                              45.4
# 25                              30.4                              46.4
# 26                              29.2                              46.2
# 27                              30.6                              46.9
# 28                              33.4                              45.0
# 29                              27.7                              41.9
# 30                              27.9                              50.5
# 31                              22.7                              62.7
# 32                              23.5                              59.0
# 33                              21.6                              64.4
# 34                              22.1                              65.1
# 35                              23.3                              60.0
# 36                              23.2                              63.8
# 37                              21.4                              60.4
# 38                              23.0                              63.1
# 39                              29.7                              48.0
# 40                              29.0                              43.0
# 41                              29.6                              49.7
# 42                              27.8                              54.2
# 43                              31.5                              41.8
# 44                              24.6                              54.8
# 45                              29.3                              42.0
# 46                              35.0                              43.4
# 47                              24.3                              57.8
# 48                              30.3                              51.2
# 49                              23.0                              59.5
# 50                              21.6                              60.3
# 51                              26.6                              55.7
# 52                              26.3                              51.2
# 53                              22.7                              61.0
# 54                              23.5                              61.3
#
#     AM WICHTIGSTEN_percent_2021  AM ZWEITWICHTIGSTEN_percent_2021  \
# 0                           5.4                              15.3
# 1                           4.9                              13.7
# 2                           5.3                              13.1
# 3                           5.6                              13.6
# 4                           5.3                              12.8
# 5                           4.9                              15.1
# 6                           5.2                              16.8
# 7                           4.5                              14.5
# 8                           5.9                              13.6
# 9                           5.0                               7.1
# 10                          5.9                              13.8
# 11                          6.1                              11.3
# 12                          5.8                              15.6
# 13                          5.7                              16.7
# 14                          5.6                              18.7
# 15                          5.7                              15.9
# 16                          6.3                              17.3
# 17                          5.1                              16.1
# 18                          4.1                              13.3
# 19                          5.4                              16.5
# 20                          3.9                              12.6
# 21                          4.1                              12.4
# 22                          4.2                              14.2
# 23                          8.6                              15.0
# 24                          9.8                              14.0
# 25                          8.1                              15.1
# 26                          8.9                              15.7
# 27                          8.2                              14.3
# 28                          7.7                              13.9
# 29                         11.7                              18.8
# 30                          7.7                              14.0
# 31                          3.5                              11.2
# 32                          2.4                              15.0
# 33                          3.7                              10.3
# 34                          3.5                               9.3
# 35                          3.4                              13.3
# 36                          5.3                               7.7
# 37                          3.2                              15.0
# 38                          2.4                              11.5
# 39                          6.5                              15.8
# 40                         10.3                              17.8
# 41                          5.6                              15.0
# 42                          4.3                              13.7
# 43                          8.8                              17.8
# 44                          5.1                              15.5
# 45                         10.7                              18.0
# 46                          6.4                              15.2
# 47                          2.5                              15.4
# 48                          2.6                              15.9
# 49                          2.6                              14.9
# 50                          3.8                              14.3
# 51                          1.4                              16.3
# 52                          5.1                              17.5
# 53                          0.3                              16.0
# 54                          1.6                              13.6
#
#     AM DRITTWICHTIGSTEN_percent_2023  AM VIERTWICHTIGSTEN_percent_2023  ...  \
# 0                               23.6                              40.9  ...
# 1                               27.7                              39.7  ...
# 2                               29.4                              41.3  ...
# 3                               24.9                              44.7  ...
# 4                               30.0                              40.8  ...
# 5                               25.3                              38.0  ...
# 6                               22.3                              37.2  ...
# 7                               25.6                              38.8  ...
# 8                               29.1                              40.7  ...
# 9                               22.5                              37.8  ...
# 10                              29.3                              42.4  ...
# 11                              31.5                              41.0  ...
# 12                              26.9                              40.3  ...
# 13                              25.1                              39.8  ...
# 14                              20.5                              44.1  ...
# 15                              26.7                              38.3  ...
# 16                              29.9                              41.5  ...
# 17                              20.3                              38.2  ...
# 18                              26.9                              38.7  ...
# 19                              26.6                              40.0  ...
# 20                              27.0                              38.4  ...
# 21                              27.6                              41.5  ...
# 22                              26.3                              36.0  ...
# 23                              26.0                              33.6  ...
# 24                              19.6                              36.1  ...
# 25                              27.4                              33.1  ...
# 26                              26.9                              39.2  ...
# 27                              25.1                              28.0  ...
# 28                              29.4                              35.2  ...
# 29                              26.2                              27.8  ...
# 30                              22.9                              35.1  ...
# 31                              28.0                              43.9  ...
# 32                              23.0                              48.3  ...
# 33                              28.5                              43.3  ...
# 34                              31.1                              44.7  ...
# 35                              25.0                              43.1  ...
# 36                              29.2                              41.9  ...
# 37                              25.2                              48.8  ...
# 38                              28.6                              42.8  ...
# 39                              29.6                              25.9  ...
# 40                              26.9                              20.4  ...
# 41                              29.2                              27.3  ...
# 42                              33.1                              27.0  ...
# 43                              26.0                              24.8  ...
# 44                              29.3                              28.6  ...
# 45                              29.0                              25.4  ...
# 46                              30.2                              23.5  ...
# 47                              26.6                              48.2  ...
# 48                              26.4                              44.9  ...
# 49                              26.5                              49.7  ...
# 50                              28.3                              48.4  ...
# 51                              25.4                              48.0  ...
# 52                              28.6                              53.4  ...
# 53                              22.2                              47.6  ...
# 54                              27.3                              44.8  ...
#
#     WUERDE NICHT WAEHLEN_percent_2021  AFD_percent_2023  \
# 0                                 7.1              22.7
# 1                                 3.9               7.5
# 2                                 3.7              12.9
# 3                                 7.2              27.8
# 4                                 2.7               9.9
# 5                                 5.5               6.8
# 6                                 7.0              17.0
# 7                                 5.1               5.0
# 8                                 4.4               6.6
# 9                                 7.0              17.0
# 10                                3.4               5.2
# 11                                3.6               9.4
# 12                                5.1               4.0
# 13                                6.6              14.6
# 14                                8.7              30.7
# 15                                5.8               9.2
# 16                                5.4              18.5
# 17                                8.0              10.2
# 18                                3.8              10.3
# 19                                5.9              20.0
# 20                                3.5               8.5
# 21                                2.9              12.9
# 22                                4.7               7.7
# 23                                4.6              12.2
# 24                                6.4              25.9
# 25                                4.2               9.4
# 26                                3.9              14.6
# 27                                5.3               9.5
# 28                                3.3               6.2
# 29                                5.5              21.3
# 30                                5.4              13.5
# 31                                4.4              12.8
# 32                                9.1              29.4
# 33                                3.4               9.8
# 34                                4.0              17.5
# 35                                4.8               7.8
# 36                                4.4              12.1
# 37                                8.2              14.8
# 38                                2.5              12.3
# 39                                5.5               8.1
# 40                                6.5              16.5
# 41                                4.7               7.1
# 42                                4.3              10.4
# 43                                6.9               5.7
# 44                                4.2               4.3
# 45                               10.3              12.9
# 46                                4.8              10.2
# 47                                4.4               5.9
# 48                                6.2              16.3
# 49                                3.6               3.8
# 50                                2.9               7.7
# 51                                5.6               4.4
# 52                                5.7               3.9
# 53                                4.4               9.3
# 54                                3.4               6.0
#
#     ANDERE PARTEI_percent_2023  CDU-CSU_percent_2023  \
# 0                          3.8                  20.6
# 1                          3.4                  25.1
# 2                          3.8                  23.0
# 3                          3.7                  19.9
# 4                          4.0                  24.3
# 5                          2.9                  24.8
# 6                          3.9                  21.4
# 7                          2.7                  26.0
# 8                          2.4                  18.4
# 9                          3.6                  18.0
# 10                         2.3                  19.2
# 11                         3.2                  17.3
# 12                         1.6                  19.4
# 13                         3.6                  29.8
# 14                         2.4                  19.5
# 15                         4.0                  33.2
# 16                         3.1                  29.6
# 17                         4.2                  30.0
# 18                         4.0                  25.6
# 19                         4.8                  22.8
# 20                         3.8                  26.1
# 21                         4.6                  24.3
# 22                         3.4                  26.9
# 23                         3.5                  19.2
# 24                         5.1                  14.6
# 25                         3.3                  21.0
# 26                         4.3                  19.9
# 27                         2.5                  18.3
# 28                         4.3                  12.3
# 29                         1.6                  28.0
# 30                         3.5                  21.5
# 31                         5.3                  23.8
# 32                         3.8                  19.7
# 33                         5.9                  24.4
# 34                         6.0                  20.8
# 35                         4.5                  27.0
# 36                         1.6                  20.8
# 37                         7.0                  26.1
# 38                         6.9                  24.5
# 39                         3.8                  13.3
# 40                         6.8                  18.8
# 41                         3.5                  13.3
# 42                         4.5                  13.0
# 43                         2.9                  13.5
# 44                         2.9                   9.4
# 45                         1.6                  19.9
# 46                         5.5                  14.6
# 47                         1.3                  33.3
# 48                         1.8                  26.8
# 49                         1.0                  35.5
# 50                         0.7                  33.8
# 51                         1.8                  32.8
# 52                         0.7                  28.1
# 53                         2.6                  38.8
# 54                         1.1                  34.5
#
#     DIE GRUENEN_percent_2023  DIE LINKE_percent_2023  FDP_percent_2023  \
# 0                       11.3                    10.8               5.9
# 1                       23.7                     3.7              10.0
# 2                       18.6                     5.5              10.8
# 3                        9.7                     9.7               6.6
# 4                       20.3                     3.6              12.0
# 5                       24.9                     5.9               7.4
# 6                       13.0                    12.0               5.2
# 7                       27.1                     3.8               7.9
# 8                       26.7                     7.7               7.7
# 9                       18.6                    10.1               3.9
# 10                      28.1                     5.0               8.5
# 11                      24.1                     7.3               9.0
# 12                      29.2                     8.2               6.4
# 13                      17.0                     4.9               8.5
# 14                       7.6                    12.2               7.6
# 15                      20.2                     2.5               8.8
# 16                      13.2                     6.1               9.7
# 17                      21.4                     3.6               7.0
# 18                      19.9                     4.4              10.7
# 19                      10.0                    10.2               5.9
# 20                      21.8                     3.3              11.6
# 21                      17.0                     3.9              12.8
# 22                      22.9                     5.0               8.5
# 23                      24.1                     6.2              10.2
# 24                      16.6                    11.0               8.5
# 25                      24.9                     4.3              11.0
# 26                      17.7                     5.5              11.1
# 27                      31.4                     7.0               9.2
# 28                      34.2                     8.2               7.6
# 29                      14.6                     5.6               9.5
# 30                      19.2                     4.7              12.9
# 31                      21.2                     5.3               8.2
# 32                      10.8                     8.6               7.0
# 33                      23.4                     4.3               8.4
# 34                      20.5                     5.1              10.0
# 35                      22.0                     5.5               6.2
# 36                      26.8                     6.7               4.4
# 37                      18.9                     4.3              10.3
# 38                      18.7                     4.8               9.6
# 39                      31.9                     9.3              12.4
# 40                      18.8                    14.3               3.8
# 41                      34.1                     6.7              14.3
# 42                      26.6                     7.9              17.2
# 43                      37.8                    10.9               7.1
# 44                      37.5                    13.7               8.0
# 45                      28.0                     5.4              11.8
# 46                      27.8                     6.4              17.2
# 47                      15.3                     3.9               7.6
# 48                       5.0                    11.5               3.7
# 49                      17.7                     1.3               8.5
# 50                      13.5                     4.7               8.1
# 51                      16.8                     3.2               7.2
# 52                      12.4                     4.5              10.3
# 53                      13.1                     4.8               4.4
# 54                      18.4                     3.0               7.1
#
#     SPD_percent_2023  WUERDE NICHT WAEHLEN_percent_2023  Share
# 0               19.5                                5.4   16.5
# 1               21.7                                5.0   79.5
# 2               20.0                                5.2   48.3
# 3               15.6                                6.9    8.0
# 4               21.0                                4.8   38.4
# 5               22.3                                5.0   51.7
# 6               23.7                                3.7    8.5
# 7               22.3                                5.1   41.1
# 8               25.0                                5.5   34.8
# 9               22.9                                5.9    3.9
# 10              26.4                                5.2   27.0
# 11              24.1                                5.5   16.6
# 12              25.8                                5.5   18.2
# 13              16.6                                5.0   21.0
# 14              14.6                                5.4    5.5
# 15              17.2                                4.9   15.5
# 16              14.9                                4.9   10.4
# 17              18.5                                5.2   10.6
# 18              20.2                                4.8   44.1
# 19              21.1                                5.2    7.1
# 20              20.0                                4.8   37.0
# 21              19.3                                5.2   21.2
# 22              21.1                                4.5   22.9
# 23              17.8                                6.9   27.8
# 24              10.4                                7.9    4.6
# 25              19.5                                6.7   21.9
# 26              19.0                                7.9   14.0
# 27              16.3                                5.8   13.8
# 28              23.6                                3.6   10.3
# 29               9.3                               10.2    5.7
# 30              16.3                                8.4   11.8
# 31              17.7                                5.8   28.7
# 32              14.6                                6.2    4.8
# 33              18.7                                5.3   22.9
# 34              15.1                                5.0   14.2
# 35              20.5                                6.6   14.4
# 36              17.5                               10.1    9.1
# 37              15.6                                3.1    6.6
# 38              18.9                                4.2   13.0
# 39              17.6                                3.6   14.4
# 40              19.5                                1.5    1.7
# 41              16.9                                4.1   12.1
# 42              15.9                                4.5    7.3
# 43              19.5                                2.6    7.0
# 44              19.7                                4.5    6.0
# 45              17.7                                2.7    2.5
# 46              15.5                                3.0    5.8
# 47              29.1                                3.6   29.1
# 48              31.0                                3.9    5.5
# 49              28.8                                3.5   22.5
# 50              28.2                                3.2   12.7
# 51              29.8                                4.0   16.4
# 52              35.8                                4.2    9.5
# 53              23.5                                3.4    6.2
# 54              26.6                                3.3   13.5
#
# [55 rows x 29 columns]

# %%
perc_share_df["Geschlecht"]=perc_share_df["Geschlecht"].str.replace("Männlich","Maennlich")
perc_share_df["Alter"]=perc_share_df["Alter"].str.replace("Ü65","65plus")
perc_share_df["Besiedelung"]=perc_share_df["Besiedelung"].str.replace("dicht besiedelt","Stadt")
perc_share_df["Besiedelung"]=perc_share_df["Besiedelung"].str.replace("gering besiedelt","Dorf")
perc_share_df["Besiedelung"]=perc_share_df["Besiedelung"].str.replace("mittlere Besiedlungsdichte","Kleinstadt")

# %%
#and we write this into a csv file
perc_share_df.to_csv("perc_share_df.csv")

# %%
json_array=[]
for index, row in perc_share_df.iterrows():
    print(row)
    base_dict=row[["Alter","Besiedelung","Geschlecht","OstWest","Share"]].to_dict()
    base_dict["inflation"]=row[[ 'AM DRITTWICHTIGSTEN_percent_2021', 'AM VIERTWICHTIGSTEN_percent_2021',
        'AM WICHTIGSTEN_percent_2021', 'AM ZWEITWICHTIGSTEN_percent_2021',
        'AM DRITTWICHTIGSTEN_percent_2023', 'AM VIERTWICHTIGSTEN_percent_2023',
        'AM WICHTIGSTEN_percent_2023', 'AM ZWEITWICHTIGSTEN_percent_2023']].to_dict()
    base_dict["wahl"]=row[['AFD_percent_2021', 'ANDERE PARTEI_percent_2021',
        'CDU-CSU_percent_2021', 'DIE GRUENEN_percent_2021',
        'DIE LINKE_percent_2021', 'FDP_percent_2021', 'SPD_percent_2021',
        'WUERDE NICHT WAEHLEN_percent_2021', 'AFD_percent_2023',
        'ANDERE PARTEI_percent_2023', 'CDU-CSU_percent_2023',
        'DIE GRUENEN_percent_2023', 'DIE LINKE_percent_2023',
        'FDP_percent_2023', 'SPD_percent_2023',
        'WUERDE NICHT WAEHLEN_percent_2023']].to_dict()
    json_array.append(base_dict)
json_array[0]
# Out:
# Alter                                 NaN
# Besiedelung                           NaN
# Geschlecht                            NaN
# OstWest                               Ost
# AM DRITTWICHTIGSTEN_percent_2021     28.3
# AM VIERTWICHTIGSTEN_percent_2021     51.1
# AM WICHTIGSTEN_percent_2021           5.4
# AM ZWEITWICHTIGSTEN_percent_2021     15.3
# AM DRITTWICHTIGSTEN_percent_2023     23.6
# AM VIERTWICHTIGSTEN_percent_2023     40.9
# AM WICHTIGSTEN_percent_2023          11.8
# AM ZWEITWICHTIGSTEN_percent_2023     23.8
# AFD_percent_2021                     11.7
# ANDERE PARTEI_percent_2021            5.6
# CDU-CSU_percent_2021                 23.1
# DIE GRUENEN_percent_2021             15.0
# DIE LINKE_percent_2021               12.9
# FDP_percent_2021                     12.2
# SPD_percent_2021                     12.3
# WUERDE NICHT WAEHLEN_percent_2021     7.1
# AFD_percent_2023                     22.7
# ANDERE PARTEI_percent_2023            3.8
# CDU-CSU_percent_2023                 20.6
# DIE GRUENEN_percent_2023             11.3
# DIE LINKE_percent_2023               10.8
# FDP_percent_2023                      5.9
# SPD_percent_2023                     19.5
# WUERDE NICHT WAEHLEN_percent_2023     5.4
# Share                                16.5
# Name: 0, dtype: object
# Alter                                 NaN
# Besiedelung                           NaN
# Geschlecht                            NaN
# OstWest                              West
# AM DRITTWICHTIGSTEN_percent_2021     25.7
# AM VIERTWICHTIGSTEN_percent_2021     55.7
# AM WICHTIGSTEN_percent_2021           4.9
# AM ZWEITWICHTIGSTEN_percent_2021     13.7
# AM DRITTWICHTIGSTEN_percent_2023     27.7
# AM VIERTWICHTIGSTEN_percent_2023     39.7
# AM WICHTIGSTEN_percent_2023          11.6
# AM ZWEITWICHTIGSTEN_percent_2023     20.9
# AFD_percent_2021                      4.3
# ANDERE PARTEI_percent_2021            3.4
# CDU-CSU_percent_2021                 25.9
# DIE GRUENEN_percent_2021             29.8
# DIE LINKE_percent_2021                5.5
# FDP_percent_2021                     11.9
# SPD_percent_2021                     15.3
# WUERDE NICHT WAEHLEN_percent_2021     3.9
# AFD_percent_2023                      7.5
# ANDERE PARTEI_percent_2023            3.4
# CDU-CSU_percent_2023                 25.1
# DIE GRUENEN_percent_2023             23.7
# DIE LINKE_percent_2023                3.7
# FDP_percent_2023                     10.0
# SPD_percent_2023                     21.7
# WUERDE NICHT WAEHLEN_percent_2023     5.0
# Share                                79.5
# Name: 1, dtype: object
# Alter                                      NaN
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          24.9
# AM VIERTWICHTIGSTEN_percent_2021          56.8
# AM WICHTIGSTEN_percent_2021                5.3
# AM ZWEITWICHTIGSTEN_percent_2021          13.1
# AM DRITTWICHTIGSTEN_percent_2023          29.4
# AM VIERTWICHTIGSTEN_percent_2023          41.3
# AM WICHTIGSTEN_percent_2023               10.0
# AM ZWEITWICHTIGSTEN_percent_2023          19.3
# AFD_percent_2021                           7.8
# ANDERE PARTEI_percent_2021                 3.8
# CDU-CSU_percent_2021                      24.1
# DIE GRUENEN_percent_2021                  24.4
# DIE LINKE_percent_2021                     7.5
# FDP_percent_2021                          13.2
# SPD_percent_2021                          15.6
# WUERDE NICHT WAEHLEN_percent_2021          3.7
# AFD_percent_2023                          12.9
# ANDERE PARTEI_percent_2023                 3.8
# CDU-CSU_percent_2023                      23.0
# DIE GRUENEN_percent_2023                  18.6
# DIE LINKE_percent_2023                     5.5
# FDP_percent_2023                          10.8
# SPD_percent_2023                          20.0
# WUERDE NICHT WAEHLEN_percent_2023          5.2
# Share                                     48.3
# Name: 2, dtype: object
# Alter                                      NaN
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                    Ost
# AM DRITTWICHTIGSTEN_percent_2021          29.9
# AM VIERTWICHTIGSTEN_percent_2021          50.8
# AM WICHTIGSTEN_percent_2021                5.6
# AM ZWEITWICHTIGSTEN_percent_2021          13.6
# AM DRITTWICHTIGSTEN_percent_2023          24.9
# AM VIERTWICHTIGSTEN_percent_2023          44.7
# AM WICHTIGSTEN_percent_2023                9.1
# AM ZWEITWICHTIGSTEN_percent_2023          21.3
# AFD_percent_2021                          15.0
# ANDERE PARTEI_percent_2021                 5.1
# CDU-CSU_percent_2021                      21.1
# DIE GRUENEN_percent_2021                  13.2
# DIE LINKE_percent_2021                    11.6
# FDP_percent_2021                          14.5
# SPD_percent_2021                          12.3
# WUERDE NICHT WAEHLEN_percent_2021          7.2
# AFD_percent_2023                          27.8
# ANDERE PARTEI_percent_2023                 3.7
# CDU-CSU_percent_2023                      19.9
# DIE GRUENEN_percent_2023                   9.7
# DIE LINKE_percent_2023                     9.7
# FDP_percent_2023                           6.6
# SPD_percent_2023                          15.6
# WUERDE NICHT WAEHLEN_percent_2023          6.9
# Share                                      8.0
# Name: 3, dtype: object
# Alter                                      NaN
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                   West
# AM DRITTWICHTIGSTEN_percent_2021          24.1
# AM VIERTWICHTIGSTEN_percent_2021          57.8
# AM WICHTIGSTEN_percent_2021                5.3
# AM ZWEITWICHTIGSTEN_percent_2021          12.8
# AM DRITTWICHTIGSTEN_percent_2023          30.0
# AM VIERTWICHTIGSTEN_percent_2023          40.8
# AM WICHTIGSTEN_percent_2023               10.2
# AM ZWEITWICHTIGSTEN_percent_2023          19.1
# AFD_percent_2021                           6.4
# ANDERE PARTEI_percent_2021                 3.6
# CDU-CSU_percent_2021                      25.0
# DIE GRUENEN_percent_2021                  26.7
# DIE LINKE_percent_2021                     6.6
# FDP_percent_2021                          12.9
# SPD_percent_2021                          16.1
# WUERDE NICHT WAEHLEN_percent_2021          2.7
# AFD_percent_2023                           9.9
# ANDERE PARTEI_percent_2023                 4.0
# CDU-CSU_percent_2023                      24.3
# DIE GRUENEN_percent_2023                  20.3
# DIE LINKE_percent_2023                     3.6
# FDP_percent_2023                          12.0
# SPD_percent_2023                          21.0
# WUERDE NICHT WAEHLEN_percent_2023          4.8
# Share                                     38.4
# Name: 4, dtype: object
# Alter                                     NaN
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         27.5
# AM VIERTWICHTIGSTEN_percent_2021         52.4
# AM WICHTIGSTEN_percent_2021               4.9
# AM ZWEITWICHTIGSTEN_percent_2021         15.1
# AM DRITTWICHTIGSTEN_percent_2023         25.3
# AM VIERTWICHTIGSTEN_percent_2023         38.0
# AM WICHTIGSTEN_percent_2023              13.3
# AM ZWEITWICHTIGSTEN_percent_2023         23.4
# AFD_percent_2021                          3.1
# ANDERE PARTEI_percent_2021                3.8
# CDU-CSU_percent_2021                     26.5
# DIE GRUENEN_percent_2021                 30.2
# DIE LINKE_percent_2021                    6.2
# FDP_percent_2021                         10.3
# SPD_percent_2021                         14.4
# WUERDE NICHT WAEHLEN_percent_2021         5.5
# AFD_percent_2023                          6.8
# ANDERE PARTEI_percent_2023                2.9
# CDU-CSU_percent_2023                     24.8
# DIE GRUENEN_percent_2023                 24.9
# DIE LINKE_percent_2023                    5.9
# FDP_percent_2023                          7.4
# SPD_percent_2023                         22.3
# WUERDE NICHT WAEHLEN_percent_2023         5.0
# Share                                    51.7
# Name: 5, dtype: object
# Alter                                     NaN
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                   Ost
# AM DRITTWICHTIGSTEN_percent_2021         26.8
# AM VIERTWICHTIGSTEN_percent_2021         51.2
# AM WICHTIGSTEN_percent_2021               5.2
# AM ZWEITWICHTIGSTEN_percent_2021         16.8
# AM DRITTWICHTIGSTEN_percent_2023         22.3
# AM VIERTWICHTIGSTEN_percent_2023         37.2
# AM WICHTIGSTEN_percent_2023              14.4
# AM ZWEITWICHTIGSTEN_percent_2023         26.1
# AFD_percent_2021                          8.2
# ANDERE PARTEI_percent_2021                6.2
# CDU-CSU_percent_2021                     25.3
# DIE GRUENEN_percent_2021                 17.0
# DIE LINKE_percent_2021                   14.4
# FDP_percent_2021                          9.6
# SPD_percent_2021                         12.3
# WUERDE NICHT WAEHLEN_percent_2021         7.0
# AFD_percent_2023                         17.0
# ANDERE PARTEI_percent_2023                3.9
# CDU-CSU_percent_2023                     21.4
# DIE GRUENEN_percent_2023                 13.0
# DIE LINKE_percent_2023                   12.0
# FDP_percent_2023                          5.2
# SPD_percent_2023                         23.7
# WUERDE NICHT WAEHLEN_percent_2023         3.7
# Share                                     8.5
# Name: 6, dtype: object
# Alter                                     NaN
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                  West
# AM DRITTWICHTIGSTEN_percent_2021         27.4
# AM VIERTWICHTIGSTEN_percent_2021         53.5
# AM WICHTIGSTEN_percent_2021               4.5
# AM ZWEITWICHTIGSTEN_percent_2021         14.5
# AM DRITTWICHTIGSTEN_percent_2023         25.6
# AM VIERTWICHTIGSTEN_percent_2023         38.8
# AM WICHTIGSTEN_percent_2023              13.0
# AM ZWEITWICHTIGSTEN_percent_2023         22.7
# AFD_percent_2021                          2.2
# ANDERE PARTEI_percent_2021                3.2
# CDU-CSU_percent_2021                     26.9
# DIE GRUENEN_percent_2021                 33.0
# DIE LINKE_percent_2021                    4.3
# FDP_percent_2021                         10.8
# SPD_percent_2021                         14.5
# WUERDE NICHT WAEHLEN_percent_2021         5.1
# AFD_percent_2023                          5.0
# ANDERE PARTEI_percent_2023                2.7
# CDU-CSU_percent_2023                     26.0
# DIE GRUENEN_percent_2023                 27.1
# DIE LINKE_percent_2023                    3.8
# FDP_percent_2023                          7.9
# SPD_percent_2023                         22.3
# WUERDE NICHT WAEHLEN_percent_2023         5.1
# Share                                    41.1
# Name: 7, dtype: object
# Alter                                  NaN
# Besiedelung                          Stadt
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      27.4
# AM VIERTWICHTIGSTEN_percent_2021      53.1
# AM WICHTIGSTEN_percent_2021            5.9
# AM ZWEITWICHTIGSTEN_percent_2021      13.6
# AM DRITTWICHTIGSTEN_percent_2023      29.1
# AM VIERTWICHTIGSTEN_percent_2023      40.7
# AM WICHTIGSTEN_percent_2023           12.0
# AM ZWEITWICHTIGSTEN_percent_2023      18.3
# AFD_percent_2021                       4.0
# ANDERE PARTEI_percent_2021             3.1
# CDU-CSU_percent_2021                  19.6
# DIE GRUENEN_percent_2021              37.1
# DIE LINKE_percent_2021                 8.6
# FDP_percent_2021                       8.5
# SPD_percent_2021                      14.7
# WUERDE NICHT WAEHLEN_percent_2021      4.4
# AFD_percent_2023                       6.6
# ANDERE PARTEI_percent_2023             2.4
# CDU-CSU_percent_2023                  18.4
# DIE GRUENEN_percent_2023              26.7
# DIE LINKE_percent_2023                 7.7
# FDP_percent_2023                       7.7
# SPD_percent_2023                      25.0
# WUERDE NICHT WAEHLEN_percent_2023      5.5
# Share                                 34.8
# Name: 8, dtype: object
# Alter                                  NaN
# Besiedelung                          Stadt
# Geschlecht                             NaN
# OstWest                                Ost
# AM DRITTWICHTIGSTEN_percent_2021      36.4
# AM VIERTWICHTIGSTEN_percent_2021      51.5
# AM WICHTIGSTEN_percent_2021            5.0
# AM ZWEITWICHTIGSTEN_percent_2021       7.1
# AM DRITTWICHTIGSTEN_percent_2023      22.5
# AM VIERTWICHTIGSTEN_percent_2023      37.8
# AM WICHTIGSTEN_percent_2023           12.7
# AM ZWEITWICHTIGSTEN_percent_2023      27.0
# AFD_percent_2021                       8.0
# ANDERE PARTEI_percent_2021             3.7
# CDU-CSU_percent_2021                  18.7
# DIE GRUENEN_percent_2021              27.3
# DIE LINKE_percent_2021                15.3
# FDP_percent_2021                      10.0
# SPD_percent_2021                      10.0
# WUERDE NICHT WAEHLEN_percent_2021      7.0
# AFD_percent_2023                      17.0
# ANDERE PARTEI_percent_2023             3.6
# CDU-CSU_percent_2023                  18.0
# DIE GRUENEN_percent_2023              18.6
# DIE LINKE_percent_2023                10.1
# FDP_percent_2023                       3.9
# SPD_percent_2023                      22.9
# WUERDE NICHT WAEHLEN_percent_2023      5.9
# Share                                  3.9
# Name: 9, dtype: object
# Alter                                  NaN
# Besiedelung                          Stadt
# Geschlecht                             NaN
# OstWest                               West
# AM DRITTWICHTIGSTEN_percent_2021      26.3
# AM VIERTWICHTIGSTEN_percent_2021      54.0
# AM WICHTIGSTEN_percent_2021            5.9
# AM ZWEITWICHTIGSTEN_percent_2021      13.8
# AM DRITTWICHTIGSTEN_percent_2023      29.3
# AM VIERTWICHTIGSTEN_percent_2023      42.4
# AM WICHTIGSTEN_percent_2023           11.6
# AM ZWEITWICHTIGSTEN_percent_2023      16.7
# AFD_percent_2021                       3.6
# ANDERE PARTEI_percent_2021             2.9
# CDU-CSU_percent_2021                  19.5
# DIE GRUENEN_percent_2021              39.9
# DIE LINKE_percent_2021                 7.5
# FDP_percent_2021                       8.4
# SPD_percent_2021                      14.7
# WUERDE NICHT WAEHLEN_percent_2021      3.4
# AFD_percent_2023                       5.2
# ANDERE PARTEI_percent_2023             2.3
# CDU-CSU_percent_2023                  19.2
# DIE GRUENEN_percent_2023              28.1
# DIE LINKE_percent_2023                 5.0
# FDP_percent_2023                       8.5
# SPD_percent_2023                      26.4
# WUERDE NICHT WAEHLEN_percent_2023      5.2
# Share                                 27.0
# Name: 10, dtype: object
# Alter                                      NaN
# Besiedelung                              Stadt
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          23.3
# AM VIERTWICHTIGSTEN_percent_2021          59.3
# AM WICHTIGSTEN_percent_2021                6.1
# AM ZWEITWICHTIGSTEN_percent_2021          11.3
# AM DRITTWICHTIGSTEN_percent_2023          31.5
# AM VIERTWICHTIGSTEN_percent_2023          41.0
# AM WICHTIGSTEN_percent_2023               11.3
# AM ZWEITWICHTIGSTEN_percent_2023          16.2
# AFD_percent_2021                           4.7
# ANDERE PARTEI_percent_2021                 3.3
# CDU-CSU_percent_2021                      18.3
# DIE GRUENEN_percent_2021                  36.4
# DIE LINKE_percent_2021                     9.6
# FDP_percent_2021                           8.3
# SPD_percent_2021                          15.8
# WUERDE NICHT WAEHLEN_percent_2021          3.6
# AFD_percent_2023                           9.4
# ANDERE PARTEI_percent_2023                 3.2
# CDU-CSU_percent_2023                      17.3
# DIE GRUENEN_percent_2023                  24.1
# DIE LINKE_percent_2023                     7.3
# FDP_percent_2023                           9.0
# SPD_percent_2023                          24.1
# WUERDE NICHT WAEHLEN_percent_2023          5.5
# Share                                     16.6
# Name: 11, dtype: object
# Alter                                     NaN
# Besiedelung                             Stadt
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         31.1
# AM VIERTWICHTIGSTEN_percent_2021         47.6
# AM WICHTIGSTEN_percent_2021               5.8
# AM ZWEITWICHTIGSTEN_percent_2021         15.6
# AM DRITTWICHTIGSTEN_percent_2023         26.9
# AM VIERTWICHTIGSTEN_percent_2023         40.3
# AM WICHTIGSTEN_percent_2023              12.6
# AM ZWEITWICHTIGSTEN_percent_2023         20.1
# AFD_percent_2021                          3.3
# ANDERE PARTEI_percent_2021                2.9
# CDU-CSU_percent_2021                     21.0
# DIE GRUENEN_percent_2021                 37.7
# DIE LINKE_percent_2021                    7.5
# FDP_percent_2021                          8.7
# SPD_percent_2021                         13.7
# WUERDE NICHT WAEHLEN_percent_2021         5.1
# AFD_percent_2023                          4.0
# ANDERE PARTEI_percent_2023                1.6
# CDU-CSU_percent_2023                     19.4
# DIE GRUENEN_percent_2023                 29.2
# DIE LINKE_percent_2023                    8.2
# FDP_percent_2023                          6.4
# SPD_percent_2023                         25.8
# WUERDE NICHT WAEHLEN_percent_2023         5.5
# Share                                    18.2
# Name: 12, dtype: object
# Alter                                 NaN
# Besiedelung                          Dorf
# Geschlecht                            NaN
# OstWest                               NaN
# AM DRITTWICHTIGSTEN_percent_2021     24.5
# AM VIERTWICHTIGSTEN_percent_2021     53.1
# AM WICHTIGSTEN_percent_2021           5.7
# AM ZWEITWICHTIGSTEN_percent_2021     16.7
# AM DRITTWICHTIGSTEN_percent_2023     25.1
# AM VIERTWICHTIGSTEN_percent_2023     39.8
# AM WICHTIGSTEN_percent_2023          11.3
# AM ZWEITWICHTIGSTEN_percent_2023     23.8
# AFD_percent_2021                      7.9
# ANDERE PARTEI_percent_2021            4.9
# CDU-CSU_percent_2021                 32.0
# DIE GRUENEN_percent_2021             14.7
# DIE LINKE_percent_2021                6.2
# FDP_percent_2021                     13.4
# SPD_percent_2021                     14.4
# WUERDE NICHT WAEHLEN_percent_2021     6.6
# AFD_percent_2023                     14.6
# ANDERE PARTEI_percent_2023            3.6
# CDU-CSU_percent_2023                 29.8
# DIE GRUENEN_percent_2023             17.0
# DIE LINKE_percent_2023                4.9
# FDP_percent_2023                      8.5
# SPD_percent_2023                     16.6
# WUERDE NICHT WAEHLEN_percent_2023     5.0
# Share                                21.0
# Name: 13, dtype: object
# Alter                                 NaN
# Besiedelung                          Dorf
# Geschlecht                            NaN
# OstWest                               Ost
# AM DRITTWICHTIGSTEN_percent_2021     26.4
# AM VIERTWICHTIGSTEN_percent_2021     49.2
# AM WICHTIGSTEN_percent_2021           5.6
# AM ZWEITWICHTIGSTEN_percent_2021     18.7
# AM DRITTWICHTIGSTEN_percent_2023     20.5
# AM VIERTWICHTIGSTEN_percent_2023     44.1
# AM WICHTIGSTEN_percent_2023          10.9
# AM ZWEITWICHTIGSTEN_percent_2023     24.5
# AFD_percent_2021                     13.9
# ANDERE PARTEI_percent_2021            4.9
# CDU-CSU_percent_2021                 25.1
# DIE GRUENEN_percent_2021              8.1
# DIE LINKE_percent_2021               10.5
# FDP_percent_2021                     15.2
# SPD_percent_2021                     13.6
# WUERDE NICHT WAEHLEN_percent_2021     8.7
# AFD_percent_2023                     30.7
# ANDERE PARTEI_percent_2023            2.4
# CDU-CSU_percent_2023                 19.5
# DIE GRUENEN_percent_2023              7.6
# DIE LINKE_percent_2023               12.2
# FDP_percent_2023                      7.6
# SPD_percent_2023                     14.6
# WUERDE NICHT WAEHLEN_percent_2023     5.4
# Share                                 5.5
# Name: 14, dtype: object
# Alter                                 NaN
# Besiedelung                          Dorf
# Geschlecht                            NaN
# OstWest                              West
# AM DRITTWICHTIGSTEN_percent_2021     23.7
# AM VIERTWICHTIGSTEN_percent_2021     54.7
# AM WICHTIGSTEN_percent_2021           5.7
# AM ZWEITWICHTIGSTEN_percent_2021     15.9
# AM DRITTWICHTIGSTEN_percent_2023     26.7
# AM VIERTWICHTIGSTEN_percent_2023     38.3
# AM WICHTIGSTEN_percent_2023          11.5
# AM ZWEITWICHTIGSTEN_percent_2023     23.5
# AFD_percent_2021                      5.6
# ANDERE PARTEI_percent_2021            4.9
# CDU-CSU_percent_2021                 34.6
# DIE GRUENEN_percent_2021             17.2
# DIE LINKE_percent_2021                4.6
# FDP_percent_2021                     12.7
# SPD_percent_2021                     14.6
# WUERDE NICHT WAEHLEN_percent_2021     5.8
# AFD_percent_2023                      9.2
# ANDERE PARTEI_percent_2023            4.0
# CDU-CSU_percent_2023                 33.2
# DIE GRUENEN_percent_2023             20.2
# DIE LINKE_percent_2023                2.5
# FDP_percent_2023                      8.8
# SPD_percent_2023                     17.2
# WUERDE NICHT WAEHLEN_percent_2023     4.9
# Share                                15.5
# Name: 15, dtype: object
# Alter                                      NaN
# Besiedelung                               Dorf
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          26.0
# AM VIERTWICHTIGSTEN_percent_2021          50.4
# AM WICHTIGSTEN_percent_2021                6.3
# AM ZWEITWICHTIGSTEN_percent_2021          17.3
# AM DRITTWICHTIGSTEN_percent_2023          29.9
# AM VIERTWICHTIGSTEN_percent_2023          41.5
# AM WICHTIGSTEN_percent_2023                8.4
# AM ZWEITWICHTIGSTEN_percent_2023          20.2
# AFD_percent_2021                          11.3
# ANDERE PARTEI_percent_2021                 5.0
# CDU-CSU_percent_2021                      29.2
# DIE GRUENEN_percent_2021                  11.4
# DIE LINKE_percent_2021                     6.8
# FDP_percent_2021                          16.6
# SPD_percent_2021                          14.3
# WUERDE NICHT WAEHLEN_percent_2021          5.4
# AFD_percent_2023                          18.5
# ANDERE PARTEI_percent_2023                 3.1
# CDU-CSU_percent_2023                      29.6
# DIE GRUENEN_percent_2023                  13.2
# DIE LINKE_percent_2023                     6.1
# FDP_percent_2023                           9.7
# SPD_percent_2023                          14.9
# WUERDE NICHT WAEHLEN_percent_2023          4.9
# Share                                     10.4
# Name: 16, dtype: object
# Alter                                     NaN
# Besiedelung                              Dorf
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         22.8
# AM VIERTWICHTIGSTEN_percent_2021         56.0
# AM WICHTIGSTEN_percent_2021               5.1
# AM ZWEITWICHTIGSTEN_percent_2021         16.1
# AM DRITTWICHTIGSTEN_percent_2023         20.3
# AM VIERTWICHTIGSTEN_percent_2023         38.2
# AM WICHTIGSTEN_percent_2023              14.2
# AM ZWEITWICHTIGSTEN_percent_2023         27.4
# AFD_percent_2021                          3.9
# ANDERE PARTEI_percent_2021                4.7
# CDU-CSU_percent_2021                     35.1
# DIE GRUENEN_percent_2021                 18.5
# DIE LINKE_percent_2021                    5.5
# FDP_percent_2021                          9.8
# SPD_percent_2021                         14.5
# WUERDE NICHT WAEHLEN_percent_2021         8.0
# AFD_percent_2023                         10.2
# ANDERE PARTEI_percent_2023                4.2
# CDU-CSU_percent_2023                     30.0
# DIE GRUENEN_percent_2023                 21.4
# DIE LINKE_percent_2023                    3.6
# FDP_percent_2023                          7.0
# SPD_percent_2023                         18.5
# WUERDE NICHT WAEHLEN_percent_2023         5.2
# Share                                    10.6
# Name: 17, dtype: object
# Alter                                       NaN
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           26.1
# AM VIERTWICHTIGSTEN_percent_2021           56.5
# AM WICHTIGSTEN_percent_2021                 4.1
# AM ZWEITWICHTIGSTEN_percent_2021           13.3
# AM DRITTWICHTIGSTEN_percent_2023           26.9
# AM VIERTWICHTIGSTEN_percent_2023           38.7
# AM WICHTIGSTEN_percent_2023                11.7
# AM ZWEITWICHTIGSTEN_percent_2023           22.7
# AFD_percent_2021                            5.5
# ANDERE PARTEI_percent_2021                  3.8
# CDU-CSU_percent_2021                       26.6
# DIE GRUENEN_percent_2021                   25.4
# DIE LINKE_percent_2021                      5.8
# FDP_percent_2021                           13.6
# SPD_percent_2021                           15.5
# WUERDE NICHT WAEHLEN_percent_2021           3.8
# AFD_percent_2023                           10.3
# ANDERE PARTEI_percent_2023                  4.0
# CDU-CSU_percent_2023                       25.6
# DIE GRUENEN_percent_2023                   19.9
# DIE LINKE_percent_2023                      4.4
# FDP_percent_2023                           10.7
# SPD_percent_2023                           20.2
# WUERDE NICHT WAEHLEN_percent_2023           4.8
# Share                                      44.1
# Name: 18, dtype: object
# Alter                                       NaN
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                     Ost
# AM DRITTWICHTIGSTEN_percent_2021           25.8
# AM VIERTWICHTIGSTEN_percent_2021           52.4
# AM WICHTIGSTEN_percent_2021                 5.4
# AM ZWEITWICHTIGSTEN_percent_2021           16.5
# AM DRITTWICHTIGSTEN_percent_2023           26.6
# AM VIERTWICHTIGSTEN_percent_2023           40.0
# AM WICHTIGSTEN_percent_2023                12.1
# AM ZWEITWICHTIGSTEN_percent_2023           21.4
# AFD_percent_2021                           12.1
# ANDERE PARTEI_percent_2021                  7.3
# CDU-CSU_percent_2021                       23.9
# DIE GRUENEN_percent_2021                   13.9
# DIE LINKE_percent_2021                     13.5
# FDP_percent_2021                           11.0
# SPD_percent_2021                           12.4
# WUERDE NICHT WAEHLEN_percent_2021           5.9
# AFD_percent_2023                           20.0
# ANDERE PARTEI_percent_2023                  4.8
# CDU-CSU_percent_2023                       22.8
# DIE GRUENEN_percent_2023                   10.0
# DIE LINKE_percent_2023                     10.2
# FDP_percent_2023                            5.9
# SPD_percent_2023                           21.1
# WUERDE NICHT WAEHLEN_percent_2023           5.2
# Share                                       7.1
# Name: 19, dtype: object
# Alter                                       NaN
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                    West
# AM DRITTWICHTIGSTEN_percent_2021           26.2
# AM VIERTWICHTIGSTEN_percent_2021           57.3
# AM WICHTIGSTEN_percent_2021                 3.9
# AM ZWEITWICHTIGSTEN_percent_2021           12.6
# AM DRITTWICHTIGSTEN_percent_2023           27.0
# AM VIERTWICHTIGSTEN_percent_2023           38.4
# AM WICHTIGSTEN_percent_2023                11.6
# AM ZWEITWICHTIGSTEN_percent_2023           23.0
# AFD_percent_2021                            4.2
# ANDERE PARTEI_percent_2021                  3.2
# CDU-CSU_percent_2021                       27.1
# DIE GRUENEN_percent_2021                   27.6
# DIE LINKE_percent_2021                      4.3
# FDP_percent_2021                           14.1
# SPD_percent_2021                           16.1
# WUERDE NICHT WAEHLEN_percent_2021           3.5
# AFD_percent_2023                            8.5
# ANDERE PARTEI_percent_2023                  3.8
# CDU-CSU_percent_2023                       26.1
# DIE GRUENEN_percent_2023                   21.8
# DIE LINKE_percent_2023                      3.3
# FDP_percent_2023                           11.6
# SPD_percent_2023                           20.0
# WUERDE NICHT WAEHLEN_percent_2023           4.8
# Share                                      37.0
# Name: 20, dtype: object
# Alter                                       NaN
# Besiedelung                          Kleinstadt
# Geschlecht                            Maennlich
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           25.5
# AM VIERTWICHTIGSTEN_percent_2021           58.1
# AM WICHTIGSTEN_percent_2021                 4.1
# AM ZWEITWICHTIGSTEN_percent_2021           12.4
# AM DRITTWICHTIGSTEN_percent_2023           27.6
# AM VIERTWICHTIGSTEN_percent_2023           41.5
# AM WICHTIGSTEN_percent_2023                 9.7
# AM ZWEITWICHTIGSTEN_percent_2023           21.2
# AFD_percent_2021                            8.4
# ANDERE PARTEI_percent_2021                  3.6
# CDU-CSU_percent_2021                       26.0
# DIE GRUENEN_percent_2021                   21.5
# DIE LINKE_percent_2021                      6.2
# FDP_percent_2021                           15.3
# SPD_percent_2021                           16.0
# WUERDE NICHT WAEHLEN_percent_2021           2.9
# AFD_percent_2023                           12.9
# ANDERE PARTEI_percent_2023                  4.6
# CDU-CSU_percent_2023                       24.3
# DIE GRUENEN_percent_2023                   17.0
# DIE LINKE_percent_2023                      3.9
# FDP_percent_2023                           12.8
# SPD_percent_2023                           19.3
# WUERDE NICHT WAEHLEN_percent_2023           5.2
# Share                                      21.2
# Name: 21, dtype: object
# Alter                                       NaN
# Besiedelung                          Kleinstadt
# Geschlecht                             Weiblich
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           26.7
# AM VIERTWICHTIGSTEN_percent_2021           54.9
# AM WICHTIGSTEN_percent_2021                 4.2
# AM ZWEITWICHTIGSTEN_percent_2021           14.2
# AM DRITTWICHTIGSTEN_percent_2023           26.3
# AM VIERTWICHTIGSTEN_percent_2023           36.0
# AM WICHTIGSTEN_percent_2023                13.5
# AM ZWEITWICHTIGSTEN_percent_2023           24.2
# AFD_percent_2021                            2.5
# ANDERE PARTEI_percent_2021                  4.1
# CDU-CSU_percent_2021                       27.3
# DIE GRUENEN_percent_2021                   29.3
# DIE LINKE_percent_2021                      5.3
# FDP_percent_2021                           11.9
# SPD_percent_2021                           14.9
# WUERDE NICHT WAEHLEN_percent_2021           4.7
# AFD_percent_2023                            7.7
# ANDERE PARTEI_percent_2023                  3.4
# CDU-CSU_percent_2023                       26.9
# DIE GRUENEN_percent_2023                   22.9
# DIE LINKE_percent_2023                      5.0
# FDP_percent_2023                            8.5
# SPD_percent_2023                           21.1
# WUERDE NICHT WAEHLEN_percent_2023           4.5
# Share                                      22.9
# Name: 22, dtype: object
# Alter                                30-49
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      29.9
# AM VIERTWICHTIGSTEN_percent_2021      46.5
# AM WICHTIGSTEN_percent_2021            8.6
# AM ZWEITWICHTIGSTEN_percent_2021      15.0
# AM DRITTWICHTIGSTEN_percent_2023      26.0
# AM VIERTWICHTIGSTEN_percent_2023      33.6
# AM WICHTIGSTEN_percent_2023           15.5
# AM ZWEITWICHTIGSTEN_percent_2023      24.9
# AFD_percent_2021                       6.1
# ANDERE PARTEI_percent_2021             5.1
# CDU-CSU_percent_2021                  21.4
# DIE GRUENEN_percent_2021              33.3
# DIE LINKE_percent_2021                 6.4
# FDP_percent_2021                      13.1
# SPD_percent_2021                      10.0
# WUERDE NICHT WAEHLEN_percent_2021      4.6
# AFD_percent_2023                      12.2
# ANDERE PARTEI_percent_2023             3.5
# CDU-CSU_percent_2023                  19.2
# DIE GRUENEN_percent_2023              24.1
# DIE LINKE_percent_2023                 6.2
# FDP_percent_2023                      10.2
# SPD_percent_2023                      17.8
# WUERDE NICHT WAEHLEN_percent_2023      6.9
# Share                                 27.8
# Name: 23, dtype: object
# Alter                                30-49
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                                Ost
# AM DRITTWICHTIGSTEN_percent_2021      30.8
# AM VIERTWICHTIGSTEN_percent_2021      45.4
# AM WICHTIGSTEN_percent_2021            9.8
# AM ZWEITWICHTIGSTEN_percent_2021      14.0
# AM DRITTWICHTIGSTEN_percent_2023      19.6
# AM VIERTWICHTIGSTEN_percent_2023      36.1
# AM WICHTIGSTEN_percent_2023           18.0
# AM ZWEITWICHTIGSTEN_percent_2023      26.3
# AFD_percent_2021                      11.8
# ANDERE PARTEI_percent_2021             8.7
# CDU-CSU_percent_2021                  17.6
# DIE GRUENEN_percent_2021              21.3
# DIE LINKE_percent_2021                10.1
# FDP_percent_2021                      16.0
# SPD_percent_2021                       8.1
# WUERDE NICHT WAEHLEN_percent_2021      6.4
# AFD_percent_2023                      25.9
# ANDERE PARTEI_percent_2023             5.1
# CDU-CSU_percent_2023                  14.6
# DIE GRUENEN_percent_2023              16.6
# DIE LINKE_percent_2023                11.0
# FDP_percent_2023                       8.5
# SPD_percent_2023                      10.4
# WUERDE NICHT WAEHLEN_percent_2023      7.9
# Share                                  4.6
# Name: 24, dtype: object
# Alter                                30-49
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                               West
# AM DRITTWICHTIGSTEN_percent_2021      30.4
# AM VIERTWICHTIGSTEN_percent_2021      46.4
# AM WICHTIGSTEN_percent_2021            8.1
# AM ZWEITWICHTIGSTEN_percent_2021      15.1
# AM DRITTWICHTIGSTEN_percent_2023      27.4
# AM VIERTWICHTIGSTEN_percent_2023      33.1
# AM WICHTIGSTEN_percent_2023           14.6
# AM ZWEITWICHTIGSTEN_percent_2023      24.9
# AFD_percent_2021                       5.1
# ANDERE PARTEI_percent_2021             4.1
# CDU-CSU_percent_2021                  23.0
# DIE GRUENEN_percent_2021              35.1
# DIE LINKE_percent_2021                 5.5
# FDP_percent_2021                      12.6
# SPD_percent_2021                      10.4
# WUERDE NICHT WAEHLEN_percent_2021      4.2
# AFD_percent_2023                       9.4
# ANDERE PARTEI_percent_2023             3.3
# CDU-CSU_percent_2023                  21.0
# DIE GRUENEN_percent_2023              24.9
# DIE LINKE_percent_2023                 4.3
# FDP_percent_2023                      11.0
# SPD_percent_2023                      19.5
# WUERDE NICHT WAEHLEN_percent_2023      6.7
# Share                                 21.9
# Name: 25, dtype: object
# Alter                                    30-49
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          29.2
# AM VIERTWICHTIGSTEN_percent_2021          46.2
# AM WICHTIGSTEN_percent_2021                8.9
# AM ZWEITWICHTIGSTEN_percent_2021          15.7
# AM DRITTWICHTIGSTEN_percent_2023          26.9
# AM VIERTWICHTIGSTEN_percent_2023          39.2
# AM WICHTIGSTEN_percent_2023               12.8
# AM ZWEITWICHTIGSTEN_percent_2023          21.2
# AFD_percent_2021                           9.0
# ANDERE PARTEI_percent_2021                 4.6
# CDU-CSU_percent_2021                      20.8
# DIE GRUENEN_percent_2021                  31.4
# DIE LINKE_percent_2021                     8.1
# FDP_percent_2021                          12.9
# SPD_percent_2021                           9.3
# WUERDE NICHT WAEHLEN_percent_2021          3.9
# AFD_percent_2023                          14.6
# ANDERE PARTEI_percent_2023                 4.3
# CDU-CSU_percent_2023                      19.9
# DIE GRUENEN_percent_2023                  17.7
# DIE LINKE_percent_2023                     5.5
# FDP_percent_2023                          11.1
# SPD_percent_2023                          19.0
# WUERDE NICHT WAEHLEN_percent_2023          7.9
# Share                                     14.0
# Name: 26, dtype: object
# Alter                                   30-49
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         30.6
# AM VIERTWICHTIGSTEN_percent_2021         46.9
# AM WICHTIGSTEN_percent_2021               8.2
# AM ZWEITWICHTIGSTEN_percent_2021         14.3
# AM DRITTWICHTIGSTEN_percent_2023         25.1
# AM VIERTWICHTIGSTEN_percent_2023         28.0
# AM WICHTIGSTEN_percent_2023              18.3
# AM ZWEITWICHTIGSTEN_percent_2023         28.7
# AFD_percent_2021                          3.2
# ANDERE PARTEI_percent_2021                5.6
# CDU-CSU_percent_2021                     21.9
# DIE GRUENEN_percent_2021                 35.2
# DIE LINKE_percent_2021                    4.7
# FDP_percent_2021                         13.2
# SPD_percent_2021                         10.8
# WUERDE NICHT WAEHLEN_percent_2021         5.3
# AFD_percent_2023                          9.5
# ANDERE PARTEI_percent_2023                2.5
# CDU-CSU_percent_2023                     18.3
# DIE GRUENEN_percent_2023                 31.4
# DIE LINKE_percent_2023                    7.0
# FDP_percent_2023                          9.2
# SPD_percent_2023                         16.3
# WUERDE NICHT WAEHLEN_percent_2023         5.8
# Share                                    13.8
# Name: 27, dtype: object
# Alter                                30-49
# Besiedelung                          Stadt
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      33.4
# AM VIERTWICHTIGSTEN_percent_2021      45.0
# AM WICHTIGSTEN_percent_2021            7.7
# AM ZWEITWICHTIGSTEN_percent_2021      13.9
# AM DRITTWICHTIGSTEN_percent_2023      29.4
# AM VIERTWICHTIGSTEN_percent_2023      35.2
# AM WICHTIGSTEN_percent_2023           13.6
# AM ZWEITWICHTIGSTEN_percent_2023      21.9
# AFD_percent_2021                       3.5
# ANDERE PARTEI_percent_2021             4.5
# CDU-CSU_percent_2021                  13.1
# DIE GRUENEN_percent_2021              49.4
# DIE LINKE_percent_2021                10.1
# FDP_percent_2021                       9.2
# SPD_percent_2021                       6.8
# WUERDE NICHT WAEHLEN_percent_2021      3.3
# AFD_percent_2023                       6.2
# ANDERE PARTEI_percent_2023             4.3
# CDU-CSU_percent_2023                  12.3
# DIE GRUENEN_percent_2023              34.2
# DIE LINKE_percent_2023                 8.2
# FDP_percent_2023                       7.6
# SPD_percent_2023                      23.6
# WUERDE NICHT WAEHLEN_percent_2023      3.6
# Share                                 10.3
# Name: 28, dtype: object
# Alter                                30-49
# Besiedelung                           Dorf
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      27.7
# AM VIERTWICHTIGSTEN_percent_2021      41.9
# AM WICHTIGSTEN_percent_2021           11.7
# AM ZWEITWICHTIGSTEN_percent_2021      18.8
# AM DRITTWICHTIGSTEN_percent_2023      26.2
# AM VIERTWICHTIGSTEN_percent_2023      27.8
# AM WICHTIGSTEN_percent_2023           14.3
# AM ZWEITWICHTIGSTEN_percent_2023      31.7
# AFD_percent_2021                       8.6
# ANDERE PARTEI_percent_2021             5.5
# CDU-CSU_percent_2021                  31.3
# DIE GRUENEN_percent_2021              17.2
# DIE LINKE_percent_2021                 4.0
# FDP_percent_2021                      15.9
# SPD_percent_2021                      12.1
# WUERDE NICHT WAEHLEN_percent_2021      5.5
# AFD_percent_2023                      21.3
# ANDERE PARTEI_percent_2023             1.6
# CDU-CSU_percent_2023                  28.0
# DIE GRUENEN_percent_2023              14.6
# DIE LINKE_percent_2023                 5.6
# FDP_percent_2023                       9.5
# SPD_percent_2023                       9.3
# WUERDE NICHT WAEHLEN_percent_2023     10.2
# Share                                  5.7
# Name: 29, dtype: object
# Alter                                     30-49
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           27.9
# AM VIERTWICHTIGSTEN_percent_2021           50.5
# AM WICHTIGSTEN_percent_2021                 7.7
# AM ZWEITWICHTIGSTEN_percent_2021           14.0
# AM DRITTWICHTIGSTEN_percent_2023           22.9
# AM VIERTWICHTIGSTEN_percent_2023           35.1
# AM WICHTIGSTEN_percent_2023                17.7
# AM ZWEITWICHTIGSTEN_percent_2023           24.3
# AFD_percent_2021                            7.5
# ANDERE PARTEI_percent_2021                  5.5
# CDU-CSU_percent_2021                       24.2
# DIE GRUENEN_percent_2021                   26.0
# DIE LINKE_percent_2021                      4.1
# FDP_percent_2021                           15.4
# SPD_percent_2021                           12.1
# WUERDE NICHT WAEHLEN_percent_2021           5.4
# AFD_percent_2023                           13.5
# ANDERE PARTEI_percent_2023                  3.5
# CDU-CSU_percent_2023                       21.5
# DIE GRUENEN_percent_2023                   19.2
# DIE LINKE_percent_2023                      4.7
# FDP_percent_2023                           12.9
# SPD_percent_2023                           16.3
# WUERDE NICHT WAEHLEN_percent_2023           8.4
# Share                                      11.8
# Name: 30, dtype: object
# Alter                                50-64
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      22.7
# AM VIERTWICHTIGSTEN_percent_2021      62.7
# AM WICHTIGSTEN_percent_2021            3.5
# AM ZWEITWICHTIGSTEN_percent_2021      11.2
# AM DRITTWICHTIGSTEN_percent_2023      28.0
# AM VIERTWICHTIGSTEN_percent_2023      43.9
# AM WICHTIGSTEN_percent_2023            9.2
# AM ZWEITWICHTIGSTEN_percent_2023      18.9
# AFD_percent_2021                       6.0
# ANDERE PARTEI_percent_2021             3.6
# CDU-CSU_percent_2021                  27.4
# DIE GRUENEN_percent_2021              27.9
# DIE LINKE_percent_2021                 6.0
# FDP_percent_2021                       9.5
# SPD_percent_2021                      15.2
# WUERDE NICHT WAEHLEN_percent_2021      4.4
# AFD_percent_2023                      12.8
# ANDERE PARTEI_percent_2023             5.3
# CDU-CSU_percent_2023                  23.8
# DIE GRUENEN_percent_2023              21.2
# DIE LINKE_percent_2023                 5.3
# FDP_percent_2023                       8.2
# SPD_percent_2023                      17.7
# WUERDE NICHT WAEHLEN_percent_2023      5.8
# Share                                 28.7
# Name: 31, dtype: object
# Alter                                50-64
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                                Ost
# AM DRITTWICHTIGSTEN_percent_2021      23.5
# AM VIERTWICHTIGSTEN_percent_2021      59.0
# AM WICHTIGSTEN_percent_2021            2.4
# AM ZWEITWICHTIGSTEN_percent_2021      15.0
# AM DRITTWICHTIGSTEN_percent_2023      23.0
# AM VIERTWICHTIGSTEN_percent_2023      48.3
# AM WICHTIGSTEN_percent_2023            6.7
# AM ZWEITWICHTIGSTEN_percent_2023      22.1
# AFD_percent_2021                      14.6
# ANDERE PARTEI_percent_2021             5.2
# CDU-CSU_percent_2021                  24.5
# DIE GRUENEN_percent_2021              13.5
# DIE LINKE_percent_2021                11.0
# FDP_percent_2021                      10.2
# SPD_percent_2021                      11.8
# WUERDE NICHT WAEHLEN_percent_2021      9.1
# AFD_percent_2023                      29.4
# ANDERE PARTEI_percent_2023             3.8
# CDU-CSU_percent_2023                  19.7
# DIE GRUENEN_percent_2023              10.8
# DIE LINKE_percent_2023                 8.6
# FDP_percent_2023                       7.0
# SPD_percent_2023                      14.6
# WUERDE NICHT WAEHLEN_percent_2023      6.2
# Share                                  4.8
# Name: 32, dtype: object
# Alter                                50-64
# Besiedelung                            NaN
# Geschlecht                             NaN
# OstWest                               West
# AM DRITTWICHTIGSTEN_percent_2021      21.6
# AM VIERTWICHTIGSTEN_percent_2021      64.4
# AM WICHTIGSTEN_percent_2021            3.7
# AM ZWEITWICHTIGSTEN_percent_2021      10.3
# AM DRITTWICHTIGSTEN_percent_2023      28.5
# AM VIERTWICHTIGSTEN_percent_2023      43.3
# AM WICHTIGSTEN_percent_2023           10.0
# AM ZWEITWICHTIGSTEN_percent_2023      18.3
# AFD_percent_2021                       4.2
# ANDERE PARTEI_percent_2021             3.4
# CDU-CSU_percent_2021                  27.8
# DIE GRUENEN_percent_2021              31.3
# DIE LINKE_percent_2021                 4.8
# FDP_percent_2021                       9.8
# SPD_percent_2021                      15.4
# WUERDE NICHT WAEHLEN_percent_2021      3.4
# AFD_percent_2023                       9.8
# ANDERE PARTEI_percent_2023             5.9
# CDU-CSU_percent_2023                  24.4
# DIE GRUENEN_percent_2023              23.4
# DIE LINKE_percent_2023                 4.3
# FDP_percent_2023                       8.4
# SPD_percent_2023                      18.7
# WUERDE NICHT WAEHLEN_percent_2023      5.3
# Share                                 22.9
# Name: 33, dtype: object
# Alter                                    50-64
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          22.1
# AM VIERTWICHTIGSTEN_percent_2021          65.1
# AM WICHTIGSTEN_percent_2021                3.5
# AM ZWEITWICHTIGSTEN_percent_2021           9.3
# AM DRITTWICHTIGSTEN_percent_2023          31.1
# AM VIERTWICHTIGSTEN_percent_2023          44.7
# AM WICHTIGSTEN_percent_2023                7.7
# AM ZWEITWICHTIGSTEN_percent_2023          16.5
# AFD_percent_2021                           6.6
# ANDERE PARTEI_percent_2021                 3.4
# CDU-CSU_percent_2021                      29.5
# DIE GRUENEN_percent_2021                  22.4
# DIE LINKE_percent_2021                     7.1
# FDP_percent_2021                          10.7
# SPD_percent_2021                          16.4
# WUERDE NICHT WAEHLEN_percent_2021          4.0
# AFD_percent_2023                          17.5
# ANDERE PARTEI_percent_2023                 6.0
# CDU-CSU_percent_2023                      20.8
# DIE GRUENEN_percent_2023                  20.5
# DIE LINKE_percent_2023                     5.1
# FDP_percent_2023                          10.0
# SPD_percent_2023                          15.1
# WUERDE NICHT WAEHLEN_percent_2023          5.0
# Share                                     14.2
# Name: 34, dtype: object
# Alter                                   50-64
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         23.3
# AM VIERTWICHTIGSTEN_percent_2021         60.0
# AM WICHTIGSTEN_percent_2021               3.4
# AM ZWEITWICHTIGSTEN_percent_2021         13.3
# AM DRITTWICHTIGSTEN_percent_2023         25.0
# AM VIERTWICHTIGSTEN_percent_2023         43.1
# AM WICHTIGSTEN_percent_2023              10.7
# AM ZWEITWICHTIGSTEN_percent_2023         21.2
# AFD_percent_2021                          5.3
# ANDERE PARTEI_percent_2021                3.8
# CDU-CSU_percent_2021                     25.0
# DIE GRUENEN_percent_2021                 34.1
# DIE LINKE_percent_2021                    4.7
# FDP_percent_2021                          8.3
# SPD_percent_2021                         13.9
# WUERDE NICHT WAEHLEN_percent_2021         4.8
# AFD_percent_2023                          7.8
# ANDERE PARTEI_percent_2023                4.5
# CDU-CSU_percent_2023                     27.0
# DIE GRUENEN_percent_2023                 22.0
# DIE LINKE_percent_2023                    5.5
# FDP_percent_2023                          6.2
# SPD_percent_2023                         20.5
# WUERDE NICHT WAEHLEN_percent_2023         6.6
# Share                                    14.4
# Name: 35, dtype: object
# Alter                                50-64
# Besiedelung                          Stadt
# ...
# ANDERE PARTEI_percent_2023                2.9
# CDU-CSU_percent_2023                     13.5
# DIE GRUENEN_percent_2023                 37.8
# DIE LINKE_percent_2023                   10.9
# FDP_percent_2023                          7.1
# SPD_percent_2023                         19.5
# WUERDE NICHT WAEHLEN_percent_2023         2.6
# Share                                     7.0
# Name: 43, dtype: object
# Alter                                  U30
# Besiedelung                          Stadt
# Geschlecht                             NaN
# OstWest                                NaN
# AM DRITTWICHTIGSTEN_percent_2021      24.6
# AM VIERTWICHTIGSTEN_percent_2021      54.8
# AM WICHTIGSTEN_percent_2021            5.1
# AM ZWEITWICHTIGSTEN_percent_2021      15.5
# AM DRITTWICHTIGSTEN_percent_2023      29.3
# AM VIERTWICHTIGSTEN_percent_2023      28.6
# AM WICHTIGSTEN_percent_2023           23.2
# AM ZWEITWICHTIGSTEN_percent_2023      18.9
# AFD_percent_2021                       2.3
# ANDERE PARTEI_percent_2021             3.7
# CDU-CSU_percent_2021                  10.2
# DIE GRUENEN_percent_2021              50.4
# DIE LINKE_percent_2021                12.7
# FDP_percent_2021                       8.7
# SPD_percent_2021                       7.9
# WUERDE NICHT WAEHLEN_percent_2021      4.2
# AFD_percent_2023                       4.3
# ANDERE PARTEI_percent_2023             2.9
# CDU-CSU_percent_2023                   9.4
# DIE GRUENEN_percent_2023              37.5
# DIE LINKE_percent_2023                13.7
# FDP_percent_2023                       8.0
# SPD_percent_2023                      19.7
# WUERDE NICHT WAEHLEN_percent_2023      4.5
# Share                                  6.0
# Name: 44, dtype: object
# Alter                                 U30
# Besiedelung                          Dorf
# Geschlecht                            NaN
# OstWest                               NaN
# AM DRITTWICHTIGSTEN_percent_2021     29.3
# AM VIERTWICHTIGSTEN_percent_2021     42.0
# AM WICHTIGSTEN_percent_2021          10.7
# AM ZWEITWICHTIGSTEN_percent_2021     18.0
# AM DRITTWICHTIGSTEN_percent_2023     29.0
# AM VIERTWICHTIGSTEN_percent_2023     25.4
# AM WICHTIGSTEN_percent_2023          23.4
# AM ZWEITWICHTIGSTEN_percent_2023     22.2
# AFD_percent_2021                     18.0
# ANDERE PARTEI_percent_2021           12.4
# CDU-CSU_percent_2021                 14.4
# DIE GRUENEN_percent_2021             13.9
# DIE LINKE_percent_2021                4.6
# FDP_percent_2021                     16.0
# SPD_percent_2021                     10.3
# WUERDE NICHT WAEHLEN_percent_2021    10.3
# AFD_percent_2023                     12.9
# ANDERE PARTEI_percent_2023            1.6
# CDU-CSU_percent_2023                 19.9
# DIE GRUENEN_percent_2023             28.0
# DIE LINKE_percent_2023                5.4
# FDP_percent_2023                     11.8
# SPD_percent_2023                     17.7
# WUERDE NICHT WAEHLEN_percent_2023     2.7
# Share                                 2.5
# Name: 45, dtype: object
# Alter                                       U30
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           35.0
# AM VIERTWICHTIGSTEN_percent_2021           43.4
# AM WICHTIGSTEN_percent_2021                 6.4
# AM ZWEITWICHTIGSTEN_percent_2021           15.2
# AM DRITTWICHTIGSTEN_percent_2023           30.2
# AM VIERTWICHTIGSTEN_percent_2023           23.5
# AM WICHTIGSTEN_percent_2023                18.9
# AM ZWEITWICHTIGSTEN_percent_2023           27.4
# AFD_percent_2021                            5.9
# ANDERE PARTEI_percent_2021                  7.1
# CDU-CSU_percent_2021                       13.0
# DIE GRUENEN_percent_2021                   30.3
# DIE LINKE_percent_2021                     10.0
# FDP_percent_2021                           16.6
# SPD_percent_2021                           12.3
# WUERDE NICHT WAEHLEN_percent_2021           4.8
# AFD_percent_2023                           10.2
# ANDERE PARTEI_percent_2023                  5.5
# CDU-CSU_percent_2023                       14.6
# DIE GRUENEN_percent_2023                   27.8
# DIE LINKE_percent_2023                      6.4
# FDP_percent_2023                           17.2
# SPD_percent_2023                           15.5
# WUERDE NICHT WAEHLEN_percent_2023           3.0
# Share                                       5.8
# Name: 46, dtype: object
# Alter                                65plus
# Besiedelung                             NaN
# Geschlecht                              NaN
# OstWest                                 NaN
# AM DRITTWICHTIGSTEN_percent_2021       24.3
# AM VIERTWICHTIGSTEN_percent_2021       57.8
# AM WICHTIGSTEN_percent_2021             2.5
# AM ZWEITWICHTIGSTEN_percent_2021       15.4
# AM DRITTWICHTIGSTEN_percent_2023       26.6
# AM VIERTWICHTIGSTEN_percent_2023       48.2
# AM WICHTIGSTEN_percent_2023             5.5
# AM ZWEITWICHTIGSTEN_percent_2023       19.7
# AFD_percent_2021                        3.9
# ANDERE PARTEI_percent_2021              1.4
# CDU-CSU_percent_2021                   33.7
# DIE GRUENEN_percent_2021               16.4
# DIE LINKE_percent_2021                  6.3
# FDP_percent_2021                       11.9
# SPD_percent_2021                       22.0
# WUERDE NICHT WAEHLEN_percent_2021       4.4
# AFD_percent_2023                        5.9
# ANDERE PARTEI_percent_2023              1.3
# CDU-CSU_percent_2023                   33.3
# DIE GRUENEN_percent_2023               15.3
# DIE LINKE_percent_2023                  3.9
# FDP_percent_2023                        7.6
# SPD_percent_2023                       29.1
# WUERDE NICHT WAEHLEN_percent_2023       3.6
# Share                                  29.1
# Name: 47, dtype: object
# Alter                                65plus
# Besiedelung                             NaN
# Geschlecht                              NaN
# OstWest                                 Ost
# AM DRITTWICHTIGSTEN_percent_2021       30.3
# AM VIERTWICHTIGSTEN_percent_2021       51.2
# AM WICHTIGSTEN_percent_2021             2.6
# AM ZWEITWICHTIGSTEN_percent_2021       15.9
# AM DRITTWICHTIGSTEN_percent_2023       26.4
# AM VIERTWICHTIGSTEN_percent_2023       44.9
# AM WICHTIGSTEN_percent_2023             8.7
# AM ZWEITWICHTIGSTEN_percent_2023       20.0
# AFD_percent_2021                       10.0
# ANDERE PARTEI_percent_2021              2.2
# CDU-CSU_percent_2021                   30.2
# DIE GRUENEN_percent_2021                7.8
# DIE LINKE_percent_2021                 17.3
# FDP_percent_2021                        8.0
# SPD_percent_2021                       18.2
# WUERDE NICHT WAEHLEN_percent_2021       6.2
# AFD_percent_2023                       16.3
# ANDERE PARTEI_percent_2023              1.8
# CDU-CSU_percent_2023                   26.8
# DIE GRUENEN_percent_2023                5.0
# DIE LINKE_percent_2023                 11.5
# FDP_percent_2023                        3.7
# SPD_percent_2023                       31.0
# WUERDE NICHT WAEHLEN_percent_2023       3.9
# Share                                   5.5
# Name: 48, dtype: object
# Alter                                65plus
# Besiedelung                             NaN
# Geschlecht                              NaN
# OstWest                                West
# AM DRITTWICHTIGSTEN_percent_2021       23.0
# AM VIERTWICHTIGSTEN_percent_2021       59.5
# AM WICHTIGSTEN_percent_2021             2.6
# AM ZWEITWICHTIGSTEN_percent_2021       14.9
# AM DRITTWICHTIGSTEN_percent_2023       26.5
# AM VIERTWICHTIGSTEN_percent_2023       49.7
# AM WICHTIGSTEN_percent_2023             4.8
# AM ZWEITWICHTIGSTEN_percent_2023       19.1
# AFD_percent_2021                        2.5
# ANDERE PARTEI_percent_2021              1.3
# CDU-CSU_percent_2021                   34.5
# DIE GRUENEN_percent_2021               18.9
# DIE LINKE_percent_2021                  3.2
# FDP_percent_2021                       13.2
# SPD_percent_2021                       22.8
# WUERDE NICHT WAEHLEN_percent_2021       3.6
# AFD_percent_2023                        3.8
# ANDERE PARTEI_percent_2023              1.0
# CDU-CSU_percent_2023                   35.5
# DIE GRUENEN_percent_2023               17.7
# DIE LINKE_percent_2023                  1.3
# FDP_percent_2023                        8.5
# SPD_percent_2023                       28.8
# WUERDE NICHT WAEHLEN_percent_2023       3.5
# Share                                  22.5
# Name: 49, dtype: object
# Alter                                   65plus
# Besiedelung                                NaN
# Geschlecht                           Maennlich
# OstWest                                    NaN
# AM DRITTWICHTIGSTEN_percent_2021          21.6
# AM VIERTWICHTIGSTEN_percent_2021          60.3
# AM WICHTIGSTEN_percent_2021                3.8
# AM ZWEITWICHTIGSTEN_percent_2021          14.3
# AM DRITTWICHTIGSTEN_percent_2023          28.3
# AM VIERTWICHTIGSTEN_percent_2023          48.4
# AM WICHTIGSTEN_percent_2023                4.8
# AM ZWEITWICHTIGSTEN_percent_2023          18.5
# AFD_percent_2021                           6.2
# ANDERE PARTEI_percent_2021                 0.7
# CDU-CSU_percent_2021                      30.8
# DIE GRUENEN_percent_2021                  15.0
# DIE LINKE_percent_2021                     5.9
# FDP_percent_2021                          13.7
# SPD_percent_2021                          24.8
# WUERDE NICHT WAEHLEN_percent_2021          2.9
# AFD_percent_2023                           7.7
# ANDERE PARTEI_percent_2023                 0.7
# CDU-CSU_percent_2023                      33.8
# DIE GRUENEN_percent_2023                  13.5
# DIE LINKE_percent_2023                     4.7
# FDP_percent_2023                           8.1
# SPD_percent_2023                          28.2
# WUERDE NICHT WAEHLEN_percent_2023          3.2
# Share                                     12.7
# Name: 50, dtype: object
# Alter                                  65plus
# Besiedelung                               NaN
# Geschlecht                           Weiblich
# OstWest                                   NaN
# AM DRITTWICHTIGSTEN_percent_2021         26.6
# AM VIERTWICHTIGSTEN_percent_2021         55.7
# AM WICHTIGSTEN_percent_2021               1.4
# AM ZWEITWICHTIGSTEN_percent_2021         16.3
# AM DRITTWICHTIGSTEN_percent_2023         25.4
# AM VIERTWICHTIGSTEN_percent_2023         48.0
# AM WICHTIGSTEN_percent_2023               6.0
# AM ZWEITWICHTIGSTEN_percent_2023         20.6
# AFD_percent_2021                          1.9
# ANDERE PARTEI_percent_2021                2.0
# CDU-CSU_percent_2021                     36.2
# DIE GRUENEN_percent_2021                 17.6
# DIE LINKE_percent_2021                    6.6
# FDP_percent_2021                         10.5
# SPD_percent_2021                         19.6
# WUERDE NICHT WAEHLEN_percent_2021         5.6
# AFD_percent_2023                          4.4
# ANDERE PARTEI_percent_2023                1.8
# CDU-CSU_percent_2023                     32.8
# DIE GRUENEN_percent_2023                 16.8
# DIE LINKE_percent_2023                    3.2
# FDP_percent_2023                          7.2
# SPD_percent_2023                         29.8
# WUERDE NICHT WAEHLEN_percent_2023         4.0
# Share                                    16.4
# Name: 51, dtype: object
# Alter                                65plus
# Besiedelung                           Stadt
# Geschlecht                              NaN
# OstWest                                 NaN
# AM DRITTWICHTIGSTEN_percent_2021       26.3
# AM VIERTWICHTIGSTEN_percent_2021       51.2
# AM WICHTIGSTEN_percent_2021             5.1
# AM ZWEITWICHTIGSTEN_percent_2021       17.5
# AM DRITTWICHTIGSTEN_percent_2023       28.6
# AM VIERTWICHTIGSTEN_percent_2023       53.4
# AM WICHTIGSTEN_percent_2023             2.5
# AM ZWEITWICHTIGSTEN_percent_2023       15.5
# AFD_percent_2021                        3.8
# ANDERE PARTEI_percent_2021              1.2
# CDU-CSU_percent_2021                   30.4
# DIE GRUENEN_percent_2021               17.5
# DIE LINKE_percent_2021                  4.9
# FDP_percent_2021                        8.9
# SPD_percent_2021                       27.6
# WUERDE NICHT WAEHLEN_percent_2021       5.7
# AFD_percent_2023                        3.9
# ANDERE PARTEI_percent_2023              0.7
# CDU-CSU_percent_2023                   28.1
# DIE GRUENEN_percent_2023               12.4
# DIE LINKE_percent_2023                  4.5
# FDP_percent_2023                       10.3
# SPD_percent_2023                       35.8
# WUERDE NICHT WAEHLEN_percent_2023       4.2
# Share                                   9.5
# Name: 52, dtype: object
# Alter                                65plus
# Besiedelung                            Dorf
# Geschlecht                              NaN
# OstWest                                 NaN
# AM DRITTWICHTIGSTEN_percent_2021       22.7
# AM VIERTWICHTIGSTEN_percent_2021       61.0
# AM WICHTIGSTEN_percent_2021             0.3
# AM ZWEITWICHTIGSTEN_percent_2021       16.0
# AM DRITTWICHTIGSTEN_percent_2023       22.2
# AM VIERTWICHTIGSTEN_percent_2023       47.6
# AM WICHTIGSTEN_percent_2023             9.0
# AM ZWEITWICHTIGSTEN_percent_2023       21.2
# AFD_percent_2021                        5.0
# ANDERE PARTEI_percent_2021              2.0
# CDU-CSU_percent_2021                   35.5
# DIE GRUENEN_percent_2021               13.7
# DIE LINKE_percent_2021                  8.3
# FDP_percent_2021                       11.7
# SPD_percent_2021                       19.4
# WUERDE NICHT WAEHLEN_percent_2021       4.4
# AFD_percent_2023                        9.3
# ANDERE PARTEI_percent_2023              2.6
# CDU-CSU_percent_2023                   38.8
# DIE GRUENEN_percent_2023               13.1
# DIE LINKE_percent_2023                  4.8
# FDP_percent_2023                        4.4
# SPD_percent_2023                       23.5
# WUERDE NICHT WAEHLEN_percent_2023       3.4
# Share                                   6.2
# Name: 53, dtype: object
# Alter                                    65plus
# Besiedelung                          Kleinstadt
# Geschlecht                                  NaN
# OstWest                                     NaN
# AM DRITTWICHTIGSTEN_percent_2021           23.5
# AM VIERTWICHTIGSTEN_percent_2021           61.3
# AM WICHTIGSTEN_percent_2021                 1.6
# AM ZWEITWICHTIGSTEN_percent_2021           13.6
# AM DRITTWICHTIGSTEN_percent_2023           27.3
# AM VIERTWICHTIGSTEN_percent_2023           44.8
# AM WICHTIGSTEN_percent_2023                 6.0
# AM ZWEITWICHTIGSTEN_percent_2023           21.9
# AFD_percent_2021                            3.4
# ANDERE PARTEI_percent_2021                  1.3
# CDU-CSU_percent_2021                       35.1
# DIE GRUENEN_percent_2021                   16.8
# DIE LINKE_percent_2021                      6.3
# FDP_percent_2021                           14.1
# SPD_percent_2021                           19.5
# WUERDE NICHT WAEHLEN_percent_2021           3.4
# AFD_percent_2023                            6.0
# ANDERE PARTEI_percent_2023                  1.1
# CDU-CSU_percent_2023                       34.5
# DIE GRUENEN_percent_2023                   18.4
# DIE LINKE_percent_2023                      3.0
# FDP_percent_2023                            7.1
# SPD_percent_2023                           26.6
# WUERDE NICHT WAEHLEN_percent_2023           3.3
# Share                                      13.5
# Name: 54, dtype: object
# {'Alter': nan,
#  'Besiedelung': nan,
#  'Geschlecht': nan,
#  'OstWest': 'Ost',
#  'Share': 16.5,
#  'inflation': {'AM DRITTWICHTIGSTEN_percent_2021': 28.3,
#   'AM VIERTWICHTIGSTEN_percent_2021': 51.1,
#   'AM WICHTIGSTEN_percent_2021': 5.4,
#   'AM ZWEITWICHTIGSTEN_percent_2021': 15.3,
#   'AM DRITTWICHTIGSTEN_percent_2023': 23.6,
#   'AM VIERTWICHTIGSTEN_percent_2023': 40.9,
#   'AM WICHTIGSTEN_percent_2023': 11.8,
#   'AM ZWEITWICHTIGSTEN_percent_2023': 23.8},
#  'wahl': {'AFD_percent_2021': 11.7,
#   'ANDERE PARTEI_percent_2021': 5.6,
#   'CDU-CSU_percent_2021': 23.1,
#   'DIE GRUENEN_percent_2021': 15.0,
#   'DIE LINKE_percent_2021': 12.9,
#   'FDP_percent_2021': 12.2,
#   'SPD_percent_2021': 12.3,
#   'WUERDE NICHT WAEHLEN_percent_2021': 7.1,
#   'AFD_percent_2023': 22.7,
#   'ANDERE PARTEI_percent_2023': 3.8,
#   'CDU-CSU_percent_2023': 20.6,
#   'DIE GRUENEN_percent_2023': 11.3,
#   'DIE LINKE_percent_2023': 10.8,
#   'FDP_percent_2023': 5.9,
#   'SPD_percent_2023': 19.5,
#   'WUERDE NICHT WAEHLEN_percent_2023': 5.4}}

# %%
! pip3 install simplejson
# Out:
# Requirement already satisfied: simplejson in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.19.3)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import simplejson as json
#And then we write out the file as a json file
with open('data_for_viz_2.json', 'w', encoding='utf-8') as file:
    json.dump(json_array, file, ignore_nan=True, indent=2)

# %%
comp_no_berlin_party=comp_party[comp_party["OstWest"]!="Berlin"].sort_values(by=["diff_percent"])
comp_no_berlin_party.head(60)
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 149    U30                         NaN        NaN     Ost
# 195  30-49             dicht besiedelt        NaN     NaN
# 35   30-49                         NaN   Männlich     NaN
# 235  50-64  mittlere Besiedlungsdichte        NaN     NaN
# 243    U30             dicht besiedelt        NaN     NaN
# 355    NaN             dicht besiedelt   Männlich     NaN
# 75   50-64                         NaN   Weiblich     NaN
# 475    NaN             dicht besiedelt        NaN    West
# 249    U30            gering besiedelt        NaN     NaN
# 499    NaN             dicht besiedelt        NaN     NaN
# 163  30-49                         NaN        NaN    West
# 226  50-64            gering besiedelt        NaN     NaN
# 3    30-49                         NaN        NaN     NaN
# 451    NaN             dicht besiedelt        NaN     Ost
# 42   50-64                         NaN   Männlich     NaN
# 147    U30                         NaN        NaN     Ost
# 379    NaN             dicht besiedelt   Weiblich     NaN
# 171  50-64                         NaN        NaN    West
# 317    NaN                         NaN   Männlich     Ost
# 461    NaN            gering besiedelt        NaN     Ost
# 255    U30            gering besiedelt        NaN     NaN
# 133  30-49                         NaN        NaN     Ost
# 277    Ü65            gering besiedelt        NaN     NaN
# 285    Ü65  mittlere Besiedlungsdichte        NaN     NaN
# 365    NaN            gering besiedelt   Männlich     NaN
# 211  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 11   50-64                         NaN        NaN     NaN
# 395    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 205  30-49            gering besiedelt        NaN     NaN
# 323    NaN                         NaN   Männlich    West
# 413    NaN                         NaN        NaN     Ost
# 419    NaN                         NaN        NaN    West
# 453    NaN             dicht besiedelt        NaN     Ost
# 347    NaN                         NaN   Weiblich    West
# 156    Ü65                         NaN        NaN     Ost
# 291    NaN                         NaN   Männlich     NaN
# 491    NaN  mittlere Besiedlungsdichte        NaN    West
# 61     Ü65                         NaN   Männlich     NaN
# 458    NaN            gering besiedelt        NaN     Ost
# 515    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 219  50-64             dicht besiedelt        NaN     NaN
# 299    NaN                         NaN   Weiblich     NaN
# 452    NaN             dicht besiedelt        NaN     Ost
# 248    U30            gering besiedelt        NaN     NaN
# 386    NaN            gering besiedelt   Weiblich     NaN
# 231  50-64            gering besiedelt        NaN     NaN
# 469    NaN  mittlere Besiedlungsdichte        NaN     Ost
# 267    Ü65             dicht besiedelt        NaN     NaN
# 51     U30                         NaN   Männlich     NaN
# 151    U30                         NaN        NaN     Ost
# 83     U30                         NaN   Weiblich     NaN
# 509    NaN            gering besiedelt        NaN     NaN
# 138  50-64                         NaN        NaN     Ost
# 189    Ü65                         NaN        NaN    West
# 131  30-49                         NaN        NaN     Ost
# 19     U30                         NaN        NaN     NaN
# 371    NaN  mittlere Besiedlungsdichte   Männlich     NaN
# 341    NaN                         NaN   Weiblich     Ost
# 87     U30                         NaN   Weiblich     NaN
# 157    Ü65                         NaN        NaN     Ost
#
#                      pv01  absolute_2021  percent_2021  absolute_2023  \
# 149                   FDP             28     22.580645              5
# 195           DIE GRUENEN            428     49.365629            292
# 35            DIE GRUENEN            354     31.355182            209
# 235           DIE GRUENEN            325     32.146390            194
# 243           DIE GRUENEN            262     50.384615            183
# 355           DIE GRUENEN            493     36.437546            337
# 75            DIE GRUENEN            346     34.088670            237
# 475           DIE GRUENEN            860     39.907193            619
# 249         ANDERE PARTEI             24     12.371134              3
# 499           DIE GRUENEN           1024     37.101449            760
# 163           DIE GRUENEN            622     35.121400            436
# 226               CDU-CSU            179     35.943775            134
# 3             DIE GRUENEN            743     33.273623            534
# 451           DIE GRUENEN             82     27.333333             57
# 42                CDU-CSU            334     29.453263            241
# 147           DIE GRUENEN             34     27.419355             25
# 379           DIE GRUENEN            531     37.739872            423
# 171           DIE GRUENEN            538     31.260895            419
# 317                   FDP             99     14.516129             45
# 461                   FDP             68     15.212528             31
# 255  WUERDE NICHT WAEHLEN             20     10.309278              5
# 133                   FDP             57     15.966387             30
# 277                   FDP             58     11.693548             22
# 285                   FDP            156     14.104882             80
# 365                   FDP            145     16.552511             85
# 211           DIE GRUENEN            237     25.986842            179
# 11            DIE GRUENEN            600     27.919963            475
# 395           DIE GRUENEN            506     29.299363            403
# 205                   FDP             72     15.859031             41
# 323           DIE GRUENEN            838     26.662424            658
# 413                   FDP            158     12.210201             77
# 419           DIE GRUENEN           1871     29.835752           1518
# 453                   FDP             30     10.000000             12
# 347           DIE GRUENEN           1033     33.024297            860
# 156             DIE LINKE             78     17.333333             50
# 291           DIE GRUENEN            968     24.382872            760
# 491           DIE GRUENEN            805     27.559055            653
# 61                    FDP            147     13.661710             92
# 458               CDU-CSU            112     25.055928             80
# 515           DIE GRUENEN            881     25.403691            711
# 219           DIE GRUENEN            206     32.187500            184
# 299           DIE GRUENEN           1179     30.230769            988
# 452             DIE LINKE             46     15.333333             31
# 248                   AFD             35     18.041237             24
# 386               CDU-CSU            269     35.117493            227
# 231  WUERDE NICHT WAEHLEN             41      8.232932             16
# 469                   FDP             60     10.968921             34
# 267           DIE GRUENEN            128     17.462483            101
# 51            DIE GRUENEN            199     31.537242            159
# 151  WUERDE NICHT WAEHLEN              8      6.451613              2
# 83            DIE GRUENEN            223     42.720307            207
# 509                   FDP            220     13.398295            138
# 138               CDU-CSU             89     24.517906             73
# 189                   FDP            238     13.222222            162
# 131           DIE GRUENEN             76     21.288515             59
# 19            DIE GRUENEN            422     36.600173            366
# 371           DIE GRUENEN            375     21.539345            308
# 341                   FDP             59      9.640523             32
# 87   WUERDE NICHT WAEHLEN             36      6.896552             14
# 157                   FDP             36      8.000000             16
#
#      percent_2023  diff_percent
# 149      3.759398    -18.821247
# 195     34.152047    -15.213582
# 35      17.666948    -13.688233
# 235     18.671800    -13.474590
# 243     37.500000    -12.884615
# 355     24.123121    -12.314425
# 75      21.964782    -12.123888
# 475     28.123580    -11.783612
# 249      1.612903    -10.758231
# 499     26.722925    -10.378524
# 163     24.900057    -10.221343
# 226     26.070039     -9.873736
# 3       24.064894     -9.208729
# 451     18.627451     -8.705882
# 42      20.775862     -8.677401
# 147     18.796992     -8.622362
# 379     29.232896     -8.506976
# 171     23.355630     -7.905265
# 317      6.627393     -7.888736
# 461      7.560976     -7.651552
# 255      2.688172     -7.621106
# 133      8.450704     -7.515682
# 277      4.426559     -7.266989
# 285      7.104796     -7.000087
# 365      9.747706     -6.804805
# 211     19.206009     -6.780834
# 11      21.214828     -6.705135
# 395     22.910745     -6.388618
# 205      9.490741     -6.368290
# 323     20.327464     -6.334961
# 413      5.945946     -6.264255
# 419     23.681747     -6.154005
# 453      3.921569     -6.078431
# 347     27.103687     -5.920609
# 156     11.467890     -5.865443
# 291     18.632018     -5.750854
# 491     21.839465     -5.719590
# 61       8.084359     -5.577352
# 458     19.512195     -5.543733
# 515     19.921547     -5.482144
# 219     26.822157     -5.365343
# 299     24.930608     -5.300161
# 452     10.130719     -5.202614
# 248     12.903226     -5.138011
# 386     29.986790     -5.130704
# 231      3.112840     -5.120091
# 469      5.872193     -5.096728
# 267     12.392638     -5.069845
# 51      26.588629     -4.948614
# 151      1.503759     -4.947854
# 83      37.773723     -4.946584
# 509      8.471455     -4.926840
# 138     19.676550     -4.841356
# 189      8.486118     -4.736104
# 131     16.619718     -4.668797
# 19      31.937173     -4.663001
# 371     17.016575     -4.522771
# 341      5.194805     -4.445718
# 87       2.554745     -4.341807
# 157      3.669725     -4.330275

# %%
comp_no_berlin_party.tail(60)
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 392    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 250    U30            gering besiedelt        NaN     NaN
# 70   30-49                         NaN   Weiblich     NaN
# 168  50-64                         NaN        NaN    West
# 32   30-49                         NaN   Männlich     NaN
# 223  50-64             dicht besiedelt        NaN     NaN
# 216  50-64             dicht besiedelt        NaN     NaN
# 190    Ü65                         NaN        NaN    West
# 208  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 0    30-49                         NaN        NaN     NaN
# 398    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 384    NaN            gering besiedelt   Weiblich     NaN
# 152    Ü65                         NaN        NaN     Ost
# 64   30-49                         NaN   Weiblich     NaN
# 422    NaN                         NaN        NaN    West
# 54     U30                         NaN   Männlich     NaN
# 232  50-64  mittlere Besiedlungsdichte        NaN     NaN
# 78   50-64                         NaN   Weiblich     NaN
# 182    U30                         NaN        NaN    West
# 504    NaN            gering besiedelt        NaN     NaN
# 8    50-64                         NaN        NaN     NaN
# 144    U30                         NaN        NaN     Ost
# 30     Ü65                         NaN        NaN     NaN
# 286    Ü65  mittlere Besiedlungsdichte        NaN     NaN
# 360    NaN            gering besiedelt   Männlich     NaN
# 414    NaN                         NaN        NaN     Ost
# 254    U30            gering besiedelt        NaN     NaN
# 22     U30                         NaN        NaN     NaN
# 6    30-49                         NaN        NaN     NaN
# 350    NaN                         NaN   Weiblich    West
# 302    NaN                         NaN   Weiblich     NaN
# 464    NaN  mittlere Besiedlungsdichte        NaN     Ost
# 270    Ü65             dicht besiedelt        NaN     NaN
# 358    NaN             dicht besiedelt   Männlich     NaN
# 470    NaN  mittlere Besiedlungsdichte        NaN     Ost
# 224  50-64            gering besiedelt        NaN     NaN
# 336    NaN                         NaN   Weiblich     Ost
# 86     U30                         NaN   Weiblich     NaN
# 448    NaN             dicht besiedelt        NaN     Ost
# 166  30-49                         NaN        NaN    West
# 38   30-49                         NaN   Männlich     NaN
# 146    U30                         NaN        NaN     Ost
# 502    NaN             dicht besiedelt        NaN     NaN
# 94     Ü65                         NaN   Weiblich     NaN
# 40   50-64                         NaN   Männlich     NaN
# 408    NaN                         NaN        NaN     Ost
# 342    NaN                         NaN   Weiblich     Ost
# 478    NaN             dicht besiedelt        NaN    West
# 246    U30             dicht besiedelt        NaN     NaN
# 382    NaN             dicht besiedelt   Weiblich     NaN
# 200  30-49            gering besiedelt        NaN     NaN
# 158    Ü65                         NaN        NaN     Ost
# 454    NaN             dicht besiedelt        NaN     Ost
# 312    NaN                         NaN   Männlich     Ost
# 251    U30            gering besiedelt        NaN     NaN
# 128  30-49                         NaN        NaN     Ost
# 136  50-64                         NaN        NaN     Ost
# 150    U30                         NaN        NaN     Ost
# 198  30-49             dicht besiedelt        NaN     NaN
# 456    NaN            gering besiedelt        NaN     Ost
#
#                      pv01  absolute_2021  percent_2021  absolute_2023  \
# 392                   AFD             43      2.489867            135
# 250               CDU-CSU             28     14.432990             37
# 70                    SPD            119     10.778986            169
# 168                   AFD             72      4.183614            175
# 32                    AFD            102      9.034544            173
# 223  WUERDE NICHT WAEHLEN             28      4.375000             69
# 216                   AFD             41      6.406250             83
# 190                   SPD            411     22.833333            550
# 208                   AFD             68      7.456140            126
# 0                     AFD            137      6.135244            271
# 398                   SPD            258     14.939201            372
# 384                   AFD             30      3.916449             77
# 152                   AFD             45     10.000000             71
# 64                    AFD             35      3.170290             98
# 422                   SPD            961     15.324510           1389
# 54                    SPD             60      9.508716             95
# 232                   AFD             58      5.736894            128
# 78                    SPD            141     13.891626            221
# 182                   SPD            100     10.214505            162
# 504                   AFD            129      7.856273            238
# 8                     AFD            129      6.002792            287
# 144                   AFD             12      9.677419             22
# 30                    SPD            514     22.012848            709
# 286                   SPD            216     19.529837            300
# 360                   AFD             99     11.301370            161
# 414                   SPD            159     12.287481            252
# 254                   SPD             20     10.309278             33
# 22                    SPD            115      9.973981            202
# 6                     SPD            224     10.031348            394
# 350                   SPD            454     14.514066            708
# 302                   SPD            562     14.410256            885
# 464                   AFD             66     12.065814            116
# 270                   SPD            202     27.557981            292
# 358                   SPD            214     15.816704            337
# 470                   SPD             68     12.431444            122
# 224                   AFD             30      6.024096             76
# 336                   AFD             50      8.169935            105
# 86                    SPD             55     10.536398            107
# 448                   AFD             24      8.000000             52
# 166                   SPD            185     10.446076            342
# 38                    SPD            105      9.300266            225
# 146               CDU-CSU             11      8.870968             25
# 502                   SPD            407     14.746377            710
# 94                    SPD            247     19.618745            388
# 40                    AFD             75      6.613757            203
# 408                   AFD            152     11.746522            294
# 342                   SPD             75     12.254902            146
# 478                   SPD            317     14.709977            580
# 246                   SPD             41      7.884615             96
# 382                   SPD            193     13.717129            373
# 200                   AFD             39      8.590308             92
# 158                   SPD             82     18.222222            135
# 454                   SPD             30     10.000000             70
# 312                   AFD            102     14.956012            189
# 251           DIE GRUENEN             27     13.917526             52
# 128                   AFD             42     11.764706             92
# 136                   AFD             53     14.600551            109
# 150                   SPD              5      4.032258             26
# 198                   SPD             59      6.805075            202
# 456                   AFD             62     13.870246            126
#
#      percent_2023  diff_percent
# 392      7.674815      5.184948
# 250     19.892473      5.459483
# 70      16.312741      5.533756
# 168      9.754738      5.571124
# 32      14.623838      5.589294
# 223     10.058309      5.683309
# 216     12.099125      5.692875
# 190     28.810896      5.977562
# 208     13.519313      6.063173
# 0       12.212708      6.077464
# 398     21.148380      6.209179
# 384     10.171731      6.255281
# 152     16.284404      6.284404
# 64       9.459459      6.289170
# 422     21.669267      6.344757
# 54      15.886288      6.377571
# 232     12.319538      6.582644
# 78      20.481928      6.590302
# 182     16.945607      6.731102
# 504     14.610190      6.753917
# 8       12.818222      6.815430
# 144     16.541353      6.863934
# 30      29.081214      7.068366
# 286     26.642984      7.113147
# 360     18.463303      7.161933
# 414     19.459459      7.171979
# 254     17.741935      7.432657
# 22      17.626527      7.652546
# 6       17.755746      7.724398
# 350     22.313268      7.799202
# 302     22.331567      7.921311
# 464     20.034542      7.968729
# 270     35.828221      8.270240
# 358     24.123121      8.306417
# 470     21.070812      8.639368
# 224     14.785992      8.761896
# 336     17.045455      8.875520
# 86      19.525547      8.989149
# 448     16.993464      8.993464
# 166     19.531696      9.085621
# 38      19.019442      9.719176
# 146     18.796992      9.926025
# 502     24.964838     10.218461
# 94      29.846154     10.227409
# 40      17.500000     10.886243
# 408     22.702703     10.956180
# 342     23.701299     11.446397
# 478     26.351658     11.641682
# 246     19.672131     11.787516
# 382     25.777471     12.060342
# 200     21.296296     12.705988
# 158     30.963303     12.741081
# 454     22.875817     12.875817
# 312     27.835052     12.879040
# 251     27.956989     14.039463
# 128     25.915493     14.150787
# 136     29.380054     14.779503
# 150     19.548872     15.516614
# 198     23.625731     16.820656
# 456     30.731707     16.861461

# %%
comp_inflation
comp_inflation["diff_percent"]=comp_inflation["percent_2023"]-comp_inflation["percent_2021"]
comp_no_berlin_infl=comp_inflation[comp_inflation["OstWest"]!="Berlin"]

comp_no_berlin_infl=comp_no_berlin_infl.sort_values("diff_percent")

# %%
comp_no_berlin_infl.head(20)
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 25     U30                         NaN   Männlich     NaN
# 121    U30             dicht besiedelt        NaN     NaN
# 73     U30                         NaN        NaN     Ost
# 89     U30                         NaN        NaN    West
# 9      U30                         NaN        NaN     NaN
# 109  50-64             dicht besiedelt        NaN     NaN
# 85   50-64                         NaN        NaN    West
# 21   50-64                         NaN   Männlich     NaN
# 117  50-64  mittlere Besiedlungsdichte        NaN     NaN
# 129    U30  mittlere Besiedlungsdichte        NaN     NaN
# 33   30-49                         NaN   Weiblich     NaN
# 245    NaN  mittlere Besiedlungsdichte        NaN    West
# 197    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 5    50-64                         NaN        NaN     NaN
# 177    NaN             dicht besiedelt   Männlich     NaN
# 193    NaN            gering besiedelt   Weiblich     NaN
# 257    NaN  mittlere Besiedlungsdichte        NaN     NaN
# 41     U30                         NaN   Weiblich     NaN
# 161    NaN                         NaN   Männlich    West
# 37   50-64                         NaN   Weiblich     NaN
#
#                     va03  absolute_2021  percent_2021  absolute_2023  \
# 25   AM VIERTWICHTIGSTEN            253     54.175589            197
# 121  AM VIERTWICHTIGSTEN            216     54.822335            168
# 73   AM VIERTWICHTIGSTEN             46     42.990654             34
# 89   AM VIERTWICHTIGSTEN            391     49.745547            327
# 9    AM VIERTWICHTIGSTEN            448     48.017149            369
# 109  AM VIERTWICHTIGSTEN            358     63.814617            373
# 85   AM VIERTWICHTIGSTEN            929     64.379764            965
# 21   AM VIERTWICHTIGSTEN            626     65.140479            624
# 117  AM VIERTWICHTIGSTEN            536     63.133098            541
# 129  AM VIERTWICHTIGSTEN            169     43.444730            137
# 33   AM VIERTWICHTIGSTEN            417     46.906637            381
# 245  AM VIERTWICHTIGSTEN           1329     57.309185           1383
# 197  AM VIERTWICHTIGSTEN            751     54.857560            792
# 5    AM VIERTWICHTIGSTEN           1156     62.689805           1227
# 177  AM VIERTWICHTIGSTEN            627     59.262760            672
# 193  AM VIERTWICHTIGSTEN            366     56.049005            393
# 257  AM VIERTWICHTIGSTEN           1573     56.481149           1658
# 41   AM VIERTWICHTIGSTEN            195     41.845494            172
# 161  AM VIERTWICHTIGSTEN           1458     57.788347           1537
# 37   AM VIERTWICHTIGSTEN            530     60.022650            603
#
#      percent_2023  diff_percent
# 25      27.023320    -27.152269
# 121     28.620102    -26.202233
# 73      20.359281    -22.631373
# 89      27.341137    -22.404410
# 9       25.949367    -22.067782
# 109     41.910112    -21.904504
# 85      43.273543    -21.106222
# 21      44.667144    -20.473335
# 117     42.800633    -20.332465
# 129     23.499142    -19.945588
# 33      27.994122    -18.912515
# 245     38.427341    -18.881844
# 197     36.000000    -18.857560
# 5       43.884120    -18.805685
# 177     41.000610    -18.262150
# 193     38.155340    -17.893665
# 257     38.675064    -17.806085
# 41      24.819625    -17.025869
# 161     40.769231    -17.019116
# 37      43.102216    -16.920434

# %%
comp_no_berlin_infl.tail(20)
# Out:
#      Alter                 Besiedelung Geschlecht OstWest  \
# 3    30-49                         NaN        NaN     NaN
# 199    NaN  mittlere Besiedlungsdichte   Weiblich     NaN
# 106  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 34   30-49                         NaN   Weiblich     NaN
# 107  30-49  mittlere Besiedlungsdichte        NaN     NaN
# 247    NaN  mittlere Besiedlungsdichte        NaN    West
# 195    NaN            gering besiedelt   Weiblich     NaN
# 131    U30  mittlere Besiedlungsdichte        NaN     NaN
# 67   30-49                         NaN        NaN     Ost
# 130    U30  mittlere Besiedlungsdichte        NaN     NaN
# 126    U30            gering besiedelt        NaN     NaN
# 103  30-49            gering besiedelt        NaN     NaN
# 26     U30                         NaN   Männlich     NaN
# 35   30-49                         NaN   Weiblich     NaN
# 10     U30                         NaN        NaN     NaN
# 90     U30                         NaN        NaN    West
# 75     U30                         NaN        NaN     Ost
# 42     U30                         NaN   Weiblich     NaN
# 122    U30             dicht besiedelt        NaN     NaN
# 227    NaN             dicht besiedelt        NaN     Ost
#
#                     va03  absolute_2021  percent_2021  absolute_2023  \
# 3    AM ZWEITWICHTIGSTEN            272     15.019326            684
# 199  AM ZWEITWICHTIGSTEN            195     14.243974            532
# 106       AM WICHTIGSTEN             57      7.671602            207
# 34        AM WICHTIGSTEN             73      8.211474            249
# 107  AM ZWEITWICHTIGSTEN            104     13.997308            283
# 247  AM ZWEITWICHTIGSTEN            293     12.634756            828
# 195  AM ZWEITWICHTIGSTEN            105     16.079632            282
# 131  AM ZWEITWICHTIGSTEN             59     15.167095            160
# 67   AM ZWEITWICHTIGSTEN             44     13.968254            118
# 130       AM WICHTIGSTEN             25      6.426735            110
# 126       AM WICHTIGSTEN             16     10.666667             59
# 103  AM ZWEITWICHTIGSTEN             74     18.781726            177
# 26        AM WICHTIGSTEN             20      4.282655            129
# 35   AM ZWEITWICHTIGSTEN            127     14.285714            390
# 10        AM WICHTIGSTEN             61      6.538049            305
# 90        AM WICHTIGSTEN             44      5.597964            255
# 75   AM ZWEITWICHTIGSTEN             19     17.757009             56
# 42        AM WICHTIGSTEN             41      8.798283            176
# 122       AM WICHTIGSTEN             20      5.076142            136
# 227  AM ZWEITWICHTIGSTEN             17      7.112971            102
#
#      percent_2023  diff_percent
# 3       24.881775      9.862449
# 199     24.181818      9.937844
# 106     17.737789     10.066188
# 34      18.295371     10.083897
# 107     24.250214     10.252906
# 247     23.006391     10.371634
# 195     27.378641     11.299008
# 131     27.444254     12.277159
# 67      26.280624     12.312370
# 130     18.867925     12.441189
# 126     23.412698     12.746032
# 103     31.720430     12.938704
# 26      17.695473     13.412818
# 35      28.655400     14.369686
# 10      21.448664     14.910615
# 90      21.321070     15.723106
# 75      33.532934     15.775925
# 42      25.396825     16.598542
# 122     23.168654     18.092512
# 227     26.984127     19.871156
