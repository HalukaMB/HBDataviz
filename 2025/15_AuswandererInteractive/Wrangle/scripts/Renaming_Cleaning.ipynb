# %%
import pandas as pd
import glob

# %%
data=pd.read_csv("all_measures.csv")
data
# Out:
#                   Country Name Country Code  gdp_rel_us  ppp_rel_us  \
# 0                      Burundi          BDI    0.001794    0.162060
# 1                  Yemen, Rep.          YEM    0.005048    0.435717
# 2     Central African Republic          CAF    0.006015    0.408493
# 3                      Somalia          SOM    0.007423    0.397925
# 4                  South Sudan          SSD    0.012588    0.666367
# ..                         ...          ...         ...         ...
# 217                     Monaco          MCO    2.990104         NaN
# 218              New Caledonia          NCL    0.390589         NaN
# 219  Korea, Dem. People's Rep.          PRK         NaN         NaN
# 220           French Polynesia          PYF    0.265402         NaN
# 221     British Virgin Islands          VGB         NaN         NaN
#
#      cost_to_gdp    popdensity  homicides      Country or Territory  \
# 0      90.341939    518.734307   5.823910                   Burundi
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'gdp_rel_us', 'ppp_rel_us',
#        'cost_to_gdp', 'popdensity', 'homicides', 'Country or Territory',
#        'FreedomScore', 'PISA Score', 'timediff', 'Cuisine Rank',
#        'SunshineHours', 'sqm/sqkm', 'max_m', 'English Proficiency',
#        'Germans Elsewhere', 'Bureaucracy Score', 'max', 'min',
#        'LivingConditions', 'Healthcare', 'CostofLiving', 'Country_Country',
#        'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
#        'Folk religion_%', 'Other religion_%', 'Jewish_%',
#        'Not Stated/Undeclared_%', 'Sikh_%', 'Not stated/Undeclared_%',
#        'Pagan_%', '/Undecided/Not Stated_%', 'Paganism/Neo-Paganism_%', 'ban'],
#       dtype='object')

# %%
data.drop(columns=["Country or Territory",'Irreligion_%', 'Folk religion_%', 'Other religion_%', 
       'Not Stated/Undeclared_%', 'Sikh_%', 'Not stated/Undeclared_%',
       'Pagan_%', '/Undecided/Not Stated_%', 'Paganism/Neo-Paganism_%'], inplace=True)

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'gdp_rel_us', 'ppp_rel_us',
#        'cost_to_gdp', 'popdensity', 'homicides', 'FreedomScore', 'PISA Score',
#        'timediff', 'Cuisine Rank', 'SunshineHours', 'sqm/sqkm', 'max_m',
#        'English Proficiency', 'Germans Elsewhere', 'Bureaucracy Score', 'max',
#        'min', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Country_Country', 'Christian_%', 'Muslim_%', 'Hindu_%', 'Buddhist_%',
#        'Jewish_%', 'ban'],
#       dtype='object')

# %%
data.columns=['Country Name', 'Country Code', 'gdp_rel_us', 'ppp_rel_us',
       'cost_to_gdp', 'popdensity_per_sqkm', 'homicides_per_100k', 'FreedomScore', 'PISAScore',
       'timediff_to_germany', 'CuisineRank', 'SunshineHours_per_year', 'm/sqkm_coastline', 'max_elevation_m',
       'EnglishProficiency', 'GermansElsewhere', 'BureaucracyScore_plus_minus', 'max_temp_since_1900',
       'min_temp_since_1900', 'LivingConditions_Score', 'Healthcare_Score', 'CostofLiving_USDollar',
       'Country_Country', 'Christian_%', 'Muslim_%', 'Hindu_%', 'Buddhist_%',
       'Jewish_%', 'Alcohol_ban']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data.columns=[['Country Name', 'Country Code', 'gdp_rel_us', 'ppp_rel_us',
#       2        'cost_to_gdp', 'popdensity', 'homicides_per_100k', 'FreedomScore', 'PISAScore',
#       3        'timediff_to_eu', 'Cuisine_Rank', 'SunshineHours_year', 'm/sqkm', 'max_elevation',
#       4        'english_proficiency', 'Location', 'sqm/sqkm_y', 'Bureaucracy Score',
#       5        'max', 'min', 'LivingConditions', 'Healthcare', 'CostofLiving',
#       6        'Country_Country', 'Christian_%', 'Muslim_%', 'Hindu_%', 'Buddhist_%',
#       7        'Jewish_%', 'ban']]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# ...
