# %%
import pandas as pd
import glob
import pycountry
import numpy as np

# %%
df_to_check=pd.read_csv("../data/all_measures_v3_cleaned.csv",encoding='latin1')
df_to_check
# Out:
#      Unnamed: 0               Country Name                           Land  \
# 0             0                    Burundi                        Burundi
# 1             1   Central African Republic  Zentral Afrikanische Republik
# 2             2                Yemen, Rep.                          Jemen
# 3             3         Somalia, Fed. Rep.                        Somalia
# 4             4                South Sudan                       Südsudan
# ..          ...                        ...                            ...
# 214         218   Northern Mariana Islands       Northern Mariana Islands
# 215         219              New Caledonia                  New Caledonia
# 216         220  Korea, Dem. People's Rep.                      Nordkorea
# 217         221           French Polynesia               French Polynesia
# 218         222     British Virgin Islands         British Virgin Islands
#
#     Country Code  gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  \
# ...

# %%
df_to_check["Anzahl_der_Deutschen_numeric"]=np.where(df_to_check["Land"]=="Deutschland",np.nan,df_to_check["Anzahl_der_Deutschen_numeric"])
df_to_check
# Out:
#      Unnamed: 0               Country Name                           Land  \
# 0             0                    Burundi                        Burundi
# 1             1   Central African Republic  Zentral Afrikanische Republik
# 2             2                Yemen, Rep.                          Jemen
# 3             3         Somalia, Fed. Rep.                        Somalia
# 4             4                South Sudan                       Südsudan
# ..          ...                        ...                            ...
# 214         218   Northern Mariana Islands       Northern Mariana Islands
# 215         219              New Caledonia                  New Caledonia
# 216         220  Korea, Dem. People's Rep.                      Nordkorea
# 217         221           French Polynesia               French Polynesia
# 218         222     British Virgin Islands         British Virgin Islands
#
#     Country Code  gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  \
# ...

# %%
df_to_check["FreedomScore"]=pd.to_numeric(df_to_check["FreedomScore"], errors='coerce')
df_to_check["LGBTQ"]=pd.to_numeric(df_to_check["LGBTQ"], errors='coerce')
df_to_check
# Out:
#      Unnamed: 0               Country Name                           Land  \
# 0             0                    Burundi                        Burundi
# 1             1   Central African Republic  Zentral Afrikanische Republik
# 2             2                Yemen, Rep.                          Jemen
# 3             3         Somalia, Fed. Rep.                        Somalia
# 4             4                South Sudan                       Südsudan
# ..          ...                        ...                            ...
# 214         218   Northern Mariana Islands       Northern Mariana Islands
# 215         219              New Caledonia                  New Caledonia
# 216         220  Korea, Dem. People's Rep.                      Nordkorea
# 217         221           French Polynesia               French Polynesia
# 218         222     British Virgin Islands         British Virgin Islands
#
#     Country Code  gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  \
# ...

# %%
df_to_check=df_to_check.sort_values(by=["FreedomScore"], ascending=[False])
df_to_check
# Out:
#      Unnamed: 0              Country Name                      Land  \
# 172         176                   Finland                  Finnland
# 176         180                    Sweden                  Schweden
# 163         166               New Zealand                Neuseeland
# 196         200                    Norway                  Norwegen
# 173         177                    Canada                    Kanada
# ..          ...                       ...                       ...
# 212         216  St. Martin (French part)  St. Martin (French part)
# 214         218  Northern Mariana Islands  Northern Mariana Islands
# 215         219             New Caledonia             New Caledonia
# 217         221          French Polynesia          French Polynesia
# 218         222    British Virgin Islands    British Virgin Islands
#
#     Country Code  gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  \
# 172          FIN     0.953197     1.075284     1.128081   18.370545
# ...

# %%
df_to_check.columns
# Out:
# Index(['Unnamed: 0', 'Country Name', 'Land', 'Country Code', 'gdp_rel_ger',
#        'ppp_rel_ger', 'cost_to_gdp', 'popdensity', 'homicides',
#        'Country or Territory', 'FreedomScore', 'PISA Score',
#        'timediff_to_germany', 'Cuisine Rank', 'SunshineHours_per_year',
#        'sqm/sqkm', 'max_m', 'min_m', 'English Proficiency', 'ISO3',
#        'Anzahl_der_Deutschen_numeric', 'Bureaucracy Score', 'MaxTemperature',
#        'MinTemperature', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Country', 'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%',
#        'Buddhist_%', 'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban',
#        'Code', 'LGBTQ'],
#       dtype='object')

# %%
df_to_check=df_to_check[['Country Name','Country Code',"Land",
             'gdp_rel_ger','ppp_rel_ger', 'cost_to_gdp', 'popdensity', 'homicides',
      'FreedomScore', 'PISA Score','timediff_to_germany', 'Cuisine Rank', 
      'SunshineHours_per_year', 'sqm/sqkm', 'max_m', 'min_m', 'English Proficiency', 
       'Anzahl_der_Deutschen_numeric', 'Bureaucracy Score', 'MaxTemperature',
       'MinTemperature', 'LivingConditions', 'Healthcare', 'CostofLiving', 
       'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
       'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban',
       'LGBTQ']]

# %%
len(df_to_check.columns)
# Out:
# 34

# %%
#df_to_check[['Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
 #      'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban']]=df_to_check[['Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
  #     'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban']].fillna(0)
#df_to_check

# %%
reisewarnungen_full=pd.read_csv("../data/reisewarnungen_full.csv")
reisewarnungen_full_list=reisewarnungen_full["0"].tolist()
reisewarnungen_full_list
# Out:
# ['Afghanistan',
#  'Belarus',
#  'Haiti',
#  'Iran',
#  'Jemen',
#  'Libyen',
#  'Mali',
#  'Myanmar',
#  'Niger',
#  'Palästinensische Gebiete',
#  'Somalia',
#  'Sudan',
#  'Südsudan',
#  'Syrien',
#  'Ukraine',
#  'Zentralafrikanische Republik']

# %%
safe_countries=df_to_check[~df_to_check["Land"].isin(reisewarnungen_full_list)]
safe_countries
# Out:
#                  Country Name Country Code                      Land  \
# 172                   Finland          FIN                  Finnland
# 176                    Sweden          SWE                  Schweden
# 163               New Zealand          NZL                Neuseeland
# 196                    Norway          NOR                  Norwegen
# 173                    Canada          CAN                    Kanada
# ..                        ...          ...                       ...
# 212  St. Martin (French part)          MAF  St. Martin (French part)
# 214  Northern Mariana Islands          MNP  Northern Mariana Islands
# 215             New Caledonia          NCL             New Caledonia
# 217          French Polynesia          PYF          French Polynesia
# 218    British Virgin Islands          VGB    British Virgin Islands
#
#      gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  homicides  \
# 172     0.953197     1.075284     1.128081   18.370545   0.981935
# ...

# %%
safe_countries_enough_data=safe_countries.dropna(thresh=29)
safe_countries_enough_data
# Out:
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ..                        ...          ...                            ...
# 120                     China          CHN            Volksrepublik China
# 115                Azerbaijan          AZE                  Aserbaidschan
# 1    Central African Republic          CAF  Zentral Afrikanische Republik
# 41                 Tajikistan          TJK                  Tadschikistan
# 102              Turkmenistan          TKM                   Turkmenistan
#
#      gdp_rel_ger  ppp_rel_ger  cost_to_gdp  popdensity  homicides  \
# ...

# %%
safe_countries_enough_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Land', 'gdp_rel_ger', 'ppp_rel_ger',
#        'cost_to_gdp', 'popdensity', 'homicides', 'FreedomScore', 'PISA Score',
#        'timediff_to_germany', 'Cuisine Rank', 'SunshineHours_per_year',
#        'sqm/sqkm', 'max_m', 'min_m', 'English Proficiency',
#        'Anzahl_der_Deutschen_numeric', 'Bureaucracy Score', 'MaxTemperature',
#        'MinTemperature', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
#        'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban', 'LGBTQ'],
#       dtype='object')

# %%
safe_countries_enough_data["Anzahl_der_Deutschen_numeric"].describe()
# Out:
# count    9.100000e+01
# mean     6.879906e+05
# std      4.464900e+06
# min      3.200000e+01
# 25%      6.015000e+02
# 50%      6.202000e+03
# 75%      6.864600e+04
# max      4.222018e+07
# Name: Anzahl_der_Deutschen_numeric, dtype: float64

# %%
safe_countries_enough_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Land', 'gdp_rel_ger', 'ppp_rel_ger',
#        'cost_to_gdp', 'popdensity', 'homicides', 'FreedomScore', 'PISA Score',
#        'timediff_to_germany', 'Cuisine Rank', 'SunshineHours_per_year',
#        'sqm/sqkm', 'max_m', 'min_m', 'English Proficiency',
#        'Anzahl_der_Deutschen_numeric', 'Bureaucracy Score', 'MaxTemperature',
#        'MinTemperature', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
#        'Folk religion_%', 'Other religion_%', 'Jewish_%', 'ban', 'LGBTQ'],
#       dtype='object')

# %%
safe_countries_enough_data.columns=['Country Name', 'Country Code', 'Land', 'BIP_rel_D', 'PurchasingPower_rel_D',
       'Cost_BIP_Ratio', 'Bevoelkerungsdichte', 'Morde_pro_100k', 'Freedom_Score', 'PISA_Score',
       'Zeitunterschied_D', 'Rang_Kueche', 'Sonnenstunde_pro_Jahr',
       'Kuestenlänge_m_km2', 'HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'EnglishSkill',
       'Anzahl_der_Deutschen_numeric', 'BuerokratieScore', 'MaxTemperatur',
       'MinTemperatur', 'LivingConditions', 'Healthcare', 'CostofLiving',
       'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
       'FolkReligion_%', 'OtherReligion_%', 'Jewish_%', 'Alkoholverbot', 'LGBTQ']

# %%
safe_countries_enough_data["Mehrals5Morde_pro_100k_boolean"]=np.where(safe_countries_enough_data["Morde_pro_100k"]>=5,1,0)
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/3043331829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Mehrals5Morde_pro_100k_boolean"]=np.where(safe_countries_enough_data["Morde_pro_100k"]>=5,1,0)
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ...

# %%
safe_countries_enough_data["Mehrals1000Deutsche_boolean"]=np.where(safe_countries_enough_data["Anzahl_der_Deutschen_numeric"]>=1000,1,0)
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/3042322697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Mehrals1000Deutsche_boolean"]=np.where(safe_countries_enough_data["Anzahl_der_Deutschen_numeric"]>=1000,1,0)
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ...

# %%
safe_countries_enough_data[safe_countries_enough_data["Mehrals1000Deutsche_boolean"]==1]
# Out:
#            Country Name Country Code                 Land  BIP_rel_D  \
# 172             Finland          FIN             Finnland   0.953197
# 176              Sweden          SWE             Schweden   1.034462
# 163         New Zealand          NZL           Neuseeland   0.873599
# 196              Norway          NOR             Norwegen   1.555724
# 173              Canada          CAN               Kanada   0.972803
# ..                  ...          ...                  ...        ...
# 116       Venezuela, RB          VEN            Venezuela   0.285727
# 74           Uzbekistan          UZB           Usbekistan   0.056661
# 149  Russian Federation          RUS             Russland   0.266827
# 120               China          CHN  Volksrepublik China   0.238407
# 102        Turkmenistan          TKM         Turkmenistan   0.153612
#
#      PurchasingPower_rel_D  Cost_BIP_Ratio  Bevoelkerungsdichte  \
# 172               1.075284        1.128081            18.370545
# ...

# %%
safe_countries_enough_data["Alkoholverbot_boolean"]=np.where(safe_countries_enough_data["Alkoholverbot"]>=1,1,0)
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/4117127103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Alkoholverbot_boolean"]=np.where(safe_countries_enough_data["Alkoholverbot"]>=1,1,0)
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ...

# %%
safe_countries_enough_data["Sonnenstunde_pro_Tag"]=safe_countries_enough_data["Sonnenstunde_pro_Jahr"]/365
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/2918575607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Sonnenstunde_pro_Tag"]=safe_countries_enough_data["Sonnenstunde_pro_Jahr"]/365
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ...

# %%
safe_countries_enough_data["Kuestenlänge_m_km2"].describe()
# Out:
# count     128.000000
# mean       44.575797
# std       141.218820
# min         0.000000
# 25%         0.387500
# 50%         3.305000
# 75%        20.775000
# max      1080.000000
# Name: Kuestenlänge_m_km2, dtype: float64

# %%
safe_countries_enough_data["Kueste_boolean"]=np.where(safe_countries_enough_data["Kuestenlänge_m_km2"]>0,1,0)
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/4222936221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Kueste_boolean"]=np.where(safe_countries_enough_data["Kuestenlänge_m_km2"]>0,1,0)
#                  Country Name Country Code                           Land  \
# 172                   Finland          FIN                       Finnland
# 176                    Sweden          SWE                       Schweden
# 163               New Zealand          NZL                     Neuseeland
# 196                    Norway          NOR                       Norwegen
# 173                    Canada          CAN                         Kanada
# ...

# %%
safe_countries_enough_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Land', 'BIP_rel_D',
#        'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'Bevoelkerungsdichte',
#        'Morde_pro_100k', 'Freedom_Score', 'PISA_Score', 'Zeitunterschied_D',
#        'Rang_Kueche', 'Sonnenstunde_pro_Jahr', 'Kuestenlänge_m_km2',
#        'HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'EnglishSkill',
#        'Anzahl_der_Deutschen_numeric', 'BuerokratieScore', 'MaxTemperatur',
#        'MinTemperatur', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
#        'FolkReligion_%', 'OtherReligion_%', 'Jewish_%', 'Alkoholverbot',
#        'LGBTQ', 'Mehrals5Morde_pro_100k_boolean',
#        'Mehrals1000Deutsche_boolean', 'Alkoholverbot_boolean',
#        'Sonnenstunde_pro_Tag', 'Kueste_boolean'],
#       dtype='object')

# %%
safe_countries_enough_data["Christian_boolean"]=np.where(safe_countries_enough_data["Christian_%"]>1,1,0)
safe_countries_enough_data["Muslim_boolean"]=np.where(safe_countries_enough_data["Muslim_%"]>1,1,0)
safe_countries_enough_data["Jewish_boolean"]=np.where(safe_countries_enough_data["Jewish_%"]>1,1,0)
safe_countries_enough_data
# Out:
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/2929609978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Christian_boolean"]=np.where(safe_countries_enough_data["Christian_%"]>1,1,0)
# /var/folders/d_/6z_vk0mx7j10g1h2zrjh_6f00000gn/T/ipykernel_33858/2929609978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   safe_countries_enough_data["Muslim_boolean"]=np.where(safe_countries_enough_data["Muslim_%"]>1,1,0)
# ...

# %%
safe_countries_enough_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Land', 'BIP_rel_D',
#        'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'Bevoelkerungsdichte',
#        'Morde_pro_100k', 'Freedom_Score', 'PISA_Score', 'Zeitunterschied_D',
#        'Rang_Kueche', 'Sonnenstunde_pro_Jahr', 'Kuestenlänge_m_km2',
#        'HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'EnglishSkill',
#        'Anzahl_der_Deutschen_numeric', 'BuerokratieScore', 'MaxTemperatur',
#        'MinTemperatur', 'LivingConditions', 'Healthcare', 'CostofLiving',
#        'Christian_%', 'Muslim_%', 'Irreligion_%', 'Hindu_%', 'Buddhist_%',
#        'FolkReligion_%', 'OtherReligion_%', 'Jewish_%', 'Alkoholverbot',
#        'LGBTQ', 'Mehrals5Morde_pro_100k_boolean',
#        'Mehrals1000Deutsche_boolean', 'Alkoholverbot_boolean',
#        'Sonnenstunde_pro_Tag', 'Kueste_boolean', 'Christian_boolean',
#        'Muslim_boolean', 'Jewish_boolean'],
#       dtype='object')

# %%
safe_countries_enough_data_red=safe_countries_enough_data[['Country Name', 'Country Code', 'Land', 'BIP_rel_D',
       'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'Bevoelkerungsdichte',
        'Freedom_Score', 'PISA_Score','Sonnenstunde_pro_Tag', 'Zeitunterschied_D',
       'Rang_Kueche','HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'EnglishSkill',
       'BuerokratieScore', 'MaxTemperatur','MinTemperatur', 'LivingConditions', 
       'Healthcare', 'CostofLiving', 'LGBTQ', 'Mehrals5Morde_pro_100k_boolean',
       'Mehrals1000Deutsche_boolean', 'Alkoholverbot_boolean',
        'Kueste_boolean', 'Christian_boolean',
       'Muslim_boolean', 'Jewish_boolean']]

# %%
countries_dict={}
percentile_upper=90
percentile_lower=10
for col in safe_countries_enough_data_red.columns[3:]:
    if "boolean" in col:
        for iso3 in safe_countries_enough_data_red["Country Code"].tolist():
            print(iso3)
            if (len(safe_countries_enough_data_red[safe_countries_enough_data_red["Country Code"]==iso3])>0):
                new_var={"id": col,
                "displayValue": int(safe_countries_enough_data_red[safe_countries_enough_data_red["Country Code"]==iso3][col].values[0]),
                "binValue": int(safe_countries_enough_data_red[safe_countries_enough_data_red["Country Code"]==iso3][col].values[0])
        }
              
            if iso3 in countries_dict:
                saved_array=countries_dict[iso3]
                saved_array.append(new_var)
                countries_dict[iso3]=saved_array
            else:
                countries_dict[iso3]=[new_var]
            
    else:
            
        print(col)

        # Get the 90th percentile value (upper 10%)
        threshold_upper = safe_countries_enough_data_red[col].quantile(percentile_upper*0.01)

        # Filter rows where column values are >= 90th percentile
        upper_10_percent = safe_countries_enough_data_red[safe_countries_enough_data_red[col] >= threshold_upper]

        # Get the 90th percentile value (upper 10%)
        threshold_lower = safe_countries_enough_data_red[col].quantile(percentile_lower*0.01)

        # Filter rows where column values are >= 90th percentile
        lower_10_percent = safe_countries_enough_data_red[safe_countries_enough_data_red[col] <= threshold_lower]

        middle_df=safe_countries_enough_data_red[safe_countries_enough_data_red[col] > threshold_lower]
        middle_df=middle_df[middle_df[col] < threshold_upper]
        for iso3 in safe_countries_enough_data_red["Country Code"].tolist():
            print(iso3)
            if (len(upper_10_percent[upper_10_percent["Country Code"]==iso3])>0):
                new_var={"id": col,
                "displayValue": float(upper_10_percent[upper_10_percent["Country Code"]==iso3][col].values[0]),
                "binValue": float(threshold_upper)
        }

            if (len(lower_10_percent[lower_10_percent["Country Code"]==iso3])>0):
                new_var={"id": col,
                "displayValue": float(lower_10_percent[lower_10_percent["Country Code"]==iso3][col].values[0]),
                            "binValue": float(threshold_lower)
                    }
            if (len(middle_df[middle_df["Country Code"]==iso3])>0):
                new_var={"id": col,
                "displayValue": float(middle_df[middle_df["Country Code"]==iso3][col].values[0]),
                            "binValue": float(middle_df[middle_df["Country Code"]==iso3][col].values[0])
                    }
            if iso3 in countries_dict:
                saved_array=countries_dict[iso3]
                saved_array.append(new_var)
                countries_dict[iso3]=saved_array
            else:
                countries_dict[iso3]=[new_var]

countries_dict
# Out:
# BIP_rel_D
# FIN
# SWE
# NZL
# NOR
# CAN
# LUX
# IRL
# URY
# CHE
# EST
# PRT
# JPN
# BEL
# CZE
# CHL
# ISL
# DEU
# AUS
# AUT
# CPV
# GBR
# CRI
# CYP
# ESP
# BHS
# LTU
# FRA
# ITA
# SVK
# LVA
# BLZ
# MLT
# MUS
# ARG
# USA
# MNG
# STP
# PAN
# HRV
# POL
# ROU
# TTO
# KOR
# ZAF
# JAM
# SUR
# SYC
# BGR
# BWA
# GUY
# NAM
# ISR
# BRA
# COL
# SEN
# DOM
# PER
# MKD
# LSO
# MWI
# HUN
# BOL
# ECU
# LBR
# PRY
# IND
# NPL
# PNG
# BEN
# SLE
# PHL
# LKA
# IDN
# MDG
# GEO
# ARM
# MYS
# ZMB
# SGP
# GTM
# HND
# SLV
# BGD
# NGA
# TUN
# MOZ
# HKG
# LBN
# MAR
# TZA
# THA
# JOR
# UGA
# TUR
# PAK
# KWT
# DZA
# IRQ
# AGO
# KGZ
# ZWE
# QAT
# OMN
# KHM
# KAZ
# RWA
# GAB
# VNM
# EGY
# ETH
# ARE
# SWZ
# COG
# BDI
# CMR
# NIC
# VEN
# LAO
# UZB
# RUS
# BHR
# CUB
# SAU
# CHN
# AZE
# CAF
# TJK
# TKM
# PurchasingPower_rel_D
# FIN
# SWE
# NZL
# NOR
# CAN
# LUX
# IRL
# URY
# CHE
# EST
# PRT
# JPN
# BEL
# CZE
# CHL
# ISL
# DEU
# AUS
# AUT
# CPV
# GBR
# CRI
# CYP
# ESP
# BHS
# LTU
# FRA
# ITA
# SVK
# LVA
# BLZ
# MLT
# ...

# %%
countries_dict
# Out:
# {'FIN': [{'id': 'BIP_rel_D',
#    'displayValue': 0.953197301807386,
#    'binValue': 0.953197301807386},
#   {'id': 'PurchasingPower_rel_D',
#    'displayValue': 1.07528416860086,
#    'binValue': 1.05578341804377},
#   {'id': 'Cost_BIP_Ratio',
#    'displayValue': 1.12808142297715,
#    'binValue': 1.12808142297715},
#   {'id': 'Bevoelkerungsdichte',
#    'displayValue': 18.3705454665088,
#    'binValue': 18.3705454665088},
#   {'id': 'Freedom_Score', 'displayValue': 100.0, 'binValue': 95.3},
#   {'id': 'PISA_Score', 'displayValue': 495.0, 'binValue': 495.0},
#   {'id': 'Sonnenstunde_pro_Tag',
#    'displayValue': 5.035616438356165,
#    'binValue': 5.035616438356165},
#   {'id': 'Zeitunterschied_D', 'displayValue': 1.0, 'binValue': 1.0},
#   {'id': 'Rang_Kueche', 'displayValue': 64.0, 'binValue': 64.0},
#   {'id': 'HoechsterPunkt_m', 'displayValue': 1324.0, 'binValue': 1324.0},
#   {'id': 'NiedrigsterPunkt_m', 'displayValue': 0.0, 'binValue': 0.0},
# ...

# %%
def skew_trimmer(col):

    safe_countries_enough_data_red[col]

    # Get the 90th percentile value (upper 10%)
    threshold_upper = safe_countries_enough_data_red[col].quantile(percentile_upper*0.01)

    # Filter rows where column values are >= 90th percentile
    upper_10_percent = safe_countries_enough_data_red[safe_countries_enough_data_red[col] >= threshold_upper]

    # Get the 90th percentile value (upper 10%)
    threshold_lower = safe_countries_enough_data_red[col].quantile(percentile_lower*0.01)

    # Filter rows where column values are >= 90th percentile
    lower_10_percent = safe_countries_enough_data_red[safe_countries_enough_data_red[col] <= threshold_lower]
    
    middle_df=safe_countries_enough_data_red[safe_countries_enough_data_red[col] > threshold_lower]
    middle_df=middle_df[middle_df[col] < threshold_upper]
    return(middle_df, threshold_upper,threshold_lower)

# %%
boundaries_dict={}
for col in safe_countries_enough_data_red.columns[3:]:
    if "boolean" in col:
        boundaries_dict[col]={"upper":int(1),
                              "lower":int(0)}
    else:
        results_list=skew_trimmer(col)
        boundaries_dict[col]={"upper":float(results_list[1]),
                              "lower":float(results_list[2])}

# %%
boundaries_dict
# Out:
# {'BIP_rel_D': {'upper': 0.9809620589583538, 'lower': 0.02186878335655002},
#  'PurchasingPower_rel_D': {'upper': 1.05578341804377,
#   'lower': 0.3521622622967434},
#  'Cost_BIP_Ratio': {'upper': 17.1218235494645, 'lower': 1.006681117984286},
#  'Bevoelkerungsdichte': {'upper': 385.6894638224061,
#   'lower': 13.997530728904694},
#  'Freedom_Score': {'upper': 95.3, 'lower': 14.700000000000001},
#  'PISA_Score': {'upper': 501.0, 'lower': 360.0},
#  'Sonnenstunde_pro_Tag': {'upper': 8.683360730593613,
#   'lower': 4.796849315068493},
#  'Zeitunterschied_D': {'upper': 7.0, 'lower': 0.0},
#  'Rang_Kueche': {'upper': 91.10000000000001, 'lower': 10.9},
#  'HoechsterPunkt_m': {'upper': 6028.299999999999, 'lower': 683.2},
#  'NiedrigsterPunkt_m': {'upper': 317.40000000000026, 'lower': 0.0},
#  'EnglishSkill': {'upper': 592.1, 'lower': 426.4},
#  'BuerokratieScore': {'upper': 1.520755338668824,
#   'lower': -0.9797395646572123},
#  'MaxTemperatur': {'upper': 38.716, 'lower': 26.103},
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_style("whitegrid")

# Get numeric columns
numeric_cols = safe_countries_enough_data_red.select_dtypes(include=[np.number]).columns

# Create subplots
n_cols = 4
n_rows = len(numeric_cols) // n_cols + (1 if len(numeric_cols) % n_cols > 0 else 0)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5*n_rows))
axes = axes.flatten() if n_rows > 1 else [axes] if n_cols == 1 else axes
edges_dict={}
for i, col in enumerate(numeric_cols):
    df_to_plot=skew_trimmer(col)[0]
    sns.histplot(data=df_to_plot, x=col, ax=axes[i], kde=1, bins=15)
    axes[i].set_title(f'Distribution of {col}')
    # Create histogram and capture the bin information
    data = df_to_plot[col].dropna()

# Create histogram and capture the bin information
    counts, bin_edges, patches = plt.hist(data, bins=15)
    edges_dict[col]=bin_edges
    print(f"Bin edges: {bin_edges}")
    print(f"Bin counts: {counts}")
    print(f"Number of bins: {len(bin_edges) - 1}")



# Hide unused subplots
for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# Bin edges: [0.02213405 0.08551197 0.1488899  0.21226783 0.27564575 0.33902368
#  0.4024016  0.46577953 0.52915746 0.59253538 0.65591331 0.71929124
#  0.78266916 0.84604709 0.90942502 0.97280294]
# Bin counts: [31. 17.  9.  6.  6.  4.  5.  3.  6.  3.  2.  2.  1.  2.  5.]
# Number of bins: 15
# Bin edges: [0.35424203 0.40082279 0.44740354 0.4939843  0.54056506 0.58714581
#  0.63372657 0.68030733 0.72688809 0.77346884 0.8200496  0.86663036
#  0.91321111 0.95979187 1.00637263 1.05295338]
# Bin counts: [13. 14. 13.  7.  9.  8.  6.  7.  1. 13.  3.  1.  1.  3.  2.]
# Number of bins: 15
# Bin edges: [ 1.00952581  2.08333793  3.15715005  4.23096216  5.30477428  6.3785864
#   7.45239852  8.52621063  9.60002275 10.67383487 11.74764698 12.8214591
#  13.89527122 14.96908333 16.04289545 17.11670757]
# Bin counts: [38. 12. 12.  9.  7.  6.  2.  3.  2.  3.  1.  2.  2.  0.  2.]
# Number of bins: 15
# Bin edges: [ 15.1524803   39.83038976  64.50829922  89.18620868 113.86411814
# ...

# %%
# First install the library if you haven't: pip install pycountry-convert
import pycountry_convert as pc

def get_continent_from_iso3(iso3_code):
    """
    Convert ISO-3 country code to continent name
    """
    try:
        # Convert ISO3 to ISO2
        iso2_code = pc.country_alpha3_to_country_alpha2(iso3_code)
        # Get continent code
        continent_code = pc.country_alpha2_to_continent_code(iso2_code)
        # Convert continent code to continent name
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except:
        return "Unknown"

# Test with some examples
test_codes = ['USA', 'GBR', 'DEU', 'JPN', 'BRA', 'EGY', 'AUS']
for code in test_codes:
    continent = get_continent_from_iso3(code)
    print(f"{code}: {continent}")
# Out:
# USA: North America
# GBR: Europe
# DEU: Europe
# JPN: Asia
# BRA: South America
# EGY: Africa
# AUS: Oceania

# %%
english_to_german_continents = {
    'Europe': 'Europa',
    'North America': 'Nordamerika', 
    'South America': 'Südamerika',
    'Asia': 'Asien',
    'Africa': 'Afrika',
    'Oceania': 'Ozeanien',
    'Antarctica': 'Antarktis',
    'Unknown': 'Unbekannt'
}

# %%
country_info_json=[]
for isocode in countries_dict.keys():
    print(isocode)
    continent=get_continent_from_iso3(isocode)
    land=df_to_check[df_to_check["Country Code"]==isocode]["Land"].values[0]
    country_name=df_to_check[df_to_check["Country Code"]==isocode]["Country Name"].values[0]
    german_continent_name=english_to_german_continents[continent]
    country_entry={"id":isocode,"label":land,"country":country_name,"groupID":continent,"groupLabel":german_continent_name,"output":countries_dict[isocode]}
    country_info_json.append(country_entry)
country_info_json
# Out:
# FIN
# SWE
# NZL
# NOR
# CAN
# LUX
# IRL
# URY
# CHE
# EST
# PRT
# JPN
# BEL
# CZE
# CHL
# ISL
# DEU
# AUS
# AUT
# CPV
# GBR
# CRI
# CYP
# ESP
# BHS
# LTU
# FRA
# ITA
# SVK
# LVA
# BLZ
# MLT
# MUS
# ARG
# USA
# MNG
# STP
# PAN
# HRV
# POL
# ROU
# TTO
# KOR
# ZAF
# JAM
# SUR
# SYC
# BGR
# BWA
# GUY
# NAM
# ISR
# BRA
# COL
# SEN
# DOM
# PER
# MKD
# LSO
# MWI
# HUN
# BOL
# ECU
# LBR
# PRY
# IND
# NPL
# PNG
# BEN
# SLE
# PHL
# LKA
# IDN
# MDG
# GEO
# ARM
# MYS
# ZMB
# SGP
# GTM
# HND
# SLV
# BGD
# NGA
# TUN
# MOZ
# HKG
# LBN
# MAR
# TZA
# THA
# JOR
# UGA
# TUR
# PAK
# KWT
# DZA
# IRQ
# AGO
# KGZ
# ZWE
# QAT
# OMN
# KHM
# KAZ
# RWA
# GAB
# VNM
# EGY
# ETH
# ARE
# SWZ
# COG
# BDI
# CMR
# NIC
# VEN
# LAO
# UZB
# RUS
# BHR
# CUB
# SAU
# CHN
# AZE
# CAF
# TJK
# TKM
# [{'id': 'FIN',
#   'label': 'Finnland',
#   'country': 'Finland',
#   'groupID': 'Europe',
#   'groupLabel': 'Europa',
#   'output': [{'id': 'BIP_rel_D',
#     'displayValue': 0.953197301807386,
# ...

# %%
import json

# Write with nice formatting
with open('country_info_formatted.json', 'w', encoding='utf-8') as f:
    json.dump(country_info_json, f, 
              indent=4,           # 4-space indentation
              ensure_ascii=False, # Keep unicode characters (like ä, ü, ö)
              sort_keys=1)     # Sort keys alphabetically

print("Formatted JSON file saved!")
# Out:
# Formatted JSON file saved!

# %%
safe_countries_enough_data_red.columns
# Out:
# Index(['Country Name', 'Country Code', 'Land', 'BIP_rel_D',
#        'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'Bevoelkerungsdichte',
#        'Freedom_Score', 'PISA_Score', 'Sonnenstunde_pro_Tag',
#        'Zeitunterschied_D', 'Rang_Kueche', 'HoechsterPunkt_m',
#        'NiedrigsterPunkt_m', 'EnglishSkill', 'BuerokratieScore',
#        'MaxTemperatur', 'MinTemperatur', 'LivingConditions', 'Healthcare',
#        'CostofLiving', 'LGBTQ', 'Mehrals5Morde_pro_100k_boolean',
#        'Mehrals1000Deutsche_boolean', 'Alkoholverbot_boolean',
#        'Kueste_boolean', 'Christian_boolean', 'Muslim_boolean',
#        'Jewish_boolean'],
#       dtype='object')

# %%
# Fixed version - use lists as VALUES, not wrapped in sets
classifier_dict = {
    "Geografie/Klima": [
        'Sonnenstunde_pro_Tag', 'Kueste_boolean', 'HoechsterPunkt_m', 
        'NiedrigsterPunkt_m', 'MaxTemperatur', 'MinTemperatur', 'Zeitunterschied_D'
    ],
    
    "Wirtschaftslage/Gesundheit": [
        'BIP_rel_D', 'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 
        'CostofLiving', 'LivingConditions', 'Healthcare'
    ],
    
    "Freiheit/Sicherheit": [
        'Mehrals5Morde_pro_100k_boolean', 'Freedom_Score', 'BuerokratieScore', 'LGBTQ', 'Alkoholverbot_boolean'
    ],
    
    "Menschen/Religion": [
        'Bevoelkerungsdichte', 'PISA_Score', 'Rang_Kueche', 
        'EnglishSkill', 'Mehrals1000Deutsche_boolean','Christian_boolean', 'Muslim_boolean',
        'Jewish_boolean'
    ]
}

print(classifier_dict)
# Out:
# {'Geografie/Klima': ['Sonnenstunde_pro_Tag', 'Kueste_boolean', 'HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'MaxTemperatur', 'MinTemperatur', 'Zeitunterschied_D'], 'Wirtschaftslage/Gesundheit': ['BIP_rel_D', 'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'CostofLiving', 'LivingConditions', 'Healthcare'], 'Freiheit/Sicherheit': ['Mehrals5Morde_pro_100k_boolean', 'Freedom_Score', 'BuerokratieScore', 'LGBTQ', 'Alkoholverbot_boolean'], 'Menschen/Religion': ['Bevoelkerungsdichte', 'PISA_Score', 'Rang_Kueche', 'EnglishSkill', 'Mehrals1000Deutsche_boolean', 'Christian_boolean', 'Muslim_boolean', 'Jewish_boolean']}

# %%
# Create a reverse mapping: column -> category
column_to_category = {}
for category, columns in classifier_dict.items():
    for column in columns:
        column_to_category[column] = category

print("Column to Category mapping:")
print(column_to_category)
# Out:
# Column to Category mapping:
# ...

# %%
id_title={'Sonnenstunde_pro_Tag': 'Durchschnittliche Sonnenstunden pro Tag',
  'Kueste_boolean': 'Hat das Land eine Küste?', 
  'HoechsterPunkt_m': 'Höchster Punkt des Landes', 
  'NiedrigsterPunkt_m': "Niedrigster Punkt des Landes", 
  'MaxTemperatur': 'Maximale mittlere Monatstemperatur', 
  'MinTemperatur': 'Minimale mittlere Monatstemperatur', 
  'Zeitunterschied_D': 'Zeitverschiebung zu Deutschland', 
  'BIP_rel_D': 'Bruttoinlandsprodukt im Vergleich zu Deutschland', 
  'PurchasingPower_rel_D': 'Kaufkraft im Vergleich zu Deutschland', 
  'Cost_BIP_Ratio': 'Verhältnis Kaufkraft zu Bruttoinlandsprodukt', 
  'CostofLiving': 'Lebenshaltungskosten', 
  'LivingConditions': 'Lebensbedinungen', 
  'Healthcare': 'Gesundheitssystem', 
  'Christian_boolean': 'Gibt es eine christliche Bevölkerung?', 
  'Muslim_boolean': 'Gibt es eine muslimische Bevölkerung?', 
  'Jewish_boolean': 'Gibt es eine jüdische Bevölkerung?', 
  'Mehrals5Morde_pro_100k_boolean': 'Mehr als 5 Morde pro 100.000 Einwohner', 
  'Freedom_Score': 'Freiheit-Score von Freedom House', 
  'BuerokratieScore': 'Bürokratie-Score der Weltbank', 
  'LGBTQ': 'LGBTQ-Rechte-Index von EqualDex ', 
  'Alkoholverbot_boolean': 'Gibt es ein striktes Alkoholverbot?', 
  'Bevoelkerungsdichte': 'Bevöllkerungsdichte', 
  'PISA_Score': 'PISA-Durchschnitt 2022', 
  'Rang_Kueche': 'Ranking der Küche von Taste Atlas', 
  'EnglishSkill': 'Englisch-Skills gemäß EF', 
  'Mehrals1000Deutsche_boolean': 'Mehr als 1000 Deutsche im Land'}

# %%
id_einheit={'Sonnenstunde_pro_Tag': 'Stunden',
            'Kueste_boolean': 'Nein/Ja',
  'HoechsterPunkt_m': 'm', 
  'NiedrigsterPunkt_m': 'm', 
  'MaxTemperatur': '°C', 
  'MinTemperatur': '°C', 
  'Zeitunterschied_D': 'hours', 
  'BIP_rel_D': '%', 
  'PurchasingPower_rel_D': '%', 
  'Cost_BIP_Ratio': 'Ratio', 
  'CostofLiving': '$', 
  'LivingConditions': 'Indexpunkte', 
  'Healthcare': 'Indexpunkte', 
  'Freedom_Score': 'Indexpunkte', 
  'BuerokratieScore': 'Indexpunkte', 
  'LGBTQ': 'Indexpunkte', 
  'Alkoholverbot': 'Nein/Ja', 
  'Bevoelkerungsdichte': 'Ew./km2', 
  'PISA_Score': 'Indexpunkte', 
  'Rang_Kueche': 'Rang', 
  'EnglishSkill': 'Indexpunkte', 
  'Anzahl_der_Deutschen_numeric': 'Ew.',
  'Christian_boolean': 'Nein/Ja', 
  'Muslim_boolean': 'Nein/Ja', 
  'Jewish_boolean': 'Nein/Ja', 
  'Mehrals5Morde_pro_100k_boolean': 'Nein/Ja', 
    'Alkoholverbot_boolean': 'Nein/Ja', 
    "Mehrals1000Deutsche_boolean": 'Nein/Ja'}

# %%
boundaries_dict
# Out:
# {'BIP_rel_D': {'upper': 0.9809620589583538, 'lower': 0.02186878335655002},
#  'PurchasingPower_rel_D': {'upper': 1.05578341804377,
#   'lower': 0.3521622622967434},
#  'Cost_BIP_Ratio': {'upper': 17.1218235494645, 'lower': 1.006681117984286},
#  'Bevoelkerungsdichte': {'upper': 385.6894638224061,
#   'lower': 13.997530728904694},
#  'Freedom_Score': {'upper': 95.3, 'lower': 14.700000000000001},
#  'PISA_Score': {'upper': 501.0, 'lower': 360.0},
#  'Sonnenstunde_pro_Tag': {'upper': 8.683360730593613,
#   'lower': 4.796849315068493},
#  'Zeitunterschied_D': {'upper': 7.0, 'lower': 0.0},
#  'Rang_Kueche': {'upper': 91.10000000000001, 'lower': 10.9},
#  'HoechsterPunkt_m': {'upper': 6028.299999999999, 'lower': 683.2},
#  'NiedrigsterPunkt_m': {'upper': 317.40000000000026, 'lower': 0.0},
#  'EnglishSkill': {'upper': 592.1, 'lower': 426.4},
#  'BuerokratieScore': {'upper': 1.520755338668824,
#   'lower': -0.9797395646572123},
#  'MaxTemperatur': {'upper': 38.716, 'lower': 26.103},
# ...

# %%
colour_category_dict={
    "Geografie/Klima": "yellow",
    "Wirtschaftslage/Gesundheit": "green",  
    "Freiheit/Sicherheit": "blue",  
    "Menschen/Religion": "orange"}

# %%
input_json=[]
for category in classifier_dict.keys():
    print(category)
    print(classifier_dict[category])
    items_json=[]
    for item in classifier_dict[category]:
        #print(item)
        #print(category)
        if "_boolean" in item:
            filtertype="boolean"
            print(item)
        else:
            filtertype="slider"
        category_input={
        "type": filtertype,
        "id": item,
        "title": id_title[item],
        "category": column_to_category[item],
        "color": colour_category_dict[category],
        "inititalMin": boundaries_dict[item]["lower"],
        "inititalMax": boundaries_dict[item]["upper"],
        "filter": {
        "min":boundaries_dict[item]["lower"],
        "max": boundaries_dict[item]["upper"],
        "threshold": edges_dict[item].tolist(),
        "unit": id_einheit[item]
        }
  
    }
        items_json.append(category_input)
    input_json.append({
        "title": category,
        "color": colour_category_dict[category],
        "items": items_json
    })
input_json
# Out:
# Geografie/Klima
# ['Sonnenstunde_pro_Tag', 'Kueste_boolean', 'HoechsterPunkt_m', 'NiedrigsterPunkt_m', 'MaxTemperatur', 'MinTemperatur', 'Zeitunterschied_D']
# Kueste_boolean
# Wirtschaftslage/Gesundheit
# ['BIP_rel_D', 'PurchasingPower_rel_D', 'Cost_BIP_Ratio', 'CostofLiving', 'LivingConditions', 'Healthcare']
# Freiheit/Sicherheit
# ['Mehrals5Morde_pro_100k_boolean', 'Freedom_Score', 'BuerokratieScore', 'LGBTQ', 'Alkoholverbot_boolean']
# Mehrals5Morde_pro_100k_boolean
# Alkoholverbot_boolean
# Menschen/Religion
# ['Bevoelkerungsdichte', 'PISA_Score', 'Rang_Kueche', 'EnglishSkill', 'Mehrals1000Deutsche_boolean', 'Christian_boolean', 'Muslim_boolean', 'Jewish_boolean']
# Mehrals1000Deutsche_boolean
# Christian_boolean
# Muslim_boolean
# Jewish_boolean
# [{'title': 'Geografie/Klima',
#   'color': 'yellow',
#   'items': [{'type': 'slider',
#     'id': 'Sonnenstunde_pro_Tag',
#     'title': 'Durchschnittliche Sonnenstunden pro Tag',
#     'category': 'Geografie/Klima',
# ...

# %%
input_json
# Out:
# [{'title': 'Geografie/Klima',
#   'color': 'yellow',
#   'items': [{'type': 'slider',
#     'id': 'Sonnenstunde_pro_Tag',
#     'title': 'Durchschnittliche Sonnenstunden pro Tag',
#     'category': 'Geografie/Klima',
#     'color': 'yellow',
#     'inititalMin': 4.796849315068493,
#     'inititalMax': 8.683360730593613,
#     'filter': {'min': 4.796849315068493,
#      'max': 8.683360730593613,
#      'threshold': [4.8054794520547945,
#       5.061455098934552,
#       5.317430745814309,
#       5.573406392694066,
#       5.829382039573822,
#       6.08535768645358,
#       6.341333333333337,
#       6.597308980213094,
#       6.853284627092851,
#       7.109260273972608,
#       7.365235920852365,
#       7.6212115677321215,
#       7.8771872146118795,
#       8.133162861491636,
#       8.389138508371392,
#       8.64511415525115],
#      'unit': 'Stunden'}},
#    {'type': 'boolean',
#     'id': 'Kueste_boolean',
#     'title': 'Hat das Land eine Küste?',
# ...

# %%
# Write with nice formatting
with open('input_formatted.json', 'w', encoding='utf-8') as f:
    json.dump(input_json, f, 
              indent=4,           # 4-space indentation
              ensure_ascii=False, # Keep unicode characters (like ä, ü, ö)
              sort_keys=1)     # Sort keys alphabetically

print("Formatted JSON file saved!")
# Out:
# Formatted JSON file saved!
