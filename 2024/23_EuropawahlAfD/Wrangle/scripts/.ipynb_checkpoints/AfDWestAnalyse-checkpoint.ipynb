# %%
import pandas as pd

# %%
#we take in the data for the current european elections
current_europe_election=pd.read_csv("../data/kerg.csv",skiprows=2, sep=';',dtype=str)
#but only when it is on Kreis-level of administration
current_europe_election=current_europe_election[(current_europe_election["Nr"].str.len()>4)]

# %%
columnarray=[]
for columnname in current_europe_election.columns:
#we rephrase the name of the columns by going through the columnnames    
    if("Unnamed" in columnname):
        columnarray.append(previousrow+"_2019")
    else:
        columnarray.append(columnname+"_2024")
    previousrow=columnname
current_europe_election.columns=columnarray
current_europe_election=current_europe_election.dropna(subset=["Gebiet_2024"])
current_europe_election
# Out:
#     Nr_2024             Gebiet_2024 gehört zu_2024 Wahlberechtigte_2024  \
# 2     01001        Flensburg, Stadt             01                70929
# 3     01002  Kiel, Landeshauptstadt             01               187041
# 4     01003      Lübeck, Hansestadt             01               166429
# 5     01004       Neumünster, Stadt             01                59983
# 6     01051            Dithmarschen             01               108756
# ..      ...                     ...            ...                  ...
# 427   16073     Saalfeld-Rudolstadt             16                84724
# 428   16074    Saale-Holzland-Kreis             16                67684
# 429   16075        Saale-Orla-Kreis             16                64882
# 430   16076                   Greiz             16                80024
# 431   16077        Altenburger Land             16                72674
#
#     Wahlberechtigte_2019 Wählende_2024 Wählende_2019 Ungültige Stimmen_2024  \
# 2                  70431         41851         39647                    299
# 3                 186195        117097        109595                    550
# 4                 166530         96558         90946                    604
# 5                  60215         33019         29036                    282
# 6                 107045         68033         58244                    506
# ..                   ...           ...           ...                    ...
# 427                88342         49575         53882                    329
# 428                68278         45600         45101                    411
# 429                67029         38507         42514                    183
# 430                82940         52514         53197                    509
# 431                75936         43444         42954                    386
#
#     Ungültige Stimmen_2019 Gültige Stimmen_2024  ...  \
# 2                      237                41552  ...
# 3                      577               116547  ...
# 4                      461                95954  ...
# 5                      231                32737  ...
# 6                      475                67527  ...
# ..                     ...                  ...  ...
# 427                   1034                49246  ...
# 428                   1003                45189  ...
# 429                    884                38324  ...
# 430                   1139                52005  ...
# 431                   1053                43058  ...
#
#     Parlament aufmischen – Stimme der Letzten Generation_2019  \
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
# 430                                                NaN
# 431                                                NaN
#
#     Partei der Vernunft_2024 Partei der Vernunft_2019  \
# 2                         43                      NaN
# 3                         63                      NaN
# 4                         79                      NaN
# 5                         24                      NaN
# 6                         55                      NaN
# ..                       ...                      ...
# 427                       38                      NaN
# 428                       31                      NaN
# 429                       27                      NaN
# 430                       37                      NaN
# 431                       36                      NaN
#
#     Partei des Fortschritts_2024 Partei des Fortschritts_2019  \
# 2                            340                          NaN
# 3                            832                          NaN
# 4                            604                          NaN
# 5                            313                          NaN
# 6                            421                          NaN
# ..                           ...                          ...
# 427                          172                          NaN
# 428                          145                          NaN
# 429                           98                          NaN
# 430                          147                          NaN
# 431                          112                          NaN
#
#     V-Partei³ - Partei für Veränderung, Vegetarier und Veganer_2024  \
# 2                                                   87
# 3                                                  210
# 4                                                  158
# 5                                                   53
# 6                                                   77
# ..                                                 ...
# 427                                                 41
# 428                                                 52
# 429                                                 29
# 430                                                 49
# 431                                                 50
#
#     V-Partei³ - Partei für Veränderung, Vegetarier und Veganer_2019  \
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
# 430                                                NaN
# 431                                                NaN
#
#     Übrige_2024 Übrige_2019 Unnamed: 82_2019
# 2           NaN         732              NaN
# 3           NaN        1733              NaN
# 4           NaN        1401              NaN
# 5           NaN         582              NaN
# 6           NaN        1055              NaN
# ..          ...         ...              ...
# 427         NaN        1736              NaN
# 428         NaN        1500              NaN
# 429         NaN        1359              NaN
# 430         NaN        1833              NaN
# 431         NaN        1461              NaN
#
# [400 rows x 84 columns]

# %%
#and take only the data for the afd and all valid votes and the district number
current_europe_election_afd=current_europe_election[["Nr_2024","Gebiet_2024","Gültige Stimmen_2024","Alternative für Deutschland_2024"]]
current_europe_election_afd[current_europe_election_afd["Nr_2024"]=="11000"]
# Out:
#     Nr_2024    Gebiet_2024 Gültige Stimmen_2024  \
# 346   11000  Berlin, Stadt              1545022
#
#     Alternative für Deutschland_2024
# 346                           179298

# %%
#we get the data for the last german election 
latest_german_election=pd.read_csv("../data/btw2021kreis.csv",skiprows=4, sep=';',dtype=str)
latest_german_election=latest_german_election[(latest_german_election["Statistische Kennziffer"].str.len()>4)]
#and sum the  data for berlin because it was split in east and west

berlin_latest_election=latest_german_election[latest_german_election["Kreisfreie Stadt bzw. Stadtkreis, Landkreis bzw. Kreis"].astype(str).str.contains("Berlin")]
berlin_latest_election[berlin_latest_election.columns[3:]]=berlin_latest_election[berlin_latest_election.columns[3:]].astype(int)
berlin_df_added=pd.DataFrame(berlin_latest_election.sum()).T
berlin_df_added["Land"]="BE"
berlin_df_added["Statistische Kennziffer"]="11000"
berlin_df_added["Kreisfreie Stadt bzw. Stadtkreis, Landkreis bzw. Kreis"]="Berlin"
berlin_df_added
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/3630396570.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berlin_latest_election[berlin_latest_election.columns[3:]]=berlin_latest_election[berlin_latest_election.columns[3:]].astype(int)
#   Land Statistische Kennziffer  \
# 0   BE                   11000
#
#   Kreisfreie Stadt bzw. Stadtkreis, Landkreis bzw. Kreis Wahlberechtigte  \
# 0                                             Berlin             2468919
#
#     Wähler Ungültige  Gültige     CDU     SPD     AfD  ... III. Weg.1  \
# 0  1856903     31631  1825272  344838  417163  147134  ...          0
#
#   Bündnis21.1 LIEBE.1 LKR.1 PdF LfK SSW.1 Team Todenhöfer.1 UNABHÄNGIGE.1  \
# 0           0       0  1232   0   0     0             20168             0
#
#   Volt.1
# 0  11645
#
# [1 rows x 94 columns]

# %%
latest_german_election_columns=[]
#again some columnname cleaning
for column in latest_german_election.columns:
    column=column.replace(".1","_Zweitstimme")
    latest_german_election_columns.append(column+"_2021")
latest_german_election=pd.concat([latest_german_election,berlin_df_added]).reset_index(drop=True)
latest_german_election.columns=latest_german_election_columns
#and we take in the data for the Afd an the list votes
latest_german_election_afd=latest_german_election[["Statistische Kennziffer_2021","Gültige_Zweitstimme_2021",'AfD_Zweitstimme_2021']]
latest_german_election_afd=latest_german_election_afd.dropna(subset=["Statistische Kennziffer_2021"])
latest_german_election_afd
election_dict["2021"]=latest_german_election_afd
latest_german_election_afd
# Out:
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 0                          01001                    50818                 2756
# 1                          01002                   139961                 7023
# 2                          01003                   117674                 7807
# 3                          01004                    39971                 3751
# 4                          01051                    80616                 7098
# ..                           ...                      ...                  ...
# 397                        16074                    52510                12865
# 398                        16075                    49552                15071
# 399                        16076                    61146                16908
# 400                        16077                    52844                15576
# 401                        11000                  1826581               153694
#
# [402 rows x 3 columns]

# %%
#we take the data for 2019s european election
european_election_2019=pd.read_csv("../data/ew19_kerg.csv",skiprows=2, sep=';',dtype=str)
european_election_2019=european_election_2019[(european_election_2019["Nr"].str.len()>4)]

columnarray=[]
for columnname in european_election_2019.columns:
    
    if("Unnamed" in columnname):
        columnarray.append(previousrow+"_2014")
    else:
        columnarray.append(columnname+"_2019")
    previousrow=columnname
european_election_2019.columns=columnarray
european_election_2019=european_election_2019.dropna(subset=["Gebiet_2019"])
european_election_2019_afd=european_election_2019[["Nr_2019","Gültige_2019","Alternative für Deutschland_2019","Gültige_2014","Alternative für Deutschland_2014"]]
european_election_2019_afd[european_election_2019_afd["Nr_2019"]=="11000"]
# Out:
#     Nr_2019 Gültige_2019 Alternative für Deutschland_2019 Gültige_2014  \
# 346   11000      1507357                           149177      1159666
#
#     Alternative für Deutschland_2014
# 346                            91759

# %%
#we take the data for 2017 german election

german_election_2017=pd.read_csv("../data/btw2017kreis.csv",skiprows=4, sep=';',dtype=str,encoding="latin")
german_election_2017=german_election_2017[(german_election_2017["Statistische Kennziffer"].str.len()>4)]

berlin_2017_election=german_election_2017[german_election_2017["Kreisfreie Stadt bzw. Stadtkreis, Landkreis bzw. Kreis"].astype(str).str.contains("Berlin")]
berlin_2017_election[berlin_2017_election.columns[3:]]=berlin_2017_election[berlin_2017_election.columns[3:]].astype(int)
berlin_2017_election=pd.DataFrame(berlin_2017_election.sum()).T
berlin_2017_election["Land"]="BE"
berlin_2017_election["Statistische Kennziffer"]="11000"
berlin_2017_election["Kreisfreie Stadt bzw. Stadtkreis, Landkreis bzw. Kreis"]="Berlin"
berlin_2017_election
german_election_2017_columns=[]
for column in german_election_2017.columns:
    column=column.replace(".1","_Zweitstimme")
    german_election_2017_columns.append(column+"_2017")
german_election_2017=pd.concat([german_election_2017,berlin_2017_election]).reset_index(drop=True)

german_election_2017.columns=german_election_2017_columns
german_election_2017_afd=german_election_2017[["Statistische Kennziffer_2017","Gültige_Zweitstimme_2017",'AfD_Zweitstimme_2017']]
german_election_2017_afd=german_election_2017_afd.dropna(subset=["Statistische Kennziffer_2017"])
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/65852515.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   berlin_2017_election[berlin_2017_election.columns[3:]]=berlin_2017_election[berlin_2017_election.columns[3:]].astype(int)

# %%
german_election_2017_afd[german_election_2017_afd["Statistische Kennziffer_2017"]=="11000"]
# Out:
#     Statistische Kennziffer_2017 Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017
# 402                        11000                  1869042               225170

# %%
# we take the data for the german election from 2012
german_election_2013=pd.read_csv("../data/btw2013kreis.csv",skiprows=4, sep=';',dtype=str,encoding="latin")
german_election_2013=german_election_2013[(german_election_2013["Statistische Kennziffer"].str.len()>4)]
german_election_2013[german_election_2013["Statistische Kennziffer"]=="11000"]
german_election_2013_columns=[]
for column in german_election_2013.columns:
    column=column.replace(".1","_Zweitstimme")
    german_election_2013_columns.append(column+"_2013")

german_election_2013.columns=german_election_2013_columns
german_election_2013_afd=german_election_2013[["Statistische Kennziffer_2013","Gültige_Zweitstimme_2013",'AfD_Zweitstimme_2013']]
german_election_2013_afd=german_election_2013_afd.dropna(subset=["Statistische Kennziffer_2013"])
election_dict["2013"]=german_election_2013_afd
german_election_2013_afd[german_election_2013_afd["Statistische Kennziffer_2013"]=="11000"]
# Out:
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013 AfD_Zweitstimme_2013
# 326                        11000                  1787721                88060

# %%
#and we sub in the old kreis number for goettingen
german_election_2013_afd["Statistische Kennziffer_2013"]=german_election_2013_afd["Statistische Kennziffer_2013"].str.replace("03152","03159")

# %%
#we merge the german election data from 2013 and 2017
german_elections_2013_2017=pd.merge(german_election_2013_afd,german_election_2017_afd,left_on="Statistische Kennziffer_2013",right_on="Statistische Kennziffer_2017", how="outer")
german_elections_2013_2017[german_elections_2013_2017["Statistische Kennziffer_2013"]=="11000"]
# Out:
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 325                        11000                  1787721
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 325                88060                        11000
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017
# 325                  1869042               225170

# %%
#and then from 2021
german_elections_2013_2017_2021=pd.merge(german_elections_2013_2017,latest_german_election_afd,left_on="Statistische Kennziffer_2017",right_on="Statistische Kennziffer_2021", how="outer")
german_elections_2013_2017_2021[german_elections_2013_2017_2021["Statistische Kennziffer_2013"]=="11000"]
# Out:
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 324                        11000                  1787721
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 324                88060                        11000
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017  \
# 324                  1869042               225170
#
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 324                        11000                  1826581               153694

# %%
#we merge the european election data from 2024 and 2019
europe_elections=pd.merge(current_europe_election_afd,european_election_2019_afd,left_on="Nr_2024",right_on="Nr_2019",how="outer")
europe_elections
# Out:
#     Nr_2024             Gebiet_2024 Gültige Stimmen_2024  \
# 0     01001        Flensburg, Stadt                41552
# 1     01002  Kiel, Landeshauptstadt               116547
# 2     01003      Lübeck, Hansestadt                95954
# 3     01004       Neumünster, Stadt                32737
# 4     01051            Dithmarschen                67527
# ..      ...                     ...                  ...
# 396   16073     Saalfeld-Rudolstadt                49246
# 397   16074    Saale-Holzland-Kreis                45189
# 398   16075        Saale-Orla-Kreis                38324
# 399   16076                   Greiz                52005
# 400   16077        Altenburger Land                43058
#
#     Alternative für Deutschland_2024 Nr_2019 Gültige_2019  \
# 0                               4273   01001        39410
# 1                               9351   01002       109018
# 2                              10290   01003        90485
# 3                               5697   01004        28805
# 4                              11005   01051        57769
# ..                               ...     ...          ...
# 396                            17307   16073        52848
# 397                            14404   16074        44098
# 398                            14426   16075        41630
# 399                            18399   16076        52058
# 400                            15893   16077        41901
#
#     Alternative für Deutschland_2019 Gültige_2014  \
# 0                               2477        25174
# 1                               6459        75336
# 2                               6773        62509
# 3                               2761        27250
# 4                               5121        42350
# ..                               ...          ...
# 396                            14592        46150
# 397                            10210        40150
# 398                            11264        37348
# 399                            13297        47189
# 400                            11371        37657
#
#     Alternative für Deutschland_2014
# 0                               1583
# 1                               4418
# 2                               4334
# 3                               1960
# 4                               2325
# ..                               ...
# 396                             4107
# 397                             3920
# 398                             3114
# 399                             4559
# 400                             3023
#
# [401 rows x 9 columns]

# %%
europe_elections[europe_elections["Gebiet_2024"].astype(str).str.contains("Berlin")]
# Out:
#     Nr_2024    Gebiet_2024 Gültige Stimmen_2024  \
# 324   11000  Berlin, Stadt              1545022
#
#     Alternative für Deutschland_2024 Nr_2019 Gültige_2019  \
# 324                           179298   11000      1507357
#
#     Alternative für Deutschland_2019 Gültige_2014  \
# 324                           149177      1159666
#
#     Alternative für Deutschland_2014
# 324                            91759

# %%
#then we filter only for the relevant columns to calculate percentage splits
afd_europe_elections=europe_elections[["Nr_2024","Gebiet_2024","Alternative für Deutschland_2014","Gültige_2014","Alternative für Deutschland_2019","Gültige_2019","Alternative für Deutschland_2024","Gültige Stimmen_2024"]]
afd_europe_elections
# Out:
#     Nr_2024             Gebiet_2024 Alternative für Deutschland_2014  \
# 0     01001        Flensburg, Stadt                             1583
# 1     01002  Kiel, Landeshauptstadt                             4418
# 2     01003      Lübeck, Hansestadt                             4334
# 3     01004       Neumünster, Stadt                             1960
# 4     01051            Dithmarschen                             2325
# ..      ...                     ...                              ...
# 396   16073     Saalfeld-Rudolstadt                             4107
# 397   16074    Saale-Holzland-Kreis                             3920
# 398   16075        Saale-Orla-Kreis                             3114
# 399   16076                   Greiz                             4559
# 400   16077        Altenburger Land                             3023
#
#     Gültige_2014 Alternative für Deutschland_2019 Gültige_2019  \
# 0          25174                             2477        39410
# 1          75336                             6459       109018
# 2          62509                             6773        90485
# 3          27250                             2761        28805
# 4          42350                             5121        57769
# ..           ...                              ...          ...
# 396        46150                            14592        52848
# 397        40150                            10210        44098
# 398        37348                            11264        41630
# 399        47189                            13297        52058
# 400        37657                            11371        41901
#
#     Alternative für Deutschland_2024 Gültige Stimmen_2024
# 0                               4273                41552
# 1                               9351               116547
# 2                              10290                95954
# 3                               5697                32737
# 4                              11005                67527
# ..                               ...                  ...
# 396                            17307                49246
# 397                            14404                45189
# 398                            14426                38324
# 399                            18399                52005
# 400                            15893                43058
#
# [401 rows x 8 columns]

# %%
#and then we merge the data from german and european elections
europe_german_afd=pd.merge(afd_europe_elections,german_elections_2013_2017_2021,right_on="Statistische Kennziffer_2021",left_on="Nr_2024",how="outer")
europe_german_afd
# Out:
#     Nr_2024             Gebiet_2024 Alternative für Deutschland_2014  \
# 0     01001        Flensburg, Stadt                             1583
# 1     01002  Kiel, Landeshauptstadt                             4418
# 2     01003      Lübeck, Hansestadt                             4334
# 3     01004       Neumünster, Stadt                             1960
# 4     01051            Dithmarschen                             2325
# ..      ...                     ...                              ...
# 399   16075        Saale-Orla-Kreis                             3114
# 400   16076                   Greiz                             4559
# 401   16077        Altenburger Land                             3023
# 402     NaN                     NaN                              879
# 403     NaN                     NaN                              879
#
#     Gültige_2014 Alternative für Deutschland_2019 Gültige_2019  \
# 0          25174                             2477        39410
# 1          75336                             6459       109018
# 2          62509                             6773        90485
# 3          27250                             2761        28805
# 4          42350                             5121        57769
# ..           ...                              ...          ...
# 399        37348                            11264        41630
# 400        47189                            13297        52058
# 401        37657                            11371        41901
# 402        17417                             3874        19341
# 403        17417                             3874        19341
#
#     Alternative für Deutschland_2024 Gültige Stimmen_2024  \
# 0                               4273                41552
# 1                               9351               116547
# 2                              10290                95954
# 3                               5697                32737
# 4                              11005                67527
# ..                               ...                  ...
# 399                            14426                38324
# 400                            18399                52005
# 401                            15893                43058
# 402                              NaN                  NaN
# 403                              NaN                  NaN
#
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 0                          01001                    46265
# 1                          01002                   130686
# 2                          01003                   112029
# 3                          01004                    39388
# 4                          01051                    73649
# ..                           ...                      ...
# 399                        16075                    48979
# 400                        16076                    61725
# 401                        16077                    52148
# 402                        16056                    22768
# 403                        03156                    44104
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 0                   1855                        01001
# 1                   4778                        01002
# 2                   4792                        01003
# 3                   1965                        01004
# 4                   3041                        01051
# ..                   ...                          ...
# 399                 3527                        16075
# 400                 4714                        16076
# 401                 3809                        16077
# 402                 1130                        16056
# 403                 1557                          NaN
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017  \
# 0                      49271                 3702
# 1                     137368                 9524
# 2                     117879                10461
# 3                      39861                 4124
# 4                      77337                 6626
# ..                       ...                  ...
# 399                    50721                13452
# 400                    63402                16203
# 401                    54846                15061
# 402                    24248                 4615
# 403                      NaN                  NaN
#
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 0                          01001                    50818                 2756
# 1                          01002                   139961                 7023
# 2                          01003                   117674                 7807
# 3                          01004                    39971                 3751
# 4                          01051                    80616                 7098
# ..                           ...                      ...                  ...
# 399                        16075                    49552                15071
# 400                        16076                    61146                16908
# 401                        16077                    52844                15576
# 402                          NaN                      NaN                  NaN
# 403                          NaN                      NaN                  NaN
#
# [404 rows x 17 columns]

# %%
europe_german_afd=europe_german_afd.rename(columns={"Gültige Stimmen_2024":'Gültige_2024'})
europe_german_afd
# Out:
#     Nr_2024             Gebiet_2024 Alternative für Deutschland_2014  \
# 0     01001        Flensburg, Stadt                             1583
# 1     01002  Kiel, Landeshauptstadt                             4418
# 2     01003      Lübeck, Hansestadt                             4334
# 3     01004       Neumünster, Stadt                             1960
# 4     01051            Dithmarschen                             2325
# ..      ...                     ...                              ...
# 399   16075        Saale-Orla-Kreis                             3114
# 400   16076                   Greiz                             4559
# 401   16077        Altenburger Land                             3023
# 402     NaN                     NaN                              879
# 403     NaN                     NaN                              879
#
#     Gültige_2014 Alternative für Deutschland_2019 Gültige_2019  \
# 0          25174                             2477        39410
# 1          75336                             6459       109018
# 2          62509                             6773        90485
# 3          27250                             2761        28805
# 4          42350                             5121        57769
# ..           ...                              ...          ...
# 399        37348                            11264        41630
# 400        47189                            13297        52058
# 401        37657                            11371        41901
# 402        17417                             3874        19341
# 403        17417                             3874        19341
#
#     Alternative für Deutschland_2024 Gültige_2024  \
# 0                               4273        41552
# 1                               9351       116547
# 2                              10290        95954
# 3                               5697        32737
# 4                              11005        67527
# ..                               ...          ...
# 399                            14426        38324
# 400                            18399        52005
# 401                            15893        43058
# 402                              NaN          NaN
# 403                              NaN          NaN
#
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 0                          01001                    46265
# 1                          01002                   130686
# 2                          01003                   112029
# 3                          01004                    39388
# 4                          01051                    73649
# ..                           ...                      ...
# 399                        16075                    48979
# 400                        16076                    61725
# 401                        16077                    52148
# 402                        16056                    22768
# 403                        03156                    44104
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 0                   1855                        01001
# 1                   4778                        01002
# 2                   4792                        01003
# 3                   1965                        01004
# 4                   3041                        01051
# ..                   ...                          ...
# 399                 3527                        16075
# 400                 4714                        16076
# 401                 3809                        16077
# 402                 1130                        16056
# 403                 1557                          NaN
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017  \
# 0                      49271                 3702
# 1                     137368                 9524
# 2                     117879                10461
# 3                      39861                 4124
# 4                      77337                 6626
# ..                       ...                  ...
# 399                    50721                13452
# 400                    63402                16203
# 401                    54846                15061
# 402                    24248                 4615
# 403                      NaN                  NaN
#
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 0                          01001                    50818                 2756
# 1                          01002                   139961                 7023
# 2                          01003                   117674                 7807
# 3                          01004                    39971                 3751
# 4                          01051                    80616                 7098
# ..                           ...                      ...                  ...
# 399                        16075                    49552                15071
# 400                        16076                    61146                16908
# 401                        16077                    52844                15576
# 402                          NaN                      NaN                  NaN
# 403                          NaN                      NaN                  NaN
#
# [404 rows x 17 columns]

# %%
#and we calculate these percentage columns
perc_summed=europe_german_afd[europe_german_afd.columns[:2]]
for columnname in europe_german_afd.columns[2:]:
    if "Alternative" in columnname:
        perc_summed["eu_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_"+columnname[-4:]])
    if "AfD" in columnname:
        perc_summed["btw_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_Zweitstimme_"+columnname[-4:]])

europe_german_afd
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["eu_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_"+columnname[-4:]])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["eu_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_"+columnname[-4:]])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["eu_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_"+columnname[-4:]])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["btw_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_Zweitstimme_"+columnname[-4:]])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["btw_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_Zweitstimme_"+columnname[-4:]])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/657282062.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed["btw_"+columnname[-4:]]=pd.to_numeric(europe_german_afd[columnname])*100/pd.to_numeric(europe_german_afd["Gültige_Zweitstimme_"+columnname[-4:]])
#     Nr_2024             Gebiet_2024 Alternative für Deutschland_2014  \
# 0     01001        Flensburg, Stadt                             1583
# 1     01002  Kiel, Landeshauptstadt                             4418
# 2     01003      Lübeck, Hansestadt                             4334
# 3     01004       Neumünster, Stadt                             1960
# 4     01051            Dithmarschen                             2325
# ..      ...                     ...                              ...
# 399   16075        Saale-Orla-Kreis                             3114
# 400   16076                   Greiz                             4559
# 401   16077        Altenburger Land                             3023
# 402     NaN                     NaN                              879
# 403     NaN                     NaN                              879
#
#     Gültige_2014 Alternative für Deutschland_2019 Gültige_2019  \
# 0          25174                             2477        39410
# 1          75336                             6459       109018
# 2          62509                             6773        90485
# 3          27250                             2761        28805
# 4          42350                             5121        57769
# ..           ...                              ...          ...
# 399        37348                            11264        41630
# 400        47189                            13297        52058
# 401        37657                            11371        41901
# 402        17417                             3874        19341
# 403        17417                             3874        19341
#
#     Alternative für Deutschland_2024 Gültige_2024  \
# 0                               4273        41552
# 1                               9351       116547
# 2                              10290        95954
# 3                               5697        32737
# 4                              11005        67527
# ..                               ...          ...
# 399                            14426        38324
# 400                            18399        52005
# 401                            15893        43058
# 402                              NaN          NaN
# 403                              NaN          NaN
#
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 0                          01001                    46265
# 1                          01002                   130686
# 2                          01003                   112029
# 3                          01004                    39388
# 4                          01051                    73649
# ..                           ...                      ...
# 399                        16075                    48979
# 400                        16076                    61725
# 401                        16077                    52148
# 402                        16056                    22768
# 403                        03156                    44104
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 0                   1855                        01001
# 1                   4778                        01002
# 2                   4792                        01003
# 3                   1965                        01004
# 4                   3041                        01051
# ..                   ...                          ...
# 399                 3527                        16075
# 400                 4714                        16076
# 401                 3809                        16077
# 402                 1130                        16056
# 403                 1557                          NaN
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017  \
# 0                      49271                 3702
# 1                     137368                 9524
# 2                     117879                10461
# 3                      39861                 4124
# 4                      77337                 6626
# ..                       ...                  ...
# 399                    50721                13452
# 400                    63402                16203
# 401                    54846                15061
# 402                    24248                 4615
# 403                      NaN                  NaN
#
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 0                          01001                    50818                 2756
# 1                          01002                   139961                 7023
# 2                          01003                   117674                 7807
# 3                          01004                    39971                 3751
# 4                          01051                    80616                 7098
# ..                           ...                      ...                  ...
# 399                        16075                    49552                15071
# 400                        16076                    61146                16908
# 401                        16077                    52844                15576
# 402                          NaN                      NaN                  NaN
# 403                          NaN                      NaN                  NaN
#
# [404 rows x 17 columns]

# %%
west_deutschland=europe_german_afd[pd.to_numeric(europe_german_afd["Nr_2024"].str[:2],errors="coerce")<11]
west_deutschland
# Out:
#     Nr_2024             Gebiet_2024 Alternative für Deutschland_2014  \
# 0     01001        Flensburg, Stadt                             1583
# 1     01002  Kiel, Landeshauptstadt                             4418
# 2     01003      Lübeck, Hansestadt                             4334
# 3     01004       Neumünster, Stadt                             1960
# 4     01051            Dithmarschen                             2325
# ..      ...                     ...                              ...
# 319   10042           Merzig-Wadern                             2888
# 320   10043             Neunkirchen                             3944
# 321   10044               Saarlouis                             5532
# 322   10045         Saarpfalz-Kreis                             4799
# 323   10046              St. Wendel                             2743
#
#     Gültige_2014 Alternative für Deutschland_2019 Gültige_2019  \
# 0          25174                             2477        39410
# 1          75336                             6459       109018
# 2          62509                             6773        90485
# 3          27250                             2761        28805
# 4          42350                             5121        57769
# ..           ...                              ...          ...
# 319        47360                             4792        53919
# 320        54607                             7115        66848
# 321        82940                             9825       101190
# 322        65332                             8556        77321
# 323        46687                             4170        52406
#
#     Alternative für Deutschland_2024 Gültige_2024  \
# 0                               4273        41552
# 1                               9351       116547
# 2                              10290        95954
# 3                               5697        32737
# 4                              11005        67527
# ..                               ...          ...
# 319                             8574        55666
# 320                            12008        67102
# 321                            16273       102964
# 322                            12565        76985
# 323                             7046        52937
#
#     Statistische Kennziffer_2013 Gültige_Zweitstimme_2013  \
# 0                          01001                    46265
# 1                          01002                   130686
# 2                          01003                   112029
# 3                          01004                    39388
# 4                          01051                    73649
# ..                           ...                      ...
# 319                        10042                    57967
# 320                        10043                    76301
# 321                        10044                   112605
# 322                        10045                    86143
# 323                        10046                    56426
#
#     AfD_Zweitstimme_2013 Statistische Kennziffer_2017  \
# 0                   1855                        01001
# 1                   4778                        01002
# 2                   4792                        01003
# 3                   1965                        01004
# 4                   3041                        01051
# ..                   ...                          ...
# 319                 2934                        10042
# 320                 4414                        10043
# 321                 5958                        10044
# 322                 4824                        10045
# 323                 2713                        10046
#
#     Gültige_Zweitstimme_2017 AfD_Zweitstimme_2017  \
# 0                      49271                 3702
# 1                     137368                 9524
# 2                     117879                10461
# 3                      39861                 4124
# 4                      77337                 6626
# ..                       ...                  ...
# 319                    61180                 5667
# 320                    78461                 8556
# 321                   117718                11846
# 322                    88957                10044
# 323                    58486                 4828
#
#     Statistische Kennziffer_2021 Gültige_Zweitstimme_2021 AfD_Zweitstimme_2021
# 0                          01001                    50818                 2756
# 1                          01002                   139961                 7023
# 2                          01003                   117674                 7807
# 3                          01004                    39971                 3751
# 4                          01051                    80616                 7098
# ..                           ...                      ...                  ...
# 319                        10042                    60816                 5888
# 320                        10043                    76088                 8620
# 321                        10044                   116396                11865
# 322                        10045                    87833                 9387
# 323                        10046                    57700                 4991
#
# [324 rows x 17 columns]

# %%
#we also quickly sum up the absolute gains of the AfD between 2024 and 2019
zugewinne_west_deutschland=(pd.to_numeric(west_deutschland["Alternative für Deutschland_2024"]).sum())-(pd.to_numeric(west_deutschland["Alternative für Deutschland_2019"]).sum())

# %%
zugewinne_west_deutschland
# Out:
# 1532806

# %%
#and then we use the percentage wise dataframe and calculate relations
perc_summed_resorted=perc_summed[["Nr_2024","Gebiet_2024","btw_2013","eu_2014","btw_2017","eu_2019","btw_2021","eu_2024"]]
perc_summed_resorted["11years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["btw_2013"]
perc_summed_resorted["10years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["eu_2014"]

perc_summed_resorted["7years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["btw_2017"]
perc_summed_resorted["5years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["eu_2019"]

perc_summed_resorted["3years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["btw_2021"]

perc_summed_resorted
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/3632355608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed_resorted["11years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["btw_2013"]
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/3632355608.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perc_summed_resorted["10years"]=perc_summed_resorted["eu_2024"]/perc_summed_resorted["eu_2014"]
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/3632355608.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 57    5.620668   6.211628  11.457545  4.175351  3.183970  1.628846  2.038467
# 52    5.442833   6.093659  11.646932  4.660066  3.790144  1.848548  2.139866
# 51    7.458055   9.549417  16.635052  6.810333  4.494430  1.836013  2.230481
#
#        3years
# 162  1.429353
# 118  1.396660
# 203  1.351830
# 223  1.466236
# 381  1.210742
# ..        ...
# 30   1.841463
# 54   1.855347
# 57   1.844532
# 52   1.911320
# 51   1.741997
#
# [400 rows x 13 columns]

# %%
perc_summed_resorted.to_csv("landkreise_all.csv",index=False)

# %%
perc_summed_resorted[perc_summed_resorted["Nr_2024"]=="03159"]
# Out:
#    Nr_2024 Gebiet_2024  btw_2013   eu_2014  btw_2017   eu_2019  btw_2021  \
# 25   03159   Göttingen   3.71789  5.021836  8.098812  6.784111  6.349654
#
#       eu_2024   11years   10years    7years    5years    3years
# 25  10.797233  2.904129  2.150057  1.333187  1.591547  1.700444

# %%
threeyears=perc_summed_resorted.sort_values(by=["3years"])
threeyears[threeyears["Gebiet_2024"].astype(str).str.contains("Berlin")]
# Out:
#     Nr_2024    Gebiet_2024  btw_2013   eu_2014   btw_2017   eu_2019  btw_2021  \
# 324   11000  Berlin, Stadt  4.925825  7.912537  12.047348  9.896594    8.4143
#
#        eu_2024   11years   10years    7years    5years    3years
# 324  11.604883  2.355927  1.466645  0.963273  1.172614  1.379186

# %%
threeyears.to_csv("afd_three_years.csv",index=False)
threeyears[threeyears["Nr_2024"]=="03159"]
# Out:
#    Nr_2024 Gebiet_2024  btw_2013   eu_2014  btw_2017   eu_2019  btw_2021  \
# 25   03159   Göttingen   3.71789  5.021836  8.098812  6.784111  6.349654
#
#       eu_2024   11years   10years    7years    5years    3years
# 25  10.797233  2.904129  2.150057  1.333187  1.591547  1.700444

# %%
#then for correlation we add the data on the quota of people working in agriculture
landwirtschaft=pd.read_csv("../data/landwirtschaft.csv",sep=";")
landwirtschaft=landwirtschaft.rename(columns={"Unnamed: 2":"Landwirtschaft"})
ags_filtered=landwirtschaft[landwirtschaft["Unnamed: 0"].str.len()==5]
ags_filtered["Landwirtschaft"]=pd.to_numeric(ags_filtered["Landwirtschaft"])
ags_filtered_landwirtschaft=ags_filtered[ags_filtered["Landwirtschaft"]<100]
ags_filtered_landwirtschaft["ags_number"]=pd.to_numeric(ags_filtered_landwirtschaft["Unnamed: 0"])
landwirtschaft_west=ags_filtered_landwirtschaft[ags_filtered_landwirtschaft["ags_number"]<11000]
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/2373002351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ags_filtered["Landwirtschaft"]=pd.to_numeric(ags_filtered["Landwirtschaft"])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/2373002351.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ags_filtered_landwirtschaft["ags_number"]=pd.to_numeric(ags_filtered_landwirtschaft["Unnamed: 0"])

# %%
landwirtschaft_west.to_csv("landwirtschaft_west.csv",index=False)

# %%
#and then we also divide into spd or green reigned districts and cdu reigned districts
landwirtschaft_west["bl"]=landwirtschaft_west["Unnamed: 0"].str[:2]
searchfor = ['03',"07","08",'10']
spd_west=landwirtschaft_west[landwirtschaft_west.bl.str.contains('|'.join(searchfor))]
cdu_west=landwirtschaft_west[~landwirtschaft_west.bl.str.contains('|'.join(searchfor))]
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_29447/325333766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   landwirtschaft_west["bl"]=landwirtschaft_west["Unnamed: 0"].str[:2]

# %%
landwirtschaft_west_merged=pd.merge(perc_summed_resorted,landwirtschaft_west,left_on="Nr_2024",right_on="Unnamed: 0")
#landwirtschaft_west_merged_2=pd.merge(ags_filtered_schweine_rinder,landwirtschaft_west_merged,right_on="Nr_2024",left_on="Unnamed: 1")
landwirtschaft_west_merged=landwirtschaft_west_merged.rename(columns={"Unnamed: 2":"Landwirtschaft"})

# %%
landwirtschaft_spd_west_merged=pd.merge(perc_summed_resorted,spd_west,left_on="Nr_2024",right_on="Unnamed: 0")
landwirtschaft_cdu_west_merged=pd.merge(perc_summed_resorted,cdu_west,left_on="Nr_2024",right_on="Unnamed: 0")

landwirtschaft_spd_west_merged
# Out:
#     Nr_2024          Gebiet_2024  btw_2013   eu_2014   btw_2017    eu_2019  \
# 0     03101  Braunschweig, Stadt  3.578733  5.626977   8.365097   6.848268
# 1     03102    Salzgitter, Stadt  3.917159  5.789967  16.437597  14.988322
# 2     03103     Wolfsburg, Stadt  3.809301  6.595599  11.681540  10.196541
# 3     03151              Gifhorn  3.560758  4.870405  11.420632   9.780852
# 4     03153               Goslar  4.133062  6.797389  11.136709  10.272480
# ..      ...                  ...       ...       ...        ...        ...
# 124   10042        Merzig-Wadern  5.061501  6.097973   9.262831   8.887405
# 125   10043          Neunkirchen  5.784983  7.222517  10.904781  10.643550
# 126   10044            Saarlouis  5.291062  6.669882  10.063032   9.709457
# 127   10045      Saarpfalz-Kreis  5.599991  7.345558  11.290848  11.065558
# 128   10046           St. Wendel  4.808067  5.875297   8.254967   7.957104
#
#       btw_2021    eu_2024   11years   10years    7years    5years    3years  \
# 0     5.914110   9.606767  2.684405  1.707270  1.148435  1.402803  1.624381
# 1    13.472299  22.032575  5.624632  3.805302  1.340377  1.469983  1.635398
# 2     9.314725  15.722671  4.127443  2.383812  1.345942  1.541961  1.687937
# 3    10.481903  17.110527  4.805304  3.513163  1.498212  1.749390  1.632387
# 4     9.236021  16.309755  3.946168  2.399415  1.464504  1.587714  1.765885
# ..         ...        ...       ...       ...       ...       ...       ...
# 124   9.681663  15.402580  3.043086  2.525852  1.662837  1.733079  1.590902
# 125  11.328987  17.895145  3.093379  2.477688  1.641037  1.681314  1.579589
# 126  10.193649  15.804553  2.987029  2.369540  1.570556  1.627748  1.550431
# 127  10.687327  16.321361  2.914534  2.221936  1.445539  1.474970  1.527170
# 128   8.649913  13.310161  2.768298  2.265445  1.612382  1.672739  1.538762
#
#     Unnamed: 0 Anteil ET Land- u. Forstwirtschaft, Fischerei (%)  \
# 0        03101                                      Braunschweig
# 1        03102                                        Salzgitter
# 2        03103                                         Wolfsburg
# 3        03151                                           Gifhorn
# 4        03153                                            Goslar
# ..         ...                                               ...
# 124      10042                                     Merzig-Wadern
# 125      10043                                       Neunkirchen
# 126      10044                                         Saarlouis
# 127      10045                                   Saarpfalz-Kreis
# 128      10046                                        St. Wendel
#
#      Landwirtschaft  ags_number  bl
# 0               0.1        3101  03
# 1               0.4        3102  03
# 2               0.1        3103  03
# 3               3.0        3151  03
# 4               1.0        3153  03
# ..              ...         ...  ..
# 124             1.4       10042  10
# 125             0.4       10043  10
# 126             0.5       10044  10
# 127             0.4       10045  10
# 128             1.0       10046  10
#
# [129 rows x 18 columns]

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/maier-borst.h/Documents/CodeRelated/HBDataviz/2024/23_EuropawahlAfD/Wrangle/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/maier-borst.h/Documents/CodeRelated/HBDataviz/2024/23_EuropawahlAfD/Wrangle/lib/python3.9/site-packages (from scipy) (1.26.4)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/maier-borst.h/Documents/CodeRelated/HBDataviz/2024/23_EuropawahlAfD/Wrangle/bin/python3 -m pip install --upgrade pip' command.

# %%
import scipy

# %%
from scipy import stats
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["3years"])
res
# Out:
# SignificanceResult(statistic=0.07506196548644933, pvalue=0.18321496265163148)

# %%
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["5years"])
res
# Out:
# SignificanceResult(statistic=0.5487335621008245, pvalue=3.04063350580699e-26)

# %%
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["7years"])
res
# Out:
# SignificanceResult(statistic=0.27877926949661447, pvalue=4.7475732503974817e-07)

# %%
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["10years"])
res
# Out:
# SignificanceResult(statistic=0.31326917433593976, pvalue=1.2659343356274726e-08)

# %%
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["11years"])
res
# Out:
# SignificanceResult(statistic=0.35845332241072636, pvalue=5.160408241438454e-11)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["3years"])
res
# Out:
# SignificanceResult(statistic=0.41230990518842126, pvalue=1.203108027270676e-06)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["5years"])
res
# Out:
# SignificanceResult(statistic=0.4352352778792644, pvalue=2.5426144672820916e-07)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["7years"])
res
# Out:
# SignificanceResult(statistic=0.43357397845528484, pvalue=2.856840865171681e-07)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["10years"])
res
# Out:
# SignificanceResult(statistic=0.3830609668450226, pvalue=7.446462378606699e-06)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["11years"])
res
# Out:
# SignificanceResult(statistic=0.3425800781873107, pvalue=7.066640119352465e-05)

# %%
res = stats.spearmanr(landwirtschaft_west_merged["Landwirtschaft"], landwirtschaft_west_merged["btw_2021"]/landwirtschaft_west_merged["eu_2019"])
res
# Out:
# SignificanceResult(statistic=0.43804993320333746, pvalue=3.0133794142248864e-16)

# %%
landwirtschaft_west_merged.to_csv("corr_base.csv",index=False)

# %%
res = stats.spearmanr(landwirtschaft_spd_west_merged["Landwirtschaft"], landwirtschaft_spd_west_merged["3years"])
res
# Out:
# SignificanceResult(statistic=0.41230990518842126, pvalue=1.203108027270676e-06)

# %%
res = stats.spearmanr(landwirtschaft_cdu_west_merged["Landwirtschaft"], landwirtschaft_cdu_west_merged["3years"])
res
# Out:
# SignificanceResult(statistic=-0.1473012506783843, pvalue=0.04424148233073329)

# %%
landwirtschaft_west_merged.sort_values(by="5years",ascending=False).head(20)
# Out:
#     Nr_2024          Gebiet_2024  btw_2013   eu_2014   btw_2017    eu_2019  \
# 50    03453          Cloppenburg  2.442619  3.701259   9.060422   7.458055
# 51    03454              Emsland  2.499306  3.072953   6.300585   5.442833
# 56    03459            Osnabrück  2.744091  3.598509   7.034149   5.620668
# 53    03456  Grafschaft Bentheim  2.535045  2.760817   5.253278   4.726121
# 29    03255           Holzminden  3.474783  4.739987   9.620642   8.327548
# 10    01059  Schleswig-Flensburg  4.116428  6.519981   6.560556   6.011148
# 12    01061            Steinburg  4.447830  5.823809   8.232852   7.776373
# 54    03457                 Leer  3.399653  5.292650   9.220794   9.038149
# 289   09673        Rhön-Grabfeld  3.224178  5.168836  10.377151   7.560083
# 5     01054        Nordfriesland  3.780780  5.679142   5.805914   5.665315
# 58    03461          Wesermarsch  3.514678  5.459527   8.324554   7.894527
# 59    03462             Wittmund  3.583448  4.963483   8.603443   8.758581
# 202   08327           Tuttlingen  5.095053  7.210238  14.110267  10.880341
# 49    03452               Aurich  3.145421  4.428735   8.924106   9.098699
# 20    03154            Helmstedt  3.718089  5.394178   9.913690   9.180258
# 92    05566            Steinfurt  2.763236  3.251326   6.491264   5.609079
# 89    05554               Borken  2.765581  3.397577   6.137097   5.418706
# 38    03357    Rotenburg (Wümme)  3.570936  4.243181   8.071417   7.272500
# 3     01051         Dithmarschen  4.129045  5.489965   8.567697   8.864616
# 57    03460               Vechta  2.233019  3.511555   6.991184   6.067489
#
#       btw_2021    eu_2024   11years   10years    7years    5years    3years  \
# 50    9.549417  16.635052  6.810333  4.494430  1.836013  2.230481  1.741997
# 51    6.093659  11.646932  4.660066  3.790144  1.848548  2.139866  1.911320
# 56    6.211628  11.457545  4.175351  3.183970  1.628846  2.038467  1.844532
# 53    5.159982   9.573557  3.776484  3.467653  1.822397  2.025669  1.855347
# 29    9.036478  16.640340  4.788886  3.510630  1.729650  1.998228  1.841463
# 10    5.915951  11.724074  2.848118  1.798176  1.787055  1.950389  1.981773
# 12    7.979447  15.132541  3.402230  2.598392  1.838068  1.945964  1.896440
# 54    8.851753  17.367766  5.108688  3.281488  1.883543  1.921606  1.962071
# 289  10.057876  14.438365  4.478154  2.793349  1.391361  1.909816  1.435528
# 5     5.233519  10.759486  2.845838  1.894562  1.853194  1.899186  2.055880
# 58    7.846913  14.970825  4.259516  2.742147  1.798394  1.896355  1.907862
# 59    8.543195  16.528545  4.612469  3.330029  1.921155  1.887126  1.934703
# 202  13.316190  20.515233  4.026501  2.845292  1.453922  1.885532  1.540623
# 49    8.226367  17.087931  5.432638  3.858422  1.914806  1.878063  2.077215
# 20    9.192201  17.112217  4.602423  3.172350  1.726120  1.864023  1.861602
# 92    5.503155  10.396993  3.762615  3.197770  1.601690  1.853601  1.889279
# 89    5.062349  10.015645  3.621534  2.947879  1.631984  1.848346  1.978458
# 38    7.055484  13.382169  3.747524  3.153806  1.657970  1.840106  1.896705
# 3     8.804704  16.297185  3.946963  2.968541  1.902166  1.838454  1.850963
# 57    5.854213  11.127247  4.983050  3.168752  1.591611  1.833913  1.900725
#
#     Unnamed: 0 Anteil ET Land- u. Forstwirtschaft, Fischerei (%)  \
# 50       03453                                       Cloppenburg
# 51       03454                                           Emsland
# 56       03459                              Osnabrück, Landkreis
# 53       03456                               Grafschaft Bentheim
# 29       03255                                        Holzminden
# 10       01059                               Schleswig-Flensburg
# 12       01061                                         Steinburg
# 54       03457                                              Leer
# 289      09673                                     Rhön-Grabfeld
# 5        01054                                     Nordfriesland
# 58       03461                                       Wesermarsch
# 59       03462                                          Wittmund
# 202      08327                                        Tuttlingen
# 49       03452                                            Aurich
# 20       03154                                         Helmstedt
# 92       05566                                         Steinfurt
# 89       05554                                            Borken
# 38       03357                                 Rotenburg (Wümme)
# 3        01051                                      Dithmarschen
# 57       03460                                            Vechta
#
#      Landwirtschaft  ags_number  bl
# 50              7.2        3453  03
# 51              4.1        3454  03
# 56              3.3        3459  03
# 53              3.4        3456  03
# 29              1.6        3255  03
# 10              4.3        1059  01
# 12              4.1        1061  01
# 54              2.8        3457  03
# 289             1.8        9673  09
# 5               3.5        1054  01
# 58              3.2        3461  03
# 59              4.1        3462  03
# 202             0.6        8327  08
# 49              3.1        3452  03
# 20              3.3        3154  03
# 92              1.8        5566  05
# 89              2.2        5554  05
# 38              4.5        3357  03
# 3               5.5        1051  01
# 57              6.0        3460  03

# %%
.to_csv("top20_zuwaechse.csv",index=False)
# Out:
#   Cell In[57], line 1
#     .to_csv("top20_zuwaechse.csv",index=False)
#     ^
# SyntaxError: invalid syntax

# %%
landwirtschaft_cdu_west_merged.to_csv("corr_cdu.csv",index=False)

# %%
landwirtschaft_spd_west_merged.to_csv("corr_spd.csv",index=False)
