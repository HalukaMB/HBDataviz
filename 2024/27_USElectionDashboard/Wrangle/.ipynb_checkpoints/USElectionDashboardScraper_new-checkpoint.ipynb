# %%
import pandas as pd
import requests
import io
import numpy as np
# Out:
# /Users/maier-borst.h/Documents/CodeRelated/HBDataviz/2024/27_USElectionDashboard/Wrangle/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
natesilver_url="https://static.dwcdn.net/data/OYvXP.csv"

# %%
response = requests.get(natesilver_url)

file_object = io.StringIO(response.content.decode('utf-8'))
nate_silver_poll_data=pd.read_csv(file_object)
nate_silver_poll_data
# Out:
#            Contest  pct_trend_adjustedHarrisnow  pct_trend_adjustedKennedynow  \
# 0     Pennsylvania                     46.03928                      3.810687
# 1         Michigan                     46.00136                      5.036161
# 2   North Carolina                     45.71910                      3.307240
# 3        Wisconsin                     47.38105                      4.108296
# 4          Georgia                     45.11050                      3.381852
# 5          Arizona                     45.77448                      4.912041
# 6           Nevada                     44.74195                      4.027943
# 7         Virginia                     47.10960                      5.240551
# 8          Florida                     42.78386                      4.391009
# 9    New Hampshire                     49.83192                      5.116941
# 10       Minnesota                     47.86847                      4.253161
# 11         Montana                     39.67111                      3.385387
# 12      Washington                     50.52018                      5.353231
# 13        National                     47.05454                      4.234886
#
#     pct_trend_adjustedTrumpnow        e_week       e_month week_cat month_cat
# 0                     44.53762   D+ 0.1@@-.1  D+ 5.9@@-5.9        D         D
# 1                     43.04430    R+ 0.3@@.3  D+ 8.5@@-8.5        R         D
# 2                     45.57507  D+ 1.6@@-1.6         NA@@0        D         E
# 3                     44.11553   D+ 0.7@@-.7  D+ 5.6@@-5.6        D         D
# 4                     46.50568    R+ 0.6@@.6  D+ 6.3@@-6.3        R         D
# 5                     43.71605  D+ 1.5@@-1.5  D+ 9.7@@-9.7        D         D
# 6                     44.85209   R+ 1.6@@1.6  D+ 9.6@@-9.6        R         D
# 7                     42.42926    R+ 0.2@@.2      D+ 4@@-4        R         D
# 8                     47.95662   D+ 0.1@@-.1  D+ 4.8@@-4.8        D         D
# 9                     43.21610    R+ 0.1@@.1         NA@@0        R         E
# 10                    40.12254    R+ 0.1@@.1         NA@@0        R         E
# 11                    54.69897    R+ 0.8@@.8         NA@@0        R         E
# 12                    36.20377   R+ 2.3@@2.3    R+ 0.9@@.9        R         R
# 13                    44.59051    R+ 0.1@@.1  D+ 5.2@@-5.2        R         D

# %%
nate_silver_poll_data["prev_week"]=nate_silver_poll_data["e_week"].astype(str).str.split("@")
nate_silver_poll_data["prev_week_party"]=nate_silver_poll_data["prev_week"].str[0].str[0]
nate_silver_poll_data["prev_week_sign"]=nate_silver_poll_data["prev_week"].str[0].str[1]
nate_silver_poll_data["prev_week_val"]=nate_silver_poll_data["prev_week"].str[0].str[3:]
nate_silver_poll_data["prev_week_val"]=nate_silver_poll_data["prev_week_val"].replace('', '0')
nate_silver_poll_data["prev_week_val"]=pd.to_numeric(nate_silver_poll_data["prev_week_val"],errors="coerce")


nate_silver_poll_data["prev_week_dem"]=nate_silver_poll_data["pct_trend_adjustedHarrisnow"]
nate_silver_poll_data["prev_week_rep"]=nate_silver_poll_data["pct_trend_adjustedTrumpnow"]
nate_silver_poll_data
# Out:
#            Contest  pct_trend_adjustedHarrisnow  pct_trend_adjustedKennedynow  \
# 0     Pennsylvania                     46.03928                      3.810687
# 1         Michigan                     46.00136                      5.036161
# 2   North Carolina                     45.71910                      3.307240
# 3        Wisconsin                     47.38105                      4.108296
# 4          Georgia                     45.11050                      3.381852
# 5          Arizona                     45.77448                      4.912041
# 6           Nevada                     44.74195                      4.027943
# 7         Virginia                     47.10960                      5.240551
# 8          Florida                     42.78386                      4.391009
# 9    New Hampshire                     49.83192                      5.116941
# 10       Minnesota                     47.86847                      4.253161
# 11         Montana                     39.67111                      3.385387
# 12      Washington                     50.52018                      5.353231
# 13        National                     47.05454                      4.234886
#
#     pct_trend_adjustedTrumpnow        e_week       e_month week_cat month_cat  \
# 0                     44.53762   D+ 0.1@@-.1  D+ 5.9@@-5.9        D         D
# 1                     43.04430    R+ 0.3@@.3  D+ 8.5@@-8.5        R         D
# 2                     45.57507  D+ 1.6@@-1.6         NA@@0        D         E
# 3                     44.11553   D+ 0.7@@-.7  D+ 5.6@@-5.6        D         D
# 4                     46.50568    R+ 0.6@@.6  D+ 6.3@@-6.3        R         D
# 5                     43.71605  D+ 1.5@@-1.5  D+ 9.7@@-9.7        D         D
# 6                     44.85209   R+ 1.6@@1.6  D+ 9.6@@-9.6        R         D
# 7                     42.42926    R+ 0.2@@.2      D+ 4@@-4        R         D
# 8                     47.95662   D+ 0.1@@-.1  D+ 4.8@@-4.8        D         D
# 9                     43.21610    R+ 0.1@@.1         NA@@0        R         E
# 10                    40.12254    R+ 0.1@@.1         NA@@0        R         E
# 11                    54.69897    R+ 0.8@@.8         NA@@0        R         E
# 12                    36.20377   R+ 2.3@@2.3    R+ 0.9@@.9        R         R
# 13                    44.59051    R+ 0.1@@.1  D+ 5.2@@-5.2        R         D
#
#            prev_week prev_week_party prev_week_sign  prev_week_val  \
# 0    [D+ 0.1, , -.1]               D              +            0.1
# 1     [R+ 0.3, , .3]               R              +            0.3
# 2   [D+ 1.6, , -1.6]               D              +            1.6
# 3    [D+ 0.7, , -.7]               D              +            0.7
# 4     [R+ 0.6, , .6]               R              +            0.6
# 5   [D+ 1.5, , -1.5]               D              +            1.5
# 6    [R+ 1.6, , 1.6]               R              +            1.6
# 7     [R+ 0.2, , .2]               R              +            0.2
# 8    [D+ 0.1, , -.1]               D              +            0.1
# 9     [R+ 0.1, , .1]               R              +            0.1
# 10    [R+ 0.1, , .1]               R              +            0.1
# 11    [R+ 0.8, , .8]               R              +            0.8
# 12   [R+ 2.3, , 2.3]               R              +            2.3
# 13    [R+ 0.1, , .1]               R              +            0.1
#
#     prev_week_dem  prev_week_rep
# 0        46.03928       44.53762
# 1        46.00136       43.04430
# 2        45.71910       45.57507
# 3        47.38105       44.11553
# 4        45.11050       46.50568
# 5        45.77448       43.71605
# 6        44.74195       44.85209
# 7        47.10960       42.42926
# 8        42.78386       47.95662
# 9        49.83192       43.21610
# 10       47.86847       40.12254
# 11       39.67111       54.69897
# 12       50.52018       36.20377
# 13       47.05454       44.59051

# %%
nate_silver_poll_data["prev_week_dem"]=np.where(nate_silver_poll_data["prev_week_party"] != "D", nate_silver_poll_data["prev_week_dem"], 
         (np.where(nate_silver_poll_data["prev_week_sign"]=="+", nate_silver_poll_data["prev_week_dem"]-nate_silver_poll_data["prev_week_val"], nate_silver_poll_data["prev_week_dem"]+nate_silver_poll_data["prev_week_val"])))


nate_silver_poll_data["prev_week_rep"]=np.where(nate_silver_poll_data["prev_week_party"] != "R", nate_silver_poll_data["prev_week_rep"], 
         (np.where(nate_silver_poll_data["prev_week_sign"]=="+", nate_silver_poll_data["prev_week_rep"]-nate_silver_poll_data["prev_week_val"], nate_silver_poll_data["prev_week_rep"]+nate_silver_poll_data["prev_week_val"])))

# %%
nate_silver_poll_data["Diff_Previous_Week"]=nate_silver_poll_data["prev_week_rep"]-nate_silver_poll_data["prev_week_dem"]
nate_silver_poll_data["Diff_This_Week"]=nate_silver_poll_data["pct_trend_adjustedTrumpnow"]-nate_silver_poll_data["pct_trend_adjustedHarrisnow"]
nate_silver_poll_data_week_comp=nate_silver_poll_data[["Contest","Diff_Previous_Week","Diff_This_Week"]]
nate_silver_poll_data_week_comp
# Out:
#            Contest  Diff_Previous_Week  Diff_This_Week
# 0     Pennsylvania            -1.40166        -1.50166
# 1         Michigan            -3.25706        -2.95706
# 2   North Carolina             1.45597        -0.14403
# 3        Wisconsin            -2.56552        -3.26552
# 4          Georgia             0.79518         1.39518
# 5          Arizona            -0.55843        -2.05843
# 6           Nevada            -1.48986         0.11014
# 7         Virginia            -4.88034        -4.68034
# 8          Florida             5.27276         5.17276
# 9    New Hampshire            -6.71582        -6.61582
# 10       Minnesota            -7.84593        -7.74593
# 11         Montana            14.22786        15.02786
# 12      Washington           -16.61641       -14.31641
# 13        National            -2.56403        -2.46403

# %%
nate_silver_poll_data_week_comp["Tendenz"]="Unklar / Wechselhaft"
nate_silver_poll_data_week_comp["Tendenz"]=np.where((nate_silver_poll_data_week_comp["Diff_This_Week"]<-2)&(nate_silver_poll_data_week_comp["Diff_This_Week"]<-2),"Eher demokratisch",nate_silver_poll_data_week_comp["Tendenz"])
nate_silver_poll_data_week_comp["Tendenz"]=np.where((nate_silver_poll_data_week_comp["Diff_This_Week"]>2)&(nate_silver_poll_data_week_comp["Diff_This_Week"]>2),"Eher republikanisch",nate_silver_poll_data_week_comp["Tendenz"])
nate_silver_poll_data_week_comp
# Out:
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_27577/3658296804.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nate_silver_poll_data_week_comp["Tendenz"]="Unklar / Wechselhaft"
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_27577/3658296804.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nate_silver_poll_data_week_comp["Tendenz"]=np.where((nate_silver_poll_data_week_comp["Diff_This_Week"]<-2)&(nate_silver_poll_data_week_comp["Diff_This_Week"]<-2),"Eher demokratisch",nate_silver_poll_data_week_comp["Tendenz"])
# /var/folders/55/79cxhkf56b38c317w6g5zkr0mmx5lp/T/ipykernel_27577/3658296804.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nate_silver_poll_data_week_comp["Tendenz"]=np.where((nate_silver_poll_data_week_comp["Diff_This_Week"]>2)&(nate_silver_poll_data_week_comp["Diff_This_Week"]>2),"Eher republikanisch",nate_silver_poll_data_week_comp["Tendenz"])
#            Contest  Diff_Previous_Week  Diff_This_Week               Tendenz
# 0     Pennsylvania            -1.40166        -1.50166  Unklar / Wechselhaft
# 1         Michigan            -3.25706        -2.95706     Eher demokratisch
# 2   North Carolina             1.45597        -0.14403  Unklar / Wechselhaft
# 3        Wisconsin            -2.56552        -3.26552     Eher demokratisch
# 4          Georgia             0.79518         1.39518  Unklar / Wechselhaft
# 5          Arizona            -0.55843        -2.05843     Eher demokratisch
# 6           Nevada            -1.48986         0.11014  Unklar / Wechselhaft
# 7         Virginia            -4.88034        -4.68034     Eher demokratisch
# 8          Florida             5.27276         5.17276   Eher republikanisch
# 9    New Hampshire            -6.71582        -6.61582     Eher demokratisch
# 10       Minnesota            -7.84593        -7.74593     Eher demokratisch
# 11         Montana            14.22786        15.02786   Eher republikanisch
# 12      Washington           -16.61641       -14.31641     Eher demokratisch
# 13        National            -2.56403        -2.46403     Eher demokratisch

# %%
electors=pd.read_csv("data/Electors.csv")
electors
# Out:
#             Jurisdiction  Electoral votes  Change from 2020 election
# 0                Alabama                9                          0
# 1                 Alaska                3                          0
# 2                Arizona               11                          0
# 3               Arkansas                6                          0
# 4             California               54                         -1
# 5               Colorado               10                          1
# 6            Connecticut                7                          0
# 7               Delaware                3                          0
# 8   District of Columbia                3                          0
# 9                Florida               30                          1
# 10               Georgia               16                          0
# 11                Hawaii                4                          0
# 12                 Idaho                4                          0
# 13              Illinois               19                         -1
# 14               Indiana               11                          0
# 15                  Iowa                6                          0
# 16                Kansas                6                          0
# 17              Kentucky                8                          0
# 18             Louisiana                8                          0
# 19                 Maine                4                          0
# 20              Maryland               10                          0
# 21         Massachusetts               11                          0
# 22              Michigan               15                         -1
# 23             Minnesota               10                          0
# 24           Mississippi                6                          0
# 25              Missouri               10                          0
# 26               Montana                4                          1
# 27              Nebraska                5                          0
# 28                Nevada                6                          0
# 29         New Hampshire                4                          0
# 30            New Jersey               14                          0
# 31            New Mexico                5                          0
# 32              New York               28                         -1
# 33        North Carolina               16                          1
# 34          North Dakota                3                          0
# 35                  Ohio               17                         -1
# 36              Oklahoma                7                          0
# 37                Oregon                8                          1
# 38          Pennsylvania               19                         -1
# 39          Rhode Island                4                          0
# 40        South Carolina                9                          0
# 41          South Dakota                3                          0
# 42             Tennessee               11                          0
# 43                 Texas               40                          2
# 44                  Utah                6                          0
# 45               Vermont                3                          0
# 46              Virginia               13                          0
# 47            Washington               12                          0
# 48         West Virginia                4                         -1
# 49             Wisconsin               10                          0
# 50               Wyoming                3                          0

# %%
poll_comp_week=pd.merge(nate_silver_poll_data_week_comp,electors,left_on="Contest",right_on="Jurisdiction")
poll_comp_week["Contest"]=poll_comp_week["Contest"]+" ("+poll_comp_week["Electoral votes"].astype(str)+")"
poll_comp_week=poll_comp_week[["Contest","Diff_Previous_Week","Diff_This_Week","Tendenz","Electoral votes"]]
poll_comp_week=poll_comp_week.sort_values(by="Electoral votes",ascending=True)
poll_comp_week
# Out:
#                 Contest  Diff_Previous_Week  Diff_This_Week  \
# 9     New Hampshire (4)            -6.71582        -6.61582
# 11          Montana (4)            14.22786        15.02786
# 6            Nevada (6)            -1.48986         0.11014
# 3        Wisconsin (10)            -2.56552        -3.26552
# 10       Minnesota (10)            -7.84593        -7.74593
# 5          Arizona (11)            -0.55843        -2.05843
# 12      Washington (12)           -16.61641       -14.31641
# 7         Virginia (13)            -4.88034        -4.68034
# 1         Michigan (15)            -3.25706        -2.95706
# 2   North Carolina (16)             1.45597        -0.14403
# 4          Georgia (16)             0.79518         1.39518
# 0     Pennsylvania (19)            -1.40166        -1.50166
# 8          Florida (30)             5.27276         5.17276
#
#                  Tendenz  Electoral votes
# 9      Eher demokratisch                4
# 11   Eher republikanisch                4
# 6   Unklar / Wechselhaft                6
# 3      Eher demokratisch               10
# 10     Eher demokratisch               10
# 5      Eher demokratisch               11
# 12     Eher demokratisch               12
# 7      Eher demokratisch               13
# 1      Eher demokratisch               15
# 2   Unklar / Wechselhaft               16
# 4   Unklar / Wechselhaft               16
# 0   Unklar / Wechselhaft               19
# 8    Eher republikanisch               30

# %%
poll_comp_week.to_csv("poll_comparison.csv",index=False)

# %%
poll_comp_week["Electoral votes"].sum()
# Out:
# np.int64(166)

# %%
base_dem=226-10-4-13
base_rep=235-16-30
base_dem+base_rep
# Out:
# 388

# %%
dem_prev_week=poll_comp_week[poll_comp_week["Diff_Previous_Week"]<-2]["Electoral votes"].sum()
rep_prev_week=poll_comp_week[poll_comp_week["Diff_Previous_Week"]>2]["Electoral votes"].sum()
dem_this_week=poll_comp_week[poll_comp_week["Diff_This_Week"]<-2]["Electoral votes"].sum()
rep_this_week=poll_comp_week[poll_comp_week["Diff_This_Week"]>2]["Electoral votes"].sum()
rep_this_week
# Out:
# np.int64(34)

# %%
toss_up_prev_week=538-base_dem-base_rep-dem_prev_week-rep_prev_week
toss_up_this_week=538-base_dem-base_rep-dem_this_week-rep_this_week
toss_up_this_week
# Out:
# np.int64(41)

# %%
df_electoral=pd.DataFrame([[base_dem+dem_prev_week,toss_up_prev_week,rep_prev_week+base_rep],
 [base_dem+dem_this_week,toss_up_this_week,rep_this_week+base_rep]],index=["Vorwoche", "Diese Woche"],columns=["Eher demokratisch","Unklar/Wechselhaft","Eher republikanisch"])
df_electoral
# Out:
#              Eher demokratisch  Unklar/Wechselhaft  Eher republikanisch
# Vorwoche                   263                  52                  223
# Diese Woche                274                  41                  223

# %%
df_electoral.to_csv("electoral_week_comp.csv")

# %%
yield_curve_csv="https://home.treasury.gov/resource-center/data-chart-center/interest-rates/daily-treasury-rates.csv/2024/all?type=daily_treasury_real_yield_curve&field_tdr_date_value=2024&page&_format=csv"
response = requests.get(yield_curve_csv)

file_object = io.StringIO(response.content.decode('utf-8'))
yield_curve_data=pd.read_csv(file_object)
yield_curve_data
# Out:
#            Date  5 YR  7 YR  10 YR  20 YR  30 YR
# 0    08/16/2024  1.80  1.80   1.81   1.95   2.06
# 1    08/15/2024  1.80  1.80   1.80   1.95   2.06
# 2    08/14/2024  1.74  1.75   1.77   1.92   2.04
# 3    08/13/2024  1.72  1.73   1.76   1.92   2.05
# 4    08/12/2024  1.77  1.77   1.79   1.94   2.06
# ..          ...   ...   ...    ...    ...    ...
# 153  01/08/2024  1.78  1.79   1.79   1.90   1.98
# 154  01/05/2024  1.83  1.83   1.83   1.94   2.02
# 155  01/04/2024  1.79  1.78   1.77   1.88   1.96
# 156  01/03/2024  1.73  1.71   1.71   1.81   1.89
# 157  01/02/2024  1.76  1.75   1.74   1.84   1.91
#
# [158 rows x 6 columns]

# %%
yield_curve_data.Date=pd.to_datetime(yield_curve_data.Date,format="%m/%d/%Y")
yield_curve_data_red=yield_curve_data[["Date","5 YR"]].iloc[:14]
yield_curve_data_red
# Out:
#          Date  5 YR
# 0  2024-08-16  1.80
# 1  2024-08-15  1.80
# 2  2024-08-14  1.74
# 3  2024-08-13  1.72
# 4  2024-08-12  1.77
# 5  2024-08-09  1.84
# 6  2024-08-08  1.85
# 7  2024-08-07  1.82
# 8  2024-08-06  1.77
# 9  2024-08-05  1.71
# 10 2024-08-02  1.73
# 11 2024-08-01  1.78
# 12 2024-07-31  1.84
# 13 2024-07-30  1.91

# %%
yield_curve_data_red.to_csv("yield_curve_data_red.csv",index=False)

# %%
sandp500_url="https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1320&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=SP500&scale=left&cosd=2024-01-01&coed=2024-08-14&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Daily%2C%20Close&fam=avg&fgst=lin&fgsnd=2024-01-01&line_index=1&transformation=lin&vintage_date=2024-08-15&revision_date=2024-08-15&nd=2014-08-15"
response = requests.get(sandp500_url)
file_object = io.StringIO(response.content.decode('utf-8'))
sandp500_data=pd.read_csv(file_object)
sandp500_data
# Out:
#            DATE    SP500
# 0    2024-01-02  4742.83
# 1    2024-01-03  4704.81
# 2    2024-01-04  4688.68
# 3    2024-01-05  4697.24
# 4    2024-01-08  4763.54
# ..          ...      ...
# 157  2024-08-08  5319.31
# 158  2024-08-09  5344.16
# 159  2024-08-12  5344.39
# 160  2024-08-13  5434.43
# 161  2024-08-14  5455.21
#
# [162 rows x 2 columns]

# %%
(sandp500_data.iloc[-14:]).to_csv("sandp500.csv",index=False)

# %%
#Deploying this on Github using Actions
#https://github.com/patrickloeber/python-github-action-template/blob/main/.github/workflows/actions.yml

# %%
apiKeys=pd.read_csv("/Users/maier-borst.h/Documents/apiKeys.csv")
apiKeys
# Out:
#        Service  user                                                key  \
# 0    AISStream   NaN           86f1ccdcae7469dfcabb65477b357219b88f6268
# 1    OpenAIKey   NaN  sk-cs7gw2dFHJHInxQ52RViT3BlbkFJbElNnXftXNJdlcR...
# 2  Datawrapper   NaN  PaGuqpE32MDUqYbFgjJxzQMojucDfnraSOnvw7QwuVYJM5...
#
#                                 Website
# 0          https://aisstream.io/apikeys
# 1  https://platform.openai.com/api-keys
# 2           https://www.datawrapper.de/

# %%
dw_key=apiKeys[apiKeys["Service"]=="Datawrapper"]["key"].values[0]
dw_key
# Out:
# 'PaGuqpE32MDUqYbFgjJxzQMojucDfnraSOnvw7QwuVYJM5O8fZTTx0Y7QVN3g7gW'

# %%
from datawrapper import Datawrapper

dw_connection = Datawrapper(access_token = dw_key)
allcharts=dw_connection.get_charts(limit=10000)
allcharts
# Out:
# {'list': [{'publicId': '6aiXf',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '6aiXf',
#    'title': 'Erwartungen erfüllt?',
#    'type': 'tables',
#    'createdAt': '2024-08-19T13:28:59.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T13:34:10.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-19T13:34:10.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/6aiXf/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 257795,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/6aiXf/64b69d0294dfca9aa14d36f08a7bea49/full.png',
#     'plain': '//img.datawrapper.de/6aiXf/64b69d0294dfca9aa14d36f08a7bea49/plain.png'},
#    'url': '/v3/charts/6aiXf'},
#   {'publicId': '81Fc3',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '81Fc3',
#    'title': 'Werden Sie in den nächsten beiden Wochen handeln?',
#    'type': 'tables',
#    'createdAt': '2024-08-19T13:28:49.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T13:31:18.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-19T13:31:18.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/81Fc3/1/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 257795,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/81Fc3/158aa458eb7decf6b3fe84baba43993f/full.png',
#     'plain': '//img.datawrapper.de/81Fc3/158aa458eb7decf6b3fe84baba43993f/plain.png'},
#    'url': '/v3/charts/81Fc3'},
#   {'publicId': 'HsUgC',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'HsUgC',
#    'title': 'Aktuelle Zyklusphase',
#    'type': 'tables',
#    'createdAt': '2024-08-19T13:28:43.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T13:31:52.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-19T13:31:52.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/HsUgC/1/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 257795,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/HsUgC/5bfd5d8b0abef933c3d9fd785dfa1858/full.png',
#     'plain': '//img.datawrapper.de/HsUgC/5bfd5d8b0abef933c3d9fd785dfa1858/plain.png'},
#    'url': '/v3/charts/HsUgC'},
#   {'publicId': 'lxtwn',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'lxtwn',
#    'title': 'Zyklusphase in drei Monaten',
#    'type': 'tables',
#    'createdAt': '2024-08-19T13:28:27.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T13:32:03.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-19T13:30:29.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/lxtwn/1/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 257795,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/lxtwn/21ac9e5fc42f8cf28dacc8bf308afddb/full.png',
#     'plain': '//img.datawrapper.de/lxtwn/21ac9e5fc42f8cf28dacc8bf308afddb/plain.png'},
#    'url': '/v3/charts/lxtwn'},
#   {'publicId': 'CORxq',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'CORxq',
#    'title': 'Mpox breiten sich aus',
#    'type': 'd3-maps-symbols',
#    'createdAt': '2024-08-16T14:22:59.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-16T15:23:41.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-16T15:23:39.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/CORxq/4/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 105639,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/CORxq/dd37d3ca4377f3b2a4ea8882a5b45f3b/full.png',
#     'plain': '//img.datawrapper.de/CORxq/dd37d3ca4377f3b2a4ea8882a5b45f3b/plain.png'},
#    'url': '/v3/charts/CORxq'},
#   {'publicId': 'UYj6k',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'UYj6k',
#    'title': 'Wo im Juni MPox-Fälle von der WHO registriert wurden',
#    'type': 'd3-maps-symbols',
#    'createdAt': '2024-08-16T11:21:18.000Z',
#    'authorId': 690161,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-16T13:45:55.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-16T12:02:20.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/UYj6k/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': 'h.maier-borst@handelsblattgroup.com',
#     'email': 'h.maier-borst@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-90'},
#    'thumbnails': {'full': '//img.datawrapper.de/UYj6k/b1cb2f7ddcbc50d1d71a5e256043f047/full.png',
#     'plain': '//img.datawrapper.de/UYj6k/b1cb2f7ddcbc50d1d71a5e256043f047/plain.png'},
#    'url': '/v3/charts/UYj6k'},
#   {'publicId': 'rO4Al',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'rO4Al',
#    'title': 'Wo ist der Döner am günstigsten',
#    'type': 'd3-bars',
#    'createdAt': '2024-08-16T10:11:13.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-16T10:31:24.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-16T10:31:24.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/rO4Al/4/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 105639,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/rO4Al/24a0397b4f7fd1d6218927a881e2d4e9/full.png',
#     'plain': '//img.datawrapper.de/rO4Al/24a0397b4f7fd1d6218927a881e2d4e9/plain.png'},
#    'url': '/v3/charts/rO4Al'},
#   {'publicId': '6IEZZ',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '6IEZZ',
#    'title': 'So verhalten sich aktuell US-Treasury-Bonds (5 Jahre)',
#    'type': 'd3-lines',
#    'createdAt': '2024-08-15T16:38:41.000Z',
#    'authorId': 690161,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T14:47:01.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-19T14:47:01.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/6IEZZ/4/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 258995,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': 'h.maier-borst@handelsblattgroup.com',
#     'email': 'h.maier-borst@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-90'},
#    'thumbnails': {'full': '//img.datawrapper.de/6IEZZ/402c2742d69c8d8babe579322041d839/full.png',
#     'plain': '//img.datawrapper.de/6IEZZ/402c2742d69c8d8babe579322041d839/plain.png'},
#    'url': '/v3/charts/6IEZZ'},
#   {'publicId': 'hHLEM',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'hHLEM',
#    'title': 'So viele Wahlmänner würden die Präsidentschaftskandidaten der beiden Partei wohl bekommen*',
#    'type': 'd3-bars-stacked',
#    'createdAt': '2024-08-15T16:12:50.000Z',
#    'authorId': 690161,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T14:47:02.000Z',
#    'publicVersion': 3,
#    'publishedAt': '2024-08-19T14:47:02.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/hHLEM/3/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 258995,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': 'h.maier-borst@handelsblattgroup.com',
#     'email': 'h.maier-borst@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-90'},
#    'thumbnails': {'full': '//img.datawrapper.de/hHLEM/d15e14cb5a25449e9a982d363776106d/full.png',
#     'plain': '//img.datawrapper.de/hHLEM/d15e14cb5a25449e9a982d363776106d/plain.png'},
#    'url': '/v3/charts/hHLEM'},
#   {'publicId': 'we59J',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'we59J',
#    'title': 'Beste kundenorientierte gesetzliche Krankenkassen',
#    'type': 'tables',
#    'createdAt': '2024-08-15T16:02:03.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-16T14:09:04.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-16T14:09:04.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/we59J/4/',
#    'customFields': {'subhed': 'Ranking 2024', 'caption': ''},
#    'folderId': 258618,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/we59J/46780723fd808972a4f566f0c9c7b971/full.png',
#     'plain': '//img.datawrapper.de/we59J/46780723fd808972a4f566f0c9c7b971/plain.png'},
#    'url': '/v3/charts/we59J'},
#   {'publicId': 'wpw0A',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'wpw0A',
#    'title': 'Beste kundenorientierte gesetzliche Krankenkassen',
#    'type': 'tables',
#    'createdAt': '2024-08-15T14:33:01.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-16T14:04:21.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-16T14:04:21.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/wpw0A/4/',
#    'customFields': {'subhed': 'Ranking 2024', 'caption': ''},
#    'folderId': 258618,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/wpw0A/70edcb99a3f1de136d26fe788394f4f4/full.png',
#     'plain': '//img.datawrapper.de/wpw0A/70edcb99a3f1de136d26fe788394f4f4/plain.png'},
#    'url': '/v3/charts/wpw0A'},
#   {'publicId': '7YNBG',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '7YNBG',
#    'title': 'So sieht die Lage in Umfragen in den Swingstates aus',
#    'type': 'd3-arrow-plot',
#    'createdAt': '2024-08-15T14:10:55.000Z',
#    'authorId': 690161,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-19T14:47:04.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-19T14:47:04.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/7YNBG/4/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 258995,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': 'h.maier-borst@handelsblattgroup.com',
#     'email': 'h.maier-borst@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-90'},
#    'thumbnails': {'full': '//img.datawrapper.de/7YNBG/40bc0a9549d254c023ca4472ca87c203/full.png',
#     'plain': '//img.datawrapper.de/7YNBG/40bc0a9549d254c023ca4472ca87c203/plain.png'},
#    'url': '/v3/charts/7YNBG'},
#   {'publicId': 'y6sjp',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'y6sjp',
#    'title': '[ Insert title here ]',
#    'type': 'locator-map',
#    'createdAt': '2024-08-15T13:38:26.000Z',
#    'authorId': 365327,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-15T13:42:28.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-15T13:42:03.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/y6sjp/1/',
#    'customFields': {},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'b.ruthmann@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-120'},
#    'thumbnails': {'full': '//img.datawrapper.de/y6sjp/d621081dc9831a45d0a8e0aba0489cdc/full.png',
#     'plain': '//img.datawrapper.de/y6sjp/d621081dc9831a45d0a8e0aba0489cdc/plain.png'},
#    'url': '/v3/charts/y6sjp'},
#   {'publicId': '7J8Xx',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '7J8Xx',
#    'title': 'Risikolebensversicherung (Musterfälle)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T23:40:46.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T23:57:39.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-13T23:57:39.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/7J8Xx/4/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 257672,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/7J8Xx/90e631ba0eb8821d13779138ec087fe4/full.png',
#     'plain': '//img.datawrapper.de/7J8Xx/90e631ba0eb8821d13779138ec087fe4/plain.png'},
#    'url': '/v3/charts/7J8Xx'},
#   {'publicId': 'gQ8en',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'gQ8en',
#    'title': 'Risikolebensversicherung (Musterfälle)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T23:20:46.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T12:33:01.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-14T12:33:00.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/gQ8en/4/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 257672,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/gQ8en/3bee89a6f19067f1de79d437acf6e8c6/full.png',
#     'plain': '//img.datawrapper.de/gQ8en/3bee89a6f19067f1de79d437acf6e8c6/plain.png'},
#    'url': '/v3/charts/gQ8en'},
#   {'publicId': 'Iuc5x',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'Iuc5x',
#    'title': 'Handwerker (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T22:24:01.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T23:02:26.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-13T23:02:25.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/Iuc5x/1/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2023',
#     'caption': ''},
#    'folderId': 258194,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/Iuc5x/93fd6ffa373e161db61014aa309b0996/full.png',
#     'plain': '//img.datawrapper.de/Iuc5x/93fd6ffa373e161db61014aa309b0996/plain.png'},
#    'url': '/v3/charts/Iuc5x'},
#   {'publicId': 'YfXao',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'YfXao',
#    'title': 'Die besten Grundfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T22:23:16.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T22:59:43.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-13T22:59:42.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/YfXao/1/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258194,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/YfXao/1076c288fb60ae6bc8643b74ca029837/full.png',
#     'plain': '//img.datawrapper.de/YfXao/1076c288fb60ae6bc8643b74ca029837/plain.png'},
#    'url': '/v3/charts/YfXao'},
#   {'publicId': 'mgNGb',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'mgNGb',
#    'title': 'Kaufmännische Angestellte (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T22:17:12.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T23:20:42.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-13T22:55:30.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/mgNGb/2/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258193,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/mgNGb/c0ab5aa84898e27858905f718576b0ab/full.png',
#     'plain': '//img.datawrapper.de/mgNGb/c0ab5aa84898e27858905f718576b0ab/plain.png'},
#    'url': '/v3/charts/mgNGb'},
#   {'publicId': 'NLV51',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'NLV51',
#    'title': 'Die besten Grundfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T22:14:39.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T00:01:58.000Z',
#    'publicVersion': 3,
#    'publishedAt': '2024-08-13T22:59:37.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/NLV51/3/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258193,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/NLV51/a7d287affcc19e17521b7408745de5a1/full.png',
#     'plain': '//img.datawrapper.de/NLV51/a7d287affcc19e17521b7408745de5a1/plain.png'},
#    'url': '/v3/charts/NLV51'},
#   {'publicId': 'EQXvD',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'EQXvD',
#    'title': 'Die besten Risikolebensversicherung',
#    'type': 'tables',
#    'createdAt': '2024-08-13T22:14:38.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T12:30:51.000Z',
#    'publicVersion': 6,
#    'publishedAt': '2024-08-14T12:30:50.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/EQXvD/6/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 257672,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/EQXvD/ecbe89a636bf29c55c10d802c5334086/full.png',
#     'plain': '//img.datawrapper.de/EQXvD/ecbe89a636bf29c55c10d802c5334086/plain.png'},
#    'url': '/v3/charts/EQXvD'},
#   {'publicId': 'tbG6Q',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'tbG6Q',
#    'title': 'Handwerker (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T21:49:48.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T22:02:40.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2024-08-13T22:02:40.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/tbG6Q/1/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258186,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/tbG6Q/c48201d0ee3b74b61427f403f4f3cfdc/full.png',
#     'plain': '//img.datawrapper.de/tbG6Q/c48201d0ee3b74b61427f403f4f3cfdc/plain.png'},
#    'url': '/v3/charts/tbG6Q'},
#   {'publicId': 'yjWLt',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'yjWLt',
#    'title': 'Kaufmännische Angestellte (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T21:48:03.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T21:59:06.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-13T21:59:06.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/yjWLt/2/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258185,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/yjWLt/067625e75dd6ab7765792ad5264e3292/full.png',
#     'plain': '//img.datawrapper.de/yjWLt/067625e75dd6ab7765792ad5264e3292/plain.png'},
#    'url': '/v3/charts/yjWLt'},
#   {'publicId': 'Wylo6',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'Wylo6',
#    'title': 'Die besten Erwerbsunfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T21:17:00.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T00:12:37.000Z',
#    'publicVersion': 3,
#    'publishedAt': '2024-08-14T00:12:36.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/Wylo6/3/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258185,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/Wylo6/5f00b9d7b148936452c91ba9d88b9f73/full.png',
#     'plain': '//img.datawrapper.de/Wylo6/5f00b9d7b148936452c91ba9d88b9f73/plain.png'},
#    'url': '/v3/charts/Wylo6'},
#   {'publicId': 'jFdNm',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'jFdNm',
#    'title': 'Die besten Erwerbsunfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T21:14:39.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T22:00:33.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-13T22:00:33.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/jFdNm/2/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258186,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/jFdNm/a20f978fc74248d5bd9585fd96437013/full.png',
#     'plain': '//img.datawrapper.de/jFdNm/a20f978fc74248d5bd9585fd96437013/plain.png'},
#    'url': '/v3/charts/jFdNm'},
#   {'publicId': '5EcGL',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '5EcGL',
#    'title': ' Handwerker (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T19:03:47.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T21:08:07.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-13T21:08:07.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/5EcGL/4/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258159,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/5EcGL/851e25961062349ada43c3ff47be7a57/full.png',
#     'plain': '//img.datawrapper.de/5EcGL/851e25961062349ada43c3ff47be7a57/plain.png'},
#    'url': '/v3/charts/5EcGL'},
#   {'publicId': 'uuiDZ',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'uuiDZ',
#    'title': 'Die besten Berufsunfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T19:03:31.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T12:40:38.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2024-08-14T00:10:17.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/uuiDZ/4/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258159,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/uuiDZ/49df5d6a06381cba43dbebaebd36037a/full.png',
#     'plain': '//img.datawrapper.de/uuiDZ/49df5d6a06381cba43dbebaebd36037a/plain.png'},
#    'url': '/v3/charts/uuiDZ'},
#   {'publicId': 't8jSn',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 't8jSn',
#    'title': 'Akademiker (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T19:03:06.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T21:08:43.000Z',
#    'publicVersion': 3,
#    'publishedAt': '2024-08-13T21:08:41.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/t8jSn/3/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258158,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/t8jSn/c46819d5913a1107b8244a3ef55c3475/full.png',
#     'plain': '//img.datawrapper.de/t8jSn/c46819d5913a1107b8244a3ef55c3475/plain.png'},
#    'url': '/v3/charts/t8jSn'},
#   {'publicId': 'fpb4U',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'fpb4U',
#    'title': 'Die besten Berufsunfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T19:02:26.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T12:37:37.000Z',
#    'publicVersion': 6,
#    'publishedAt': '2024-08-14T12:37:36.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/fpb4U/6/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258157,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/fpb4U/43c1b2ad085e5fa0edd6fc72c10a4f1b/full.png',
#     'plain': '//img.datawrapper.de/fpb4U/43c1b2ad085e5fa0edd6fc72c10a4f1b/plain.png'},
#    'url': '/v3/charts/fpb4U'},
#   {'publicId': 'rPdHg',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'rPdHg',
#    'title': 'Kaufmännische Angestellte (Musterfall)',
#    'type': 'tables',
#    'createdAt': '2024-08-13T18:24:44.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-13T21:09:19.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2024-08-13T21:09:19.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/rPdHg/2/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258157,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'i.jablonowska@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-40'},
#    'thumbnails': {'full': '//img.datawrapper.de/rPdHg/bbccc9089744fac599dc600497187769/full.png',
#     'plain': '//img.datawrapper.de/rPdHg/bbccc9089744fac599dc600497187769/plain.png'},
#    'url': '/v3/charts/rPdHg'},
#   {'publicId': 'FwSy7',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'FwSy7',
#    'title': 'Die besten Berufsunfähigkeitsversicherungen',
#    'type': 'tables',
#    'createdAt': '2024-08-13T18:21:24.000Z',
#    'authorId': 125105,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2024-08-14T12:40:00.000Z',
#    'publicVersion': 6,
#    'publishedAt': '2024-08-14T12:39:59.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/FwSy7/6/',
#    'customFields': {'subhed': 'Arbeitskraftabsicherung und Risikovorsorge 2024',
#     'caption': ''},
#    'folderId': 258158,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
# ...
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/2DRV9/adbdf96ed3173c1a4085d7318813d3a5/full.png',
#     'plain': '//img.datawrapper.de/2DRV9/adbdf96ed3173c1a4085d7318813d3a5/plain.png'},
#    'url': '/v3/charts/2DRV9'},
#   {'publicId': 'KyW4x',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'KyW4x',
#    'title': '',
#    'type': 'tables',
#    'createdAt': '2023-11-28T11:04:09.000Z',
#    'authorId': 235847,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-12-04T11:15:18.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2023-11-28T11:07:14.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/KyW4x/1/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'h.wuensche@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/KyW4x/4daefb5519e53db71cb90dcc862da251/full.png',
#     'plain': '//img.datawrapper.de/KyW4x/4daefb5519e53db71cb90dcc862da251/plain.png'},
#    'url': '/v3/charts/KyW4x'},
#   {'publicId': '0zegJ',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': '0zegJ',
#    'title': 'Das Schweigen der Wirtschaft',
#    'type': 'd3-bars',
#    'createdAt': '2023-11-27T17:45:58.000Z',
#    'authorId': 235847,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-30T15:40:10.000Z',
#    'publicVersion': 1,
#    'publishedAt': '2023-11-30T15:40:09.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/0zegJ/1/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'h.wuensche@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/0zegJ/e5bc27426ae3f15186bbffd2579d7492/full.png',
#     'plain': '//img.datawrapper.de/0zegJ/e5bc27426ae3f15186bbffd2579d7492/plain.png'},
#    'url': '/v3/charts/0zegJ'},
#   {'publicId': 'iL9mU',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'iL9mU',
#    'title': 'Aufstieg der AfD',
#    'type': 'd3-lines',
#    'createdAt': '2023-11-27T16:20:42.000Z',
#    'authorId': 235847,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T09:59:21.000Z',
#    'publicVersion': 3,
#    'publishedAt': '2023-11-28T09:59:19.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/iL9mU/3/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'h.wuensche@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/iL9mU/ec3481711fd7b303194994bf9e1aaf50/full.png',
#     'plain': '//img.datawrapper.de/iL9mU/ec3481711fd7b303194994bf9e1aaf50/plain.png'},
#    'url': '/v3/charts/iL9mU'},
#   {'publicId': 'KUj6Q',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'KUj6Q',
#    'title': 'Zyklusphase in drei Monaten',
#    'type': 'tables',
#    'createdAt': '2023-11-27T13:58:16.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T10:32:44.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2023-11-28T10:32:41.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/KUj6Q/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 208837,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/KUj6Q/71200c38a88fe0dc3c6aada6a28643cf/full.png',
#     'plain': '//img.datawrapper.de/KUj6Q/71200c38a88fe0dc3c6aada6a28643cf/plain.png'},
#    'url': '/v3/charts/KUj6Q'},
#   {'publicId': 'SRR2i',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'SRR2i',
#    'title': 'Aktuelle Zyklusphase',
#    'type': 'tables',
#    'createdAt': '2023-11-27T13:58:10.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T10:32:56.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2023-11-28T10:32:55.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/SRR2i/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 208837,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/SRR2i/cc0a98acb11914dd505fc7bf759f6a4e/full.png',
#     'plain': '//img.datawrapper.de/SRR2i/cc0a98acb11914dd505fc7bf759f6a4e/plain.png'},
#    'url': '/v3/charts/SRR2i'},
#   {'publicId': 'nZ4ha',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'nZ4ha',
#    'title': 'Werden Sie in den nächsten beiden Wochen handeln?',
#    'type': 'tables',
#    'createdAt': '2023-11-27T13:58:02.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T11:03:57.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2023-11-28T10:33:05.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/nZ4ha/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 208837,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/nZ4ha/7339dc0cd19fad88b1edafa725f88022/full.png',
#     'plain': '//img.datawrapper.de/nZ4ha/7339dc0cd19fad88b1edafa725f88022/plain.png'},
#    'url': '/v3/charts/nZ4ha'},
#   {'publicId': 'z6vOM',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'z6vOM',
#    'title': 'Erwartungen erfüllt?',
#    'type': 'tables',
#    'createdAt': '2023-11-27T13:57:47.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T10:33:19.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2023-11-28T10:33:18.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/z6vOM/2/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': 208837,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/z6vOM/696c08bda3e0205b8ef3416c6c3f877d/full.png',
#     'plain': '//img.datawrapper.de/z6vOM/696c08bda3e0205b8ef3416c6c3f877d/plain.png'},
#    'url': '/v3/charts/z6vOM'},
#   {'publicId': 'VJ4ad',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'VJ4ad',
#    'title': 'Handelsblatt-Dividendenprognose 2024 <br>\nfür das Geschäftsjahr 2023',
#    'type': 'tables',
#    'createdAt': '2023-11-27T13:25:42.000Z',
#    'authorId': 235847,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-27T13:58:39.000Z',
#    'publicVersion': 2,
#    'publishedAt': '2023-11-27T13:58:37.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/VJ4ad/2/',
#    'customFields': {'subhed': 'Dividenden der Dax-Konzerne', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'h.wuensche@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/VJ4ad/38bfeb913779f7275a0798692b17df0d/full.png',
#     'plain': '//img.datawrapper.de/VJ4ad/38bfeb913779f7275a0798692b17df0d/plain.png'},
#    'url': '/v3/charts/VJ4ad'},
#   {'publicId': 'o5e4c',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'o5e4c',
#    'title': 'Hainan Bielefeld University of Applied Sciences',
#    'type': 'locator-map',
#    'createdAt': '2023-11-27T11:32:58.000Z',
#    'authorId': 235847,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-27T13:22:59.000Z',
#    'publicVersion': 5,
#    'publishedAt': '2023-11-27T13:22:58.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/o5e4c/5/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'h.wuensche@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/o5e4c/1dcaa4e5fd19f2e2d44017e8e0e25e07/full.png',
#     'plain': '//img.datawrapper.de/o5e4c/1dcaa4e5fd19f2e2d44017e8e0e25e07/plain.png'},
#    'url': '/v3/charts/o5e4c'},
#   {'publicId': 'naauI',
#    'language': 'de-DE',
#    'theme': 'handelsblatt',
#    'id': 'naauI',
#    'title': 'Urlaub und Arbeiten verbinden \n',
#    'type': 'tables',
#    'createdAt': '2023-11-27T11:26:12.000Z',
#    'authorId': 284562,
#    'organizationId': 'handelsblatt-2',
#    'lastEditStep': 5,
#    'lastModifiedAt': '2023-11-28T09:26:38.000Z',
#    'publicVersion': 4,
#    'publishedAt': '2023-11-27T12:19:19.000Z',
#    'publicUrl': 'https://datawrapper.dwcdn.net/naauI/4/',
#    'customFields': {'subhed': '', 'caption': ''},
#    'folderId': None,
#    'metadata': {'data': {'changes': [],
#      'transpose': False,
#      'vertical-header': True,
#      'horizontal-header': True},
#     'describe': {'source-name': '',
#      'source-url': '',
#      'intro': '',
#      'byline': '',
#      'aria-description': '',
#      'number-format': '-',
#      'number-divisor': 0,
#      'number-append': '',
#      'number-prepend': ''},
#     'visualize': {'dark-mode-invert': True,
#      'highlighted-series': [],
#      'highlighted-values': [],
#      'sharing': {'enabled': False}},
#     'axes': {},
#     'publish': {'embed-width': 600,
#      'embed-height': 400,
#      'blocks': {},
#      'export-pdf': {}},
#     'annotate': {'notes': ''},
#     'custom': {}},
#    'author': {'name': None,
#     'email': 'j.rosenberger@handelsblattgroup.com',
#     'avatar': None,
#     'color': 'color-dw-presence-100'},
#    'thumbnails': {'full': '//img.datawrapper.de/naauI/8e9ae0ccaca46c40e27520da58cb6ce9/full.png',
#     'plain': '//img.datawrapper.de/naauI/8e9ae0ccaca46c40e27520da58cb6ce9/plain.png'},
#    'url': '/v3/charts/naauI'},
#   ...],
#  'total': 3888}

# %%
all_charts_corona_dashboard=list(filter(lambda item: item["folderId"] == 30694, allcharts))
for item in (all_charts_corona_dashboard):
  print(item)
  dw_connection.publish_chart(chart_id=item["id"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 all_charts_corona_dashboard=list(filter(lambda item: item["folderId"] == 30694, allcharts))
#       2 for item in (all_charts_corona_dashboard):
#       3   print(item)
#
# Cell In[27], line 1, in <lambda>(item)
# ----> 1 all_charts_corona_dashboard=list(filter(lambda item: item["folderId"] == 30694, allcharts))
#       2 for item in (all_charts_corona_dashboard):
#       3   print(item)
#
# TypeError: string indices must be integers
