# %%
import pandas as pd

# %%
data=pd.read_csv("../data/usbases.csv")
data
# Out:
#          country               name        lat        lon  \
# 0    Afghanistan          Bagram Ab  34.946222  69.264639
# 1    Afghanistan  Kandahar Airfield  31.506807  65.847511
# 2    Afghanistan     Mazar-E-Sharif  36.707497  67.209892
# 3    Afghanistan             Gardez  33.625017  69.235840
# 4    Afghanistan              Kabul  34.534477  69.150352
# ..           ...                ...        ...        ...
# 326      Germany         Seckenheim  49.463903   8.559200
# 327      Germany            Sembach  49.511398   7.864983
# 328      Germany        Spangdahlem  49.985679   6.684338
# 329      Germany          Stuttgart  48.775418   9.181759
# 330      Germany              Trier  49.746883   6.634751
#
#                                                  notes Unnamed: 5 Unnamed: 6  \
# 0    2014 agreement allows U.S. troops to remain at...     Former  FormerLat
# 1                                                  NaN        NaN        NaN
# ...

# %%
data.groupby(["country"]).count()
# Out:
#                                 name  lat  lon  notes  Unnamed: 5  Unnamed: 6  \
# country
# Afghanistan                        9    9    9      1           1           1
# American Samoa                     1    1    1      1           0           0
# Ascension Island                   1    1    1      1           1           1
# Australia                          2    2    2      1           0           0
# Bahrain                            4    4    4      3           0           0
# Belgium                            6    6    6      2           0           0
# British Indian Ocean Territory     1    1    1      1           0           0
# Bulgaria                           1    1    1      1           0           0
# Cambodia                           1    1    1      1           1           0
# Cuba                               1    1    1      1           0           0
# Djibouti                           1    1    1      1           0           0
# ...

# %%
data=data.drop_duplicates(subset=["country","name","lat","lon"])
data["lat"]=data["lat"].astype(str)
data["lon"]=data["lon"].astype(str)

# %%
data.to_csv("us_bases_no_dup.csv",index=False, )
