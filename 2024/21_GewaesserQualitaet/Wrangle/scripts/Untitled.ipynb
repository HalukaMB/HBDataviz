# %%
import pandas as pd

# %%
data=pd.read_excel("../data/Auftragsliste_BfG_Stand_240423.xlsx",skiprows=2)
data
# Out:
# /Users/maier-borst.h/Documents/CodeRelated/HBDataviz/2024/21_GewaesserQualitaet/Wrangle/lib/python3.9/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       Projekt-Nr.                                       Projekttitel  \
# 0    M39630304106                        Unterhaltungspläne ABz Hamm
# 1    M39610202437  Längerfristige Wasserstandsvorhersage für die ...
# 2    M39610504111                           Beschaff. Messsystem RMD
# 3    M39610504183                              Fachbeitrag Ersatz PR
# 4    M39620100285  Sauerstoffmessungen Donau, Main und Neckar, La...
# ..            ...                                                ...
# 549  M39610504167              Hauptnivellement Weser-Unterweser2022
# 550  M39630104058                      BBD-MP-Erfolgskontrolle Weser
# ...

# %%
data[data["Bundeswasserstraße"].str.contains("Oder")]
# Out:
#       Projekt-Nr.                                       Projekttitel  \
# 85   M39610304079  Hydrogeologische Beratung; Baggergut-/ Grundwa...
# 86   M39630204052                                      SpreeWasser:N
# 159  M39600000913             Allgemeine Beratung des WSA Oder Havel
# 160  M39610204077                 Wasserhaushaltsmodell für die Oder
# 161  M39610304040            Auswertung der durchgeführten Messungen
# 162  M39620202186  Chemische Sediment-, Schwebstoff- und Wasserun...
# 163  M39630104055                  SRK Grenzoder, dt.-poln. Abkommen
# 164  M39630304042  Beurteilung der durch die Baumaßnahme hervorge...
# 243  M39630104028  Fachtechnische Begleitung der Instandsetzung d...
# 244  M39630304093                    Flachwassermonitoring SOW & UHW
#
#            Bundeswasserstraße  km von   km bis     Beginn       Ende
# 85   Havel-Oder-Wasserstraße      NaN      NaN 2015-07-01 2024-06-30
# 86   Havel-Oder-Wasserstraße      NaN      NaN 2022-08-01 2025-07-31
# ...
