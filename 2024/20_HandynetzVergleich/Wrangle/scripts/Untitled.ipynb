# %%
import pandas as pd
import geopandas as gpd

# %%
geo_ausbau_gdf = gpd.read_file("../data/Mobilfunk_Daten/202310_Geodaten_GebieteMitAusbaudefizit/202310_GebieteMitAusbaudefizit.gpkg")
geo_ausbau_gdf
# Out:
#          Nr betroffene_Laender betroffene_Kreise betroffene_Gemeinden  \
# 0         1                 08             08336             08336105
# 1         2                 08             08336             08336105
# 2         3                 08             08336             08336105
# 3         4                 08             08336             08336105
# 4         5                 08             08336             08336043
# ...     ...                ...               ...                  ...
# 7705  39371                 08             08135             08135031
# 7706  39373                 08             08135             08135031
# 7707  39374                 08             08135             08135031
# 7708  39375                 08             08135             08135021
# 7709  39387                 08             08135             08135010
#
#       Gebietsflaeche_qkm                                           geometry
# ...

# %%
geo_breitband_gdf = gpd.read_file("../data/Mobilfunk_Daten/202401_Geodaten_breitbandigeMobilfunkversorgung/202401_Geodaten_breitbandigeMobilfunkversorgung.gpkg")
geo_breitband_gdf
# Out:
#         BL mobilesBB_AnzahlMNB  \
# 0       08                   2
# 1       08                   2
# 2       08                   2
# 3       08                   2
# 4       08                   2
# ...     ..                 ...
# 690278  01                   1
# 690279  01                   1
# 690280  01                   1
# 690281  01                   1
# 690282  01                   1
#
#                                                  geometry
# 0       POLYGON ((396000.000 5270200.000, 396000.000 5...
# 1       POLYGON ((396300.000 5270300.000, 396400.000 5...
# 2       POLYGON ((395000.000 5270300.000, 395000.000 5...
# 3       POLYGON ((395500.000 5270400.000, 395600.000 5...
# 4       POLYGON ((395100.000 5270400.000, 395100.000 5...
# ...                                                   ...
# 690278  POLYGON ((620100.000 5935100.000, 620100.000 5...
# 690279  POLYGON ((620700.000 5935100.000, 620600.000 5...
# ...
