# %% [markdown]
# We load the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We read in the classification for jobs into different job sectors according to the German office for statistics

# %%
berufbereiche=pd.read_excel("../data/ew2024_bewerb/ab2017_klassifikation_berufe.xlsx",sheet_name="Berufsbereiche",skiprows=5,dtype=str)
berufbereiche=berufbereiche.rename(columns={"Unnamed: 2":"Bezeichnung"})
berufbereiche=berufbereiche.dropna(thresh=2)
berufbereiche
# Out:
#    von  bis                                        Bezeichnung
# 1   01  NaN                                            Militär
# 2   04  NaN                  Schüler, Auszubildende, Studenten
# 3   05  NaN                                Rentner, Pensionäre
# 4   06  NaN                        Hausfrauen, Arbeitssuchende
# 5   09  NaN  Ohne nähere Tätigkeitsangabe, z. B. Selbststän...
# 6   11   12     Land-, Forst- und Tierwirtschaft und Gartenbau
# 7   21   29        Rohstoffgewinnung, Produktion und Fertigung
# 8   31   34    Bau, Architektur, Vermessung und Gebäudetechnik
# 9   41   43        Naturwissenschaft, Geografie und Informatik
# 10  51   54           Verkehr, Logistik, Schutz und Sicherheit
# 11  61   63  Kaufmännische Dienstleistungen, Warenhandel, V...
# 12  71   73  Unternehmensorganisation, Buchhaltung, Recht u...
# 13  81   84          Gesundheit, Soziales, Lehre und Erziehung
# 14  91   94  Sprach-, Literatur-, Geistes-, Gesellschafts- ...

# %% [markdown]
# Now we modify this slightly by creating for the dataframe a "from" and a "to" column which defines between which encoded numbers certain job sectors can be found

# %%
berufbereiche["bis"]=np.where(berufbereiche["bis"].isna(),berufbereiche["von"],berufbereiche["bis"])
berufbereiche
# Out:
#    von bis                                        Bezeichnung
# 1   01  01                                            Militär
# 2   04  04                  Schüler, Auszubildende, Studenten
# 3   05  05                                Rentner, Pensionäre
# 4   06  06                        Hausfrauen, Arbeitssuchende
# 5   09  09  Ohne nähere Tätigkeitsangabe, z. B. Selbststän...
# 6   11  12     Land-, Forst- und Tierwirtschaft und Gartenbau
# 7   21  29        Rohstoffgewinnung, Produktion und Fertigung
# 8   31  34    Bau, Architektur, Vermessung und Gebäudetechnik
# 9   41  43        Naturwissenschaft, Geografie und Informatik
# 10  51  54           Verkehr, Logistik, Schutz und Sicherheit
# 11  61  63  Kaufmännische Dienstleistungen, Warenhandel, V...
# 12  71  73  Unternehmensorganisation, Buchhaltung, Recht u...
# 13  81  84          Gesundheit, Soziales, Lehre und Erziehung
# 14  91  94  Sprach-, Literatur-, Geistes-, Gesellschafts- ...

# %% [markdown]
# Now we iterate through this dataframe and create a dictionary that assigns to each number a job sector

# %%
berufbereiche_dict={}
for index, row in berufbereiche.iterrows():
    print(row["von"],row["bis"])
    for i in range(int(row["von"]),int(row["bis"])+1):
        berufbereiche_dict[i]=row["Bezeichnung"]
        berufbereiche_dict
berufbereiche_dict
# Out:
# 01 01
# 04 04
# 05 05
# 06 06
# 09 09
# 11 12
# 21 29
# 31 34
# 41 43
# 51 54
# 61 63
# 71 73
# 81 84
# 91 94
# {1: 'Militär',
#  4: 'Schüler, Auszubildende, Studenten',
#  5: 'Rentner, Pensionäre',
#  6: 'Hausfrauen, Arbeitssuchende',
#  9: 'Ohne nähere Tätigkeitsangabe, z. B. Selbstständige',
#  11: 'Land-, Forst- und Tierwirtschaft und Gartenbau',
#  12: 'Land-, Forst- und Tierwirtschaft und Gartenbau',
#  21: 'Rohstoffgewinnung, Produktion und Fertigung',
#  22: 'Rohstoffgewinnung, Produktion und Fertigung',
#  23: 'Rohstoffgewinnung, Produktion und Fertigung',
#  24: 'Rohstoffgewinnung, Produktion und Fertigung',
#  25: 'Rohstoffgewinnung, Produktion und Fertigung',
#  26: 'Rohstoffgewinnung, Produktion und Fertigung',
#  27: 'Rohstoffgewinnung, Produktion und Fertigung',
#  28: 'Rohstoffgewinnung, Produktion und Fertigung',
#  29: 'Rohstoffgewinnung, Produktion und Fertigung',
#  31: 'Bau, Architektur, Vermessung und Gebäudetechnik',
#  32: 'Bau, Architektur, Vermessung und Gebäudetechnik',
#  33: 'Bau, Architektur, Vermessung und Gebäudetechnik',
#  34: 'Bau, Architektur, Vermessung und Gebäudetechnik',
#  41: 'Naturwissenschaft, Geografie und Informatik',
#  42: 'Naturwissenschaft, Geografie und Informatik',
#  43: 'Naturwissenschaft, Geografie und Informatik',
#  51: 'Verkehr, Logistik, Schutz und Sicherheit',
#  52: 'Verkehr, Logistik, Schutz und Sicherheit',
#  53: 'Verkehr, Logistik, Schutz und Sicherheit',
#  54: 'Verkehr, Logistik, Schutz und Sicherheit',
#  61: 'Kaufmännische Dienstleistungen, Warenhandel, Vertrieb, Hotel und Tourismus',
#  62: 'Kaufmännische Dienstleistungen, Warenhandel, Vertrieb, Hotel und Tourismus',
#  63: 'Kaufmännische Dienstleistungen, Warenhandel, Vertrieb, Hotel und Tourismus',
#  71: 'Unternehmensorganisation, Buchhaltung, Recht und Verwaltung',
#  72: 'Unternehmensorganisation, Buchhaltung, Recht und Verwaltung',
#  73: 'Unternehmensorganisation, Buchhaltung, Recht und Verwaltung',
#  81: 'Gesundheit, Soziales, Lehre und Erziehung',
#  82: 'Gesundheit, Soziales, Lehre und Erziehung',
#  83: 'Gesundheit, Soziales, Lehre und Erziehung',
#  84: 'Gesundheit, Soziales, Lehre und Erziehung',
#  91: 'Sprach-, Literatur-, Geistes-, Gesellschafts- und Wirtschaftswissenschaften,\nMedien, Kunst, Kultur und Gestaltung',
#  92: 'Sprach-, Literatur-, Geistes-, Gesellschafts- und Wirtschaftswissenschaften,\nMedien, Kunst, Kultur und Gestaltung',
#  93: 'Sprach-, Literatur-, Geistes-, Gesellschafts- und Wirtschaftswissenschaften,\nMedien, Kunst, Kultur und Gestaltung',
#  94: 'Sprach-, Literatur-, Geistes-, Gesellschafts- und Wirtschaftswissenschaften,\nMedien, Kunst, Kultur und Gestaltung'}

# %% [markdown]
# Now we read in the data for the candidates for the Bundestagswahl and the European election

# %%
data_europa=pd.read_csv("../data/ew2024_bewerb/ew2024_bewerb_uft8.csv",sep=";",skiprows=8)
data_bund=pd.read_csv("../data/btw2021_bewerb/btw2021_bewerb_utf8.csv",sep=";",skiprows=8)
data_europa.columns
# Out:
# Index(['Wahlart', 'Wahltag', 'Titel', 'Namenszusatz', 'Name', 'Vornamen',
#        'Künstlername', 'Geschlecht', 'Geburtsjahr', 'PLZ', 'Wohnort', 'Staat',
#        'WohnortLand', 'Geburtsort', 'Staatsangehörigkeit', 'Beruf',
#        'Berufsschluessel', 'Kennzeichen', 'Gebietsart', 'Gebietsnummer',
#        'Gebietsname', 'GebietLandAbk', 'Gruppenname', 'GruppennameLang',
#        'Listenplatz', 'VerknKennzeichen', 'VerknGebietsart',
#        'VerknGebietsnummer', 'VerknGebietsname', 'VerknGebietLandAbk',
#        'VerknGruppenname', 'VerknListenplatz', 'VorpGewaehlt'],
#       dtype='object')

# %% [markdown]
# And then process the Berufsschluessel column so that we can assign to each candidate into which job sector he or she belongs

# %%
data_bund["Berufsbezeichnung"]=data_bund["Berufsschluessel"].astype(int)
data_bund["Berufsbezeichnung"]=data_bund["Berufsbezeichnung"].replace(berufbereiche_dict)

data_europa["Berufsbezeichnung"]=data_europa["Berufsschluessel"].astype(int)
data_europa["Berufsbezeichnung"]=data_europa["Berufsbezeichnung"].replace(berufbereiche_dict)
data_bund.Gruppenname.unique()
# Out:
# array(['CDU', 'SPD', 'FDP', 'GRÜNE', 'AfD', 'DIE LINKE', 'FREIE WÄHLER',
#        'dieBasis', 'du.', 'LKR', 'SSW', 'V-Partei³', 'Die PARTEI', 'MLPD',
#        'DKP', 'Volt', 'EB: Schlüter', 'EB: Kerkhoff', 'PIRATEN',
#        'EB: Löwe', 'Tierschutzpartei', 'EB: Krüger', 'UNABHÄNGIGE', 'ÖDP',
#        'NPD', 'EB: Janoske-Kizildag', 'ÖLDP', 'EB: Lenz', 'EB: Balzer',
#        'EB: Gums', 'EB: Großkopf', 'EB: Weich', 'Die Humanisten',
#        'EB: Kober', 'EB: Neumann', 'EB: Kunick', 'EB: Göller',
#        'EB: Wieczorek', 'EB: Herzig', 'EB: Jagau', 'EB: Deutsch',
#        'EB: Rosenbaum', 'EB: Wolter', 'EB: Gust', 'EB: Wiesenthal',
#        'EB: Hönig', 'EB: Schäuble-Leopold', 'EB: Glamann',
#        'EB: Eckelmann', 'EB: Buro', 'EB: Schlippenbach', 'EB: Lorenz',
#        'EB: Schütz', 'EB: Conrad', 'EB: Hinners', 'EB: Roloff',
#        'EB: Müller', 'EB: Grütte', 'EB: Charnow', 'EB: Gabler',
#        'EB: Hitzer', 'EB: Commentz', 'FAMILIE', 'EB: Kaun',
#        'EB: Marquardt', 'EB: Janda', 'EB: Bibiella', 'EB: Janowski',
#        'Tierschutzallianz', 'EB: Barth', 'Gartenpartei', '#TeamFranka',
#        'EB: Rohne', 'EB: Wassenaar', 'EB: Zimmermann', 'EB: Fielsch',
#        'EB: Zebian', 'Gesundheitsforschung', 'Die Grauen', 'BÜNDNIS21',
#        'EB: Bunte', 'EB: Voß', 'MENSCHLICHE WELT', 'Team Todenhöfer',
#        'sonstige', 'EB: Pape', 'EB: Lindlmair', 'EB: Moser', 'B*',
#        'EB: Wendt', 'EB: Snelinski', 'EB: Böving', 'EB: Teßmann', 'LIEBE',
#        'EB: Przybylski', 'EB: Podjaski', 'EB: Goldbeck',
#        'Volksabstimmung', 'EB: Blum', 'EB: Kramer', 'EB: Klimczak',
#        'EB: Herrmann', 'Bündnis C', 'EB: Richter', 'EB: Baumanns',
#        'EB: Herbert', 'EB: Opfer', 'EB: Ergin', 'EB: Saygili', 'EB: Bilo',
#        'EB: Wetklo', 'EB: Georgiou', 'EB: Kaldewei', 'EB: Dumberger',
#        'EB: Geselbracht', 'EB: Brehm', 'EB: Martinschledde', 'EB: Zajonc',
#        'EB: Sonnabend', 'EB: Tropp', 'EB: Hofmann', 'EB: Trojanowski',
#        'EB: Peiler', 'EB: Meister', 'EB: Asmus', 'EB: Oschkinat',
#        'EB: Härtlein', 'EB: Hummitzsch', 'EB: Kohl', 'EB: Bayer',
#        'EB: Schöllner', 'EB: Zimmet', 'EB: Blickle', 'EB: Brähmig',
#        'EB: Queck', 'EB: Fuchs', 'EB: Häupl', 'BüSo', 'EB: Hannig',
#        '#KLIMAfirst', 'EB: Weidemann', 'EB: Röhder', 'EB: Reichel',
#        'EB: Krajak', 'III. Weg', 'EB: Gerisch', 'EB: Meyer',
#        'EB: Mascher', 'EB: El-Fayoumy', 'EB: Schmidt', 'EB: Klement',
#        'EB: Marinello', 'EB: Carstensen', 'TNT', 'EB: Hemm',
#        'EB: Schlossbauer', 'EB: Rehbein', 'EB: Stachowiak', 'EB: Stein',
#        'EB: Grammbitter', 'Graue Panther', 'THP', 'EB: Nebeler',
#        'EB: Berger', 'EB: Bieling', 'EB: Erdmann', 'EB: Mandel',
#        'EB: Sayn', 'EB: Krämer', 'EB: Vollmer', 'EB: Bartholomé',
#        'EB: Moritz', 'EB: Engels', 'EB: Seiffert', 'EB: Heil', 'EB: Pohl',
#        'EB: Hackel', 'EB: Schöne', 'EB: Bechtel', 'EB: Wittner',
#        'EB: Schwang', 'EB: Hoppe', 'EB: Lauer', 'EB: Mobasheri',
#        'EB: Koccu', 'EB: Vogler', 'CSU', 'BP', 'EB: Hilz',
#        'EB: Klopstock', 'EB: Dönmez', 'EB: Sommerfeldt', 'EB: Englisch',
#        'EB: Ryssel', 'EB: Manz', 'EB: Pettenkofer', 'EB: Knott',
#        'EB: Gradl', 'EB: Friedl', 'EB: Bauer', 'EB: Dippel',
#        'EB: Roensch', 'EB: Löhnert', 'EB: Kunstmann', 'EB: Kalupner',
#        'EB: Henig', 'EB: Eppel', 'EB: Schlot', 'EB: Lembach',
#        'EB: Kaiser', 'EB: Schürer', 'EB: Kolb', 'EB: Sirin', 'EB: Baydar',
#        'EB: Langhans', 'EB: Dorn', 'DiB', 'BÜRGERBEWEGUNG',
#        'EB: Ressdorf', 'EB: Demir', 'EB: Miller', 'EB: Tolzin',
#        'EB: Gibanica', 'EB: Novotny', 'EB: Hartmann', 'KlimalisteBW',
#        'EB: Mund', 'EB: Rapps', 'EB: Schmitt', 'EB: Fritsch',
#        'EB: Herrlinger', 'EB: Harting', 'EB: Ringger', 'EB: Poss', 'SGP',
#        'PdF', 'LfK'], dtype=object)

# %%
data_bund.Gruppenname=data_bund.Gruppenname.astype(str).str.replace("CDU","Union")
data_bund.Gruppenname=data_bund.Gruppenname.astype(str).str.replace("CSU","Union")
data_europa.Gruppenname=data_europa.Gruppenname.astype(str).str.replace("CDU","Union")
data_europa.Gruppenname=data_europa.Gruppenname.astype(str).str.replace("CSU","Union")
data_europa.Gruppenname=data_europa.Gruppenname.astype(str).str.replace("DIE LINKE","Die Linke")
data_bund.Gruppenname=data_bund.Gruppenname.astype(str).str.replace("DIE LINKE","Die Linke")
data_europa.Gruppenname=data_europa.Gruppenname.astype(str).str.replace("GRÜNE","Grüne")
data_bund.Gruppenname=data_bund.Gruppenname.astype(str).str.replace("GRÜNE","Grüne")

# %%
data_europa.groupby(["Gruppenname"]).count()
# Out:
#                      Wahlart  Wahltag  Titel  Namenszusatz  Name  Vornamen  \
# Gruppenname
# ABG                        9        9      0             0     9         9
# AfD                       35       35      4             0    35        35
# BIG                       23       23      0             0    23        23
# BSW                       20       20      4             2    20        20
# BÜNDNIS DEUTSCHLAND       11       11      0             0    11        11
# Bündnis C                 13       13      2             0    13        13
# DAVA                      13       13      2             0    13        13
# DKP                       43       43      1             0    43        43
# Die Linke                 20       20      0             0    20        20
# Die PARTEI               211      211      2             0   211       211
# FAMILIE                   11       11      1             0    11        11
# FDP                      194      194     19             4   194       194
# FREIE WÄHLER              27       27      1             0    27        27
# Grüne                     40       40      2             1    40        40
# HEIMAT                    15       15      0             0    15        15
# KLIMALISTE                14       14      2             0    14        14
# LETZTE GENERATION         12       12      0             0    12        12
# MENSCHLICHE WELT           9        9      0             0     9         9
# MERA25                    14       14      1             0    14        14
# MLPD                      18       18      1             0    18        18
# PDV                       13       13      1             0    13        13
# PIRATEN                   18       18      1             0    18        18
# PdF                       10       10      0             0    10        10
# PdH                       21       21      0             0    21        21
# SGP                       11       11      0             0    11        11
# SPD                      189      189     13             0   189       189
# TIERSCHUTZ hier!           7        7      0             0     7         7
# Tierschutzpartei           8        8      1             0     8         8
# Union                    259      259     27             6   259       259
# V-Partei³                 19       19      1             0    19        19
# Volt                      27       27      2             2    27        27
# dieBasis                   4        4      0             0     4         4
# nan                       19       19      0             0    19        19
# ÖDP                       87       87      9             1    87        87
#
#                      Künstlername  Geschlecht  Geburtsjahr  PLZ  ...  \
# Gruppenname                                                      ...
# ABG                             0           9            9    9  ...
# AfD                             0          35           35   35  ...
# BIG                             0          23           23   23  ...
# BSW                             0          20           20   20  ...
# BÜNDNIS DEUTSCHLAND             0          11           11   11  ...
# Bündnis C                       0          13           13   13  ...
# DAVA                            0          13           13   13  ...
# DKP                             0          43           43   43  ...
# Die Linke                       0          20           20   20  ...
# Die PARTEI                      0         211          211  211  ...
# FAMILIE                         0          11           11   11  ...
# FDP                             0         194          194  194  ...
# FREIE WÄHLER                    0          27           27   27  ...
# Grüne                           0          40           40   40  ...
# HEIMAT                          0          15           15   15  ...
# KLIMALISTE                      0          14           14   14  ...
# LETZTE GENERATION               0          12           12   12  ...
# MENSCHLICHE WELT                0           9            9    9  ...
# MERA25                          0          14           14   14  ...
# MLPD                            0          18           18   18  ...
# PDV                             0          13           13   13  ...
# PIRATEN                         0          18           18   18  ...
# PdF                             0          10           10   10  ...
# PdH                             0          21           21   21  ...
# SGP                             0          11           11   11  ...
# SPD                             0         189          189  189  ...
# TIERSCHUTZ hier!                0           7            7    7  ...
# Tierschutzpartei                0           8            8    8  ...
# Union                           0         259          259  259  ...
# V-Partei³                       0          19           19   19  ...
# Volt                            0          27           27   27  ...
# dieBasis                        0           4            4    4  ...
# nan                             0          19           19   19  ...
# ÖDP                             0          87           87   87  ...
#
#                      VerknKennzeichen  VerknGebietsart  VerknGebietsnummer  \
# Gruppenname
# ABG                                 0                0                   0
# AfD                                 0                0                   0
# BIG                                 0                0                   0
# BSW                                 0                0                   0
# BÜNDNIS DEUTSCHLAND                 0                0                   0
# Bündnis C                           0                0                   0
# DAVA                                0                0                   0
# DKP                                 0                0                   0
# Die Linke                           0                0                   0
# Die PARTEI                          0                0                   0
# FAMILIE                             0                0                   0
# FDP                                 0                0                   0
# FREIE WÄHLER                        0                0                   0
# Grüne                               0                0                   0
# HEIMAT                              0                0                   0
# KLIMALISTE                          0                0                   0
# LETZTE GENERATION                   0                0                   0
# MENSCHLICHE WELT                    0                0                   0
# MERA25                              0                0                   0
# MLPD                                0                0                   0
# PDV                                 0                0                   0
# PIRATEN                             0                0                   0
# PdF                                 0                0                   0
# PdH                                 0                0                   0
# SGP                                 0                0                   0
# SPD                                62               62                  62
# TIERSCHUTZ hier!                    0                0                   0
# Tierschutzpartei                    0                0                   0
# Union                               0                0                   0
# V-Partei³                           0                0                   0
# Volt                                0                0                   0
# dieBasis                            0                0                   0
# nan                                 0                0                   0
# ÖDP                                 0                0                   0
#
#                      VerknGebietsname  VerknGebietLandAbk  VerknGruppenname  \
# Gruppenname
# ABG                                 0                   0                 0
# AfD                                 0                   0                 0
# BIG                                 0                   0                 0
# BSW                                 0                   0                 0
# BÜNDNIS DEUTSCHLAND                 0                   0                 0
# Bündnis C                           0                   0                 0
# DAVA                                0                   0                 0
# DKP                                 0                   0                 0
# Die Linke                           0                   0                 0
# Die PARTEI                          0                   0                 0
# FAMILIE                             0                   0                 0
# FDP                                 0                   0                 0
# FREIE WÄHLER                        0                   0                 0
# Grüne                               0                   0                 0
# HEIMAT                              0                   0                 0
# KLIMALISTE                          0                   0                 0
# LETZTE GENERATION                   0                   0                 0
# MENSCHLICHE WELT                    0                   0                 0
# MERA25                              0                   0                 0
# MLPD                                0                   0                 0
# PDV                                 0                   0                 0
# PIRATEN                             0                   0                 0
# PdF                                 0                   0                 0
# PdH                                 0                   0                 0
# SGP                                 0                   0                 0
# SPD                                62                  62                62
# TIERSCHUTZ hier!                    0                   0                 0
# Tierschutzpartei                    0                   0                 0
# Union                               0                   0                 0
# V-Partei³                           0                   0                 0
# Volt                                0                   0                 0
# dieBasis                            0                   0                 0
# nan                                 0                   0                 0
# ÖDP                                 0                   0                 0
#
#                      VerknListenplatz  VorpGewaehlt  Berufsbezeichnung  Alter
# Gruppenname
# ABG                                 0             0                  9      9
# AfD                                 0             4                 35     35
# BIG                                 0             0                 23     23
# BSW                                 0             0                 20     20
# BÜNDNIS DEUTSCHLAND                 0             1                 11     11
# Bündnis C                           0             0                 13     13
# DAVA                                0             0                 13     13
# DKP                                 0             0                 43     43
# Die Linke                           0             2                 20     20
# Die PARTEI                          0             1                211    211
# FAMILIE                             0             1                 11     11
# FDP                                 0             4                194    194
# FREIE WÄHLER                        0             1                 27     27
# Grüne                               0            15                 40     40
# HEIMAT                              0             0                 15     15
# KLIMALISTE                          0             0                 14     14
# LETZTE GENERATION                   0             0                 12     12
# MENSCHLICHE WELT                    0             0                  9      9
# MERA25                              0             0                 14     14
# MLPD                                0             0                 18     18
# PDV                                 0             0                 13     13
# PIRATEN                             0             0                 18     18
# PdF                                 0             0                 10     10
# PdH                                 0             0                 21     21
# SGP                                 0             0                 11     11
# SPD                                62            13                189    189
# TIERSCHUTZ hier!                    0             0                  7      7
# Tierschutzpartei                    0             0                  8      8
# Union                               0            25                259    259
# V-Partei³                           0             0                 19     19
# Volt                                0             1                 27     27
# dieBasis                            0             0                  4      4
# nan                                 0             0                 19     19
# ÖDP                                 0             1                 87     87
#
# [34 rows x 34 columns]

# %% [markdown]
# Then we count the occurence of each job sector for each party

# %%
data_bund_jobs=data_bund[["Nachname","Berufsbezeichnung","Gruppenname"]].groupby(["Gruppenname","Berufsbezeichnung"]).count().reset_index()
data_bund_jobs=data_bund_jobs.rename(columns={"Nachname":"count"})
data_bund_jobs
# Out:
#      Gruppenname                                  Berufsbezeichnung  count
# 0    #KLIMAfirst          Gesundheit, Soziales, Lehre und Erziehung      1
# 1    #TeamFranka        Rohstoffgewinnung, Produktion und Fertigung      1
# 2            AfD    Bau, Architektur, Vermessung und Gebäudetechnik      8
# 3            AfD          Gesundheit, Soziales, Lehre und Erziehung     45
# 4            AfD  Kaufmännische Dienstleistungen, Warenhandel, V...     22
# ..           ...                                                ...    ...
# 580          ÖDP                  Schüler, Auszubildende, Studenten     38
# 581          ÖDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...     19
# 582          ÖDP  Unternehmensorganisation, Buchhaltung, Recht u...     38
# 583          ÖDP           Verkehr, Logistik, Schutz und Sicherheit      9
# 584         ÖLDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...      1
#
# [585 rows x 3 columns]

# %% [markdown]
# But as the number of candidates differ between the elections, we will only compare the percentage wise share. We do this using grpupby and transform.

# %%
data_bund_jobs["share"]=data_bund_jobs["count"]*100/data_bund_jobs.groupby("Gruppenname")["count"].transform('sum')
data_bund_jobs
# Out:
#      Gruppenname                                  Berufsbezeichnung  count  \
# 0    #KLIMAfirst          Gesundheit, Soziales, Lehre und Erziehung      1
# 1    #TeamFranka        Rohstoffgewinnung, Produktion und Fertigung      1
# 2            AfD    Bau, Architektur, Vermessung und Gebäudetechnik      8
# 3            AfD          Gesundheit, Soziales, Lehre und Erziehung     45
# 4            AfD  Kaufmännische Dienstleistungen, Warenhandel, V...     22
# ..           ...                                                ...    ...
# 580          ÖDP                  Schüler, Auszubildende, Studenten     38
# 581          ÖDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...     19
# 582          ÖDP  Unternehmensorganisation, Buchhaltung, Recht u...     38
# 583          ÖDP           Verkehr, Logistik, Schutz und Sicherheit      9
# 584         ÖLDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...      1
#
#           share
# 0    100.000000
# 1    100.000000
# 2      1.713062
# 3      9.635974
# 4      4.710921
# ..          ...
# 580   11.242604
# 581    5.621302
# 582   11.242604
# 583    2.662722
# 584  100.000000
#
# [585 rows x 4 columns]

# %%
data_europa_jobs=data_europa[["Name","Berufsbezeichnung","Gruppenname"]].groupby(["Gruppenname","Berufsbezeichnung"]).count().reset_index()
data_europa_jobs=data_europa_jobs.rename(columns={"Name":"count"})
data_europa_jobs
# Out:
#     Gruppenname                                  Berufsbezeichnung  count
# 0           ABG          Gesundheit, Soziales, Lehre und Erziehung      2
# 1           ABG  Kaufmännische Dienstleistungen, Warenhandel, V...      1
# 2           ABG                                Rentner, Pensionäre      1
# 3           ABG  Unternehmensorganisation, Buchhaltung, Recht u...      5
# 4           AfD          Gesundheit, Soziales, Lehre und Erziehung      3
# ..          ...                                                ...    ...
# 242         ÖDP        Rohstoffgewinnung, Produktion und Fertigung      8
# 243         ÖDP                  Schüler, Auszubildende, Studenten      4
# 244         ÖDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...      4
# 245         ÖDP  Unternehmensorganisation, Buchhaltung, Recht u...     15
# 246         ÖDP           Verkehr, Logistik, Schutz und Sicherheit      5
#
# [247 rows x 3 columns]

# %%
data_europa_jobs["share"]=data_europa_jobs["count"]*100/data_europa_jobs.groupby("Gruppenname")["count"].transform('sum')
data_europa_jobs
# Out:
#     Gruppenname                                  Berufsbezeichnung  count  \
# 0           ABG          Gesundheit, Soziales, Lehre und Erziehung      2
# 1           ABG  Kaufmännische Dienstleistungen, Warenhandel, V...      1
# 2           ABG                                Rentner, Pensionäre      1
# 3           ABG  Unternehmensorganisation, Buchhaltung, Recht u...      5
# 4           AfD          Gesundheit, Soziales, Lehre und Erziehung      3
# ..          ...                                                ...    ...
# 242         ÖDP        Rohstoffgewinnung, Produktion und Fertigung      8
# 243         ÖDP                  Schüler, Auszubildende, Studenten      4
# 244         ÖDP  Sprach-, Literatur-, Geistes-, Gesellschafts- ...      4
# 245         ÖDP  Unternehmensorganisation, Buchhaltung, Recht u...     15
# 246         ÖDP           Verkehr, Logistik, Schutz und Sicherheit      5
#
#          share
# 0    22.222222
# 1    11.111111
# 2    11.111111
# 3    55.555556
# 4     8.571429
# ..         ...
# 242   9.195402
# 243   4.597701
# 244   4.597701
# 245  17.241379
# 246   5.747126
#
# [247 rows x 4 columns]

# %%
data_europa_bund_jobs=pd.merge(data_bund_jobs,data_europa_jobs, on=["Gruppenname","Berufsbezeichnung"],suffixes=["_bund","_europa"], how="outer")
data_europa_bund_jobs=data_europa_bund_jobs.fillna(0)

# %% [markdown]
# Then we only filter for the parties that are currently in the Bundestag

# %%
filterlist=['AfD','Union', 'Die Linke', 'FDP',
       'Grüne', 'SPD']

# %%
bundes_parteien_filtered=data_europa_bund_jobs[data_europa_bund_jobs["Gruppenname"].str.contains('|'.join(filterlist))]
bundes_parteien_filtered_share=bundes_parteien_filtered[["Gruppenname","Berufsbezeichnung","share_bund","share_europa"]]
bundes_parteien_filtered_share
# Out:
#     Gruppenname                                  Berufsbezeichnung  \
# 6           AfD    Bau, Architektur, Vermessung und Gebäudetechnik
# 7           AfD          Gesundheit, Soziales, Lehre und Erziehung
# 8           AfD  Kaufmännische Dienstleistungen, Warenhandel, V...
# 9           AfD     Land-, Forst- und Tierwirtschaft und Gartenbau
# 10          AfD                                            Militär
# ..          ...                                                ...
# 601       Union        Rohstoffgewinnung, Produktion und Fertigung
# 602       Union                  Schüler, Auszubildende, Studenten
# 603       Union  Sprach-, Literatur-, Geistes-, Gesellschafts- ...
# 604       Union  Unternehmensorganisation, Buchhaltung, Recht u...
# 605       Union           Verkehr, Logistik, Schutz und Sicherheit
#
#      share_bund  share_europa
# 6      1.713062      0.000000
# 7      9.635974      8.571429
# 8      4.710921     14.285714
# 9      1.284797      0.000000
# 10     0.642398      0.000000
# ..          ...           ...
# 601    3.947368      4.247104
# 602    2.990431      7.335907
# 603    5.861244      7.335907
# 604   66.985646     51.737452
# 605    1.794258      0.772201
#
# [82 rows x 4 columns]

# %% [markdown]
# And write this as a long form to a csv

# %%
bundes_parteien_filtered_share.to_csv("jobs_longform.csv",index=False)

# %% [markdown]
# We also rewrite the names of the job sectors into shorter forms

# %%
pivot_df_bund=bundes_parteien_filtered.pivot(index='Gruppenname', columns='Berufsbezeichnung')["share_bund"].reset_index().fillna(0)
pivot_df_europa=bundes_parteien_filtered.pivot(index='Gruppenname', columns='Berufsbezeichnung')["share_europa"].reset_index().fillna(0)
alt_columns=['Partei', 'Baubranche',
       'Gesundheit und Soziales',
       'Hausfrauen und Arbeitssuchende',
       'Kaufmännisch',
       'Landwirtschaft', 'Militär',
       'Naturwissenschaften',
       'Ohne Angabe',
       'Rentner', 'Rohstoffe und Produktion',
       'Azubis und Studenten',
       'Geisteswissenschaften und Wirtschaft',
       'Recht und Verwaltung',
       'Verkehr und Logistik']
pivot_df_europa.columns=alt_columns
pivot_df_bund.columns=alt_columns

pivot_df_bund_T=pivot_df_bund.T
pivot_df_europa_T=pivot_df_europa.T
pivot_df_europa_T.columns=pivot_df_europa_T.iloc[0].tolist()
pivot_df_bund_T.columns=pivot_df_bund_T.iloc[0].tolist()
pivot_df_bund_T=pivot_df_bund_T.iloc[1:]
pivot_df_europa_T=pivot_df_europa_T.iloc[1:]
pivot_df_europa_T
# Out:
#                                             AfD Die Linke        FDP Grüne  \
# Baubranche                                  0.0       0.0   1.030928   0.0
# Gesundheit und Soziales                8.571429      20.0  10.824742  15.0
# Hausfrauen und Arbeitssuchende              0.0       0.0   0.515464   2.5
# Kaufmännisch                          14.285714       5.0   4.123711   0.0
# Landwirtschaft                              0.0       0.0   1.030928   5.0
# Militär                                     0.0       0.0   2.061856   2.5
# Naturwissenschaften                         0.0       5.0   7.731959   0.0
# Ohne Angabe                            2.857143       0.0   1.546392   0.0
# Rentner                                     0.0       5.0   1.546392   0.0
# Rohstoffe und Produktion               8.571429       5.0   4.123711   7.5
# Azubis und Studenten                        0.0      15.0  22.164948  10.0
# Geisteswissenschaften und Wirtschaft  11.428571       5.0   7.216495  17.5
# Recht und Verwaltung                  54.285714      40.0   35.56701  37.5
# Verkehr und Logistik                        0.0       0.0   0.515464   2.5
#
#                                             SPD      Union
# Baubranche                                  0.0   0.772201
# Gesundheit und Soziales                19.57672  16.988417
# Hausfrauen und Arbeitssuchende              0.0     0.3861
# Kaufmännisch                           2.645503   1.930502
# Landwirtschaft                         1.587302   2.702703
# Militär                                0.529101   1.544402
# Naturwissenschaften                    2.645503   1.930502
# Ohne Angabe                            1.058201     0.3861
# Rentner                                1.587302   1.930502
# Rohstoffe und Produktion               4.232804   4.247104
# Azubis und Studenten                   8.994709   7.335907
# Geisteswissenschaften und Wirtschaft   6.878307   7.335907
# Recht und Verwaltung                  49.206349  51.737452
# Verkehr und Logistik                   1.058201   0.772201

# %%
pivot_df_bund_T
# Out:
#                                             AfD  Die Linke        FDP  \
# Baubranche                             1.713062   2.061856   1.866252
# Gesundheit und Soziales                9.635974  18.556701   9.486781
# Hausfrauen und Arbeitssuchende              0.0   0.206186   0.155521
# Kaufmännisch                           4.710921   4.123711   5.443235
# Landwirtschaft                         1.284797   0.206186   2.177294
# Militär                                0.642398        0.0   1.244168
# Naturwissenschaften                    4.282655    3.71134    4.66563
# Ohne Angabe                            1.284797   0.824742   1.399689
# Rentner                                4.710921   3.505155   0.155521
# Rohstoffe und Produktion               9.635974    5.56701   5.754277
# Azubis und Studenten                   0.856531  12.989691   9.175739
# Geisteswissenschaften und Wirtschaft    6.20985  12.164948   7.931571
# Recht und Verwaltung                  52.034261   34.43299  48.833593
# Verkehr und Logistik                   2.997859   1.649485   1.710731
#
#                                           Grüne        SPD      Union
# Baubranche                             2.002861   0.821918   0.598086
# Gesundheit und Soziales                17.88269  15.479452   9.449761
# Hausfrauen und Arbeitssuchende         0.143062   0.273973        0.0
# Kaufmännisch                             1.8598   3.287671   3.229665
# Landwirtschaft                         3.147353        0.0   0.837321
# Militär                                     0.0   0.821918   0.119617
# Naturwissenschaften                    5.150215    3.69863   1.913876
# Ohne Angabe                            0.858369   0.136986   0.717703
# Rentner                                0.572246    1.09589   1.555024
# Rohstoffe und Produktion               5.865522   2.191781   3.947368
# Azubis und Studenten                  11.874106   3.972603   2.990431
# Geisteswissenschaften und Wirtschaft  11.587983  10.410959   5.861244
# Recht und Verwaltung                  38.054363   56.30137  66.985646
# Verkehr und Logistik                   1.001431   1.506849   1.794258

# %% [markdown]
# And then we calculate a diff dataframe that shows which sectors are more or less represented this time around

# %%
diff_eu_bund=pivot_df_europa_T-pivot_df_bund_T

diff_eu_bund["mean_union_afd"]=diff_eu_bund[["Union","AfD"]].mean(axis=1)
diff_eu_bund["mean_spd_gruene"]=diff_eu_bund[["Grüne","SPD"]].mean(axis=1)
diff_eu_bund["mean_fdp_linke"]=diff_eu_bund[["FDP","Die Linke"]].mean(axis=1)
diff_eu_bund
# Out:
#                                            AfD Die Linke        FDP     Grüne  \
# Baubranche                           -1.713062 -2.061856  -0.835324 -2.002861
# Gesundheit und Soziales              -1.064546  1.443299   1.337962  -2.88269
# Hausfrauen und Arbeitssuchende             0.0 -0.206186   0.359943  2.356938
# Kaufmännisch                          9.574794  0.876289  -1.319523   -1.8598
# Landwirtschaft                       -1.284797 -0.206186  -1.146366  1.852647
# Militär                              -0.642398       0.0   0.817688       2.5
# Naturwissenschaften                  -4.282655   1.28866   3.066329 -5.150215
# Ohne Angabe                           1.572346 -0.824742   0.146703 -0.858369
# Rentner                              -4.710921  1.494845   1.390871 -0.572246
# Rohstoffe und Produktion             -1.064546  -0.56701  -1.630565  1.634478
# Azubis und Studenten                 -0.856531  2.010309   12.98921 -1.874106
# Geisteswissenschaften und Wirtschaft  5.218721 -7.164948  -0.715076  5.912017
# Recht und Verwaltung                  2.251453   5.56701 -13.266582 -0.554363
# Verkehr und Logistik                 -2.997859 -1.649485  -1.195267  1.498569
#
#                                            SPD      Union mean_union_afd  \
# Baubranche                           -0.821918   0.174115      -0.769474
# Gesundheit und Soziales               4.097268   7.538656       3.237055
# Hausfrauen und Arbeitssuchende       -0.273973     0.3861        0.19305
# Kaufmännisch                         -0.642169  -1.299163       4.137815
# Landwirtschaft                        1.587302   1.865382       0.290293
# Militär                              -0.292817   1.424784       0.391193
# Naturwissenschaften                  -1.053127   0.016626      -2.133014
# Ohne Angabe                           0.921215  -0.331603       0.620372
# Rentner                               0.491411   0.375478      -2.167721
# Rohstoffe und Produktion              2.041023   0.299736      -0.382405
# Azubis und Studenten                  5.022106   4.345477       1.744473
# Geisteswissenschaften und Wirtschaft -3.532652   1.474663       3.346692
# Recht und Verwaltung                 -7.095021 -15.248194      -6.498371
# Verkehr und Logistik                 -0.448648  -1.022058      -2.009958
#
#                                      mean_spd_gruene mean_fdp_linke
# Baubranche                                  -1.41239       -1.44859
# Gesundheit und Soziales                     0.607289        1.39063
# Hausfrauen und Arbeitssuchende              1.041483       0.076879
# Kaufmännisch                               -1.250984      -0.221617
# Landwirtschaft                              1.719974      -0.676276
# Militär                                     1.103591       0.408844
# Naturwissenschaften                        -3.101671       2.177494
# Ohne Angabe                                 0.031423       -0.33902
# Rentner                                    -0.040417       1.442858
# Rohstoffe und Produktion                    1.837751      -1.098788
# Azubis und Studenten                           1.574        7.49976
# Geisteswissenschaften und Wirtschaft        1.189683      -3.940012
# Recht und Verwaltung                       -3.824692      -3.849786
# Verkehr und Logistik                        0.524961      -1.422376

# %%
diff_eu_bund[["Union","AfD","mean_union_afd"]].to_csv("diff_eu_bund_1.csv")
diff_eu_bund[["SPD","Grüne","mean_spd_gruene"]].to_csv("diff_eu_bund_2.csv")
diff_eu_bund[["FDP","Die Linke","mean_fdp_linke"]].to_csv("diff_eu_bund_3.csv")

# %%
pivot_df_europa_T_first_half=pivot_df_europa_T[["Union","SPD","AfD"]].reset_index()
pivot_df_bund_T_first_half=pivot_df_bund_T[["Union","SPD","AfD"]].reset_index()
pivot_df_europa_T_first_half=pivot_df_europa_T_first_half.rename(columns={"index":"Branche"})
pivot_df_bund_T_first_half=pivot_df_bund_T_first_half.rename(columns={"index":"Branche"})
europa_bund_comp=pd.merge(pivot_df_bund_T_first_half,pivot_df_europa_T_first_half,on="Branche",suffixes=[" Bund"," Europa"])
europa_bund_comp.to_csv("bund_europa_comparison.csv",index=False)
europa_bund_comp
# Out:
#                                  Branche Union Bund   SPD Bund   AfD Bund  \
# 0                             Baubranche   0.598086   0.821918   1.713062
# 1                Gesundheit und Soziales   9.449761  15.479452   9.635974
# 2         Hausfrauen und Arbeitssuchende        0.0   0.273973        0.0
# 3                           Kaufmännisch   3.229665   3.287671   4.710921
# 4                         Landwirtschaft   0.837321        0.0   1.284797
# 5                                Militär   0.119617   0.821918   0.642398
# 6                    Naturwissenschaften   1.913876    3.69863   4.282655
# 7                            Ohne Angabe   0.717703   0.136986   1.284797
# 8                                Rentner   1.555024    1.09589   4.710921
# 9               Rohstoffe und Produktion   3.947368   2.191781   9.635974
# 10                  Azubis und Studenten   2.990431   3.972603   0.856531
# 11  Geisteswissenschaften und Wirtschaft   5.861244  10.410959    6.20985
# 12                  Recht und Verwaltung  66.985646   56.30137  52.034261
# 13                  Verkehr und Logistik   1.794258   1.506849   2.997859
#
#    Union Europa SPD Europa AfD Europa
# 0      0.772201        0.0        0.0
# 1     16.988417   19.57672   8.571429
# 2        0.3861        0.0        0.0
# 3      1.930502   2.645503  14.285714
# 4      2.702703   1.587302        0.0
# 5      1.544402   0.529101        0.0
# 6      1.930502   2.645503        0.0
# 7        0.3861   1.058201   2.857143
# 8      1.930502   1.587302        0.0
# 9      4.247104   4.232804   8.571429
# 10     7.335907   8.994709        0.0
# 11     7.335907   6.878307  11.428571
# 12    51.737452  49.206349  54.285714
# 13     0.772201   1.058201        0.0

# %%
pivot_df_europa_T_second_half=pivot_df_europa_T[["Grüne","FDP","Die Linke"]].reset_index()
pivot_df_bund_T_second_half=pivot_df_bund_T[["Grüne","FDP","Die Linke"]].reset_index()
pivot_df_europa_T_second_half=pivot_df_europa_T_second_half.rename(columns={"index":"Branche"})
pivot_df_bund_T_second_half=pivot_df_bund_T_second_half.rename(columns={"index":"Branche"})
europa_bund_comp_2=pd.merge(pivot_df_bund_T_second_half,pivot_df_europa_T_second_half,on="Branche",suffixes=[" Bund"," Europa"])
europa_bund_comp_2
# Out:
#                                  Branche Grüne Bund   FDP Bund Die Linke Bund  \
# 0                             Baubranche   2.002861   1.866252       2.061856
# 1                Gesundheit und Soziales   17.88269   9.486781      18.556701
# 2         Hausfrauen und Arbeitssuchende   0.143062   0.155521       0.206186
# 3                           Kaufmännisch     1.8598   5.443235       4.123711
# 4                         Landwirtschaft   3.147353   2.177294       0.206186
# 5                                Militär        0.0   1.244168            0.0
# 6                    Naturwissenschaften   5.150215    4.66563        3.71134
# 7                            Ohne Angabe   0.858369   1.399689       0.824742
# 8                                Rentner   0.572246   0.155521       3.505155
# 9               Rohstoffe und Produktion   5.865522   5.754277        5.56701
# 10                  Azubis und Studenten  11.874106   9.175739      12.989691
# 11  Geisteswissenschaften und Wirtschaft  11.587983   7.931571      12.164948
# 12                  Recht und Verwaltung  38.054363  48.833593       34.43299
# 13                  Verkehr und Logistik   1.001431   1.710731       1.649485
#
#    Grüne Europa FDP Europa Die Linke Europa
# 0           0.0   1.030928              0.0
# 1          15.0  10.824742             20.0
# 2           2.5   0.515464              0.0
# 3           0.0   4.123711              5.0
# 4           5.0   1.030928              0.0
# 5           2.5   2.061856              0.0
# 6           0.0   7.731959              5.0
# 7           0.0   1.546392              0.0
# 8           0.0   1.546392              5.0
# 9           7.5   4.123711              5.0
# 10         10.0  22.164948             15.0
# 11         17.5   7.216495              5.0
# 12         37.5   35.56701             40.0
# 13          2.5   0.515464              0.0

# %% [markdown]
# Next up, we want to calculate the age of the candidates and compare the age of canditates between both elections

# %%
data_europa["Alter"]=data_europa["Wahltag"].astype(str).str[-4:].astype(int)-data_europa["Geburtsjahr"]
data_bund["Alter"]=data_bund["Wahltag"].astype(str).str[-4:].astype(int)-data_bund["Geburtsjahr"]
data_bund
# Out:
#      Wahlart     Wahltag Titel Namenszusatz          Nachname  \
# 0         BT  26.09.2021   NaN          NaN        Nicolaisen
# 1         BT  26.09.2021   NaN          NaN         Brzezicha
# 2         BT  26.09.2021   NaN          NaN      Anastasiadis
# 3         BT  26.09.2021   NaN          NaN            Habeck
# 4         BT  26.09.2021   NaN          NaN  Petersen-Brendel
# ...      ...         ...   ...          ...               ...
# 8282      BT  26.09.2021   NaN          NaN           Beutler
# 8283      BT  26.09.2021   NaN          NaN         Trautmann
# 8284      BT  26.09.2021   NaN          NaN              Volz
# 8285      BT  26.09.2021   NaN          NaN            Arlaud
# 8286      BT  26.09.2021   NaN          NaN             Gödel
#
#                 Vornamen Künstlername Geschlecht  Geburtsjahr    PLZ  ...  \
# 0                  Petra          NaN          w         1965  24997  ...
# 1        Franziska Maria          NaN          w         1993  24896  ...
# 2     Christoph Georgios          NaN          m         1995  24943  ...
# 3                 Robert          NaN          m         1969  24939  ...
# 4                    Jan          NaN          m         1968  24997  ...
# ...                  ...          ...        ...          ...    ...  ...
# 8282               Benno          NaN          m         1967  99610  ...
# 8283              Sophie          NaN          w         1998   7743  ...
# 8284          Maximilian          NaN          m         1996  99423  ...
# 8285         Leah Esther          NaN          w         1997  99086  ...
# 8286             Michael          NaN          m         1996   7743  ...
#
#      VerknKennzeichen  VerknGebietsart VerknGebietsnummer    VerknGebietsname  \
# 0         Landesliste             Land                1.0  Schleswig-Holstein
# 1         Landesliste             Land                1.0  Schleswig-Holstein
# 2         Landesliste             Land                1.0  Schleswig-Holstein
# 3         Landesliste             Land                1.0  Schleswig-Holstein
# 4                 NaN              NaN                NaN                 NaN
# ...               ...              ...                ...                 ...
# 8282              NaN              NaN                NaN                 NaN
# 8283              NaN              NaN                NaN                 NaN
# 8284              NaN              NaN                NaN                 NaN
# 8285              NaN              NaN                NaN                 NaN
# 8286              NaN              NaN                NaN                 NaN
#
#      VerknGebietLandAbk VerknGruppenname  VerknListenplatz VorpGewaehlt  \
# 0                    SH              CDU               4.0            X
# 1                    SH              SPD               6.0          NaN
# 2                    SH              FDP               6.0          NaN
# 3                    SH            GRÜNE               2.0          NaN
# 4                   NaN              NaN               NaN          NaN
# ...                 ...              ...               ...          ...
# 8282                NaN              NaN               NaN          NaN
# 8283                NaN              NaN               NaN          NaN
# 8284                NaN              NaN               NaN          NaN
# 8285                NaN              NaN               NaN          NaN
# 8286                NaN              NaN               NaN          NaN
#
#                                       Berufsbezeichnung  Alter
# 0     Unternehmensorganisation, Buchhaltung, Recht u...     56
# 1             Gesundheit, Soziales, Lehre und Erziehung     28
# 2     Kaufmännische Dienstleistungen, Warenhandel, V...     26
# 3     Unternehmensorganisation, Buchhaltung, Recht u...     52
# 4           Rohstoffgewinnung, Produktion und Fertigung     53
# ...                                                 ...    ...
# 8282  Kaufmännische Dienstleistungen, Warenhandel, V...     54
# 8283                  Schüler, Auszubildende, Studenten     23
# 8284                  Schüler, Auszubildende, Studenten     25
# 8285                  Schüler, Auszubildende, Studenten     24
# 8286          Gesundheit, Soziales, Lehre und Erziehung     25
#
# [8287 rows x 35 columns]

# %% [markdown]
# Then we group by party and calculate the mean age of candidates per party

# %%
EU_born_years=data_europa[["Alter","Gruppenname"]].groupby("Gruppenname").mean().reset_index()
EU_born_years
# Out:
#             Gruppenname      Alter
# 0                   ABG  54.888889
# 1                   AfD  48.657143
# 2                   BIG  46.782609
# 3                   BSW  55.650000
# 4   BÜNDNIS DEUTSCHLAND  51.909091
# 5             Bündnis C  61.769231
# 6                  DAVA  47.307692
# 7                   DKP  51.790698
# 8             Die Linke  42.850000
# 9            Die PARTEI  41.815166
# 10              FAMILIE  46.272727
# 11                  FDP  39.876289
# 12         FREIE WÄHLER  47.888889
# 13                Grüne  39.350000
# 14               HEIMAT  54.600000
# 15           KLIMALISTE  47.071429
# 16    LETZTE GENERATION  41.250000
# 17     MENSCHLICHE WELT  50.000000
# 18               MERA25  38.785714
# 19                 MLPD  49.722222
# 20                  PDV  50.615385
# 21              PIRATEN  44.000000
# 22                  PdF  32.800000
# 23                  PdH  28.761905
# 24                  SGP  48.090909
# 25                  SPD  39.010582
# 26     TIERSCHUTZ hier!  46.285714
# 27     Tierschutzpartei  46.500000
# 28                Union  42.606178
# 29            V-Partei³  38.052632
# 30                 Volt  35.629630
# 31             dieBasis  61.000000
# 32                  nan  42.894737
# 33                  ÖDP  53.390805

# %%
Bund_born_years=data_bund[["Alter","Gruppenname"]].groupby("Gruppenname").mean().reset_index()
Bund_born_years
# Out:
#      Gruppenname      Alter
# 0    #KLIMAfirst  61.000000
# 1    #TeamFranka  40.000000
# 2            AfD  51.306210
# 3             B*  39.000000
# 4             BP  48.868852
# ..           ...        ...
# 231     dieBasis  52.662500
# 232          du.  37.270270
# 233     sonstige  51.000000
# 234          ÖDP  47.360947
# 235         ÖLDP  41.000000
#
# [236 rows x 2 columns]

# %% [markdown]
# And we merge the average ages from both elections

# %%
age_comp=pd.merge(Bund_born_years,EU_born_years,on="Gruppenname",suffixes=["_Bund","_EU"])
main_parties_age_comp=age_comp[age_comp.Gruppenname.str.contains(('|'.join(filterlist)))]
main_parties_age_comp.to_csv("mainparties_age.csv",index=False)

# %% [markdown]
# *And we see that for most bigger parties actually the average candidates were younger for the EU election*

# %% [markdown]
# Next up, we want to check, if age is younger BUT whether older candidates got better places on the list in general and especially at the European level

# %%
data_bund["Listenplatz_gemeinsam"]=data_bund["Listenplatz"]
data_bund["Listenplatz_gemeinsam"]=np.where(data_bund["Listenplatz"].isna(),data_bund["VerknListenplatz"],data_bund["Listenplatz"])

# %%
data_bund
# Out:
#      Wahlart     Wahltag Titel Namenszusatz          Nachname  \
# 0         BT  26.09.2021   NaN          NaN        Nicolaisen
# 1         BT  26.09.2021   NaN          NaN         Brzezicha
# 2         BT  26.09.2021   NaN          NaN      Anastasiadis
# 3         BT  26.09.2021   NaN          NaN            Habeck
# 4         BT  26.09.2021   NaN          NaN  Petersen-Brendel
# ...      ...         ...   ...          ...               ...
# 8282      BT  26.09.2021   NaN          NaN           Beutler
# 8283      BT  26.09.2021   NaN          NaN         Trautmann
# 8284      BT  26.09.2021   NaN          NaN              Volz
# 8285      BT  26.09.2021   NaN          NaN            Arlaud
# 8286      BT  26.09.2021   NaN          NaN             Gödel
#
#                 Vornamen Künstlername Geschlecht  Geburtsjahr    PLZ  ...  \
# 0                  Petra          NaN          w         1965  24997  ...
# 1        Franziska Maria          NaN          w         1993  24896  ...
# 2     Christoph Georgios          NaN          m         1995  24943  ...
# 3                 Robert          NaN          m         1969  24939  ...
# 4                    Jan          NaN          m         1968  24997  ...
# ...                  ...          ...        ...          ...    ...  ...
# 8282               Benno          NaN          m         1967  99610  ...
# 8283              Sophie          NaN          w         1998   7743  ...
# 8284          Maximilian          NaN          m         1996  99423  ...
# 8285         Leah Esther          NaN          w         1997  99086  ...
# 8286             Michael          NaN          m         1996   7743  ...
#
#      VerknGebietsart  VerknGebietsnummer    VerknGebietsname  \
# 0               Land                 1.0  Schleswig-Holstein
# 1               Land                 1.0  Schleswig-Holstein
# 2               Land                 1.0  Schleswig-Holstein
# 3               Land                 1.0  Schleswig-Holstein
# 4                NaN                 NaN                 NaN
# ...              ...                 ...                 ...
# 8282             NaN                 NaN                 NaN
# 8283             NaN                 NaN                 NaN
# 8284             NaN                 NaN                 NaN
# 8285             NaN                 NaN                 NaN
# 8286             NaN                 NaN                 NaN
#
#      VerknGebietLandAbk VerknGruppenname VerknListenplatz  VorpGewaehlt  \
# 0                    SH              CDU              4.0             X
# 1                    SH              SPD              6.0           NaN
# 2                    SH              FDP              6.0           NaN
# 3                    SH            GRÜNE              2.0           NaN
# 4                   NaN              NaN              NaN           NaN
# ...                 ...              ...              ...           ...
# 8282                NaN              NaN              NaN           NaN
# 8283                NaN              NaN              NaN           NaN
# 8284                NaN              NaN              NaN           NaN
# 8285                NaN              NaN              NaN           NaN
# 8286                NaN              NaN              NaN           NaN
#
#                                       Berufsbezeichnung Alter  \
# 0     Unternehmensorganisation, Buchhaltung, Recht u...    56
# 1             Gesundheit, Soziales, Lehre und Erziehung    28
# 2     Kaufmännische Dienstleistungen, Warenhandel, V...    26
# 3     Unternehmensorganisation, Buchhaltung, Recht u...    52
# 4           Rohstoffgewinnung, Produktion und Fertigung    53
# ...                                                 ...   ...
# 8282  Kaufmännische Dienstleistungen, Warenhandel, V...    54
# 8283                  Schüler, Auszubildende, Studenten    23
# 8284                  Schüler, Auszubildende, Studenten    25
# 8285                  Schüler, Auszubildende, Studenten    24
# 8286          Gesundheit, Soziales, Lehre und Erziehung    25
#
#       Listenplatz_gemeinsam
# 0                       4.0
# 1                       6.0
# 2                       6.0
# 3                       2.0
# 4                       NaN
# ...                     ...
# 8282                    6.0
# 8283                    1.0
# 8284                    2.0
# 8285                    3.0
# 8286                    4.0
#
# [8287 rows x 36 columns]

# %%
#we only take in the columns for party, list spot and age
GruppePlatzAlter_EU=data_europa[["Gruppenname","Listenplatz","Alter"]]
listofparties=GruppePlatzAlter_EU.Gruppenname.unique()
print(listofparties)
coeff_eu={}
#and we iterate through the name of parties
for party in listofparties:
    #filter for the party
    partydf=GruppePlatzAlter_EU[GruppePlatzAlter_EU["Gruppenname"]==party]
    #calculate the correlation using spearman-rank coefficient to exclude non-normality
    result=partydf[["Listenplatz","Alter"]].corr(method="spearman",min_periods=10)
    #and save the coefficient for each party in a dictionary
    corrcoeff=result["Listenplatz"].iloc[-1]
    coeff_eu[party]=corrcoeff
coeff_eu
# Out:
# ['Union' 'BIG' 'SPD' 'PdH' 'FDP' 'DAVA' 'PDV' 'MERA25' 'AfD' 'Grüne'
#  'V-Partei³' 'SGP' 'Die PARTEI' 'Die Linke' 'KLIMALISTE'
#  'MENSCHLICHE WELT' 'MLPD' 'BSW' 'ÖDP' 'DKP' 'PIRATEN' 'Volt'
#  'BÜNDNIS DEUTSCHLAND' 'ABG' 'nan' 'LETZTE GENERATION' 'PdF' 'Bündnis C'
#  'FAMILIE' 'Tierschutzpartei' 'FREIE WÄHLER' 'HEIMAT' 'dieBasis'
#  'TIERSCHUTZ hier!']
# {'Union': -0.2647576692109586,
#  'BIG': -0.4036609567214213,
#  'SPD': -0.15325237185331658,
#  'PdH': 0.07947924900773393,
#  'FDP': 0.08136007682341583,
#  'DAVA': 0.04126551359105471,
#  'PDV': -0.14344950397247302,
#  'MERA25': 0.2156216926334733,
#  'AfD': -0.02425177988627412,
#  'Grüne': -0.1632309178390667,
#  'V-Partei³': -0.17032491200132613,
#  'SGP': -0.4555820475782052,
#  'Die PARTEI': 0.09415416477582231,
#  'Die Linke': 0.060971058811826497,
#  'KLIMALISTE': 0.4532455988009745,
#  'MENSCHLICHE WELT': nan,
#  'MLPD': -0.07028432219742134,
#  'BSW': -0.21068478499955973,
#  'ÖDP': 0.03118317480157763,
#  'DKP': 0.07988213684001644,
#  'PIRATEN': 0.5906786495739423,
#  'Volt': -0.08487882087435483,
#  'BÜNDNIS DEUTSCHLAND': 0.5330309956665001,
#  'ABG': nan,
#  'nan': -0.011428599030582857,
#  'LETZTE GENERATION': 0.6935212036549627,
#  'PdF': 0.06097674333191042,
#  'Bündnis C': 0.12707376262526088,
#  'FAMILIE': -0.07272727272727272,
#  'Tierschutzpartei': nan,
#  'FREIE WÄHLER': 0.09871645518356244,
#  'HEIMAT': 0.34495098671459007,
#  'dieBasis': nan,
#  'TIERSCHUTZ hier!': nan}

# %%
#same on the eu level
GruppePlatzAlter_Bund=data_bund[["Gruppenname","Listenplatz_gemeinsam","Alter"]]
listofparties=GruppePlatzAlter_Bund.Gruppenname.unique()
coeff_bund={}
for party in listofparties:
    partydf=GruppePlatzAlter_Bund[GruppePlatzAlter_Bund["Gruppenname"]==party]
    result=partydf[["Listenplatz_gemeinsam","Alter"]].corr(method="spearman",min_periods=10)
    corrcoeff=result["Listenplatz_gemeinsam"].iloc[-1]
    coeff_bund[party]=corrcoeff

# %%
coeff_bund
# Out:
# {'Union': -0.19762800430375888,
#  'SPD': -0.07171627753249857,
#  'FDP': -0.09623823520618426,
#  'Grüne': -0.056843865760654366,
#  'AfD': 0.00441200434203883,
#  'Die Linke': -0.39110616286787003,
#  'FREIE WÄHLER': 0.026681040285578835,
#  'dieBasis': -0.047080921059994396,
#  'du.': 0.05373393269350766,
#  'LKR': -0.17900785747938341,
#  'SSW': -0.08292905364553438,
#  'V-Partei³': -0.11578471586534259,
#  'Die PARTEI': -0.005598485544065585,
#  'MLPD': 0.3501508616713351,
#  'DKP': 0.08647781651080104,
#  'Volt': -0.0284223374098359,
#  'EB: Schlüter': nan,
#  'EB: Kerkhoff': nan,
#  'PIRATEN': 0.022729947545964416,
#  'EB: Löwe': nan,
#  'Tierschutzpartei': -0.05446603364639135,
#  'EB: Krüger': nan,
#  'UNABHÄNGIGE': 0.38285691853056275,
#  'ÖDP': 0.1527812888525821,
#  'NPD': 0.07257444343996998,
#  'EB: Janoske-Kizildag': nan,
#  'ÖLDP': nan,
#  'EB: Lenz': nan,
#  'EB: Balzer': nan,
#  'EB: Gums': nan,
#  'EB: Großkopf': nan,
#  'EB: Weich': nan,
#  'Die Humanisten': -0.10361323263219997,
#  'EB: Kober': nan,
#  'EB: Neumann': nan,
#  'EB: Kunick': nan,
#  'EB: Göller': nan,
#  'EB: Wieczorek': nan,
#  'EB: Herzig': nan,
#  'EB: Jagau': nan,
#  'EB: Deutsch': nan,
#  'EB: Rosenbaum': nan,
#  'EB: Wolter': nan,
#  'EB: Gust': nan,
#  'EB: Wiesenthal': nan,
#  'EB: Hönig': nan,
#  'EB: Schäuble-Leopold': nan,
#  'EB: Glamann': nan,
#  'EB: Eckelmann': nan,
#  'EB: Buro': nan,
#  'EB: Schlippenbach': nan,
#  'EB: Lorenz': nan,
#  'EB: Schütz': nan,
#  'EB: Conrad': nan,
#  'EB: Hinners': nan,
#  'EB: Roloff': nan,
#  'EB: Müller': nan,
#  'EB: Grütte': nan,
#  'EB: Charnow': nan,
#  'EB: Gabler': nan,
#  'EB: Hitzer': nan,
#  'EB: Commentz': nan,
#  'FAMILIE': nan,
#  'EB: Kaun': nan,
#  'EB: Marquardt': nan,
#  'EB: Janda': nan,
#  'EB: Bibiella': nan,
#  'EB: Janowski': nan,
#  'Tierschutzallianz': 0.1572824832487991,
#  'EB: Barth': nan,
#  'Gartenpartei': nan,
#  '#TeamFranka': nan,
#  'EB: Rohne': nan,
#  'EB: Wassenaar': nan,
#  'EB: Zimmermann': nan,
#  'EB: Fielsch': nan,
#  'EB: Zebian': nan,
#  'Gesundheitsforschung': -0.03066923783996197,
#  'Die Grauen': -0.3853251549446803,
#  'BÜNDNIS21': -0.06807096149403145,
#  'EB: Bunte': nan,
#  'EB: Voß': nan,
#  'MENSCHLICHE WELT': nan,
#  'Team Todenhöfer': -0.0009873477732162644,
#  'sonstige': nan,
#  'EB: Pape': nan,
#  'EB: Lindlmair': nan,
#  'EB: Moser': nan,
#  'B*': nan,
#  'EB: Wendt': nan,
#  'EB: Snelinski': nan,
#  'EB: Böving': nan,
#  'EB: Teßmann': nan,
#  'LIEBE': nan,
#  'EB: Przybylski': nan,
#  'EB: Podjaski': nan,
#  'EB: Goldbeck': nan,
#  'Volksabstimmung': nan,
#  'EB: Blum': nan,
#  'EB: Kramer': nan,
#  'EB: Klimczak': nan,
#  'EB: Herrmann': nan,
#  'Bündnis C': 0.163376714006461,
#  'EB: Richter': nan,
#  'EB: Baumanns': nan,
#  'EB: Herbert': nan,
#  'EB: Opfer': nan,
#  'EB: Ergin': nan,
#  'EB: Saygili': nan,
#  'EB: Bilo': nan,
#  'EB: Wetklo': nan,
#  'EB: Georgiou': nan,
#  'EB: Kaldewei': nan,
#  'EB: Dumberger': nan,
#  'EB: Geselbracht': nan,
#  'EB: Brehm': nan,
#  'EB: Martinschledde': nan,
#  'EB: Zajonc': nan,
#  'EB: Sonnabend': nan,
#  'EB: Tropp': nan,
#  'EB: Hofmann': nan,
#  'EB: Trojanowski': nan,
#  'EB: Peiler': nan,
#  'EB: Meister': nan,
#  'EB: Asmus': nan,
#  'EB: Oschkinat': nan,
#  'EB: Härtlein': nan,
#  'EB: Hummitzsch': nan,
#  'EB: Kohl': nan,
#  'EB: Bayer': nan,
#  'EB: Schöllner': nan,
#  'EB: Zimmet': nan,
#  'EB: Blickle': nan,
#  'EB: Brähmig': nan,
#  'EB: Queck': nan,
#  'EB: Fuchs': nan,
#  'EB: Häupl': nan,
#  'BüSo': nan,
#  'EB: Hannig': nan,
#  '#KLIMAfirst': nan,
#  'EB: Weidemann': nan,
#  'EB: Röhder': nan,
#  'EB: Reichel': nan,
#  'EB: Krajak': nan,
#  'III. Weg': nan,
#  'EB: Gerisch': nan,
#  'EB: Meyer': nan,
#  'EB: Mascher': nan,
#  'EB: El-Fayoumy': nan,
#  'EB: Schmidt': nan,
#  'EB: Klement': nan,
#  'EB: Marinello': nan,
#  'EB: Carstensen': nan,
#  'TNT': nan,
#  'EB: Hemm': nan,
#  'EB: Schlossbauer': nan,
#  'EB: Rehbein': nan,
#  'EB: Stachowiak': nan,
#  'EB: Stein': nan,
#  'EB: Grammbitter': nan,
#  'Graue Panther': nan,
#  'THP': nan,
#  'EB: Nebeler': nan,
#  'EB: Berger': nan,
#  'EB: Bieling': nan,
#  'EB: Erdmann': nan,
#  'EB: Mandel': nan,
#  'EB: Sayn': nan,
#  'EB: Krämer': nan,
#  'EB: Vollmer': nan,
#  'EB: Bartholomé': nan,
#  'EB: Moritz': nan,
#  'EB: Engels': nan,
#  'EB: Seiffert': nan,
#  'EB: Heil': nan,
#  'EB: Pohl': nan,
#  'EB: Hackel': nan,
#  'EB: Schöne': nan,
#  'EB: Bechtel': nan,
#  'EB: Wittner': nan,
#  'EB: Schwang': nan,
#  'EB: Hoppe': nan,
#  'EB: Lauer': nan,
#  'EB: Mobasheri': nan,
#  'EB: Koccu': nan,
#  'EB: Vogler': nan,
#  'BP': 0.018417008720775847,
#  'EB: Hilz': nan,
#  'EB: Klopstock': nan,
#  'EB: Dönmez': nan,
#  'EB: Sommerfeldt': nan,
#  'EB: Englisch': nan,
#  'EB: Ryssel': nan,
#  'EB: Manz': nan,
#  'EB: Pettenkofer': nan,
#  'EB: Knott': nan,
#  'EB: Gradl': nan,
#  'EB: Friedl': nan,
#  'EB: Bauer': nan,
#  'EB: Dippel': nan,
#  'EB: Roensch': nan,
#  'EB: Löhnert': nan,
#  'EB: Kunstmann': nan,
#  'EB: Kalupner': nan,
#  'EB: Henig': nan,
#  'EB: Eppel': nan,
#  'EB: Schlot': nan,
#  'EB: Lembach': nan,
#  'EB: Kaiser': nan,
#  'EB: Schürer': nan,
#  'EB: Kolb': nan,
#  'EB: Sirin': nan,
#  'EB: Baydar': nan,
#  'EB: Langhans': nan,
#  'EB: Dorn': nan,
#  'DiB': -0.11670046463456957,
#  'BÜRGERBEWEGUNG': -0.324226704256906,
#  'EB: Ressdorf': nan,
#  'EB: Demir': nan,
#  'EB: Miller': nan,
#  'EB: Tolzin': nan,
#  'EB: Gibanica': nan,
#  'EB: Novotny': nan,
#  'EB: Hartmann': nan,
#  'KlimalisteBW': nan,
#  'EB: Mund': nan,
#  'EB: Rapps': nan,
#  'EB: Schmitt': nan,
#  'EB: Fritsch': nan,
#  'EB: Herrlinger': nan,
#  'EB: Harting': nan,
#  'EB: Ringger': nan,
#  'EB: Poss': nan,
#  'SGP': nan,
#  'PdF': nan,
#  'LfK': nan}

# %%
#we create dataframes that we merge
coeff_bund=pd.DataFrame(coeff_bund,index=["corr"]).T.reset_index()
coeff_eu=pd.DataFrame(coeff_eu,index=["corr"]).T.reset_index()
coefficients_age=pd.merge(coeff_bund,coeff_eu,on="index",suffixes=["_bund","_eu"]).dropna()
coefficients_age
# Out:
#            index  corr_bund   corr_eu
# 0          Union  -0.197628 -0.264758
# 1            SPD  -0.071716 -0.153252
# 2            FDP  -0.096238  0.081360
# 3          Grüne  -0.056844 -0.163231
# 4            AfD   0.004412 -0.024252
# 5      Die Linke  -0.391106  0.060971
# 6   FREIE WÄHLER   0.026681  0.098716
# 8      V-Partei³  -0.115785 -0.170325
# 9     Die PARTEI  -0.005598  0.094154
# 10          MLPD   0.350151 -0.070284
# 11           DKP   0.086478  0.079882
# 12          Volt  -0.028422 -0.084879
# 13       PIRATEN   0.022730  0.590679
# 15           ÖDP   0.152781  0.031183
# 18     Bündnis C   0.163377  0.127074

# %%
df_parties_coefficients=coefficients_age[coefficients_age["index"].str.contains("|".join(filterlist))]
df_parties_coefficients
# Out:
#        index  corr_bund   corr_eu
# 0      Union  -0.197628 -0.264758
# 1        SPD  -0.071716 -0.153252
# 2        FDP  -0.096238  0.081360
# 3      Grüne  -0.056844 -0.163231
# 4        AfD   0.004412 -0.024252
# 5  Die Linke  -0.391106  0.060971

# %%
df_parties_coefficients.to_csv("coefficients.csv",index=False)

# %% [markdown]
# *We see that for CDU, SPD and greens the correlation is stronger, for AfD and FDP it is debatable, and for AfD,CSU it is actually the other way*

# %%
data_bund.columns
# Out:
# Index(['Wahlart', 'Wahltag', 'Titel', 'Namenszusatz', 'Nachname', 'Vornamen',
#        'Künstlername', 'Geschlecht', 'Geburtsjahr', 'PLZ', 'Wohnort', 'Staat',
#        'WohnortLandAbk', 'Geburtsort', 'Staatsangehörigkeit', 'Beruf',
#        'Berufsschluessel', 'Kennzeichen', 'Gebietsart', 'Gebietsnummer',
#        'Gebietsname', 'GebietLandAbk', 'Gruppenname', 'GruppennameLang',
#        'Listenplatz', 'VerknKennzeichen', 'VerknGebietsart',
#        'VerknGebietsnummer', 'VerknGebietsname', 'VerknGebietLandAbk',
#        'VerknGruppenname', 'VerknListenplatz', 'VorpGewaehlt',
#        'Berufsbezeichnung', 'Alter', 'Listenplatz_gemeinsam'],
#       dtype='object')

# %%
data_bund_gender=data_bund[['Gruppenname',"Geschlecht","Alter"]].groupby(['Gruppenname',"Geschlecht"]).count().reset_index()
data_europa_gender=data_europa[['Gruppenname',"Geschlecht","Alter"]].groupby(['Gruppenname',"Geschlecht"]).count().reset_index()
data_europa_gender
# Out:
#    Gruppenname Geschlecht  Alter
# 0          ABG          m      3
# 1          ABG          w      6
# 2          AfD          m     31
# 3          AfD          w      4
# 4          BIG          m     18
# ..         ...        ...    ...
# 61    dieBasis          w      2
# 62         nan          m     16
# 63         nan          w      3
# 64         ÖDP          m     59
# 65         ÖDP          w     28
#
# [66 rows x 3 columns]

# %%
data_bund_gender["gender_share"]=data_bund_gender["Alter"]*100/data_bund_gender.groupby("Gruppenname")["Alter"].transform('sum')
data_europa_gender["gender_share"]=data_europa_gender["Alter"]*100/data_europa_gender.groupby("Gruppenname")["Alter"].transform('sum')
data_bund_europa_gender=pd.merge(data_bund_gender,data_europa_gender,on=["Gruppenname","Geschlecht"],suffixes=["_bund","_europa"])
data_bund_europa_gender
# Out:
#          Gruppenname Geschlecht  Alter_bund  gender_share_bund  Alter_europa  \
# 0                AfD          m         404          86.509636            31
# 1                AfD          w          63          13.490364             4
# 2          Bündnis C          m          47          73.437500            10
# 3          Bündnis C          w          17          26.562500             3
# 4                DKP          m          91          71.653543            30
# 5                DKP          w          36          28.346457            13
# 6          Die Linke          m         286          58.969072            10
# 7          Die Linke          w         198          40.824742            10
# 8         Die PARTEI          m         492          70.893372           165
# 9         Die PARTEI          w         202          29.106628            46
# 10           FAMILIE          m           1         100.000000             7
# 11               FDP          m         491          76.360809           150
# 12               FDP          w         152          23.639191            44
# 13      FREIE WÄHLER          m         417          76.654412            18
# 14      FREIE WÄHLER          w         127          23.345588             9
# 15             Grüne          m         333          47.639485            18
# 16             Grüne          w         366          52.360515            22
# 17  MENSCHLICHE WELT          m           2          40.000000             6
# 18  MENSCHLICHE WELT          w           3          60.000000             3
# 19              MLPD          m         182          63.194444            10
# 20              MLPD          w         106          36.805556             8
# 21           PIRATEN          m         162          85.263158            13
# 22           PIRATEN          w          28          14.736842             5
# 23               PdF          m           6          66.666667            10
# 24               SGP          m           3          75.000000             8
# 25               SGP          w           1          25.000000             3
# 26               SPD          m         421          57.671233            93
# 27               SPD          w         309          42.328767            96
# 28  Tierschutzpartei          m          83          44.385027             3
# 29  Tierschutzpartei          w         104          55.614973             5
# 30             Union          m         524          62.679426           135
# 31             Union          w         312          37.320574           124
# 32         V-Partei³          m          31          38.271605             8
# 33         V-Partei³          w          50          61.728395            11
# 34              Volt          m         135          56.485356            13
# 35              Volt          w         104          43.514644            14
# 36          dieBasis          m         395          70.535714             2
# 37          dieBasis          w         165          29.464286             2
# 38               ÖDP          m         240          71.005917            59
# 39               ÖDP          w          98          28.994083            28
#
#     gender_share_europa
# 0             88.571429
# 1             11.428571
# 2             76.923077
# 3             23.076923
# 4             69.767442
# 5             30.232558
# 6             50.000000
# 7             50.000000
# 8             78.199052
# 9             21.800948
# 10            63.636364
# 11            77.319588
# 12            22.680412
# 13            66.666667
# 14            33.333333
# 15            45.000000
# 16            55.000000
# 17            66.666667
# 18            33.333333
# 19            55.555556
# 20            44.444444
# 21            72.222222
# 22            27.777778
# 23           100.000000
# 24            72.727273
# 25            27.272727
# 26            49.206349
# 27            50.793651
# 28            37.500000
# 29            62.500000
# 30            52.123552
# 31            47.876448
# 32            42.105263
# 33            57.894737
# 34            48.148148
# 35            51.851852
# 36            50.000000
# 37            50.000000
# 38            67.816092
# 39            32.183908

# %%
data_bund_europa_gender_filtered=data_bund_europa_gender[data_bund_europa_gender["Gruppenname"].astype(str).str.contains('|'.join(filterlist))]

# %%
data_bund_europa_gender_filtered[data_bund_europa_gender_filtered["Geschlecht"]=="w"].to_csv("gender_share_comp.csv",index=False)

# %%
data_bund.Kennzeichen
# Out:
# 0       Kreiswahlvorschlag
# 1       Kreiswahlvorschlag
# 2       Kreiswahlvorschlag
# 3       Kreiswahlvorschlag
# 4       Kreiswahlvorschlag
#                ...
# 8282           Landesliste
# 8283           Landesliste
# 8284           Landesliste
# 8285           Landesliste
# 8286           Landesliste
# Name: Kennzeichen, Length: 8287, dtype: object
